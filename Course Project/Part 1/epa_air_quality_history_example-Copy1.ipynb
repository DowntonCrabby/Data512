# %%
import json, time
import requests
import EPA_Requests as EPA

# %%
API_REQUEST_URL = 'https://aqs.epa.gov/data/api'
API_THROTTLE_WAIT = 0.1  # Throttle wait time between requests
EMAIL = 'kateroll@gmail.com'
USERNAME = 'kateroll@gmail.com'
APIKEY = 'silverfox66'

AQI_PARAMS_GASEOUS = ["O3", "NO2", "SO2"]
AQI_PARAMS_PARTICULATES = ["PM2.5", "PM10"]
EXTRACTION_FIELDS = ['sample_duration', 'observation_count', 'arithmetic_mean', 'aqi']

# API Endpoints
API_ACTION_LIST_CLASSES = '/list/classes?email={email}&key={key}'
API_ACTION_LIST_PARAMS = '/list/parametersByClass?email={email}&key={key}&pc={pclass}'
API_ACTION_LIST_SITES = '/list/sitesByCounty?email={email}&key={key}&state={state}&county={county}'
API_ACTION_MONITORS_COUNTY = '/monitors/byCounty?email={email}&key={key}&param={param}&bdate={begin_date}&edate={end_date}'
API_ACTION_MONITORS_BOX = '/monitors/byBox?email={email}&key={key}&param={param}&minlat={minlat}&maxlat={maxlat}&minlon={minlon}&maxlon={maxlon}&bdate={begin_date}&edate={end_date}'
API_ACTION_DAILY_SUMMARY_COUNTY = '/dailyData/byCounty?email={email}&key={key}&param={param}&state={state}&county={county}&bdate={begin_date}&edate={end_date}'

TALLAHASSEE_AQS_REQUEST_TEMPLATE = {
    "email":      EMAIL,     
    "key":        APIKEY,      
    "state":      "12",     # the two digit state FIPS # as a string
    "county":     "073",     # the three digit county FIPS # as a string
    "begin_date": "",     # the start of a time window in YYYYMMDD format
    "end_date":   "",     # the end of a time window in YYYYMMDD format, begin_date and end_date must be in the same year
    "minlat":    29.71366231884058,
    "maxlat":    31.162937681159423,
    "minlon":    -85.19645091575092,
    "maxlon":    -83.36494908424908,
    "param":     "",     # a list of comma separated 5 digit codes, max 5 codes requested
    "pclass":    ""      # parameter class is only used by the List calls
}

# %%
TEST_CITY_INFO = {'city_name'   : 'Seaside',
                  'county_name' : 'Clatsop',
                  'state_name'  : 'Oregon',
                  'state'       : '41',
                  'county'      : '007',
                  'fips'        : '41007',
                  'latlon' : [45.9932, -123.9226] }

# %%
def request_list_info(email_address = None, key = None,
                      endpoint_url = API_REQUEST_URL, 
                      endpoint_action = API_ACTION_LIST_CLASSES, 
                      request_template = AQS_REQUEST_TEMPLATE,
                      headers = None):
    
    #  Make sure we have email and key - at least
    #  This prioritizes the info from the call parameters - not what's already in the template
    if email_address:
        request_template['email'] = email_address
    if key:
        request_template['key'] = key
    
    # For the basic request we need an email address and a key
    if not request_template['email']:
        raise Exception("Must supply an email address to call 'request_list_info()'")
    if not request_template['key']: 
        raise Exception("Must supply a key to call 'request_list_info()'")

    # compose the request
    request_url = endpoint_url+endpoint_action.format(**request_template)
        
    # make the request
    try:
        # Wait first, to make sure we don't exceed a rate limit in the situation where an exception occurs
        # during the request processing - throttling is always a good practice with a free data source
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(request_url, headers=headers)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

def request_monitors(email_address = None, key = None, param=None,
                          begin_date = None, end_date = None, fips = None,
                          endpoint_url = API_REQUEST_URL, 
                          endpoint_action = API_ACTION_MONITORS_COUNTY, 
                          request_template = AQS_REQUEST_TEMPLATE,
                          headers = None):
    
    #  This prioritizes the info from the call parameters - not what's already in the template
    if email_address:
        request_template['email'] = email_address
    if key:
        request_template['key'] = key
    if param:
        request_template['param'] = param
    if begin_date:
        request_template['begin_date'] = begin_date
    if end_date:
        request_template['end_date'] = end_date
    if fips and len(fips)==5:
        request_template['state'] = fips[:2]
        request_template['county'] = fips[2:]            

    # Make sure there are values that allow us to make a call - these are always required
    if not request_template['email']:
        raise Exception("Must supply an email address to call 'request_monitors()'")
    if not request_template['key']: 
        raise Exception("Must supply a key to call 'request_monitors()'")
    if not request_template['param']: 
        raise Exception("Must supply param values to call 'request_monitors()'")
    if not request_template['begin_date']: 
        raise Exception("Must supply a begin_date to call 'request_monitors()'")
    if not request_template['end_date']: 
        raise Exception("Must supply an end_date to call 'request_monitors()'")
    # Note we're not validating FIPS fields because not all of the monitors actions require the FIPS numbers
    
    # compose the request
    request_url = endpoint_url+endpoint_action.format(**request_template)
    
    # make the request
    try:
        # Wait first, to make sure we don't exceed a rate limit in the situation where an exception occurs
        # during the request processing - throttling is always a good practice with a free data source
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(request_url, headers=headers)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

def request_daily_summary(email_address = None, key = None, param=None,
                          begin_date = None, end_date = None, fips = None,
                          endpoint_url = API_REQUEST_URL, 
                          endpoint_action = API_ACTION_DAILY_SUMMARY_COUNTY, 
                          request_template = AQS_REQUEST_TEMPLATE,
                          headers = None):
    
    #  This prioritizes the info from the call parameters - not what's already in the template
    if email_address:
        request_template['email'] = email_address
    if key:
        request_template['key'] = key
    if param:
        request_template['param'] = param
    if begin_date:
        request_template['begin_date'] = begin_date
    if end_date:
        request_template['end_date'] = end_date
    if fips and len(fips)==5:
        request_template['state'] = fips[:2]
        request_template['county'] = fips[2:]            

    # Make sure there are values that allow us to make a call - these are always required
    if not request_template['email']:
        raise Exception("Must supply an email address to call 'request_daily_summary()'")
    if not request_template['key']: 
        raise Exception("Must supply a key to call 'request_daily_summary()'")
    if not request_template['param']: 
        raise Exception("Must supply param values to call 'request_daily_summary()'")
    if not request_template['begin_date']: 
        raise Exception("Must supply a begin_date to call 'request_daily_summary()'")
    if not request_template['end_date']: 
        raise Exception("Must supply an end_date to call 'request_daily_summary()'")
    # Note we're not validating FIPS fields because not all of the daily summary actions require the FIPS numbers
        
    # compose the request
    request_url = endpoint_url+endpoint_action.format(**request_template)
        
    # make the request
    try:
        # Wait first, to make sure we don't exceed a rate limit in the situation where an exception occurs
        # during the request processing - throttling is always a good practice with a free data source
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(request_url, headers=headers)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

def extract_summary_from_response(r=None, fields=EXTRACTION_FIELDS):
    ## the result will be structured around monitoring site, parameter, and then date
    result = dict()
    data = r["Data"]
    for record in data:
        # make sure the record is set up
        site = record['site_number']
        param = record['parameter_code']
        #date = record['date_local']    # this version keeps the respnse value YYYY-
        date = record['date_local'].replace('-','') # this puts it in YYYYMMDD format
        if site not in result:
            result[site] = dict()
            result[site]['local_site_name'] = record['local_site_name']
            result[site]['site_address'] = record['site_address']
            result[site]['state'] = record['state']
            result[site]['county'] = record['county']
            result[site]['city'] = record['city']
            result[site]['pollutant_type'] = dict()
        if param not in result[site]['pollutant_type']:
            result[site]['pollutant_type'][param] = dict()
            result[site]['pollutant_type'][param]['parameter_name'] = record['parameter']
            result[site]['pollutant_type'][param]['units_of_measure'] = record['units_of_measure']
            result[site]['pollutant_type'][param]['method'] = record['method']
            result[site]['pollutant_type'][param]['data'] = dict()
        if date not in result[site]['pollutant_type'][param]['data']:
            result[site]['pollutant_type'][param]['data'][date] = list()
        
        # now extract the specified fields
        extract = dict()
        for k in fields:
            if str(k) in record:
                extract[str(k)] = record[k]
            else:
                # this makes sure we always have the requested fields, even if
                # we have a missing value for a given day/month
                extract[str(k)] = None
        
        # add this extraction to the list for the day
        result[site]['pollutant_type'][param]['data'][date].append(extract)
    
    return result

def bounding_latlon(place=None,scale=1.0):
    minlat = place['latlon'][0] - float(scale) * LAT_25MILES
    maxlat = place['latlon'][0] + float(scale) * LAT_25MILES
    minlon = place['latlon'][1] - float(scale) * LON_25MILES
    maxlon = place['latlon'][1] + float(scale) * LON_25MILES
    return [minlat,maxlat,minlon,maxlon]

# %%
response = EPA.request_list_info()
response
# Out:
#                        code                                  value_represented
# 0               AIRNOW MAPS  The parameters represented on AirNow maps (881...
# 1                       ALL                    Select all Parameters Available
# 2            AQI POLLUTANTS                Pollutants that have an AQI Defined
# 3                 CORE_HAPS                         Urban Air Toxic Pollutants
# 4                  CRITERIA                                Criteria Pollutants
# 5                  CSN DART  List of CSN speciation parameters to populate ...
# 6                  FORECAST     Parameters routinely extracted by AirNow (STI)
# 7                      HAPS                           Hazardous Air Pollutants
# 8            IMPROVE CARBON                          IMPROVE Carbon Parameters
# 9        IMPROVE_SPECIATION  PM2.5 Speciated Parameters Measured at IMPROVE...
# 10                      MET                          Meteorological Parameters
# 11          NATTS CORE HAPS  The core list of toxics of interest to the NAT...
# 12           NATTS REQUIRED  Required compounds to be collected in the Nati...
# 13                     PAMS         Photochemical Assessment Monitoring System
# 14                 PAMS_VOC  Volatile Organic Compound subset of the PAMS P...
# 15                PM COARSE                  PM between 2.5 and 10 micrometers
# 16          PM10 SPECIATION                          PM10 Speciated Parameters
# 17        PM2.5 CONT NONREF             PM2.5 Continuous, Nonreference Methods
# 18            PM2.5 MASS/QA                       PM2.5 Mass and QA Parameters
# 19        SCHOOL AIR TOXICS               School Air Toxics Program Parameters
# 20               SPECIATION                         PM2.5 Speciated Parameters
# 21        SPECIATION CARBON                 PM2.5 Speciation Carbon Parameters
# 22  SPECIATION CATION/ANION           PM2.5 Speciation Cation/Anion Parameters
# 23        SPECIATION METALS                  PM2.5 Speciation Metal Parameters
# 24           UATMP CARBONYL      Urban Air Toxics Monitoring Program Carbonyls
# 25                UATMP VOC           Urban Air Toxics Monitoring Program VOCs
# 26                      VOC                         Volatile organic compounds

# %%
response = EPA.request_AQI_Pollutants()
response
# Out:
#     code                       value_represented
# 0  42101                         Carbon monoxide
# 1  42401                          Sulfur dioxide
# 2  42602                  Nitrogen dioxide (NO2)
# 3  44201                                   Ozone
# 4  81102                   PM10 Total 0-10um STP
# 5  88101                PM2.5 - Local Conditions
# 6  88502  Acceptable PM2.5 AQI & Speciation Mass

# %%
response = EPA.get_monitoring_stations_by_county()
response
# Out:
#     code              value_represented
# 0   0001                           None
# 1   0002                           None
# 2   0003                           None
# 3   0004                           None
# 4   0005                           None
# 5   0006                           None
# 6   0007                           None
# 7   0008                           None
# 8   0009                           None
# 9   0010                           None
# 10  0011                           None
# 11  0012  Tallahassee Community College
# 12  0013      MICCOSUKEE GREENWAYS PARK
# 13  1001                           None
# 14  1002                           None
# 15  1003                           None
# 16  1004                           None
# 17  1005   APALACHICOLA NATIONAL FOREST

# %% [markdown]
# ## Example 3. Making a daily summary request
#
# The function below is designed to encapsulate requests to the EPA AQS API. When calling the function one should create/copy a parameter template, then initialize that template with values that won't change with each call. Then on each call simply pass in the parameters that need to change, like date ranges.
#
# Another function below provides an example of extracting values and restructuring the response to make it a little more usable.

# %%
request_data = AQS_REQUEST_TEMPLATE.copy()
request_data['email'] = USERNAME
request_data['key'] = APIKEY
request_data['param'] = AQI_PARAMS_GASEOUS
request_data['state'] = TEST_CITY_INFO['fips'][:2]
request_data['county'] = TEST_CITY_INFO['fips'][2:]

# request daily summary data for the month of July in 2021
gaseous_aqi = request_daily_summary(request_template=request_data, begin_date="20210701", end_date="20210731")
print("Response for the gaseous pollutants ...")
#
if gaseous_aqi["Header"][0]['status'] == "Success":
    print(json.dumps(gaseous_aqi['Data'],indent=4))
elif gaseous_aqi["Header"][0]['status'].startswith("No data "):
    print("Looks like the response generated no data. You might take a closer look at your request and the response data.")
else:
    print(json.dumps(gaseous_aqi,indent=4))
# Out:
# Response for the gaseous pollutants ...
# {
#     "Header": [
#         {
#             "status": "Failed",
#             "request_time": "2024-10-30T21:57:03.182-04:00",
#             "url": "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=41&county=007&bdate=20210701&edate=20210731",
#             "error": [
#                 "parameter code: ['O3', requires numeric value.",
#                 "parameter code:  'NO2', requires numeric value.",
#                 "parameter code:  'SO2'], requires numeric value."
#             ]
#         }
#     ]
# }

# %%
request_data = AQS_REQUEST_TEMPLATE.copy()
request_data['param'] = AQI_PARAMS_GASEOUS
# request daily summary data for the month of July in 2021
gaseous_aqi = request_daily_summary(request_template=request_data, begin_date="20210701", end_date="20210731")

# %%
gaseous_aqi
# Out:
# {'Header': [{'status': 'Failed',
#    'request_time': '2024-10-30T21:47:13.746-04:00',
#    'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=20210701&edate=20210731",
#    'error': ["parameter code: ['O3', requires numeric value.",
#     "parameter code:  'NO2', requires numeric value.",
#     "parameter code:  'SO2'], requires numeric value."]}]}

# %%
# request daily summary data for the month of July in 2021
gaseous_aqi = request_daily_summary(request_template=request_data, begin_date="20210901", end_date="20210931")
print("Response for the gaseous pollutants ...")
#
if gaseous_aqi["Header"][0]['status'] == "Success":
    print(json.dumps(gaseous_aqi['Data'],indent=4))
elif gaseous_aqi["Header"][0]['status'].startswith("No data "):
    print("Looks like the response generated no data. You might take a closer look at your request and the response data.")
else:
    print(json.dumps(gaseous_aqi,indent=4))
# Out:
# Response for the gaseous pollutants ...
# {
#     "Header": [
#         {
#             "status": "Failed",
#             "request_time": "2024-10-30T21:48:04.205-04:00",
#             "url": "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=20210901&edate=20210931",
#             "error": [
#                 "parameter code: ['O3', requires numeric value.",
#                 "parameter code:  'NO2', requires numeric value.",
#                 "parameter code:  'SO2'], requires numeric value.",
#                 "edate: 20210931, requires the following format: yyyymmdd."
#             ]
#         }
#     ]
# }

# %%
request_data = AQS_REQUEST_TEMPLATE.copy()
request_data['param'] = AQI_PARAMS_GASEOUS

# %%
request_data = AQS_REQUEST_TEMPLATE.copy()
request_data['param'] = AQI_PARAMS_GASEOUS

# Initialize a list to hold all results
all_gaseous_aqi_data = []

# Define the start and end years for data retrieval
start_year = 1961
end_year = 2021

# Loop through each year and retrieve data for the date range May 1 - October 31
for year in range(start_year, end_year + 1):
    # Set the date range for May 1 - October 31
    may_oct_start = f"{year}0501"
    may_oct_end = f"{year}1031"

    # Request data for May 1 - October 31
    year_data = request_daily_summary(request_template=request_data,
                                      begin_date=may_oct_start,
                                      end_date=may_oct_end)

    # Check if data was returned and add it to the list
    if year_data is not None:
        all_gaseous_aqi_data.append({year: year_data})

    # Print status for each year's data retrieval
    print(f"Data retrieved for {year}")
# Out:
# Data retrieved for 1961
# Data retrieved for 1962
# Data retrieved for 1963
# Data retrieved for 1964
# Data retrieved for 1965
# Data retrieved for 1966
# Data retrieved for 1967
# Data retrieved for 1968
# Data retrieved for 1969
# Data retrieved for 1970
# Data retrieved for 1971
# Data retrieved for 1972
# Data retrieved for 1973
# Data retrieved for 1974
# Data retrieved for 1975
# Data retrieved for 1976
# Data retrieved for 1977
# Data retrieved for 1978
# Data retrieved for 1979
# Data retrieved for 1980
# Data retrieved for 1981
# Data retrieved for 1982
# Data retrieved for 1983
# Data retrieved for 1984
# Data retrieved for 1985
# Data retrieved for 1986
# Data retrieved for 1987
# Data retrieved for 1988
# Data retrieved for 1989
# Data retrieved for 1990
# Data retrieved for 1991
# Data retrieved for 1992
# Data retrieved for 1993
# Data retrieved for 1994
# Data retrieved for 1995
# Data retrieved for 1996
# Data retrieved for 1997
# Data retrieved for 1998
# Data retrieved for 1999
# Data retrieved for 2000
# Data retrieved for 2001
# Data retrieved for 2002
# Data retrieved for 2003
# Data retrieved for 2004
# Data retrieved for 2005
# Data retrieved for 2006
# Data retrieved for 2007
# Data retrieved for 2008
# Data retrieved for 2009
# Data retrieved for 2010
# Data retrieved for 2011
# Data retrieved for 2012
# Data retrieved for 2013
# Data retrieved for 2014
# Data retrieved for 2015
# Data retrieved for 2016
# Data retrieved for 2017
# Data retrieved for 2018
# Data retrieved for 2019
# Data retrieved for 2020
# Data retrieved for 2021

# %%
all_gaseous_aqi_data
# Out:
# [{1961: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:08:46.816-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19610501&edate=19611031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1962: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:08:47.281-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19620501&edate=19621031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1963: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:08:47.773-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19630501&edate=19631031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1964: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:08:48.239-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19640501&edate=19641031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1965: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:08:48.726-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19650501&edate=19651031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1966: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:08:49.200-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19660501&edate=19661031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1967: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:08:49.664-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19670501&edate=19671031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1968: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:08:50.145-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19680501&edate=19681031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1969: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:08:50.630-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19690501&edate=19691031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1970: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:08:51.102-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19700501&edate=19701031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1971: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:08:51.552-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19710501&edate=19711031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1972: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:08:52.013-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19720501&edate=19721031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1973: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:08:52.466-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19730501&edate=19731031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1974: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:08:52.913-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19740501&edate=19741031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1975: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:08:53.372-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19750501&edate=19751031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1976: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:08:53.825-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19760501&edate=19761031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1977: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:08:54.275-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19770501&edate=19771031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1978: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:08:54.767-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19780501&edate=19781031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1979: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:08:55.215-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19790501&edate=19791031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1980: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:08:55.674-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19800501&edate=19801031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1981: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:08:56.160-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19810501&edate=19811031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1982: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:08:56.625-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19820501&edate=19821031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1983: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:08:57.074-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19830501&edate=19831031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1984: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:08:57.543-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19840501&edate=19841031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1985: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:08:58.004-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19850501&edate=19851031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1986: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:08:58.452-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19860501&edate=19861031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1987: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:08:58.899-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19870501&edate=19871031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1988: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:08:59.354-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19880501&edate=19881031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1989: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:08:59.837-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19890501&edate=19891031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1990: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:09:00.387-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19900501&edate=19901031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1991: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:09:00.879-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19910501&edate=19911031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1992: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:09:01.357-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19920501&edate=19921031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1993: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:09:01.833-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19930501&edate=19931031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1994: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:09:02.291-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19940501&edate=19941031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1995: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:09:02.750-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19950501&edate=19951031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1996: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:09:03.206-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19960501&edate=19961031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1997: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:09:03.657-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19970501&edate=19971031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1998: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:09:04.108-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19980501&edate=19981031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {1999: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:09:04.565-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=19990501&edate=19991031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {2000: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:09:05.066-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=20000501&edate=20001031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {2001: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:09:05.514-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=20010501&edate=20011031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {2002: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:09:06.013-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=20020501&edate=20021031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {2003: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:09:06.462-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=20030501&edate=20031031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {2004: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:09:06.910-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=20040501&edate=20041031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {2005: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:09:07.479-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=20050501&edate=20051031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {2006: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:09:07.934-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=20060501&edate=20061031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {2007: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:09:08.383-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=20070501&edate=20071031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {2008: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:09:08.841-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=20080501&edate=20081031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {2009: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:09:09.291-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=20090501&edate=20091031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {2010: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:09:09.774-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=20100501&edate=20101031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {2011: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:09:10.242-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=20110501&edate=20111031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {2012: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:09:10.719-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=20120501&edate=20121031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {2013: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:09:11.185-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=20130501&edate=20131031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {2014: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:09:11.642-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=20140501&edate=20141031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {2015: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:09:12.089-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=20150501&edate=20151031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {2016: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:09:12.544-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=20160501&edate=20161031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {2017: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:09:12.992-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=20170501&edate=20171031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {2018: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:09:13.468-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=20180501&edate=20181031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {2019: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:09:13.936-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=20190501&edate=20191031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {2020: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:09:14.389-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=20200501&edate=20201031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}},
#  {2021: {'Header': [{'status': 'Failed',
#      'request_time': '2024-10-30T21:09:14.872-04:00',
#      'url': "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'O3',%20'NO2',%20'SO2'%5D&state=12&county=073&bdate=20210501&edate=20211031",
#      'error': ["parameter code: ['O3', requires numeric value.",
#       "parameter code:  'NO2', requires numeric value.",
#       "parameter code:  'SO2'], requires numeric value."]}]}}]

# %%
request_data['param'] = AQI_PARAMS_PARTICULATES
# request daily summary data for the month of July in 2020
particulate_aqi = request_daily_summary(request_template=request_data, begin_date="20200701", end_date="20200731")
print("Response for the particulate pollutants ...")
#
if particulate_aqi["Header"][0]['status'] == "Success":
    print(json.dumps(particulate_aqi['Data'],indent=4))
elif particulate_aqi["Header"][0]['status'].startswith("No data "):
    print("Looks like the response generated no data. You might take a closer look at your request and the response data.")
else:
    print(json.dumps(particulate_aqi,indent=4))
# Out:
# Response for the particulate pollutants ...
# {
#     "Header": [
#         {
#             "status": "Failed",
#             "request_time": "2024-10-30T20:50:37.445-04:00",
#             "url": "https://aqs.epa.gov/data/api/dailyData/byCounty?email=kateroll@gmail.com&key=silverfox66&param=%5B'PM2.5',%20'PM10'%5D&state=12&county=073&bdate=20200701&edate=20200731",
#             "error": [
#                 "parameter code: ['PM2.5', requires numeric value.",
#                 "parameter code:  'PM10'], requires numeric value."
#             ]
#         }
#     ]
# }

# %%
extract_summary_from_response(gaseous_aqi)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 extract_summary_from_response(gaseous_aqi)
#
# Cell In[8], line 11, in extract_summary_from_response(r, fields)
#       8 def extract_summary_from_response(r=None, fields=EXTRACTION_FIELDS):
#       9     ## the result will be structured around monitoring site, parameter, and then date
#      10     result = dict()
# ---> 11     data = r["Data"]
#      12     for record in data:
#      13         # make sure the record is set up
#      14         site = record['site_number']
#
# KeyError: 'Data'

# %%
request_data = AQS_REQUEST_TEMPLATE.copy()
request_data['email'] = USERNAME
request_data['key'] = APIKEY
request_data['param'] = AQI_PARAMS_GASEOUS
request_data['state'] = CITY_LOCATIONS['loveland']['fips'][:2]
request_data['county'] = CITY_LOCATIONS['loveland']['fips'][2:]

# request daily summary data for the month of July in 2021
gaseous_aqi = request_daily_summary(request_template=request_data, begin_date="20210701", end_date="20210731")
print("Response for the gaseous pollutants ...")
#
if gaseous_aqi["Header"][0]['status'] == "Success":
    print(json.dumps(gaseous_aqi['Data'],indent=4))
elif gaseous_aqi["Header"][0]['status'].startswith("No data "):
    print("Looks like the response generated no data. You might take a closer look at your request and the response data.")
else:
    print(json.dumps(gaseous_aqi,indent=4))

request_data['param'] = AQI_PARAMS_PARTICULATES
# request daily summary data for the month of July in 2021
particulate_aqi = request_daily_summary(request_template=request_data, begin_date="20210701", end_date="20210731")
print("Response for the particulate pollutants ...")
#
if particulate_aqi["Header"][0]['status'] == "Success":
    print(json.dumps(particulate_aqi['Data'],indent=4))
elif particulate_aqi["Header"][0]['status'].startswith("No data "):
    print("Looks like the response generated no data. You might take a closer look at your request and the response data.")
else:
    print(json.dumps(particulate_aqi,indent=4))
# Out:
# Response for the gaseous pollutants ...
# [
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-01",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.037542,
#         "first_max_value": 0.049,
#         "first_max_hour": 14,
#         "aqi": null,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-02",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.036708,
#         "first_max_value": 0.051,
#         "first_max_hour": 16,
#         "aqi": null,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-03",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.046708,
#         "first_max_value": 0.058,
#         "first_max_hour": 12,
#         "aqi": null,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-04",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.0435,
#         "first_max_value": 0.055,
#         "first_max_hour": 15,
#         "aqi": null,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-05",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.043042,
#         "first_max_value": 0.06,
#         "first_max_hour": 8,
#         "aqi": null,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-06",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 23,
#         "observation_percent": 96.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.038391,
#         "first_max_value": 0.054,
#         "first_max_hour": 17,
#         "aqi": null,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-07",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 23,
#         "observation_percent": 96.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.04613,
#         "first_max_value": 0.067,
#         "first_max_hour": 17,
#         "aqi": null,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-08",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.050708,
#         "first_max_value": 0.056,
#         "first_max_hour": 9,
#         "aqi": null,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-09",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.051792,
#         "first_max_value": 0.063,
#         "first_max_hour": 23,
#         "aqi": null,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-10",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.055958,
#         "first_max_value": 0.073,
#         "first_max_hour": 16,
#         "aqi": null,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-11",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.05425,
#         "first_max_value": 0.068,
#         "first_max_hour": 16,
#         "aqi": null,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-12",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.065542,
#         "first_max_value": 0.082,
#         "first_max_hour": 16,
#         "aqi": null,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-13",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.0575,
#         "first_max_value": 0.074,
#         "first_max_hour": 1,
#         "aqi": null,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-14",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.053708,
#         "first_max_value": 0.062,
#         "first_max_hour": 1,
#         "aqi": null,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-15",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.055,
#         "first_max_value": 0.063,
#         "first_max_hour": 9,
#         "aqi": null,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-16",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.055458,
#         "first_max_value": 0.064,
#         "first_max_hour": 11,
#         "aqi": null,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-17",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.053333,
#         "first_max_value": 0.062,
#         "first_max_hour": 8,
#         "aqi": null,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-18",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.062833,
#         "first_max_value": 0.08,
#         "first_max_hour": 17,
#         "aqi": null,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-19",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.067792,
#         "first_max_value": 0.083,
#         "first_max_hour": 16,
#         "aqi": null,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-20",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 23,
#         "observation_percent": 96.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.070435,
#         "first_max_value": 0.09,
#         "first_max_hour": 15,
#         "aqi": null,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-21",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.052,
#         "first_max_value": 0.068,
#         "first_max_hour": 0,
#         "aqi": null,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-22",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.054708,
#         "first_max_value": 0.064,
#         "first_max_hour": 8,
#         "aqi": null,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-23",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.0485,
#         "first_max_value": 0.069,
#         "first_max_hour": 12,
#         "aqi": null,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-24",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.062667,
#         "first_max_value": 0.081,
#         "first_max_hour": 17,
#         "aqi": null,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-25",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.056417,
#         "first_max_value": 0.076,
#         "first_max_hour": 15,
#         "aqi": null,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-26",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.05725,
#         "first_max_value": 0.077,
#         "first_max_hour": 15,
#         "aqi": null,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-27",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.067167,
#         "first_max_value": 0.088,
#         "first_max_hour": 16,
#         "aqi": null,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-28",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.066958,
#         "first_max_value": 0.086,
#         "first_max_hour": 16,
#         "aqi": null,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-29",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.059875,
#         "first_max_value": 0.065,
#         "first_max_hour": 15,
#         "aqi": null,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-30",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.056417,
#         "first_max_value": 0.075,
#         "first_max_hour": 15,
#         "aqi": null,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "1",
#         "sample_duration": "1 HOUR",
#         "pollutant_standard": "Ozone 1-hour 1979",
#         "date_local": "2021-07-31",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.048792,
#         "first_max_value": 0.065,
#         "first_max_hour": 14,
#         "aqi": null,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 1997",
#         "date_local": "2021-07-01",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.037292,
#         "first_max_value": 0.046,
#         "first_max_hour": 8,
#         "aqi": 43,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 1997",
#         "date_local": "2021-07-02",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.038,
#         "first_max_value": 0.046,
#         "first_max_hour": 10,
#         "aqi": 43,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 1997",
#         "date_local": "2021-07-03",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.046292,
#         "first_max_value": 0.054,
#         "first_max_hour": 9,
#         "aqi": 50,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 1997",
#         "date_local": "2021-07-04",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.041667,
#         "first_max_value": 0.051,
#         "first_max_hour": 8,
#         "aqi": 47,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 1997",
#         "date_local": "2021-07-05",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.042167,
#         "first_max_value": 0.055,
#         "first_max_hour": 7,
#         "aqi": 51,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 1997",
#         "date_local": "2021-07-06",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.037958,
#         "first_max_value": 0.051,
#         "first_max_hour": 11,
#         "aqi": 47,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 1997",
#         "date_local": "2021-07-07",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.04875,
#         "first_max_value": 0.059,
#         "first_max_hour": 11,
#         "aqi": 64,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 1997",
#         "date_local": "2021-07-08",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.050083,
#         "first_max_value": 0.054,
#         "first_max_hour": 8,
#         "aqi": 50,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 1997",
#         "date_local": "2021-07-09",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.051125,
#         "first_max_value": 0.054,
#         "first_max_hour": 8,
#         "aqi": 50,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 1997",
#         "date_local": "2021-07-10",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.054917,
#         "first_max_value": 0.068,
#         "first_max_hour": 12,
#         "aqi": 93,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
#         "longitude": -105.54564,
#         "datum": "WGS84",
#         "parameter": "Ozone",
#         "sample_duration_code": "W",
#         "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#         "pollutant_standard": "Ozone 8-Hour 1997",
#         "date_local": "2021-07-11",
#         "units_of_measure": "Parts per million",
#         "event_type": "No Events",
#         "observation_count": 24,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 0.0555,
#         "first_max_value": 0.065,
#         "first_max_hour": 10,
#         "aqi": 84,
#         "method_code": "047",
#         "method": "INSTRUMENTAL - ULTRA VIOLET",
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-05-26"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0007",
#         "parameter_code": "44201",
#         "poc": 1,
#         "latitude": 40.27813,
# ...
#         "arithmetic_mean": 7.8,
#         "first_max_value": 7.8,
#         "first_max_hour": 0,
#         "aqi": 43,
#         "method_code": "195",
#         "method": "GRIMM EDM Model 180 with naphion dryer - Laser Light Scattering",
#         "local_site_name": "FORT COLLINS - CSU - Edison",
#         "site_address": "251 EDISON DR.",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Fort Collins",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-08-06"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0009",
#         "parameter_code": "88101",
#         "poc": 3,
#         "latitude": 40.571288,
#         "longitude": -105.079693,
#         "datum": "WGS84",
#         "parameter": "PM2.5 - Local Conditions",
#         "sample_duration_code": "X",
#         "sample_duration": "24-HR BLK AVG",
#         "pollutant_standard": "PM25 Annual 2024",
#         "date_local": "2021-07-19",
#         "units_of_measure": "Micrograms/cubic meter (LC)",
#         "event_type": "No Events",
#         "observation_count": 1,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 13.9,
#         "first_max_value": 13.9,
#         "first_max_hour": 0,
#         "aqi": 60,
#         "method_code": "195",
#         "method": "GRIMM EDM Model 180 with naphion dryer - Laser Light Scattering",
#         "local_site_name": "FORT COLLINS - CSU - Edison",
#         "site_address": "251 EDISON DR.",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Fort Collins",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-08-06"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0009",
#         "parameter_code": "88101",
#         "poc": 3,
#         "latitude": 40.571288,
#         "longitude": -105.079693,
#         "datum": "WGS84",
#         "parameter": "PM2.5 - Local Conditions",
#         "sample_duration_code": "X",
#         "sample_duration": "24-HR BLK AVG",
#         "pollutant_standard": "PM25 Annual 2024",
#         "date_local": "2021-07-20",
#         "units_of_measure": "Micrograms/cubic meter (LC)",
#         "event_type": "No Events",
#         "observation_count": 1,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 13.9,
#         "first_max_value": 13.9,
#         "first_max_hour": 0,
#         "aqi": 60,
#         "method_code": "195",
#         "method": "GRIMM EDM Model 180 with naphion dryer - Laser Light Scattering",
#         "local_site_name": "FORT COLLINS - CSU - Edison",
#         "site_address": "251 EDISON DR.",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Fort Collins",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-08-06"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0009",
#         "parameter_code": "88101",
#         "poc": 3,
#         "latitude": 40.571288,
#         "longitude": -105.079693,
#         "datum": "WGS84",
#         "parameter": "PM2.5 - Local Conditions",
#         "sample_duration_code": "X",
#         "sample_duration": "24-HR BLK AVG",
#         "pollutant_standard": "PM25 Annual 2024",
#         "date_local": "2021-07-21",
#         "units_of_measure": "Micrograms/cubic meter (LC)",
#         "event_type": "No Events",
#         "observation_count": 1,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 9.4,
#         "first_max_value": 9.4,
#         "first_max_hour": 0,
#         "aqi": 52,
#         "method_code": "195",
#         "method": "GRIMM EDM Model 180 with naphion dryer - Laser Light Scattering",
#         "local_site_name": "FORT COLLINS - CSU - Edison",
#         "site_address": "251 EDISON DR.",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Fort Collins",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-08-06"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0009",
#         "parameter_code": "88101",
#         "poc": 3,
#         "latitude": 40.571288,
#         "longitude": -105.079693,
#         "datum": "WGS84",
#         "parameter": "PM2.5 - Local Conditions",
#         "sample_duration_code": "X",
#         "sample_duration": "24-HR BLK AVG",
#         "pollutant_standard": "PM25 Annual 2024",
#         "date_local": "2021-07-22",
#         "units_of_measure": "Micrograms/cubic meter (LC)",
#         "event_type": "No Events",
#         "observation_count": 1,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 7.2,
#         "first_max_value": 7.2,
#         "first_max_hour": 0,
#         "aqi": 40,
#         "method_code": "195",
#         "method": "GRIMM EDM Model 180 with naphion dryer - Laser Light Scattering",
#         "local_site_name": "FORT COLLINS - CSU - Edison",
#         "site_address": "251 EDISON DR.",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Fort Collins",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-08-06"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0009",
#         "parameter_code": "88101",
#         "poc": 3,
#         "latitude": 40.571288,
#         "longitude": -105.079693,
#         "datum": "WGS84",
#         "parameter": "PM2.5 - Local Conditions",
#         "sample_duration_code": "X",
#         "sample_duration": "24-HR BLK AVG",
#         "pollutant_standard": "PM25 Annual 2024",
#         "date_local": "2021-07-23",
#         "units_of_measure": "Micrograms/cubic meter (LC)",
#         "event_type": "No Events",
#         "observation_count": 1,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 6.1,
#         "first_max_value": 6.1,
#         "first_max_hour": 0,
#         "aqi": 34,
#         "method_code": "195",
#         "method": "GRIMM EDM Model 180 with naphion dryer - Laser Light Scattering",
#         "local_site_name": "FORT COLLINS - CSU - Edison",
#         "site_address": "251 EDISON DR.",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Fort Collins",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-08-06"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0009",
#         "parameter_code": "88101",
#         "poc": 3,
#         "latitude": 40.571288,
#         "longitude": -105.079693,
#         "datum": "WGS84",
#         "parameter": "PM2.5 - Local Conditions",
#         "sample_duration_code": "X",
#         "sample_duration": "24-HR BLK AVG",
#         "pollutant_standard": "PM25 Annual 2024",
#         "date_local": "2021-07-24",
#         "units_of_measure": "Micrograms/cubic meter (LC)",
#         "event_type": "No Events",
#         "observation_count": 1,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 15.7,
#         "first_max_value": 15.7,
#         "first_max_hour": 0,
#         "aqi": 63,
#         "method_code": "195",
#         "method": "GRIMM EDM Model 180 with naphion dryer - Laser Light Scattering",
#         "local_site_name": "FORT COLLINS - CSU - Edison",
#         "site_address": "251 EDISON DR.",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Fort Collins",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-08-06"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0009",
#         "parameter_code": "88101",
#         "poc": 3,
#         "latitude": 40.571288,
#         "longitude": -105.079693,
#         "datum": "WGS84",
#         "parameter": "PM2.5 - Local Conditions",
#         "sample_duration_code": "X",
#         "sample_duration": "24-HR BLK AVG",
#         "pollutant_standard": "PM25 Annual 2024",
#         "date_local": "2021-07-25",
#         "units_of_measure": "Micrograms/cubic meter (LC)",
#         "event_type": "No Events",
#         "observation_count": 1,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 17.1,
#         "first_max_value": 17.1,
#         "first_max_hour": 0,
#         "aqi": 66,
#         "method_code": "195",
#         "method": "GRIMM EDM Model 180 with naphion dryer - Laser Light Scattering",
#         "local_site_name": "FORT COLLINS - CSU - Edison",
#         "site_address": "251 EDISON DR.",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Fort Collins",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-08-06"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0009",
#         "parameter_code": "88101",
#         "poc": 3,
#         "latitude": 40.571288,
#         "longitude": -105.079693,
#         "datum": "WGS84",
#         "parameter": "PM2.5 - Local Conditions",
#         "sample_duration_code": "X",
#         "sample_duration": "24-HR BLK AVG",
#         "pollutant_standard": "PM25 Annual 2024",
#         "date_local": "2021-07-26",
#         "units_of_measure": "Micrograms/cubic meter (LC)",
#         "event_type": "No Events",
#         "observation_count": 1,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 10.3,
#         "first_max_value": 10.3,
#         "first_max_hour": 0,
#         "aqi": 53,
#         "method_code": "195",
#         "method": "GRIMM EDM Model 180 with naphion dryer - Laser Light Scattering",
#         "local_site_name": "FORT COLLINS - CSU - Edison",
#         "site_address": "251 EDISON DR.",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Fort Collins",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-08-06"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0009",
#         "parameter_code": "88101",
#         "poc": 3,
#         "latitude": 40.571288,
#         "longitude": -105.079693,
#         "datum": "WGS84",
#         "parameter": "PM2.5 - Local Conditions",
#         "sample_duration_code": "X",
#         "sample_duration": "24-HR BLK AVG",
#         "pollutant_standard": "PM25 Annual 2024",
#         "date_local": "2021-07-27",
#         "units_of_measure": "Micrograms/cubic meter (LC)",
#         "event_type": "No Events",
#         "observation_count": 1,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 9.2,
#         "first_max_value": 9.2,
#         "first_max_hour": 0,
#         "aqi": 51,
#         "method_code": "195",
#         "method": "GRIMM EDM Model 180 with naphion dryer - Laser Light Scattering",
#         "local_site_name": "FORT COLLINS - CSU - Edison",
#         "site_address": "251 EDISON DR.",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Fort Collins",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-08-06"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0009",
#         "parameter_code": "88101",
#         "poc": 3,
#         "latitude": 40.571288,
#         "longitude": -105.079693,
#         "datum": "WGS84",
#         "parameter": "PM2.5 - Local Conditions",
#         "sample_duration_code": "X",
#         "sample_duration": "24-HR BLK AVG",
#         "pollutant_standard": "PM25 Annual 2024",
#         "date_local": "2021-07-28",
#         "units_of_measure": "Micrograms/cubic meter (LC)",
#         "event_type": "No Events",
#         "observation_count": 1,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 7.6,
#         "first_max_value": 7.6,
#         "first_max_hour": 0,
#         "aqi": 42,
#         "method_code": "195",
#         "method": "GRIMM EDM Model 180 with naphion dryer - Laser Light Scattering",
#         "local_site_name": "FORT COLLINS - CSU - Edison",
#         "site_address": "251 EDISON DR.",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Fort Collins",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-08-06"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0009",
#         "parameter_code": "88101",
#         "poc": 3,
#         "latitude": 40.571288,
#         "longitude": -105.079693,
#         "datum": "WGS84",
#         "parameter": "PM2.5 - Local Conditions",
#         "sample_duration_code": "X",
#         "sample_duration": "24-HR BLK AVG",
#         "pollutant_standard": "PM25 Annual 2024",
#         "date_local": "2021-07-29",
#         "units_of_measure": "Micrograms/cubic meter (LC)",
#         "event_type": "No Events",
#         "observation_count": 1,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 10.6,
#         "first_max_value": 10.6,
#         "first_max_hour": 0,
#         "aqi": 54,
#         "method_code": "195",
#         "method": "GRIMM EDM Model 180 with naphion dryer - Laser Light Scattering",
#         "local_site_name": "FORT COLLINS - CSU - Edison",
#         "site_address": "251 EDISON DR.",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Fort Collins",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-08-06"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0009",
#         "parameter_code": "88101",
#         "poc": 3,
#         "latitude": 40.571288,
#         "longitude": -105.079693,
#         "datum": "WGS84",
#         "parameter": "PM2.5 - Local Conditions",
#         "sample_duration_code": "X",
#         "sample_duration": "24-HR BLK AVG",
#         "pollutant_standard": "PM25 Annual 2024",
#         "date_local": "2021-07-30",
#         "units_of_measure": "Micrograms/cubic meter (LC)",
#         "event_type": "No Events",
#         "observation_count": 1,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 8.9,
#         "first_max_value": 8.9,
#         "first_max_hour": 0,
#         "aqi": 49,
#         "method_code": "195",
#         "method": "GRIMM EDM Model 180 with naphion dryer - Laser Light Scattering",
#         "local_site_name": "FORT COLLINS - CSU - Edison",
#         "site_address": "251 EDISON DR.",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Fort Collins",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-08-06"
#     },
#     {
#         "state_code": "08",
#         "county_code": "069",
#         "site_number": "0009",
#         "parameter_code": "88101",
#         "poc": 3,
#         "latitude": 40.571288,
#         "longitude": -105.079693,
#         "datum": "WGS84",
#         "parameter": "PM2.5 - Local Conditions",
#         "sample_duration_code": "X",
#         "sample_duration": "24-HR BLK AVG",
#         "pollutant_standard": "PM25 Annual 2024",
#         "date_local": "2021-07-31",
#         "units_of_measure": "Micrograms/cubic meter (LC)",
#         "event_type": "No Events",
#         "observation_count": 1,
#         "observation_percent": 100.0,
#         "validity_indicator": "Y",
#         "arithmetic_mean": 19.4,
#         "first_max_value": 19.4,
#         "first_max_hour": 0,
#         "aqi": 70,
#         "method_code": "195",
#         "method": "GRIMM EDM Model 180 with naphion dryer - Laser Light Scattering",
#         "local_site_name": "FORT COLLINS - CSU - Edison",
#         "site_address": "251 EDISON DR.",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Fort Collins",
#         "cbsa_code": "22660",
#         "cbsa": "Fort Collins, CO",
#         "date_of_last_change": "2024-08-06"
#     }
# ]

# %% [markdown]
# The form of the daily summary response is a bit verbose with lots of repeated values. What we'll do is create a data structure that relies on a hierarchical context to summarize the data.
#
# The two responses (for Bend, OR) show that not every monitoring site produces values. As well, it looks like the monitoring sites only produce values for particulates and not for gaseous pollutants.
#
# The next function takes the response and a set of fields that should be extracted for their data values. The code assumes those fields are available. If there are missing values something could certainly go wrong. The function creates a summary for each monitoring site.

# %%
#
#    This is a list of field names - data - that will be extracted from each record
#
EXTRACTION_FIELDS = ['sample_duration','observation_count','arithmetic_mean','aqi']

#
#    The function creates a summary record
def extract_summary_from_response(r=None, fields=EXTRACTION_FIELDS):
    ## the result will be structured around monitoring site, parameter, and then date
    result = dict()
    data = r["Data"]
    for record in data:
        # make sure the record is set up
        site = record['site_number']
        param = record['parameter_code']
        #date = record['date_local']    # this version keeps the respnse value YYYY-
        date = record['date_local'].replace('-','') # this puts it in YYYYMMDD format
        if site not in result:
            result[site] = dict()
            result[site]['local_site_name'] = record['local_site_name']
            result[site]['site_address'] = record['site_address']
            result[site]['state'] = record['state']
            result[site]['county'] = record['county']
            result[site]['city'] = record['city']
            result[site]['pollutant_type'] = dict()
        if param not in result[site]['pollutant_type']:
            result[site]['pollutant_type'][param] = dict()
            result[site]['pollutant_type'][param]['parameter_name'] = record['parameter']
            result[site]['pollutant_type'][param]['units_of_measure'] = record['units_of_measure']
            result[site]['pollutant_type'][param]['method'] = record['method']
            result[site]['pollutant_type'][param]['data'] = dict()
        if date not in result[site]['pollutant_type'][param]['data']:
            result[site]['pollutant_type'][param]['data'][date] = list()
        
        # now extract the specified fields
        extract = dict()
        for k in fields:
            if str(k) in record:
                extract[str(k)] = record[k]
            else:
                # this makes sure we always have the requested fields, even if
                # we have a missing value for a given day/month
                extract[str(k)] = None
        
        # add this extraction to the list for the day
        result[site]['pollutant_type'][param]['data'][date].append(extract)
    
    return result

# %%
extract_gaseous = extract_summary_from_response(gaseous_aqi)
print("Summary of gaseous extraction ...")
print(json.dumps(extract_gaseous,indent=4))

extract_particulate = extract_summary_from_response(particulate_aqi)
print("Summary of particulate extraction ...")
print(json.dumps(extract_particulate,indent=4))
# Out:
# Summary of gaseous extraction ...
# {
#     "0007": {
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "pollutant_type": {
#             "44201": {
#                 "parameter_name": "Ozone",
#                 "units_of_measure": "Parts per million",
#                 "method": "INSTRUMENTAL - ULTRA VIOLET",
#                 "data": {
#                     "20210701": [
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.037542,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.037292,
#                             "aqi": 43
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.037292,
#                             "aqi": 43
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.037824,
#                             "aqi": 43
#                         },
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 23,
#                             "arithmetic_mean": 0.03913,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.038167,
#                             "aqi": 44
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.038167,
#                             "aqi": 44
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.038471,
#                             "aqi": 44
#                         }
#                     ],
#                     "20210702": [
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.036708,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.038,
#                             "aqi": 43
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.038,
#                             "aqi": 43
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.040118,
#                             "aqi": 43
#                         },
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 23,
#                             "arithmetic_mean": 0.037652,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.038708,
#                             "aqi": 43
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.038708,
#                             "aqi": 43
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.040882,
#                             "aqi": 43
#                         }
#                     ],
#                     "20210703": [
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.046708,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.046292,
#                             "aqi": 50
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.046292,
#                             "aqi": 50
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.046412,
#                             "aqi": 50
#                         },
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 23,
#                             "arithmetic_mean": 0.047783,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.047375,
#                             "aqi": 51
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.047375,
#                             "aqi": 51
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.047412,
#                             "aqi": 51
#                         }
#                     ],
#                     "20210704": [
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.0435,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.041667,
#                             "aqi": 47
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.041667,
#                             "aqi": 47
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.039647,
#                             "aqi": 47
#                         },
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 23,
#                             "arithmetic_mean": 0.044435,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.042417,
#                             "aqi": 47
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.042417,
#                             "aqi": 47
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.040294,
#                             "aqi": 47
#                         }
#                     ],
#                     "20210705": [
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.043042,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.042167,
#                             "aqi": 51
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.042167,
#                             "aqi": 51
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.041588,
#                             "aqi": 51
#                         },
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 23,
#                             "arithmetic_mean": 0.044348,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.043333,
#                             "aqi": 54
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.043333,
#                             "aqi": 54
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.042647,
#                             "aqi": 54
#                         }
#                     ],
#                     "20210706": [
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 23,
#                             "arithmetic_mean": 0.038391,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.037958,
#                             "aqi": 47
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.037958,
#                             "aqi": 47
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.040235,
#                             "aqi": 47
#                         },
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 22,
#                             "arithmetic_mean": 0.039773,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.038958,
#                             "aqi": 48
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.038958,
#                             "aqi": 48
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.040765,
#                             "aqi": 48
#                         }
#                     ],
#                     "20210707": [
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 23,
#                             "arithmetic_mean": 0.04613,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.04875,
#                             "aqi": 64
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.04875,
#                             "aqi": 64
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.053118,
#                             "aqi": 64
#                         },
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 22,
#                             "arithmetic_mean": 0.048364,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.049458,
#                             "aqi": 64
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.049458,
#                             "aqi": 64
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.053294,
#                             "aqi": 64
#                         }
#                     ],
#                     "20210708": [
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.050708,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.050083,
#                             "aqi": 50
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.050083,
#                             "aqi": 50
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.050059,
#                             "aqi": 50
#                         },
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 23,
#                             "arithmetic_mean": 0.05113,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.0505,
#                             "aqi": 50
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.0505,
#                             "aqi": 50
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.050529,
#                             "aqi": 50
#                         }
#                     ],
#                     "20210709": [
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.051792,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.051125,
#                             "aqi": 50
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.051125,
#                             "aqi": 50
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.052294,
#                             "aqi": 50
#                         },
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 23,
#                             "arithmetic_mean": 0.052565,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.052083,
#                             "aqi": 51
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.052083,
#                             "aqi": 51
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.053353,
#                             "aqi": 51
#                         }
#                     ],
#                     "20210710": [
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.055958,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.054917,
#                             "aqi": 93
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.054917,
#                             "aqi": 93
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.057294,
#                             "aqi": 93
#                         },
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 23,
#                             "arithmetic_mean": 0.057565,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.056375,
#                             "aqi": 97
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.056375,
#                             "aqi": 97
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.058941,
#                             "aqi": 97
#                         }
#                     ],
#                     "20210711": [
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.05425,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.0555,
#                             "aqi": 84
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.0555,
#                             "aqi": 84
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.057588,
#                             "aqi": 84
#                         },
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 23,
#                             "arithmetic_mean": 0.055826,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.056333,
#                             "aqi": 87
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.056333,
#                             "aqi": 87
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.058235,
#                             "aqi": 87
#                         }
#                     ],
#                     "20210712": [
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.065542,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.0665,
#                             "aqi": 119
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.0665,
#                             "aqi": 119
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.070588,
#                             "aqi": 119
#                         },
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 23,
#                             "arithmetic_mean": 0.066783,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.0675,
#                             "aqi": 126
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.0675,
#                             "aqi": 126
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.071765,
#                             "aqi": 126
#                         }
#                     ],
#                     "20210713": [
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.0575,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.056708,
#                             "aqi": 67
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.056708,
#                             "aqi": 67
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.056,
#                             "aqi": 67
#                         },
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 23,
#                             "arithmetic_mean": 0.058087,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.057417,
#                             "aqi": 71
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.057417,
#                             "aqi": 71
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.056824,
#                             "aqi": 71
#                         }
#                     ],
#                     "20210714": [
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.053708,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.051292,
#                             "aqi": 67
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.051292,
#                             "aqi": 67
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.048,
#                             "aqi": 58
#                         },
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 23,
#                             "arithmetic_mean": 0.054087,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.051958,
#                             "aqi": 71
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.051958,
#                             "aqi": 71
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.048765,
#                             "aqi": 61
#                         }
#                     ],
#                     "20210715": [
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.055,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.055375,
#                             "aqi": 64
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.055375,
#                             "aqi": 64
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.055353,
#                             "aqi": 64
#                         },
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 23,
#                             "arithmetic_mean": 0.056217,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.0565,
#                             "aqi": 67
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.0565,
#                             "aqi": 67
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.056529,
#                             "aqi": 67
#                         }
#                     ],
#                     "20210716": [
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.055458,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.0545,
#                             "aqi": 71
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.0545,
#                             "aqi": 71
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.054176,
#                             "aqi": 71
#                         },
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 23,
#                             "arithmetic_mean": 0.056609,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.055292,
#                             "aqi": 74
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.055292,
#                             "aqi": 74
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.054824,
#                             "aqi": 74
#                         }
#                     ],
#                     "20210717": [
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.053333,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.05325,
#                             "aqi": 61
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.05325,
#                             "aqi": 61
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.053353,
#                             "aqi": 61
#                         },
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 23,
#                             "arithmetic_mean": 0.053652,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.053583,
#                             "aqi": 61
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.053583,
#                             "aqi": 61
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.053706,
#                             "aqi": 61
#                         }
#                     ],
#                     "20210718": [
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.062833,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.063708,
#                             "aqi": 108
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.063708,
#                             "aqi": 108
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.066412,
#                             "aqi": 108
#                         },
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 23,
#                             "arithmetic_mean": 0.064522,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.064875,
#                             "aqi": 112
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.064875,
#                             "aqi": 112
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.067529,
#                             "aqi": 112
#                         }
#                     ],
#                     "20210719": [
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.067792,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.0685,
#                             "aqi": 122
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.0685,
#                             "aqi": 122
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.071647,
#                             "aqi": 122
#                         },
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 23,
#                             "arithmetic_mean": 0.068957,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.069167,
#                             "aqi": 122
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.069167,
#                             "aqi": 122
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.072294,
#                             "aqi": 122
#                         }
#                     ],
#                     "20210720": [
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 23,
#                             "arithmetic_mean": 0.070435,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.069083,
#                             "aqi": 133
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.069083,
#                             "aqi": 133
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.070412,
#                             "aqi": 133
#                         },
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 22,
#                             "arithmetic_mean": 0.070955,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.069875,
#                             "aqi": 129
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.069875,
#                             "aqi": 129
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.071059,
#                             "aqi": 129
#                         }
#                     ],
#                     "20210721": [
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.052,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.050583,
#                             "aqi": 61
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.050583,
#                             "aqi": 61
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.048294,
#                             "aqi": 54
#                         },
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 23,
#                             "arithmetic_mean": 0.052609,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.051042,
#                             "aqi": 64
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.051042,
#                             "aqi": 64
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 17,
#                             "arithmetic_mean": 0.048588,
#                             "aqi": 54
#                         }
#                     ],
#                     "20210722": [
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.054708,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.054792,
#                             "aqi": 67
#                         },
#                         {
#                             "sample_duration": "8-HR RUN AVG BEGIN HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 0.054792,
# ...
#                         },
#                         {
#                             "sample_duration": "24-HR BLK AVG",
#                             "observation_count": 1,
#                             "arithmetic_mean": 7.6,
#                             "aqi": 42
#                         },
#                         {
#                             "sample_duration": "24-HR BLK AVG",
#                             "observation_count": 1,
#                             "arithmetic_mean": 7.6,
#                             "aqi": 42
#                         },
#                         {
#                             "sample_duration": "24-HR BLK AVG",
#                             "observation_count": 1,
#                             "arithmetic_mean": 7.6,
#                             "aqi": 42
#                         },
#                         {
#                             "sample_duration": "24-HR BLK AVG",
#                             "observation_count": 1,
#                             "arithmetic_mean": 7.6,
#                             "aqi": 42
#                         },
#                         {
#                             "sample_duration": "24-HR BLK AVG",
#                             "observation_count": 1,
#                             "arithmetic_mean": 7.6,
#                             "aqi": 42
#                         }
#                     ],
#                     "20210729": [
#                         {
#                             "sample_duration": "24-HR BLK AVG",
#                             "observation_count": 1,
#                             "arithmetic_mean": 10.6,
#                             "aqi": 54
#                         },
#                         {
#                             "sample_duration": "24-HR BLK AVG",
#                             "observation_count": 1,
#                             "arithmetic_mean": 10.6,
#                             "aqi": 54
#                         },
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 22,
#                             "arithmetic_mean": 10.645455,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "24-HR BLK AVG",
#                             "observation_count": 1,
#                             "arithmetic_mean": 10.6,
#                             "aqi": 54
#                         },
#                         {
#                             "sample_duration": "24-HR BLK AVG",
#                             "observation_count": 1,
#                             "arithmetic_mean": 10.6,
#                             "aqi": 54
#                         },
#                         {
#                             "sample_duration": "24-HR BLK AVG",
#                             "observation_count": 1,
#                             "arithmetic_mean": 10.6,
#                             "aqi": 54
#                         },
#                         {
#                             "sample_duration": "24-HR BLK AVG",
#                             "observation_count": 1,
#                             "arithmetic_mean": 10.6,
#                             "aqi": 54
#                         },
#                         {
#                             "sample_duration": "24-HR BLK AVG",
#                             "observation_count": 1,
#                             "arithmetic_mean": 10.6,
#                             "aqi": 54
#                         },
#                         {
#                             "sample_duration": "24-HR BLK AVG",
#                             "observation_count": 1,
#                             "arithmetic_mean": 10.6,
#                             "aqi": 54
#                         }
#                     ],
#                     "20210730": [
#                         {
#                             "sample_duration": "24-HR BLK AVG",
#                             "observation_count": 1,
#                             "arithmetic_mean": 8.9,
#                             "aqi": 49
#                         },
#                         {
#                             "sample_duration": "24-HR BLK AVG",
#                             "observation_count": 1,
#                             "arithmetic_mean": 8.9,
#                             "aqi": 49
#                         },
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 8.991667,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "24-HR BLK AVG",
#                             "observation_count": 1,
#                             "arithmetic_mean": 8.9,
#                             "aqi": 49
#                         },
#                         {
#                             "sample_duration": "24-HR BLK AVG",
#                             "observation_count": 1,
#                             "arithmetic_mean": 8.9,
#                             "aqi": 49
#                         },
#                         {
#                             "sample_duration": "24-HR BLK AVG",
#                             "observation_count": 1,
#                             "arithmetic_mean": 8.9,
#                             "aqi": 49
#                         },
#                         {
#                             "sample_duration": "24-HR BLK AVG",
#                             "observation_count": 1,
#                             "arithmetic_mean": 8.9,
#                             "aqi": 49
#                         },
#                         {
#                             "sample_duration": "24-HR BLK AVG",
#                             "observation_count": 1,
#                             "arithmetic_mean": 8.9,
#                             "aqi": 49
#                         },
#                         {
#                             "sample_duration": "24-HR BLK AVG",
#                             "observation_count": 1,
#                             "arithmetic_mean": 8.9,
#                             "aqi": 49
#                         }
#                     ],
#                     "20210731": [
#                         {
#                             "sample_duration": "24-HR BLK AVG",
#                             "observation_count": 1,
#                             "arithmetic_mean": 19.4,
#                             "aqi": 70
#                         },
#                         {
#                             "sample_duration": "24-HR BLK AVG",
#                             "observation_count": 1,
#                             "arithmetic_mean": 19.4,
#                             "aqi": 70
#                         },
#                         {
#                             "sample_duration": "1 HOUR",
#                             "observation_count": 24,
#                             "arithmetic_mean": 19.458333,
#                             "aqi": null
#                         },
#                         {
#                             "sample_duration": "24-HR BLK AVG",
#                             "observation_count": 1,
#                             "arithmetic_mean": 19.4,
#                             "aqi": 70
#                         },
#                         {
#                             "sample_duration": "24-HR BLK AVG",
#                             "observation_count": 1,
#                             "arithmetic_mean": 19.4,
#                             "aqi": 70
#                         },
#                         {
#                             "sample_duration": "24-HR BLK AVG",
#                             "observation_count": 1,
#                             "arithmetic_mean": 19.4,
#                             "aqi": 70
#                         },
#                         {
#                             "sample_duration": "24-HR BLK AVG",
#                             "observation_count": 1,
#                             "arithmetic_mean": 19.4,
#                             "aqi": 70
#                         },
#                         {
#                             "sample_duration": "24-HR BLK AVG",
#                             "observation_count": 1,
#                             "arithmetic_mean": 19.4,
#                             "aqi": 70
#                         },
#                         {
#                             "sample_duration": "24-HR BLK AVG",
#                             "observation_count": 1,
#                             "arithmetic_mean": 19.4,
#                             "aqi": 70
#                         }
#                     ]
#                 }
#             }
#         }
#     },
#     "9002": {
#         "local_site_name": null,
#         "site_address": "CIRA, Colorado State University,1375 Campus Delivery,FORT COLLINS CO 80523-1375",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "pollutant_type": {
#             "88502": {
#                 "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#                 "units_of_measure": "Micrograms/cubic meter (LC)",
#                 "method": "IMPROVE Module A with Cyclone Inlet-Teflon Filter, 2.2 sq. cm. - GRAVIMETRIC",
#                 "data": {
#                     "20210703": [
#                         {
#                             "sample_duration": "24 HOUR",
#                             "observation_count": 1,
#                             "arithmetic_mean": 3.2,
#                             "aqi": 18
#                         }
#                     ],
#                     "20210706": [
#                         {
#                             "sample_duration": "24 HOUR",
#                             "observation_count": 1,
#                             "arithmetic_mean": 4.0,
#                             "aqi": 22
#                         }
#                     ],
#                     "20210709": [
#                         {
#                             "sample_duration": "24 HOUR",
#                             "observation_count": 1,
#                             "arithmetic_mean": 7.2,
#                             "aqi": 40
#                         }
#                     ],
#                     "20210712": [
#                         {
#                             "sample_duration": "24 HOUR",
#                             "observation_count": 1,
#                             "arithmetic_mean": 11.9,
#                             "aqi": 56
#                         }
#                     ],
#                     "20210715": [
#                         {
#                             "sample_duration": "24 HOUR",
#                             "observation_count": 1,
#                             "arithmetic_mean": 7.6,
#                             "aqi": 42
#                         }
#                     ],
#                     "20210718": [
#                         {
#                             "sample_duration": "24 HOUR",
#                             "observation_count": 1,
#                             "arithmetic_mean": 6.1,
#                             "aqi": 34
#                         }
#                     ],
#                     "20210721": [
#                         {
#                             "sample_duration": "24 HOUR",
#                             "observation_count": 1,
#                             "arithmetic_mean": 7.1,
#                             "aqi": 39
#                         }
#                     ],
#                     "20210724": [
#                         {
#                             "sample_duration": "24 HOUR",
#                             "observation_count": 1,
#                             "arithmetic_mean": 12.8,
#                             "aqi": 58
#                         }
#                     ],
#                     "20210727": [
#                         {
#                             "sample_duration": "24 HOUR",
#                             "observation_count": 1,
#                             "arithmetic_mean": 7.7,
#                             "aqi": 43
#                         }
#                     ],
#                     "20210730": [
#                         {
#                             "sample_duration": "24 HOUR",
#                             "observation_count": 1,
#                             "arithmetic_mean": 7.3,
#                             "aqi": 41
#                         }
#                     ]
#                 }
#             }
#         }
#     },
#     "0007": {
#         "local_site_name": "Rocky Mountain NP - Long's Peak",
#         "site_address": "ROCKY MOUNTAIN NP",
#         "state": "Colorado",
#         "county": "Larimer",
#         "city": "Not in a city",
#         "pollutant_type": {
#             "88502": {
#                 "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#                 "units_of_measure": "Micrograms/cubic meter (LC)",
#                 "method": "IMPROVE Module A with Cyclone Inlet-Teflon Filter, 2.2 sq. cm. - GRAVIMETRIC",
#                 "data": {
#                     "20210703": [
#                         {
#                             "sample_duration": "24 HOUR",
#                             "observation_count": 1,
#                             "arithmetic_mean": 2.7,
#                             "aqi": 15
#                         }
#                     ],
#                     "20210706": [
#                         {
#                             "sample_duration": "24 HOUR",
#                             "observation_count": 1,
#                             "arithmetic_mean": 3.4,
#                             "aqi": 19
#                         }
#                     ],
#                     "20210709": [
#                         {
#                             "sample_duration": "24 HOUR",
#                             "observation_count": 1,
#                             "arithmetic_mean": 4.1,
#                             "aqi": 23
#                         }
#                     ],
#                     "20210712": [
#                         {
#                             "sample_duration": "24 HOUR",
#                             "observation_count": 1,
#                             "arithmetic_mean": 16.0,
#                             "aqi": 64
#                         }
#                     ],
#                     "20210715": [
#                         {
#                             "sample_duration": "24 HOUR",
#                             "observation_count": 1,
#                             "arithmetic_mean": 9.0,
#                             "aqi": 50
#                         }
#                     ],
#                     "20210718": [
#                         {
#                             "sample_duration": "24 HOUR",
#                             "observation_count": 1,
#                             "arithmetic_mean": 6.1,
#                             "aqi": 34
#                         }
#                     ],
#                     "20210721": [
#                         {
#                             "sample_duration": "24 HOUR",
#                             "observation_count": 1,
#                             "arithmetic_mean": 4.8,
#                             "aqi": 27
#                         }
#                     ],
#                     "20210724": [
#                         {
#                             "sample_duration": "24 HOUR",
#                             "observation_count": 1,
#                             "arithmetic_mean": 16.0,
#                             "aqi": 64
#                         }
#                     ],
#                     "20210727": [
#                         {
#                             "sample_duration": "24 HOUR",
#                             "observation_count": 1,
#                             "arithmetic_mean": 8.6,
#                             "aqi": 48
#                         }
#                     ],
#                     "20210730": [
#                         {
#                             "sample_duration": "24 HOUR",
#                             "observation_count": 1,
#                             "arithmetic_mean": 5.8,
#                             "aqi": 32
#                         }
#                     ]
#                 }
#             }
#         }
#     }
# }

# %% [markdown]
# ## Example 4. Making request by bounding box
#
# There are some places that don't have monitoring stations. In the EPA FAQ that covers the AQS system, they note that their monitoring covers 2000 of the 3000+ US counties.
#
# The AQS API has a mechanism of requesting data and monitoring stations using a geographic bounding box. The above examples just demonstrated the use of the AQS API for making requests by counties. The examples below illustrate the use of bounding boxes. The example below makes requests to identify monitoring stations within the bounding box. Once you knew you have monitoring stations, then the bounding box could be used in the daily summary requests to get AQS data.

# %%
#
#   These are rough estimates for creating bounding boxes based on a city location
#   You can find these rough estimates on the USGS website:
#   https://www.usgs.gov/faqs/how-much-distance-does-a-degree-minute-and-second-cover-your-maps
#
LAT_25MILES = 25.0 * (1.0/69.0)    # This is about 25 miles of latitude in decimal degrees
LON_25MILES = 25.0 * (1.0/54.6)    # This is about 25 miles of longitude in decimal degrees
#
#   Compute rough estimates for a bounding box around a given place
#   The bounding box is scaled in 50 mile increments. That is, the bounding box will have sides that
#   are rough multiples of 50 miles, with the center of the box around the indicated place.
#   The scale parameter determines the scale (size) of the bounding box
#
def bounding_latlon(place=None,scale=1.0):
    minlat = place['latlon'][0] - float(scale) * LAT_25MILES
    maxlat = place['latlon'][0] + float(scale) * LAT_25MILES
    minlon = place['latlon'][1] - float(scale) * LON_25MILES
    maxlon = place['latlon'][1] + float(scale) * LON_25MILES
    return [minlat,maxlat,minlon,maxlon]

# %%
#
#    This implements the monitors request. This requests monitoring stations. This can be done by state, county, or bounding box. 
#
#    Like the two other functions, this can be called with a mixture of a defined parameter dictionary, or with function
#    parameters. If function parameters are provided, those take precedence over any parameters from the request template.
#
def request_monitors(email_address = None, key = None, param=None,
                          begin_date = None, end_date = None, fips = None,
                          endpoint_url = API_REQUEST_URL, 
                          endpoint_action = API_ACTION_MONITORS_COUNTY, 
                          request_template = AQS_REQUEST_TEMPLATE,
                          headers = None):
    
    #  This prioritizes the info from the call parameters - not what's already in the template
    if email_address:
        request_template['email'] = email_address
    if key:
        request_template['key'] = key
    if param:
        request_template['param'] = param
    if begin_date:
        request_template['begin_date'] = begin_date
    if end_date:
        request_template['end_date'] = end_date
    if fips and len(fips)==5:
        request_template['state'] = fips[:2]
        request_template['county'] = fips[2:]            

    # Make sure there are values that allow us to make a call - these are always required
    if not request_template['email']:
        raise Exception("Must supply an email address to call 'request_monitors()'")
    if not request_template['key']: 
        raise Exception("Must supply a key to call 'request_monitors()'")
    if not request_template['param']: 
        raise Exception("Must supply param values to call 'request_monitors()'")
    if not request_template['begin_date']: 
        raise Exception("Must supply a begin_date to call 'request_monitors()'")
    if not request_template['end_date']: 
        raise Exception("Must supply an end_date to call 'request_monitors()'")
    # Note we're not validating FIPS fields because not all of the monitors actions require the FIPS numbers
    
    # compose the request
    request_url = endpoint_url+endpoint_action.format(**request_template)
    
    # make the request
    try:
        # Wait first, to make sure we don't exceed a rate limit in the situation where an exception occurs
        # during the request processing - throttling is always a good practice with a free data source
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(request_url, headers=headers)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %%
#
request_data = AQS_REQUEST_TEMPLATE.copy()
request_data['email'] = USERNAME
request_data['key'] = APIKEY
request_data['param'] = AQI_PARAMS_PARTICULATES     # remember we have both gaseous and particulates
# 
#   We got the monitoring stations for Bend OR above (Deschutes county) - let's work with that one again
request_data['state'] = CITY_LOCATIONS['bend']['fips'][:2]
request_data['county'] = CITY_LOCATIONS['bend']['fips'][2:]
#
# the first example uses the default - request monitors by county, we'll just use a recent date for now
response = request_monitors(request_template=request_data, begin_date="20210701", end_date="20210731")
#
# the response should be similar to the 'list' request above - but in this case we should only get monitors that
# monitor the AQI_PARAMS_PARTICULATES set of params.
#
if response["Header"][0]['status'] == "Success":
    print(json.dumps(response['Data'],indent=4))
else:
    print(json.dumps(response,indent=4))
# Out:
# [
#     {
#         "state_code": "41",
#         "county_code": "017",
#         "site_number": "0120",
#         "parameter_code": "88101",
#         "poc": 1,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "2001-03-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "209",
#         "last_method_description": "Met One BAM-1022 Mass Monitor w/ VSCC or TE-PM2.5C - Beta Attenuation",
#         "last_method_begin_date": "2023-09-30",
#         "naaqs_primary_monitor": "Y",
#         "qa_primary_monitor": null,
#         "monitor_type": "SPM",
#         "networks": null,
#         "monitoring_agency_code": "0821",
#         "monitoring_agency": "Oregon Department Of Environmental Quality",
#         "si_id": 13113,
#         "latitude": 44.063916,
#         "longitude": -121.312554,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 23.98,
#         "elevation": 1105.0,
#         "probe_height": 3.0,
#         "pl_probe_location": "OTHER",
#         "local_site_name": "OPEN FIELD/RESIDENTIAL AREA BY DESCHUTES RIVER. CITY PUMP STATION.",
#         "address": "35 NW PORTLAND ST, BEND, OREGON",
#         "state_name": "Oregon",
#         "county_name": "Deschutes",
#         "city_name": "Bend",
#         "cbsa_code": "13460",
#         "cbsa_name": "Bend-Redmond, OR",
#         "csa_code": "140",
#         "csa_name": "Bend-Redmond-Prineville, OR",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "41",
#         "county_code": "017",
#         "site_number": "0004",
#         "parameter_code": "88502",
#         "poc": 3,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2011-05-17",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "771",
#         "last_method_description": "Correlated Radiance Research M903 With Heated Inlet - Nephelometry",
#         "last_method_begin_date": "2011-05-17",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SPM",
#         "networks": null,
#         "monitoring_agency_code": "0821",
#         "monitoring_agency": "Oregon Department Of Environmental Quality",
#         "si_id": 96153,
#         "latitude": 44.2921,
#         "longitude": -121.5555,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 1.0,
#         "elevation": 975.0,
#         "probe_height": 3.0,
#         "pl_probe_location": "SIDE OF BUILDING",
#         "local_site_name": "Sisters Forest Service Station (SFS)",
#         "address": "Sisters Forest Service Station (SFS)",
#         "state_name": "Oregon",
#         "county_name": "Deschutes",
#         "city_name": "Sisters",
#         "cbsa_code": "13460",
#         "cbsa_name": "Bend-Redmond, OR",
#         "csa_code": "140",
#         "csa_name": "Bend-Redmond-Prineville, OR",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "41",
#         "county_code": "017",
#         "site_number": "0120",
#         "parameter_code": "88502",
#         "poc": 3,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2004-01-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "771",
#         "last_method_description": "Correlated Radiance Research M903 With Heated Inlet - Nephelometry",
#         "last_method_begin_date": "2004-01-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "0821",
#         "monitoring_agency": "Oregon Department Of Environmental Quality",
#         "si_id": 13113,
#         "latitude": 44.063916,
#         "longitude": -121.312554,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 23.98,
#         "elevation": 1105.0,
#         "probe_height": 3.0,
#         "pl_probe_location": "GROUND LEVEL SUPPORT",
#         "local_site_name": "OPEN FIELD/RESIDENTIAL AREA BY DESCHUTES RIVER. CITY PUMP STATION.",
#         "address": "35 NW PORTLAND ST, BEND, OREGON",
#         "state_name": "Oregon",
#         "county_name": "Deschutes",
#         "city_name": "Bend",
#         "cbsa_code": "13460",
#         "cbsa_name": "Bend-Redmond, OR",
#         "csa_code": "140",
#         "csa_name": "Bend-Redmond-Prineville, OR",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "41",
#         "county_code": "017",
#         "site_number": "1001",
#         "parameter_code": "88502",
#         "poc": 3,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2019-10-08",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "791",
#         "last_method_description": "OTHR AUTOMATD 2.5 MASS CONCENT - SURROGATE MEASURE",
#         "last_method_begin_date": "2019-10-08",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SPM",
#         "networks": null,
#         "monitoring_agency_code": "0821",
#         "monitoring_agency": "Oregon Department Of Environmental Quality",
#         "si_id": 104670,
#         "latitude": 44.274996,
#         "longitude": -121.190338,
#         "datum": "NAD83",
#         "lat_lon_accuracy": 1.0,
#         "elevation": 911.0,
#         "probe_height": 2.0,
#         "pl_probe_location": "GROUND LEVEL SUPPORT",
#         "local_site_name": null,
#         "address": "Redmond High School (RHS), 675 SW Rimrock Way",
#         "state_name": "Oregon",
#         "county_name": "Deschutes",
#         "city_name": "Redmond",
#         "cbsa_code": "13460",
#         "cbsa_name": "Bend-Redmond, OR",
#         "csa_code": "140",
#         "csa_name": "Bend-Redmond-Prineville, OR",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "41",
#         "county_code": "017",
#         "site_number": "0123",
#         "parameter_code": "88502",
#         "poc": 3,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2020-07-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "791",
#         "last_method_description": "OTHR AUTOMATD 2.5 MASS CONCENT - SURROGATE MEASURE",
#         "last_method_begin_date": "2020-07-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SPM",
#         "networks": null,
#         "monitoring_agency_code": "0821",
#         "monitoring_agency": "Oregon Department Of Environmental Quality",
#         "si_id": 104671,
#         "latitude": 44.0548,
#         "longitude": -121.2942,
#         "datum": "NAD83",
#         "lat_lon_accuracy": 25.0,
#         "elevation": 1114.0,
#         "probe_height": 2.0,
#         "pl_probe_location": "GROUND LEVEL SUPPORT",
#         "local_site_name": null,
#         "address": "Bend High School (BEE), 230 NE 6th St, Bend, OR 97701",
#         "state_name": "Oregon",
#         "county_name": "Deschutes",
#         "city_name": "Bend",
#         "cbsa_code": "13460",
#         "cbsa_name": "Bend-Redmond, OR",
#         "csa_code": "140",
#         "csa_name": "Bend-Redmond-Prineville, OR",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "41",
#         "county_code": "017",
#         "site_number": "2002",
#         "parameter_code": "88502",
#         "poc": 3,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2020-07-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "791",
#         "last_method_description": "OTHR AUTOMATD 2.5 MASS CONCENT - SURROGATE MEASURE",
#         "last_method_begin_date": "2020-07-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SPM",
#         "networks": null,
#         "monitoring_agency_code": "0821",
#         "monitoring_agency": "Oregon Department Of Environmental Quality",
#         "si_id": 104674,
#         "latitude": 43.70376,
#         "longitude": -121.5273,
#         "datum": "NAD83",
#         "lat_lon_accuracy": 3.0,
#         "elevation": 1293.0,
#         "probe_height": 2.0,
#         "pl_probe_location": "GROUND LEVEL SUPPORT",
#         "local_site_name": null,
#         "address": "La Pine RFPD Fire Station 103, 15990 Burgess Rd, La Pine",
#         "state_name": "Oregon",
#         "county_name": "Deschutes",
#         "city_name": "La Pine",
#         "cbsa_code": "13460",
#         "cbsa_name": "Bend-Redmond, OR",
#         "csa_code": "140",
#         "csa_name": "Bend-Redmond-Prineville, OR",
#         "tribal_code": null,
#         "tribe_name": null
#     }
# ]

# %% [markdown]
# Given the response above for Bend, OR - it looks like there are 5 monitoring sites that are in Deschutes County - AND that monitor particulate air quality. Their unique site IDs are given in the 'site_number' field of the dictionary. The response also includes their lat,lon positions should we need that. Comparing the site numbers to the response from the list request above - all of the sites here are there. So, things seem to be heading in the right direction.

# %% [markdown]
# Next, we're going to change the monitors request to use a bounding box and see what happens.

# %%
#
#    Create a copy of the AQS_REQUEST_TEMPLATE
#
request_data = AQS_REQUEST_TEMPLATE.copy()
request_data['email'] = USERNAME
request_data['key'] = APIKEY
request_data['param'] = AQI_PARAMS_PARTICULATES     # same particulate request as the one abover
# 
#   Not going to use these - comment them out
#request_data['state'] = CITY_LOCATIONS['bend']['fips'][:2]
#request_data['county'] = CITY_LOCATIONS['bend']['fips'][2:]
#
#   Now, we need bounding box parameters

#   50 mile box
bbox = bounding_latlon(CITY_LOCATIONS['bend'],scale=1.0)
#   100 mile box
#bbox = bounding_latlon(CITY_LOCATIONS['bend'],scale=2.0)
#   150 mile box
#bbox = bounding_latlon(CITY_LOCATIONS['bend'],scale=3.0)
#   200 mile box
#bbox = bounding_latlon(CITY_LOCATIONS['bend'],scale=4.0)

# the bbox response comes back as a list - [minlat,maxlat,minlon,maxlon]

#   put our bounding box into the request_data
request_data['minlat'] = bbox[0]
request_data['maxlat'] = bbox[1]
request_data['minlon'] = bbox[2]
request_data['maxlon'] = bbox[3]

#
#   we need to change the action for the API from the default to the bounding box - same recent date for now
response = request_monitors(request_template=request_data, begin_date="20210701", end_date="20210731",
                            endpoint_action = API_ACTION_MONITORS_BOX)
#
#
#
if response["Header"][0]['status'] == "Success":
    print(json.dumps(response['Data'],indent=4))
else:
    print(json.dumps(response,indent=4))
# Out:
# [
#     {
#         "state_code": "41",
#         "county_code": "017",
#         "site_number": "0120",
#         "parameter_code": "88101",
#         "poc": 1,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "2001-03-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "209",
#         "last_method_description": "Met One BAM-1022 Mass Monitor w/ VSCC or TE-PM2.5C - Beta Attenuation",
#         "last_method_begin_date": "2023-09-30",
#         "naaqs_primary_monitor": "Y",
#         "qa_primary_monitor": null,
#         "monitor_type": "SPM",
#         "networks": null,
#         "monitoring_agency_code": "0821",
#         "monitoring_agency": "Oregon Department Of Environmental Quality",
#         "si_id": 13113,
#         "latitude": 44.063916,
#         "longitude": -121.312554,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 23.98,
#         "elevation": 1105.0,
#         "probe_height": 3.0,
#         "pl_probe_location": "OTHER",
#         "local_site_name": "OPEN FIELD/RESIDENTIAL AREA BY DESCHUTES RIVER. CITY PUMP STATION.",
#         "address": "35 NW PORTLAND ST, BEND, OREGON",
#         "state_name": "Oregon",
#         "county_name": "Deschutes",
#         "city_name": "Bend",
#         "cbsa_code": "13460",
#         "cbsa_name": "Bend-Redmond, OR",
#         "csa_code": "140",
#         "csa_name": "Bend-Redmond-Prineville, OR",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "41",
#         "county_code": "017",
#         "site_number": "0004",
#         "parameter_code": "88502",
#         "poc": 3,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2011-05-17",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "771",
#         "last_method_description": "Correlated Radiance Research M903 With Heated Inlet - Nephelometry",
#         "last_method_begin_date": "2011-05-17",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SPM",
#         "networks": null,
#         "monitoring_agency_code": "0821",
#         "monitoring_agency": "Oregon Department Of Environmental Quality",
#         "si_id": 96153,
#         "latitude": 44.2921,
#         "longitude": -121.5555,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 1.0,
#         "elevation": 975.0,
#         "probe_height": 3.0,
#         "pl_probe_location": "SIDE OF BUILDING",
#         "local_site_name": "Sisters Forest Service Station (SFS)",
#         "address": "Sisters Forest Service Station (SFS)",
#         "state_name": "Oregon",
#         "county_name": "Deschutes",
#         "city_name": "Sisters",
#         "cbsa_code": "13460",
#         "cbsa_name": "Bend-Redmond, OR",
#         "csa_code": "140",
#         "csa_name": "Bend-Redmond-Prineville, OR",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "41",
#         "county_code": "017",
#         "site_number": "0120",
#         "parameter_code": "88502",
#         "poc": 3,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2004-01-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "771",
#         "last_method_description": "Correlated Radiance Research M903 With Heated Inlet - Nephelometry",
#         "last_method_begin_date": "2004-01-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "0821",
#         "monitoring_agency": "Oregon Department Of Environmental Quality",
#         "si_id": 13113,
#         "latitude": 44.063916,
#         "longitude": -121.312554,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 23.98,
#         "elevation": 1105.0,
#         "probe_height": 3.0,
#         "pl_probe_location": "GROUND LEVEL SUPPORT",
#         "local_site_name": "OPEN FIELD/RESIDENTIAL AREA BY DESCHUTES RIVER. CITY PUMP STATION.",
#         "address": "35 NW PORTLAND ST, BEND, OREGON",
#         "state_name": "Oregon",
#         "county_name": "Deschutes",
#         "city_name": "Bend",
#         "cbsa_code": "13460",
#         "cbsa_name": "Bend-Redmond, OR",
#         "csa_code": "140",
#         "csa_name": "Bend-Redmond-Prineville, OR",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "41",
#         "county_code": "017",
#         "site_number": "1001",
#         "parameter_code": "88502",
#         "poc": 3,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2019-10-08",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "791",
#         "last_method_description": "OTHR AUTOMATD 2.5 MASS CONCENT - SURROGATE MEASURE",
#         "last_method_begin_date": "2019-10-08",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SPM",
#         "networks": null,
#         "monitoring_agency_code": "0821",
#         "monitoring_agency": "Oregon Department Of Environmental Quality",
#         "si_id": 104670,
#         "latitude": 44.274996,
#         "longitude": -121.190338,
#         "datum": "NAD83",
#         "lat_lon_accuracy": 1.0,
#         "elevation": 911.0,
#         "probe_height": 2.0,
#         "pl_probe_location": "GROUND LEVEL SUPPORT",
#         "local_site_name": null,
#         "address": "Redmond High School (RHS), 675 SW Rimrock Way",
#         "state_name": "Oregon",
#         "county_name": "Deschutes",
#         "city_name": "Redmond",
#         "cbsa_code": "13460",
#         "cbsa_name": "Bend-Redmond, OR",
#         "csa_code": "140",
#         "csa_name": "Bend-Redmond-Prineville, OR",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "41",
#         "county_code": "017",
#         "site_number": "0123",
#         "parameter_code": "88502",
#         "poc": 3,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2020-07-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "791",
#         "last_method_description": "OTHR AUTOMATD 2.5 MASS CONCENT - SURROGATE MEASURE",
#         "last_method_begin_date": "2020-07-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SPM",
#         "networks": null,
#         "monitoring_agency_code": "0821",
#         "monitoring_agency": "Oregon Department Of Environmental Quality",
#         "si_id": 104671,
#         "latitude": 44.0548,
#         "longitude": -121.2942,
#         "datum": "NAD83",
#         "lat_lon_accuracy": 25.0,
#         "elevation": 1114.0,
#         "probe_height": 2.0,
#         "pl_probe_location": "GROUND LEVEL SUPPORT",
#         "local_site_name": null,
#         "address": "Bend High School (BEE), 230 NE 6th St, Bend, OR 97701",
#         "state_name": "Oregon",
#         "county_name": "Deschutes",
#         "city_name": "Bend",
#         "cbsa_code": "13460",
#         "cbsa_name": "Bend-Redmond, OR",
#         "csa_code": "140",
#         "csa_name": "Bend-Redmond-Prineville, OR",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "41",
#         "county_code": "017",
#         "site_number": "2002",
#         "parameter_code": "88502",
#         "poc": 3,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2020-07-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "791",
#         "last_method_description": "OTHR AUTOMATD 2.5 MASS CONCENT - SURROGATE MEASURE",
#         "last_method_begin_date": "2020-07-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SPM",
#         "networks": null,
#         "monitoring_agency_code": "0821",
#         "monitoring_agency": "Oregon Department Of Environmental Quality",
#         "si_id": 104674,
#         "latitude": 43.70376,
#         "longitude": -121.5273,
#         "datum": "NAD83",
#         "lat_lon_accuracy": 3.0,
#         "elevation": 1293.0,
#         "probe_height": 2.0,
#         "pl_probe_location": "GROUND LEVEL SUPPORT",
#         "local_site_name": null,
#         "address": "La Pine RFPD Fire Station 103, 15990 Burgess Rd, La Pine",
#         "state_name": "Oregon",
#         "county_name": "Deschutes",
#         "city_name": "La Pine",
#         "cbsa_code": "13460",
#         "cbsa_name": "Bend-Redmond, OR",
#         "csa_code": "140",
#         "csa_name": "Bend-Redmond-Prineville, OR",
#         "tribal_code": null,
#         "tribe_name": null
#     }
# ]

# %% [markdown]
# The response above indicates that all five of the particulate monitoring stations in Deschutes County are within (roughly) 25 miles of Bend, OR. Our 50 mile bounding box was centered on Bend - and we got all 5 stations.
#
# There are places where monitoring stations might be hard to find. This would mean that air quality data is harder to get for that location.
#
# Lets, consider Seaside, OR.

# %%
#
request_data = AQS_REQUEST_TEMPLATE.copy()
request_data['email'] = USERNAME
request_data['key'] = APIKEY
request_data['param'] = AQI_PARAMS_PARTICULATES     # like the above example, just focusing on particulates
# 
#    This time, we'll try getting the list of monitoring stations for Seaside, OR
request_data['state'] = CITY_LOCATIONS['seaside']['fips'][:2]
request_data['county'] = CITY_LOCATIONS['seaside']['fips'][2:]
#
#    For the Seaside example, let's get everything that we can find in the county.
response = request_monitors(request_template=request_data, begin_date="20210701", end_date="20210731")
#
#
if response["Header"][0]['status'] == "Success":
    print(json.dumps(response['Data'],indent=4))
elif response["Header"][0]['status'].startswith("No data "):
    print("Looks like the response generated no monitoring stations.")
else:
    print(json.dumps(response,indent=4))
# Out:
# Looks like the response generated no monitoring stations.

# %% [markdown]
# The response indicates that there are no monitoring stations in Clatsop County (where Seaside, OR is located). The EPA says they only have monitoring stations in about 2000 of the 3000+ US counties. If we're going to find monitoring stations - maybe we can use the bounding box to find them.
#
# Let's scale up some bounding boxes and see if we can find some monitoring stations for Seaside OR.

# %%
request_data = AQS_REQUEST_TEMPLATE.copy()
request_data['email'] = USERNAME
request_data['key'] = APIKEY
request_data['param'] = AQI_PARAMS_PARTICULATES     # same particulate request as the one abover
# 
#   Not going to use these - comment them out
#request_data['state'] = CITY_LOCATIONS['seaside']['fips'][:2]
#request_data['county'] = CITY_LOCATIONS['seaside']['fips'][2:]
#
#   Now, we need bounding box parameters

#   50 mile box - roughly within 25 miles of the location
#bbox = bounding_latlon(CITY_LOCATIONS['seaside'],scale=1.0)
#   100 mile box - roughly within 50 miles of the location
bbox = bounding_latlon(CITY_LOCATIONS['seaside'],scale=2.0)
#   150 mile box - roughly within 75 miles of the location
#bbox = bounding_latlon(CITY_LOCATIONS['seaside'],scale=3.0)
#   200 mile box
#bbox = bounding_latlon(CITY_LOCATIONS['seaside'],scale=4.0)

# the bbox response comes back as a list - [minlat,maxlat,minlon,maxlon]

#   put our bounding box into the request_data
request_data['minlat'] = bbox[0]
request_data['maxlat'] = bbox[1]
request_data['minlon'] = bbox[2]
request_data['maxlon'] = bbox[3]

#
#   we need to change the action for the API from the default to the bounding box - same recent date for now
response = request_monitors(request_template=request_data, begin_date="20210701", end_date="20210731",
                            endpoint_action = API_ACTION_MONITORS_BOX)
#
#
#
if response["Header"][0]['status'] == "Success":
    print(json.dumps(response['Data'],indent=4))
else:
    print(json.dumps(response,indent=4))
# Out:
# [
#     {
#         "state_code": "41",
#         "county_code": "067",
#         "site_number": "0006",
#         "parameter_code": "88502",
#         "poc": 3,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2019-06-20",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "791",
#         "last_method_description": "OTHR AUTOMATD 2.5 MASS CONCENT - SURROGATE MEASURE",
#         "last_method_begin_date": "2019-06-20",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SPM",
#         "networks": null,
#         "monitoring_agency_code": "0821",
#         "monitoring_agency": "Oregon Department Of Environmental Quality",
#         "si_id": 104536,
#         "latitude": 45.52483,
#         "longitude": -123.10554,
#         "datum": "NAD83",
#         "lat_lon_accuracy": 1.0,
#         "elevation": 56.0,
#         "probe_height": 2.0,
#         "pl_probe_location": "GROUND LEVEL SUPPORT",
#         "local_site_name": null,
#         "address": "Pacific University, Cedar St and 23rd Place, Forest Grove (FGC)",
#         "state_name": "Oregon",
#         "county_name": "Washington",
#         "city_name": "Forest Grove",
#         "cbsa_code": "38900",
#         "cbsa_name": "Portland-Vancouver-Hillsboro, OR-WA",
#         "csa_code": "440",
#         "csa_name": "Portland-Vancouver-Salem, OR-WA",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "41",
#         "county_code": "057",
#         "site_number": "0001",
#         "parameter_code": "88502",
#         "poc": 3,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2020-07-01",
#         "close_date": "2022-06-23",
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "791",
#         "last_method_description": "OTHR AUTOMATD 2.5 MASS CONCENT - SURROGATE MEASURE",
#         "last_method_begin_date": "2020-07-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0821",
#         "monitoring_agency": "Oregon Department Of Environmental Quality",
#         "si_id": 104680,
#         "latitude": 45.45735,
#         "longitude": -123.8028,
#         "datum": "NAD83",
#         "lat_lon_accuracy": 3.0,
#         "elevation": 19.0,
#         "probe_height": 2.0,
#         "pl_probe_location": "GROUND LEVEL SUPPORT",
#         "local_site_name": null,
#         "address": "Tillamook ODF (TDF) 5005 3rd St, Tillamook, OR 97141",
#         "state_name": "Oregon",
#         "county_name": "Tillamook",
#         "city_name": "Tillamook",
#         "cbsa_code": null,
#         "cbsa_name": null,
#         "csa_code": null,
#         "csa_name": null,
#         "tribal_code": null,
#         "tribe_name": null
#     }
# ]

# %% [markdown]
# Looks like we can find two monitoring stations within 50 miles of Seaside, OR. If we needed to know the air quality in Seaside, we could use a Daily Summary request with the same bounding box and get data for these two stations - which are the closest ones we could find.
