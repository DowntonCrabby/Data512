# %%
# Overview
- **Objective**: [What this notebook aims to accomplish]
- **Data Source**: [Briefly describe the datasets being used]
- **Dependencies**: [List libraries and versions, if applicable]
- **Author**: [Your Name or Team Name]
- **Date**: [Creation or last modification date]

# %% [markdown]
# ## Imports

# %%
import os
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from statsmodels.tsa.arima.model import ARIMA

# %% [markdown]
# ## Constants

# %%
input_directory  = r"C:\Users\clark.roll\python coding\code_personal\Data512\Course Project\Data Analysis and Modeling\input_files"
viz_directory    = r"C:\Users\clark.roll\python coding\code_personal\Data512\Course Project\Data Analysis and Modeling\visualizations"
output_directory = r"C:\Users\clark.roll\python coding\code_personal\Data512\Course Project\Data Analysis and Modeling\output_files"

# %%
AQI_CATEGORIES = {
    'Good':                        {'color': 'green',   'threshold_min':0,   'threshold_max':50},
    'Moderate':                    {'color': 'yellow',  'threshold_min':51,  'threshold_max':100},
    'Unhealthy for sensitive grps':{'color': 'orange',  'threshold_min':101, 'threshold_max':150},
    'Unhealthy':                   {'color': 'red',     'threshold_min':151, 'threshold_max':200},
    'Very unhealthy':              {'color': 'purple',  'threshold_min':201, 'threshold_max':300},
    'Hazardous':                   {'color': 'maroon',  'threshold_min':301, 'threshold_max':1000}
}

# %% [markdown]
# ## Load Data

# %%
survey                 = 'activity_survey_subset.csv'
fullYear_daily_aqi     = 'AQI_fullYear_daily_avg.csv'
seasonal_daily_aqi     = 'AQI_seasonal_daily_avg.csv'
parks                  = 'parks_data.csv'
survey_thresh          = 'activity_reduction_perc_by_AQI.csv'

# Full paths for each file
survey_path        = os.path.join(input_directory, survey)
year_aqi_path      = os.path.join(input_directory, fullYear_daily_aqi)
szn_aqi_path       = os.path.join(input_directory, seasonal_daily_aqi)
parks_path         = os.path.join(input_directory, parks)
beh_thresh_path    = os.path.join(input_directory, survey_thresh)

# load dataframes
survey_df        = pd.read_csv(survey_path)
beh_thresh_df    = pd.read_csv(beh_thresh_path)
aqi_y_df         = pd.read_csv(year_aqi_path)
aqi_s_df         = pd.read_csv(szn_aqi_path)
parks_df         = pd.read_csv(parks_path)

# %% [markdown]
# ## Define Functions

# %%
def gen_png_savepath(filename:str):
    save_path = os.path.join(viz_directory, filename)
    return save_path

def categorize_aqi(aqi_value: float) -> str:
    """
    Categorize an AQI value based on predefined AQI categories.
    
    Parameters
    ----------
    aqi_value : float
        The Air Quality Index (AQI) value to categorize.
    
    Returns
    -------
    str
        The category name corresponding to the AQI value.
    """
    for category, thresholds in AQI_CATEGORIES.items():
        if thresholds['threshold_min'] <= aqi_value <= thresholds['threshold_max']:
            return category
    return "Unknown"

# %% [markdown]
# # Prepare AQI data for modeling

# %%
aqi_y_df.rename(columns={"date_local":"date"}, inplace=True)

# Convert the 'date' column to datetime
aqi_y_df['date'] = pd.to_datetime(aqi_y_df['date'], errors='coerce')
# Extract year from the 'date' column
aqi_y_df['year'] = aqi_y_df['date'].dt.year
# Convert 'aqi' column to float and round to the nearest integer
aqi_y_df['aqi'] = aqi_y_df['aqi'].astype(float).round()

# %% [markdown]
# Apply the AQI categories to the measurement

# %%
daily_aqi_long = aqi_y_df.copy()

# Apply the function to the dataframe
daily_aqi_long['aqi_category'] = daily_aqi_long['aqi'].apply(categorize_aqi)
daily_aqi_long
# Out:
#            date   aqi  year aqi_category
# 0    1998-01-01   6.0  1998         Good
# 1    1998-01-02  10.0  1998         Good
# 2    1998-01-03  11.0  1998         Good
# 3    1998-01-04  10.0  1998         Good
# 4    1998-01-05  11.0  1998         Good
# ...         ...   ...   ...          ...
# 8733 2021-12-27  25.0  2021         Good
# 8734 2021-12-28  28.0  2021         Good
# 8735 2021-12-29  36.0  2021         Good
# 8736 2021-12-30  35.0  2021         Good
# 8737 2021-12-31  33.0  2021         Good
#
# [8738 rows x 4 columns]

# %% [markdown]
# Get counts of days in AQI categories by year because we want to be able to predict the number of days in each category per year

# %%
# Group by year and category, then count occurrences
annual_aqi_long = daily_aqi_long.groupby(['year', 'aqi_category']).size().reset_index(name='count')

# Pivot the table to have categories as columns
annual_aqi_wide = annual_aqi_long.pivot(index='year', columns='aqi_category', values='count').fillna(0).astype(int)

# %% [markdown]
# make sure year is the index

# %%
# Drop the index level of column names
annual_aqi_wide.columns.name = None
annual_aqi_wide = annual_aqi_wide.reset_index()
# Out:
#     year  Good  Moderate  Unhealthy for sensitive grps
# 0   1998   331        28                             0
# 1   1999   311        52                             2
# 2   2000   306        54                             3
# 3   2001   329        36                             0
# 4   2002   335        30                             0
# 5   2003   307        56                             2
# 6   2004   245       118                             2
# 7   2005   238       125                             2
# 8   2006   229       136                             0
# 9   2007   228       126                            11
# 10  2008   270        96                             0
# 11  2009   303        61                             1
# 12  2010   282        83                             0
# 13  2011   265       100                             0
# 14  2012   317        49                             0
# 15  2013   336        28                             1
# ...

# %%
# Ensure 'year' is the index and set it as a datetime index with Year Start frequency
annual_aqi_wide["year"] = pd.to_datetime(annual_aqi_wide["year"], format="%Y")
annual_aqi_wide.set_index("year", inplace=True)
annual_aqi_wide.index.freq = "YS"

# %%
annual_aqi_wide
# Out:
#             Good  Moderate  Unhealthy for sensitive grps
# year
# 1998-01-01   331        28                             0
# 1999-01-01   311        52                             2
# 2000-01-01   306        54                             3
# 2001-01-01   329        36                             0
# 2002-01-01   335        30                             0
# 2003-01-01   307        56                             2
# 2004-01-01   245       118                             2
# 2005-01-01   238       125                             2
# 2006-01-01   229       136                             0
# 2007-01-01   228       126                            11
# 2008-01-01   270        96                             0
# 2009-01-01   303        61                             1
# 2010-01-01   282        83                             0
# 2011-01-01   265       100                             0
# 2012-01-01   317        49                             0
# ...

# %% [markdown]
# ## Run the model on the aqi categories

# %%
model_df = annual_aqi_wide.copy()

# %%
# Initialize dictionaries for models and forecasts
arima_models = {}
forecasts = {}

for category in model_df.columns:
    # Fit ARIMA model for the category
    model = ARIMA(model_df[category], order=(1, 1, 0))  # Adjust order as needed
    arima_fitted = model.fit()

    # Forecast for the next 20 years
    forecast = arima_fitted.get_forecast(steps=20)
    forecast_summary = forecast.summary_frame(alpha=0.05)

    # Generate forecast dates
    forecast_dates = pd.date_range(
        start=model_df.index[-1] + pd.DateOffset(years=1),
        periods=20,
        freq="YS"
    )

    # Store the forecast data
    forecasts[category] = forecast_summary

# %%
# Check the structure of each forecast in the dictionary
for category, forecast in forecasts.items():
    print(f"{category}: {forecast.columns}")
# Out:
# Good: Index(['mean', 'mean_se', 'mean_ci_lower', 'mean_ci_upper'], dtype='object', name='Good')
# Moderate: Index(['mean', 'mean_se', 'mean_ci_lower', 'mean_ci_upper'], dtype='object', name='Moderate')
# Unhealthy for sensitive grps: Index(['mean', 'mean_se', 'mean_ci_lower', 'mean_ci_upper'], dtype='object', name='Unhealthy for sensitive grps')

# %%
# Combine forecasts into a single dataframe
combined_forecast = pd.concat(forecasts, axis=1)

combined_forecast.columns = pd.MultiIndex.from_tuples(
    [(category, col) for category in forecasts.keys() for col in ["mean", "mean_se", "mean_ci_lower", "mean_ci_upper"]]
)

# combined_forecast.to_csv('aqi_category_forecasts.csv')

# %%
# Add totals for each year across all categories
combined_forecast['Total Days'] = combined_forecast.xs('mean', axis=1, level=1).sum(axis=1)

# Calculate yearly trends for key categories
category_trends = combined_forecast.xs('mean', axis=1, level=1)

# %%
# Create the plot
plt.figure(figsize=(14, 8))

for category in model_df.columns:
    # Get the color from AQI_CATEGORIES
    color = AQI_CATEGORIES[category]['color']

    # Historical data
    plt.plot(
        model_df.index,
        model_df[category],
        label=f"{category} (Historical)",
        marker="o",
        color=color
    )

    # Forecasted data
    forecast_summary = forecasts[category]
    forecast_dates = pd.date_range(
        start=model_df.index[-1] + pd.DateOffset(years=1),
        periods=20,
        freq="YS"
    )
    plt.plot(
        forecast_dates,
        forecast_summary["mean"],
        label=f"{category} (Forecast)",
        linestyle="--",
        color=color
    )
    plt.fill_between(
        forecast_dates,
        forecast_summary["mean_ci_lower"],
        forecast_summary["mean_ci_upper"],
        alpha=0.2,
        label=f"{category} (95% CI)",
        color=color
    )

# Finalize the plot
plt.title("Historical and Forecasted Days per AQI Category")
plt.xlabel("Year")
plt.ylabel("Number of Days")
plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
plt.grid()


plt.tight_layout()
filepath = gen_png_savepath('AQI_Category_models.png')
plt.savefig(filepath)

plt.show()

# %%
category_trends
# Out:
#                   Good   Moderate  Unhealthy for sensitive grps
# 2022-01-01  320.677563  44.112898                      0.568071
# 2023-01-01  320.458959  44.267716                      0.245366
# 2024-01-01  320.422822  44.289253                      0.428685
# 2025-01-01  320.416849  44.292249                      0.324547
# 2026-01-01  320.415861  44.292666                      0.383705
# 2027-01-01  320.415698  44.292724                      0.350099
# 2028-01-01  320.415671  44.292732                      0.369190
# 2029-01-01  320.415667  44.292733                      0.358345
# 2030-01-01  320.415666  44.292733                      0.364506
# 2031-01-01  320.415666  44.292733                      0.361006
# 2032-01-01  320.415666  44.292733                      0.362994
# 2033-01-01  320.415666  44.292733                      0.361865
# 2034-01-01  320.415666  44.292733                      0.362506
# 2035-01-01  320.415666  44.292733                      0.362142
# ...

# %% [markdown]
# INCORPORATING AQI BEHAVIOR DATA

# %%
annual_attendance_all_parks = parks_df["Annual Attendance"].sum()
daily_attendance_all_parks = annual_attendance_all_parks/365

# %%
daily_attendance_all_parks
# Out:
# 10999.65205479452

# %%
beh_thresh_df['daily_attendance_impact'] = beh_thresh_df['Adjusted Percentage']* (daily_attendance_all_parks/100)

# %%
cats_df = pd.read_csv(r"C:\Users\clark.roll\python coding\code_personal\Data512\Course Project\Data Analysis and Modeling\AQI_CATS.csv")

# %%
cats_df
# Out:
#                         Category     Action  Percentage of "yes"  \
# 0                           Good     Reduce             0.192926
# 1                       Moderate     Reduce            12.733119
# 2   Unhealthy for sensitive grps     Reduce            52.926045
# 3                      Unhealthy     Reduce            26.881029
# 4                 Very unhealthy     Reduce             3.794212
# 5                      Hazardous     Reduce             0.771704
# 6                           Good  Eliminate             0.192308
# 7                       Moderate  Eliminate             2.371795
# 8   Unhealthy for sensitive grps  Eliminate            22.179487
# 9                      Unhealthy  Eliminate            47.435897
# 10                Very unhealthy  Eliminate            19.487179
# 11                     Hazardous  Eliminate             5.705128
#
#     threshold_min  threshold_max  Percentage of total  \
# 0               0             50             0.138907
# ...

# %%
cats_df['daily_attendance_impact'] = daily_attendance_all_parks * (cats_df['percentage with previous categories adjustment']/100)
cats_df
# Out:
#                         Category     Action  Percentage of "yes"  \
# 0                           Good     Reduce             0.192926
# 1                       Moderate     Reduce            12.733119
# 2   Unhealthy for sensitive grps     Reduce            52.926045
# 3                      Unhealthy     Reduce            26.881029
# 4                 Very unhealthy     Reduce             3.794212
# 5                      Hazardous     Reduce             0.771704
# 6                           Good  Eliminate             0.192308
# 7                       Moderate  Eliminate             2.371795
# 8   Unhealthy for sensitive grps  Eliminate            22.179487
# 9                      Unhealthy  Eliminate            47.435897
# 10                Very unhealthy  Eliminate            19.487179
# 11                     Hazardous  Eliminate             5.705128
#
#     threshold_min  threshold_max  Percentage of total  \
# 0               0             50             0.138907
# ...

# %%
cats_elim = cats_df.loc[cats_df['Action']=="Eliminate"].copy()

# %%
cats_elim["direct_econ_loss"] = cats_elim["daily_attendance_impact"] * 162.13

# %%
cats_elim
# Out:
#                         Category     Action  Percentage of "yes"  \
# 6                           Good  Eliminate             0.192308
# 7                       Moderate  Eliminate             2.371795
# 8   Unhealthy for sensitive grps  Eliminate            22.179487
# 9                      Unhealthy  Eliminate            47.435897
# 10                Very unhealthy  Eliminate            19.487179
# 11                     Hazardous  Eliminate             5.705128
#
#     threshold_min  threshold_max  Percentage of total  \
# 6               0             50             0.138462
# 7              51            100             1.707692
# 8             101            150            15.969231
# 9             151            200            34.153846
# 10            201            300            14.030769
# 11            301           1000             4.107692
#
#     percentage with previous categories adjustment  daily_attendance_impact  \
# ...

# %%
cats_elim_rnd  = cats_elim.round(2)

# %%
cats_df
# Out:
#                         Category     Action  Percentage of "yes"  \
# 0                           Good     Reduce             0.192926
# 1                       Moderate     Reduce            12.733119
# 2   Unhealthy for sensitive grps     Reduce            52.926045
# 3                      Unhealthy     Reduce            26.881029
# 4                 Very unhealthy     Reduce             3.794212
# 5                      Hazardous     Reduce             0.771704
# 6                           Good  Eliminate             0.192308
# 7                       Moderate  Eliminate             2.371795
# 8   Unhealthy for sensitive grps  Eliminate            22.179487
# 9                      Unhealthy  Eliminate            47.435897
# 10                Very unhealthy  Eliminate            19.487179
# 11                     Hazardous  Eliminate             5.705128
#
#     threshold_min  threshold_max  Percentage of total  \
# 0               0             50             0.138907
# ...

# %%
# Set seaborn style to 'whitegrid'
sns.set_style("whitegrid")

# %%
# Define color palette for AQI categories
aqi_palette = {
    "Good": "green",
    "Moderate": "yellow",
    "Unhealthy for sensitive grps": "orange",
    "Unhealthy": "red",
    "Very unhealthy": "purple",
    "Hazardous": "maroon"
}

# Define hatches for actions
hatches = {'Reduce': '//', 'Eliminate': '.'}

# Set up the figure
plt.figure(figsize=(14, 8))

# Create the barplot
axis = sns.barplot(
    x='Category',
    y='daily_attendance_impact',
    hue='Action',
    data=cats_df,
    dodge=True
)

# Apply colors and hatches to bars
patch_index = 0
for index, row in cats_df.iterrows():
    bar_patch = axis.patches[patch_index]
    category = row['Category']
    action = row['Action']

    # Set color and hatch
    bar_patch.set_facecolor(aqi_palette[category])
    bar_patch.set_hatch(hatches[action])

    patch_index += 1

# Add percentage labels above bars
for bar_container in axis.containers:
    axis.bar_label(bar_container, fmt='%.0f', label_type='edge', padding=3)

# Customize the plot
plt.xlabel('AQI Category')
plt.ylabel('Daily Attendance Impact')
plt.title('Impact of AQI on Park Attendance by Action')
plt.xticks(rotation=45)
plt.legend(title='Action', loc='upper right')

# Add custom legend for hatches
reduce_patch = mpatches.Patch(facecolor='white', edgecolor='black', hatch=hatches['Reduce'], label='Reduce')
eliminate_patch = mpatches.Patch(facecolor='white', edgecolor='black', hatch=hatches['Eliminate'], label='Eliminate')
plt.legend(handles=[reduce_patch, eliminate_patch], title='Action', loc='upper right')


# Display the plot and save the figure
plt.tight_layout()
file_path = 'Impact_of_aqi_on_park_attendance.png'
plt.savefig(file_path)

# Display the plot
plt.tight_layout()
plt.show()

# %%
cats_df.to_csv("CAT_with_attend_impact.csv", index = False)

# %%
# Adjust percentages to account for the full population
beh_thresh_df["Adjusted Percentage"] = beh_thresh_df["Percentage"] * 0.72 
beh_thresh_df
# Out:
#                     AQI Category     Action  Percentage  threshold_min  \
# 0                           Good     Reduce    0.192926              0
# 1                       Moderate     Reduce   12.733119             51
# 2   Unhealthy for sensitive grps     Reduce   52.926045            101
# 3                      Unhealthy     Reduce   26.881029            151
# 4                 Very unhealthy     Reduce    3.794212            201
# 5                      Hazardous     Reduce    0.771704            301
# 6                           Good  Eliminate    0.192308              0
# 7                       Moderate  Eliminate    2.371795             51
# 8   Unhealthy for sensitive grps  Eliminate   22.179487            101
# 9                      Unhealthy  Eliminate   47.435897            151
# 10                Very unhealthy  Eliminate   19.487179            201
# 11                     Hazardous  Eliminate    5.705128            301
#
# ...

# %%
beh_thresh_df
# Out:
#                     AQI Category     Action  Percentage  threshold_min  \
# 0                           Good     Reduce    0.192926              0
# 1                       Moderate     Reduce   12.733119             51
# 2   Unhealthy for sensitive grps     Reduce   52.926045            101
# 3                      Unhealthy     Reduce   26.881029            151
# 4                 Very unhealthy     Reduce    3.794212            201
# 5                      Hazardous     Reduce    0.771704            301
# 6                           Good  Eliminate    0.192308              0
# 7                       Moderate  Eliminate    2.371795             51
# 8   Unhealthy for sensitive grps  Eliminate   22.179487            101
# 9                      Unhealthy  Eliminate   47.435897            151
# 10                Very unhealthy  Eliminate   19.487179            201
# 11                     Hazardous  Eliminate    5.705128            301
#
# ...

# %%
reduced_df = beh_thresh_df.loc[beh_thresh_df["Action"] == "Reduce"]
elim_df = beh_thresh_df.loc[beh_thresh_df["Action"] == "Eliminate"]

# %%
reduced_df['daily_attendance_impact'] =

# %%
beh_thresh_df['reduced_daily_attendance']

# %%
# Extract Reduce action percentages into a dictionary
attendance_reduction = (
    beh_thresh_df[beh_thresh_df["Action"] == "Reduce"]
    .set_index("AQI Category")["Adjusted Percentage"]
    .to_dict()
)

# %%
# Separate Reduce and Eliminate actions
reduce_thresholds = beh_thresh_df[beh_thresh_df["Action"] == "Reduce"].set_index("AQI Category")["Adjusted Percentage"].to_dict()
eliminate_thresholds = beh_thresh_df[beh_thresh_df["Action"] == "Eliminate"].set_index("AQI Category")["Adjusted Percentage"].to_dict()

# Initialize adjusted dataframes
reduced_days = category_trends.copy()
eliminated_days = category_trends.copy()

# Apply adjustments
for category in category_trends.columns:
    reduced_days[category] = category_trends[category] * reduce_thresholds.get(category, 0)
    eliminated_days[category] = category_trends[category] * eliminate_thresholds.get(category, 0)

# %%
# Calculate total reductions for each year
total_reduced_days = reduced_days.sum(axis=1)
total_eliminated_days = eliminated_days.sum(axis=1)

# Combine results into a summary dataframe
behavior_summary = pd.DataFrame({
    "Total Reduced Days": total_reduced_days,
    "Total Eliminated Days": total_eliminated_days
})

# %%
plt.figure(figsize=(14, 8))
plt.plot(behavior_summary.index, behavior_summary["Total Reduced Days"], label="Reduced Activity Days", color="blue")
plt.plot(behavior_summary.index, behavior_summary["Total Eliminated Days"], label="Eliminated Activity Days", color="red")
plt.title("Projected Outdoor Activity Reductions Based on AQI")
plt.xlabel("Year")
plt.ylabel("Number of Days")
plt.legend()
plt.grid()
plt.tight_layout()
plt.tight_layout()
filepath = gen_png_savepath('Projected Outdoor Activity Reductions based on AQI.png')
plt.savefig(filepath)

plt.show()

# %%
parks_df
# Out:
#     Park District                                      Park Annual Attendance  \
# 0               1                  Alfred B. Maclay Gardens            84,260
# 1               1                                Bald Point             38963
# 2               1                               Big Lagoon             116435
# 3               1                Blackwater Heritage Trail             159609
# 4               1                         Blackwater River              82890
# 5               1                               Camp Helen              57380
# 6               1                                Deer Lake              26019
# 7               1                        St. George Island             215427
# 8               1                           Econfina River              10668
# 9               1                             Eden Gardens              42695
# 10              1                          Wakulla Springs             166551
# ...

# %%
annual_attendance_all_parks = parks_df["Annual Attendance"].sum()
daily_attendance_all_parks = annual_attendance_all_parks/365

# %%
moderate_reduction_percentage = beh_thresh_df.loc[(beh_thresh_df["AQI Category"] == "Moderate") & (beh_thresh_df["Action"] == "Reduce"),"Adjusted Percentage"].values[0]

# %%
parks_df["Annual Attendance"] = pd.to_numeric(parks_df["Annual Attendance"], errors='coerce')

# %%
parks_df["Daily Attendance"] = parks_df["Annual Attendance"] / 365

# %%
# Extract mean forecast values from combined_forecast
forecast_means = combined_forecast.xs("mean", axis=1, level=1)

# %%
# Define relevant categories
relevant_categories = ["Moderate", "Unhealthy for sensitive grps"]

# Initialize a dictionary for reduced attendance per park
parks_reductions = {}

for col_type in ["mean", "min", "max"]:  # For mean, lower, and upper forecasts
    parks_reductions[col_type] = {}

    for category in relevant_categories:
        # Get forecasted AQI days and clip to non-negative values
        forecast_data = forecast_means[category] if col_type == "mean" else combined_forecast[(category, f"mean_ci_{col_type}")]
        forecast_data = forecast_data.clip(lower=0)  # Ensure AQI days are non-negative

        # Calculate park-level attendance losses for the category
        for park in parks_df["Park"]:
            if park not in parks_reductions[col_type]:
                parks_reductions[col_type][park] = 0  # Initialize entry

            # Fetch the park's daily attendance
            park_daily_attendance = parks_df.loc[parks_df["Park"] == park, "Daily Attendance"].values[0]

            # Add attendance losses for this category
            parks_reductions[col_type][park] += forecast_data.sum() * park_daily_attendance * attendance_reduction[category]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\anaconda\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mean_ci_min'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File index.pyx:768, in pandas._libs.index.BaseMultiIndexCodesEngine.get_loc()
#
# ...

# %%
# Create a summary dataframe for park-level impacts
parks_impact_summary = parks_df.copy()

for col_type in ["mean", "min", "max"]:
    total_losses = []
    adjusted_attendances = []

    for park in parks_df["Park"]:
        # Sum total losses for this park
        park_loss = parks_reductions[col_type][park].sum()
        total_losses.append(park_loss)
        
        # Calculate adjusted attendance
        annual_attendance = parks_df.loc[parks_df["Park"] == park, "Annual Attendance"].values[0]
        adjusted_attendance = annual_attendance - park_loss
        adjusted_attendances.append(adjusted_attendance)

    # Add columns for total loss and adjusted attendance
    parks_impact_summary[f"Total Loss ({col_type})"] = total_losses
    parks_impact_summary[f"Adjusted Attendance ({col_type})"] = adjusted_attendances

# %%
# Initialize attendance and reduction assumptions
annual_park_attendance = 100000  # Example total annual park attendance
days_in_year = 365  # Assuming no leap year
daily_attendance = annual_park_attendance / days_in_year

# Attendance reduction percentages by AQI category
attendance_reduction = {
    "Good": 0.0,
    "Moderate": 0.1,  # 10% drop
    "Unhealthy for sensitive grps": 0.3,  # 30% drop
    "Unhealthy": 0.5,  # 50% drop
    "Very unhealthy": 0.7,  # 70% drop
    "Hazardous": 0.9  # 90% drop
}

# Calculate attendance losses for mean, lower, and upper forecasts
attendance_losses = {"mean": {}, "min": {}, "max": {}}

for col_type in ["mean", "mean_ci_lower", "mean_ci_upper"]:
    for category in forecast_means.columns:
        # Get the relevant forecast data, ensuring no negative AQI days
        forecast_data = forecast_means[category] if col_type == "mean" else combined_forecast[(category, col_type)]
        forecast_data = forecast_data.clip(lower=0)  # Ensure AQI days can't be negative

        # Calculate attendance losses for this forecast type
        attendance_losses[col_type][category] = (
            forecast_data * daily_attendance * attendance_reduction[category]
        )

# Summarize losses and adjusted attendance for mean, min, and max
attendance_summary = pd.DataFrame(index=forecast_means.index)

for col_type, losses in attendance_losses.items():
    # Sum losses across all AQI categories
    total_loss = pd.DataFrame(losses).sum(axis=1)
    
    # Add to summary dataframe
    attendance_summary[f"Total Loss ({col_type})"] = total_loss
    attendance_summary[f"Adjusted Attendance ({col_type})"] = annual_park_attendance - total_loss

# Display the summary dataframe
import ace_tools as tools; tools.display_dataframe_to_user(name="Park Attendance Impact Summary", dataframe=attendance_summary)

# %%
def calculate_reduction_factor(aqi_value: float,
                               thresholds_df: pd.DataFrame,
                               action_type: str
                              ) -> float:
    """
    Calculate the reduction factor for a given AQI value.

    Parameters
    ----------
    aqi_value : float
        The AQI value for the day.
    thresholds_df : pd.DataFrame
        DataFrame containing AQI thresholds, actions, and percentages.
        Must have columns: ['threshold_min', 'threshold_max', 'Action', 'Percentage'].
    action_type : str
        The action type ('Reduce' or 'Eliminate').

    Returns
    -------
    float
        The reduction factor (0 to 1) for the specified AQI value and action type.
    """
    relevant_thresholds = thresholds_df[thresholds_df["Action"] == action_type]
    for _, row in relevant_thresholds.iterrows():
        if row["threshold_min"] <= aqi_value < row["threshold_max"]:
            return row["Percentage"] / 100  # Convert percentage to decimal
    return 0.0  # No reduction if AQI is out of all defined ranges

# %%
# Apply the reduction factor calculation for both "Reduce" and "Eliminate" actions
aqi_y_df["reduce_factor"] = aqi_y_df["aqi"].apply(
    lambda x: calculate_reduction_factor(x, aqi_cats_perc_df, "Reduce")
)
aqi_y_df["eliminate_factor"] = aqi_y_df["aqi"].apply(
    lambda x: calculate_reduction_factor(x, aqi_cats_perc_df, "Eliminate")
)

# %%
# Add a "Year" column to the daily AQI dataset
aqi_y_df["date"] = pd.to_datetime(aqi_y_df["date"])
aqi_y_df["Year"] = aqi_y_df["date"].dt.year

# Initialize category counts columns for each AQI category
for _, row in aqi_cats_perc_df.iterrows():
    category_name = row["AQI Category"]
    aqi_y_df[category_name] = aqi_y_df["aqi"].apply(
        lambda x: 1 if row["threshold_min"] <= x < row["threshold_max"] else 0
    )

# %%
# Group by year to calculate annual summaries
annual_aqi_summary = aqi_y_df.groupby("Year").agg(
    average_reduce_factor=("reduce_factor", "mean"),
    average_eliminate_factor=("eliminate_factor", "mean"),
    **{
        f"{row['AQI Category']} Days": (row["AQI Category"], "sum")
        for _, row in aqi_cats_perc_df.iterrows()
    }).reset_index()

annual_aqi_summary["Total Days"] = aqi_y_df.groupby("Year")["date"].count().values

# %%
# Out:
#                     AQI Category     Action  Percentage  threshold_min  \
# 0                           Good     Reduce    0.192926              0
# 1                       Moderate     Reduce   12.733119             51
# 2   Unhealthy for sensitive grps     Reduce   52.926045            101
# 3                      Unhealthy     Reduce   26.881029            151
# 4                 Very unhealthy     Reduce    3.794212            201
# 5                      Hazardous     Reduce    0.771704            301
# 6                           Good  Eliminate    0.192308              0
# 7                       Moderate  Eliminate    2.371795             51
# 8   Unhealthy for sensitive grps  Eliminate   22.179487            101
# 9                      Unhealthy  Eliminate   47.435897            151
# 10                Very unhealthy  Eliminate   19.487179            201
# 11                     Hazardous  Eliminate    5.705128            301
#
#     threshold_max
# 0              50
# ...

# %%
annual_aqi_summary
# Out:
#     Year  average_reduce_factor  average_eliminate_factor  Good Days  \
# 0   1998               0.011699                  0.003612        329
# 1   1999               0.022674                  0.006222        309
# 2   2000               0.024581                  0.006906        304
# 3   2001               0.013600                  0.003943        329
# 4   2002               0.012236                  0.003714        335
# 5   2003               0.024043                  0.006456        304
# 6   2004               0.044609                  0.009991        235
# 7   2005               0.047717                  0.010544        229
# 8   2006               0.048258                  0.009932        220
# 9   2007               0.058567                  0.015223        219
# 10  2008               0.034099                  0.007484        265
# 11  2009               0.022878                  0.005850        292
# 12  2010               0.029351                  0.006637        273
# ...

# %% [markdown]
# MODEL EXTENSION: PREDICTING AQI

# %%
# Handle missing AQI data using linear interpolation
aqi_full_year_df = aqi_y_df.copy()
aqi_full_year_df.rename(columns={"date_local":"date"}, inplace=True)

# %%
# Ensure 'date' column is datetime and set as index
aqi_full_year_df["date"] = pd.to_datetime(aqi_full_year_df["date"])
aqi_full_year_df.set_index("date", inplace=True)

# Generate a complete daily date range
full_date_range = pd.date_range(
    start=aqi_full_year_df.index.min(),
    end=aqi_full_year_df.index.max(),
    freq="D"
)

# Reindex to ensure daily frequency, filling missing dates with NaN
aqi_full_year_df = aqi_full_year_df.reindex(full_date_range)

# Rename the index to 'date' for clarity
aqi_full_year_df.index.name = "date"

# Interpolate missing values
aqi_full_year_df["aqi"] = aqi_full_year_df["aqi"].interpolate(method="time")

# Ensure index is now consistent with daily frequency
aqi_full_year_df.index.freq = "D"

# %%
# Aggregate AQI data into weekly averages
weekly_aqi = aqi_full_year_df.resample("W").mean()

# Reset the index for clarity
weekly_aqi.reset_index(inplace=True)
weekly_aqi.rename(columns={"date": "Week"}, inplace=True)

# %%
# Check if all missing values are resolved
remaining_missing = aqi_full_year_df["aqi"].isnull().sum()
remaining_missing
# Out:
# 0

# %%
aqi_full_year_df
# Out:
#                   aqi
# date
# 1998-01-01   6.000000
# 1998-01-02  10.000000
# 1998-01-03  11.000000
# 1998-01-04  10.000000
# 1998-01-05  11.000000
# ...               ...
# 2021-12-27  25.000000
# 2021-12-28  28.000000
# 2021-12-29  35.500000
# 2021-12-30  34.666667
# 2021-12-31  33.000000
#
# [8766 rows x 1 columns]

# %%
# Refit the SARIMA model with proper frequency
sarima_model = SARIMAX(
    aqi_full_year_df["aqi"],
    order=(1, 1, 1),  # ARIMA component
    seasonal_order=(1, 1, 1, 365),  # Seasonal component with yearly seasonality
    enforce_stationarity=False,
    enforce_invertibility=False,
)
sarima_fitted = sarima_model.fit(disp=False)

# Project AQI data 20 years into the future
forecast_sarima = sarima_fitted.get_forecast(steps=20 * 365)  # Daily projections
forecast_sarima_summary = forecast_sarima.summary_frame(alpha=0.05)  # 95% CI

# Generate future dates for 20 years
future_dates_sarima = pd.date_range(
    start=aqi_full_year_df.index[-1] + pd.Timedelta(days=1),
    periods=20 * 365,
    freq="D"
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 16
#       1 # # Reassigning frequency to the date index for the time series
#       2 # aqi_full_year_df.index = pd.date_range(
#       3 #     start=aqi_full_year_df.index.min(),
#    (...)
#       7
#       8 # Refit the SARIMA model with proper frequency
#       9 sarima_model = SARIMAX(
#      10     aqi_full_year_df["aqi"],
#      11     order=(1, 1, 1),  # ARIMA component
#    (...)
#      14     enforce_invertibility=False,
#      15 )
# ---> 16 sarima_fitted = sarima_model.fit(disp=False)
#      18 # Project AQI data 20 years into the future
#      19 forecast_sarima = sarima_fitted.get_forecast(steps=20 * 365)  # Daily projections
#
# ...

# %%
# Fit an ARIMA model to the cleaned AQI data
arima_model = ARIMA(aqi_full_year_df["aqi"], order=(1, 1, 0))  # ARIMA(1,1,0)
arima_fitted = arima_model.fit()

# Project AQI data 20 years into the future
forecast = arima_fitted.get_forecast(steps=20 * 365)  # Daily projections for 20 years
forecast_summary = forecast.summary_frame(alpha=0.05)  # 95% confidence intervals

# Plot historical and projected AQI with confidence intervals
plt.figure(figsize=(14, 7))
plt.plot(aqi_full_year_df.index, aqi_full_year_df["aqi"], label="Historical AQI")
plt.plot(
    forecast_summary.index, forecast_summary["mean"], label="Projected AQI"
)
plt.fill_between(
    forecast_summary.index,
    forecast_summary["mean_ci_lower"],
    forecast_summary["mean_ci_upper"],
    color="gray",
    alpha=0.2,
    label="95% Confidence Interval",
)
plt.title("Projected Daily AQI with 95% Confidence Intervals")
plt.xlabel("Date")
plt.ylabel("AQI")
plt.legend()
plt.grid()
plt.show()
# Out:
# C:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# ...

# %%
# Update forecast index with future dates
forecast_sarima_summary.index = future_dates_sarima

# Plot historical and projected AQI with SARIMA adjustments
plt.figure(figsize=(14, 7))
plt.plot(aqi_full_year_df.index, aqi_full_year_df["aqi"], label="Historical AQI")
plt.plot(
    forecast_sarima_summary.index, forecast_sarima_summary["mean"], label="Projected AQI"
)
plt.fill_between(
    forecast_sarima_summary.index,
    forecast_sarima_summary["mean_ci_lower"],
    forecast_sarima_summary["mean_ci_upper"],
    color="gray",
    alpha=0.2,
    label="95% Confidence Interval",
)
plt.title("Projected Daily AQI with SARIMA Adjustments and 95% Confidence Intervals")
plt.xlabel("Date")
plt.ylabel("AQI")
plt.legend()
plt.grid()
plt.show()

# %%
annual_aqi_summary.to_csv('annual_reduction_factor_summary.csv', index = False)

# %% [markdown]
# Plan to Estimate Park Attendance Impacts
# Baseline Attendance:
#
# Use the annual attendance data from parks_df.
# Convert the Annual Attendance column to numeric if necessary.
# Apply Reduction Factors:
#
# Use the annual reduction factors (average_reduce_factor and average_eliminate_factor) to estimate the percentage reduction in attendance.
# Adjusted Attendance:

# %%
# Step 1: Prepare a DataFrame to hold results for each park
parks_summary = parks_df.copy()

# Initialize columns for estimated reduction and adjusted attendance for each park
parks_summary["Estimated Reduction"] = 0.0
parks_summary["Adjusted Attendance"] = 0.0

# Step 2: Calculate impacts for each park
for _, annual_row in annual_aqi_summary.iterrows():
    # Extract the year's reduction factors
    year = annual_row["Year"]
    reduce_factor = annual_row["average_reduce_factor"]
    eliminate_factor = annual_row["average_eliminate_factor"]
    total_factor = reduce_factor + eliminate_factor

    # Apply reduction factors to each park's annual attendance
    parks_summary[f"Estimated Reduction {int(year)}"] = (
        parks_summary["Annual Attendance"] * total_factor
    )
    parks_summary[f"Adjusted Attendance {int(year)}"] = (
        parks_summary["Annual Attendance"] 
        - parks_summary[f"Estimated Reduction {int(year)}"]
    )

# %%
parks_summary
# Out:
#     Park District                                      Park  \
# 0               1                  Alfred B. Maclay Gardens
# 1               1                                Bald Point
# 2               1                               Big Lagoon
# 3               1                Blackwater Heritage Trail
# 4               1                         Blackwater River
# 5               1                               Camp Helen
# 6               1                                Deer Lake
# 7               1                        St. George Island
# 8               1                           Econfina River
# 9               1                             Eden Gardens
# 10              1                          Wakulla Springs
# 11              1                           Falling Waters
# 12              1                           Florida Caverns
# 13              1                  Fred Gannon Rocky Bayou
# 14              1                            Grayton Beach
# ...

# %%
# Calculate total annual attendance for all parks
total_annual_attendance = parks_df["Annual Attendance"].sum()

# Step 2: Estimate attendance impacts for all parks combined
annual_aqi_summary["Estimated Reduction"] = (
    total_annual_attendance
    * (annual_aqi_summary["average_reduce_factor"] + annual_aqi_summary["average_eliminate_factor"])
)

annual_aqi_summary["Adjusted Attendance"] = (
    total_annual_attendance - annual_aqi_summary["Estimated Reduction"]
)

# %%
total_annual_attendance
# Out:
# 4235880.0

# %%
# Remove latitude and longitude columns and compute average AQI per date
daily_aqi_df["date_local"] = pd.to_datetime(daily_aqi_df["date_local"])  # Ensure dates are in datetime format
avg_daily_aqi_df = daily_aqi_df.groupby("date_local", as_index=False).agg({"aqi": "mean"})

# %%
avg_daily_aqi_df.rename(columns={"date_local":"date"}, inplace = True)

# %%
avg_daily_aqi_df.to_csv("avg_daily_aqi.csv", index=False)

# %%
## Preprocess our survey data

# just want people who do outdoor activities
# and people who said they do reduce their activities due to smoke
filtered_survey = survey_df[
    (survey_df['outside_activity_frequency'] != "Never") &  # Exclude those who never do outdoor activities
    (survey_df['reduced_outdoor_activities_due_to_smoke'] == "Yes")  # Include only those who reduce activity
]

# Filter out rows with invalid or missing thresholds
cleaned_survey = filtered_survey.dropna(subset=['min_aqi_reduce_activity', 'min_aqi_eliminate_activity'])

# %%
# Grouping by thresholds for 'reduce' and 'eliminate'
reduce_group_summary = cleaned_survey['min_aqi_reduce_activity'].value_counts(normalize=True).sort_index()
eliminate_group_summary = cleaned_survey['min_aqi_eliminate_activity'].value_counts(normalize=True).sort_index()

# Combine summaries into a single dataframe for better visualization
threshold_summary = pd.DataFrame({
    "Reduce (%)": (reduce_group_summary * 100).round(2),
    "Eliminate (%)": (eliminate_group_summary * 100).round(2)
}).fillna(0)

# Display the threshold summary
threshold_summary
# Out:
#                                            Reduce (%)  Eliminate (%)
# 0-50:\nGood                                      0.21           0.21
# 101-150:\nUnhealthy for\n Sensitive Grps.       52.89          20.66
# 151-200:\nUnhealthy                             27.55          48.42
# 201-300:\nVery Unhealthy                         3.86          19.83
# 301+:\nHazardous                                 0.69           5.79
# 51-100:\nModerate                               12.12           2.41
# I am not familiar with this rating               2.69           2.69

# %%
Reduction Factor Calculation
The reduction factor represents the proportion of the population that would reduce or eliminate outdoor activities on a given day based on the AQI value for that day.

Steps:

For each AQI value:
Match the value to the appropriate range (threshold_min, threshold_max) in the AQI thresholds dataset (aqi_cats_perc_df).
Identify whether the action is "Reduce" or "Eliminate."
Use the Percentage value corresponding to the matched range. Convert this percentage into a decimal by dividing by 100.
If the AQI value does not fall within any defined range, the reduction factor is set to 0.
