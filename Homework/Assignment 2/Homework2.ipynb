# %% [markdown]
# ### Imports

# %%
import os
import time
import json
import requests
import urllib.parse
import pandas as pd
from typing import Any, Dict, List, Optional

# %% [markdown]
# ### Constants

# %% [markdown]
# 1. API endpoints and models

# %%
# The LiftWing ORES API endpoint and prediction model
API_ORES_LIFTWING_ENDPOINT = "https://api.wikimedia.org/service/lw/inference/v1/models/{model_name}:predict"
API_ORES_EN_QUALITY_MODEL = "enwiki-articlequality"

# The basic English Wikipedia API endpoint
API_HEADER_AGENT = 'User-Agent'
API_ENWIKIPEDIA_ENDPOINT = "https://en.wikipedia.org/w/api.php"

# %% [markdown]
# 2. Throttling and rate limits

# %%
# Assumed latency and throttling for LiftWing API
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = ((60.0 * 60.0) / 5000.0) - API_LATENCY_ASSUMED  # LiftWing key authorizes 5000 requests per hour

# Assumed throttling for Wikipedia API (100 requests/second)
API_THROTTLE_WAIT_ENWIKI = (1.0 / 100.0) - API_LATENCY_ASSUMED

# %% [markdown]
# 3. Request headers

# %%
# LiftWing API request headers with authorization
REQUEST_HEADER_TEMPLATE = {
    'User-Agent': "rollk@uw.edu, University of Washington, MSDS DATA 512 - AUTUMN 2024",
    'Content-Type': 'application/json',
    'Authorization': "Bearer {access_token}"
}

# Wikipedia API headers
REQUEST_HEADERS = {
    'User-Agent': 'rollk@uw.edu, University of Washington, MSDS DATA 512 - AUTUMN 2024'
}

# Template for request parameters (to be filled with actual values)
REQUEST_HEADER_PARAMS_TEMPLATE = {
    'email_address': "rollk@uw.edu",         # Your email address should go here
    'access_token': "eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9.....anuC2cjC67SIvr9H2Mjktp6TqxJbGFyjP1wxWvb7lv7PkP30c8VIyadng0iN8HXkQxpQb4A4j3N2JmiXXBxzNKBtf94WuAp9rCh0dgR-Gmj6CdqoWGrNglKJB_dFK4NboJi826shrrl7Zd2IRfpSzXzFsTCNvb6LiNp9n4-lYo_e3QPspyt6-YIYIU2D9J_Fnli2IdBPohH7Wm9Rj8AlcwgjURN_Msn44p56WI0QCCS5Z8FAEEZYhHMZT4-d_q8semz7dsr6Va_B9IvmJ8a-L7JVsMo1IxtZ1DW7V-XIkB-dEzDFNQk41nH680IhtHFqhOpBYab0217-qDlXVB2ySSpIjFLmAntx0uUk5urdXZY6Kmu521E6Shxb8LVRD9jCHvkXMy75EnAhIexYuw4aO6wB5Qr6Zwp4NHCfpg05dU9mYR5FUHeFEw2hxKX4JtXU6riZGRl60AZDcaYOK0yw2IOQ_X9QK1l32Cb7IiikQb1pWCg2tKvBsvleHYUi4l2GI8ehwsKG2Hn8S2JjsCUQzdJvUEOVqW15RBLxbZVrsipzgue8eHHF7C01iqaC9B8yYg0QtAVpbTrpM8u_UrC0E8tIyLRajSPy7Tzhhz4REYjpFKIS8HD3LYALZfjB-DbMy4w9O1xI6VZvM0mcoXGZ2X7BX3mIp0AIBW3OTpHlcEs"           # The access token you create will need to go here
}

# %% [markdown]
# 4. Article revisions and page information

# %%
# Template for ORES request payload (required data)
ORES_REQUEST_DATA_TEMPLATE = {
    "lang": "en",     # Required that it's English - we're scoring English Wikipedia revisions
    "rev_id": "",     # This request requires a revision id
    "features": True
}

# Additional page properties to request from Wikipedia API (optional)
PAGEINFO_EXTENDED_PROPERTIES = "talkid|url|watched|watchers"

# Template for making requests to the Wikipedia API for page information
PAGEINFO_PARAMS_TEMPLATE = {
    "action": "query",
    "format": "json",
    "titles": "",           # Single page title at a time
    "prop": "info",
    "inprop": PAGEINFO_EXTENDED_PROPERTIES
}

# %% [markdown]
# 5. ORES User authentication variables

# %%
# Variables to store user credentials for API requests
USERNAME = "DowntonCrabby"
ACCESS_TOKEN = "eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9.....anuC2cjC67SIvr9H2Mjktp6TqxJbGFyjP1wxWvb7lv7PkP30c8VIyadng0iN8HXkQxpQb4A4j3N2JmiXXBxzNKBtf94WuAp9rCh0dgR-Gmj6CdqoWGrNglKJB_dFK4NboJi826shrrl7Zd2IRfpSzXzFsTCNvb6LiNp9n4-lYo_e3QPspyt6-YIYIU2D9J_Fnli2IdBPohH7Wm9Rj8AlcwgjURN_Msn44p56WI0QCCS5Z8FAEEZYhHMZT4-d_q8semz7dsr6Va_B9IvmJ8a-L7JVsMo1IxtZ1DW7V-XIkB-dEzDFNQk41nH680IhtHFqhOpBYab0217-qDlXVB2ySSpIjFLmAntx0uUk5urdXZY6Kmu521E6Shxb8LVRD9jCHvkXMy75EnAhIexYuw4aO6wB5Qr6Zwp4NHCfpg05dU9mYR5FUHeFEw2hxKX4JtXU6riZGRl60AZDcaYOK0yw2IOQ_X9QK1l32Cb7IiikQb1pWCg2tKvBsvleHYUi4l2GI8ehwsKG2Hn8S2JjsCUQzdJvUEOVqW15RBLxbZVrsipzgue8eHHF7C01iqaC9B8yYg0QtAVpbTrpM8u_UrC0E8tIyLRajSPy7Tzhhz4REYjpFKIS8HD3LYALZfjB-DbMy4w9O1xI6VZvM0mcoXGZ2X7BX3mIp0AIBW3OTpHlcEs"

# %% [markdown]
# ## Functions

# %% [markdown]
# ##### Utility Functions

# %%
def prep_article_title(article_title: str) -> str:
    """
    Prepares the article title for use in a URL by replacing spaces with underscores
    and URL-encoding the title to ensure it is safe for use in API requests.

    Parameters
    ----------
    article_title : str
        The title of the Wikipedia article to be formatted.

    Returns
    -------
    str
        The formatted article title with spaces replaced by underscores and URL-encoded.
    """
    # Replace spaces in the article title with underscores,
    # as Wikipedia URLs use underscores instead of spaces
    prepped_title = article_title.replace(' ', '_')

    # URL-encode the article title to ensure it is safe for use in a URL
    # (e.g., handling special characters)
    encoded_title = urllib.parse.quote(prepped_title)

    return encoded_title

# %% [markdown]
# #### Requesting information from Wiki

# %% [markdown]
# ##### For a single article

# %%
# Function to get the current revision ID of an article
def get_revision_id(page_title: str) -> Optional[int]:
    """
    Retrieves the latest revision ID for a given Wikipedia article.

    Parameters:
    -----------
    page_title : str
        The title of the Wikipedia page for which to retrieve the latest revision ID.

    Returns:
    --------
    Optional[int]
        The latest revision ID of the page, or None if not found.

    Raises:
    -------
    Exception:
        If the request to the Wikipedia API fails.
    """
    params = {
        "action": "query",
        "format": "json",
        "titles": page_title,
        "prop": "info"
    }
    
    try:
        response = requests.get(API_ENWIKIPEDIA_ENDPOINT, headers=REQUEST_HEADERS, params=params)
        response_data = response.json()
        
        # Extract page info
        page_data = list(response_data['query']['pages'].values())[0]
        return page_data.get('lastrevid', None)
    except Exception as e:
        print(f"Error occurred while retrieving revision ID for {page_title}: {e}")
        return None


# Function to get the ORES quality prediction
def get_ores_quality_prediction(revision_id: int) -> Optional[str]:
    """
    Retrieves the ORES quality prediction for a given revision ID.

    Parameters:
    -----------
    revision_id : int
        The revision ID of the Wikipedia article for which to retrieve the ORES quality prediction.

    Returns:
    --------
    Optional[str]
        The predicted quality class (e.g., 'Stub', 'Start', 'C', 'B', 'GA', 'FA'), or None if not found.

    Raises:
    -------
    Exception:
        If the request to the ORES API fails or the prediction cannot be retrieved.
    """
    if revision_id:
        ores_url = ORES_API_ENDPOINT.format("enwiki", revision_id)
        
        try:
            response = requests.get(ores_url, headers=REQUEST_HEADERS)
            response_data = response.json()
            
            # Return the predicted quality class
            return response_data['enwiki']['scores'][str(revision_id)]['wp10']['score']['prediction']
        except KeyError:
            print(f"KeyError: Quality prediction not available for revision ID {revision_id}")
            return None
        except Exception as e:
            print(f"Error occurred while retrieving ORES prediction for revision ID {revision_id}: {e}")
            return None
    return None


# Function to apply the above functions to get article quality prediction
def get_article_quality(row: Dict[str, Any]) -> Optional[str]:
    """
    Retrieves the ORES quality prediction for a given Wikipedia article (row).

    Parameters:
    -----------
    row : Dict[str, Any]
        A row from the dataset, expected to contain a 'name' field with the article title.

    Returns:
    --------
    Optional[str]
        The predicted quality class for the article, or None if not found.
    
    Workflow:
    ---------
    1. Get the latest revision ID using the article's title.
    2. Use the revision ID to get the ORES quality prediction.
    """
    
    # Step 1: Get revision ID
    revision_id = get_revision_id(row['name'])
    
    # Throttle requests to avoid exceeding the API rate limits
    time.sleep(0.05)
    
    # Step 2: Get ORES quality prediction
    return get_ores_quality_prediction(revision_id)

def request_pageinfo_per_article(
    article_title: Optional[str] = None,
    endpoint_url: str = API_ENWIKIPEDIA_ENDPOINT,
    request_template: Dict[str, Any] = PAGEINFO_PARAMS_TEMPLATE,
    headers: Dict[str, str] = REQUEST_HEADERS
) -> Optional[Dict[str, Any]]:
    """
    Makes a request to the Wikipedia API to retrieve page information for a given article.

    Parameters:
    -----------
    article_title : Optional[str]
        The title of the Wikipedia article. This can be passed as a function parameter 
        or pre-populated in the request_template. If not provided, the request will fail.
    
    endpoint_url : str
        The Wikipedia API endpoint to send the request to (default is API_ENWIKIPEDIA_ENDPOINT).
    
    request_template : Dict[str, Any]
        The template for the parameters to be sent in the request.
    
    headers : Dict[str, str]
        The headers for the request, which must include the 'User-Agent' field containing a valid email address.
    
    Returns:
    --------
    Optional[Dict[str, Any]]
        The JSON response from the Wikipedia API as a dictionary, or None in case of an error.

    Raises:
    -------
    Exception:
        If the article title is missing, if 'User-Agent' is missing from headers, or if a placeholder email is used.
    """

    # Ensure the article title is included in the request
    if article_title:
        request_template['titles'] = encoded_title

    if not request_template['titles']:
        raise Exception("Must supply an article title to make a pageinfo request.")

    if API_HEADER_AGENT not in headers:
        raise Exception(f"The header data should include a '{API_HEADER_AGENT}' field that contains your UW email address.")

    if 'uwnetid@uw' in headers[API_HEADER_AGENT]:
        raise Exception(f"Use your UW email address in the '{API_HEADER_AGENT}' field.")

    # Make the request to the Wikipedia API
    try:
        # Throttle to avoid exceeding the API request limits
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(endpoint_url, headers=headers, params=request_template)
        json_response = response.json()
    except Exception as e:
        print(f"Error occurred: {e}")
        json_response = None

    return json_response

def request_ores_score_per_article(
    article_revid: Optional[int] = None,
    email_address: Optional[str] = None,
    access_token: Optional[str] = None,
    endpoint_url: str = API_ORES_LIFTWING_ENDPOINT,
    model_name: str = API_ORES_EN_QUALITY_MODEL,
    request_data: Dict[str, Any] = ORES_REQUEST_DATA_TEMPLATE,
    header_format: Dict[str, str] = REQUEST_HEADER_TEMPLATE,
    header_params: Dict[str, str] = REQUEST_HEADER_PARAMS_TEMPLATE
) -> Optional[Dict[str, Any]]:
    """
    Makes a request to the ORES API to retrieve an article quality score for a given Wikipedia article revision.

    Parameters:
    -----------
    article_revid : Optional[int]
        The revision ID of the Wikipedia article to score. Required for the ORES request.
    
    email_address : Optional[str]
        The user's email address to include in the API request headers for identification. Required.
    
    access_token : Optional[str]
        The access token for authentication with the ORES API. Required.
    
    endpoint_url : str
        The LiftWing ORES API endpoint (default is API_ORES_LIFTWING_ENDPOINT).
    
    model_name : str
        The name of the ORES model to use (default is API_ORES_EN_QUALITY_MODEL).
    
    request_data : Dict[str, Any]
        The data payload to be sent in the request, including revision ID and features flag.
    
    header_format : Dict[str, str]
        The template for constructing request headers, with placeholders for email and access token.
    
    header_params : Dict[str, str]
        The dictionary containing values (email_address and access_token) to fill into the header template.

    Returns:
    --------
    Optional[Dict[str, Any]]
        The JSON response from the ORES API as a dictionary, or None in case of an error.

    Raises:
    -------
    Exception:
        If the revision ID, email address, or access token is missing.
    """

    # Ensure all required fields are provided
    if article_revid:
        request_data['rev_id'] = article_revid
    if email_address:
        header_params['email_address'] = email_address
    if access_token:
        header_params['access_token'] = access_token
    
    if not request_data['rev_id']:
        raise Exception("Must provide an article revision ID (rev_id) to score articles.")
    if not header_params['email_address']:
        raise Exception("Must provide an 'email_address' value.")
    if not header_params['access_token']:
        raise Exception("Must provide an 'access_token' value.")
    
    # Format the request URL and headers
    request_url = endpoint_url.format(model_name=model_name)
    
    headers = {key: header_format[key].format(**header_params) for key in header_format}
    
    # Make the request to the ORES API
    try:
        # Throttle to avoid exceeding the API request limits
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.post(request_url, headers=headers, data=json.dumps(request_data))
        json_response = response.json()
    except Exception as e:
        print(f"Error occurred: {e}")
        json_response = None

    return json_response

# %% [markdown]
# ##### For multiple article/batch requests
# significantly speeds things up

# %%
# Function to get the latest revision IDs for a batch of Wikipedia article titles
def fetch_revision_ids_for_batch(article_titles):
    """
    Fetches the latest revision IDs for a batch of Wikipedia articles using the Wikipedia API.

    Args:
        article_titles (list): A list of article titles to query.

    Returns
        dict: A dictionary mapping article titles to their respective revision IDs. 
        If an article is missing or a revision ID is not available, None is returned for that title.
    """
    try:
        # Join the titles with "|" to form a single request
        titles_query_str = "|".join(article_titles)

        # Define the parameters for the Wikipedia API query
        query_params = {
            "action": "query",
            "format": "json",
            "titles": titles_query_str,
            "prop": "info"
        }

        # Send the request to the Wikipedia API
        response = requests.get(API_ENWIKIPEDIA_ENDPOINT, headers=REQUEST_HEADERS, params=query_params)
        response_data = response.json()

        # Initialize dictionary to hold revision IDs
        article_revision_ids = {}

        # Process the response to extract revision IDs
        for page_id, page_data in response_data['query']['pages'].items():
            title = page_data.get('title', 'Unknown')
            if 'missing' in page_data:
                print(f"Article missing for title: {title}")
                article_revision_ids[title] = None  # Mark missing pages
            else:
                # Store the revision ID if available
                revision_id = page_data.get('lastrevid', None)
                if revision_id is None:
                    print(f"Revision ID missing for title: {title}")
                article_revision_ids[title] = revision_id

        return article_revision_ids

    except Exception as e:
        print(f"Error occurred while retrieving batch revision IDs: {e}")
        return {title: None for title in article_titles}  # Return None for all titles in case of failure


# Function to process all article titles in batches and retrieve their revision IDs
def fetch_revision_ids_for_all_articles(article_titles, batch_size=50):
    """
    Retrieves the revision IDs for a list of Wikipedia articles in batches to optimize API requests.

    Args:
        article_titles (list): A list of article titles for which to fetch revision IDs.
        batch_size (int, optional): The number of articles to query in each batch (default is 50).

    Returns:
        dict: A dictionary mapping article titles to their respective revision IDs.
    """
    
    all_revision_ids = {}

    # Loop over the article titles in batches
    for batch_start in range(0, len(article_titles), batch_size):
        batch_titles = article_titles[batch_start:batch_start + batch_size]
        batch_revision_ids = fetch_revision_ids_for_batch(batch_titles)
        all_revision_ids.update(batch_revision_ids)

        # Delay to avoid overwhelming the API with requests
        time.sleep(0.1)

    return all_revision_ids

# %% [markdown]
# ## Data Loading and Cleaning

# %% [markdown]
# ### Load the provided politicans and population datasets

# %%
pol_df = pd.read_csv('politicians_by_country_AUG2024.csv')
pop_df = pd.read_csv('population_by_country_AUG2024.csv')

# %% [markdown]
# Display the first few rows of each dataframe to inspect structure

# %%
pol_df.head()
# Out:
#                    name                                                url  \
# 0        Majah Ha Adrif       https://en.wikipedia.org/wiki/Majah_Ha_Adrif
# 1     Haroon al-Afghani    https://en.wikipedia.org/wiki/Haroon_al-Afghani
# 2           Tayyab Agha          https://en.wikipedia.org/wiki/Tayyab_Agha
# 3  Khadija Zahra Ahmadi  https://en.wikipedia.org/wiki/Khadija_Zahra_Ah...
# 4        Aziza Ahmadyar       https://en.wikipedia.org/wiki/Aziza_Ahmadyar
#
#        country
# 0  Afghanistan
# 1  Afghanistan
# 2  Afghanistan
# 3  Afghanistan
# 4  Afghanistan

# %%
pop_df.head()
# Out:
#          Geography  Population
# 0            WORLD      8009.0
# 1           AFRICA      1453.0
# 2  NORTHERN AFRICA       256.0
# 3          Algeria        46.8
# 4            Egypt       105.2

# %% [markdown]
# ### Clean & Standardize the data
# We need to clean and standardize the country names in both datasets to ensure the entries are consistent.
#
# We will also exclude cumulative regional rows (like "AFRICA", "NORTHERN AFRICA") from the country-specific analysis but retain them in a separate dataframe for regional-level analysis.

# %%
# Clean the population dataset
# Separate out regions (all caps) and countries
regions_df = pop_df[pop_df['Geography'].str.isupper()]
countries_df = pop_df[~pop_df['Geography'].str.isupper()]

# Rename columns to have a consistent naming format
countries_df = countries_df.rename(columns={'Geography': 'country', 'Population': 'population_millions'})
regions_df = regions_df.rename(columns={'Geography': 'region', 'Population': 'population_millions'})

# Standardize the column names for the politicians dataset as well
pol_df = pol_df.rename(columns={'country': 'country'})

# %% [markdown]
# Let’s view the intermediate cleaned dataframes

# %%
# lets look at the contries to see if there are any glaring issues: 
pol_df["country"].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan', 'Guinea-Bissau',
#        'Bolivia', 'Bosnia Herzegovina', 'Botswana', 'Brazil', 'Bulgaria',
#        'Burkina Faso', 'Myanmar', 'Burundi', 'Cambodia', 'Cameroon',
#        'Cape Verde', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo', 'Congo DR', 'Costa Rica',
#        'Croatia', 'Cuba', 'Cyprus', 'Czechia', 'Djibouti',
#        'Dominican Republic', 'Timor Leste', 'Ecuador', 'Egypt',
#        'United Arab Emirates', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Ethiopia', 'Finland', 'France', 'Gabon', 'Gambia', 'Germany',
#        'Ghana', 'Greece', 'Grenada', 'Guatemala', 'Guinea', 'Guyana',
#        'Haiti', 'Honduras', 'Hungary', 'India', 'Indonesia', 'Iran',
#        'Iraq', 'Israel', 'Italy', "Cote d'Ivoire", 'Japan', 'Jordan',
#        'Kazakhstan', 'Kenya', 'Korean', 'Kosovo', 'Kuwait', 'Kyrgyzstan',
#        'Laos', 'Latvia', 'Lebanon', 'Lesotho', 'Liberia', 'Libya',
#        'Lithuania', 'Luxembourg', 'North Macedonia', 'Madagascar',
#        'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Marshall Islands', 'Mauritania', 'Federated States of Micronesia',
#        'Moldova', 'Monaco', 'Mongolia', 'Montenegro', 'Morocco',
#        'Mozambique', 'Namibia', 'Nepal', 'Nicaragua', 'Nigeria', 'Niger',
#        'Norway', 'Oman', 'Pakistan', 'Palestinian Territory', 'Panama',
#        'Papua New Guinea', 'Paraguay', 'Peru', 'Poland', 'Portugal',
#        'Qatar', 'Russia', 'Rwanda', 'St. Kitts and Nevis', 'St. Lucia',
#        'St. Vincent and the Grenadines', 'El Salvador', 'Samoa',
#        'Saudi Arabia', 'Senegal', 'Serbia', 'Seychelles', 'Sierra Leone',
#        'Singapore', 'Slovakia', 'Slovenia', 'Solomon Islands', 'Somalia',
#        'South Africa', 'Korea, South', 'South Sudan', 'Spain',
#        'Sri Lanka', 'Sudan', 'Sweden', 'Switzerland', 'Syria', 'Taiwan',
#        'Tajikistan', 'Tanzania', 'Thailand', 'Togo', 'Tonga',
#        'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan',
#        'Tuvalu', 'Uganda', 'Ukraine', 'Uruguay', 'Uzbekistan', 'Vanuatu',
#        'Venezuela', 'Vietnam', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %%
countries_df["country"].unique()
# Out:
# array(['Algeria', 'Egypt', 'Libya', 'Morocco', 'Sudan', 'Tunisia',
#        'Western Sahara', 'Benin', 'Burkina Faso', 'Cape Verde',
#        "Cote d'Ivoire", 'Gambia', 'Ghana', 'Guinea', 'GuineaBissau',
#        'Liberia', 'Mali', 'Mauritania', 'Niger', 'Nigeria', 'Senegal',
#        'Sierra Leone', 'Togo', 'Burundi', 'Comoros', 'Djibouti',
#        'Eritrea', 'Ethiopia', 'Kenya', 'Madagascar', 'Malawi',
#        'Mauritius', 'Mayotte', 'Mozambique', 'Reunion', 'Rwanda',
#        'Seychelles', 'Somalia', 'South Sudan', 'Tanzania', 'Uganda',
#        'Zambia', 'Zimbabwe', 'Angola', 'Cameroon',
#        'Central African Republic', 'Chad', 'Congo', 'Congo DR',
#        'Equatorial Guinea', 'Gabon', 'Sao Tome and Principe', 'Botswana',
#        'eSwatini', 'Lesotho', 'Namibia', 'South Africa', 'Canada',
#        'United States', 'Belize', 'Costa Rica', 'El Salvador',
#        'Guatemala', 'Honduras', 'Mexico', 'Nicaragua', 'Panama',
#        'Antigua and Barbuda', 'Bahamas', 'Barbados', 'Cuba', 'Curacao',
#        'Dominica', 'Dominican Republic', 'Grenada', 'Guadeloupe', 'Haiti',
#        'Jamaica', 'Martinique', 'Puerto Rico', 'St. Kitts and Nevis',
#        'St. Lucia', 'St. Vincent and the Grenadines',
#        'Trinidad and Tobago', 'Argentina', 'Bolivia', 'Brazil', 'Chile',
#        'Colombia', 'Ecuador', 'French Guiana', 'Guyana', 'Paraguay',
#        'Peru', 'Suriname', 'Uruguay', 'Venezuela', 'Armenia',
#        'Azerbaijan', 'Bahrain', 'Cyprus', 'Georgia', 'Iraq', 'Israel',
#        'Jordan', 'Kuwait', 'Lebanon', 'Oman', 'Palestinian Territory',
#        'Qatar', 'Saudi Arabia', 'Syria', 'Turkey', 'United Arab Emirates',
#        'Yemen', 'Kazakhstan', 'Kyrgyzstan', 'Tajikistan', 'Turkmenistan',
#        'Uzbekistan', 'Afghanistan', 'Bangladesh', 'Bhutan', 'India',
#        'Iran', 'Maldives', 'Nepal', 'Pakistan', 'Sri Lanka', 'Brunei',
#        'Cambodia', 'Indonesia', 'Laos', 'Malaysia', 'Myanmar',
#        'Philippines', 'Singapore', 'Thailand', 'Timor Leste', 'Vietnam',
#        'China', 'China (Hong Kong SAR)', 'China (Macao SAR)', 'Japan',
#        'Korea (North)', 'Korea (South)', 'Mongolia', 'Taiwan', 'Denmark',
#        'Estonia', 'Finland', 'Iceland', 'Ireland', 'Latvia', 'Lithuania',
#        'Norway', 'Sweden', 'United Kingdom', 'Austria', 'Belgium',
#        'France', 'Germany', 'Liechtenstein', 'Luxembourg', 'Monaco',
#        'Netherlands', 'Switzerland', 'Belarus', 'Bulgaria', 'Czechia',
#        'Hungary', 'Moldova', 'Poland', 'Romania', 'Russia', 'Slovakia',
#        'Ukraine', 'Albania', 'Andorra', 'Bosnia Herzegovina', 'Croatia',
#        'Greece', 'Italy', 'Kosovo', 'Malta', 'Montenegro',
#        'North Macedonia', 'Portugal', 'San Marino', 'Serbia', 'Slovenia',
#        'Spain', 'Australia', 'Federated States of Micronesia', 'Fiji',
#        'French Polynesia', 'Guam', 'Kiribati', 'Marshall Islands',
#        'Nauru', 'New Caledonia', 'New Zealand', 'Palau',
#        'Papua New Guinea', 'Samoa', 'Solomon Islands', 'Tonga', 'Tuvalu',
#        'Vanuatu'], dtype=object)

# %% [markdown]
# The one thing I'm noticing is that in the politicians df there is a country 'Korean'- which I'm not sure if that means Korea (North) because there is an n at the end of it. That might be something to keep an eye on.

# %%
regions_df["region"].unique()
# Out:
# array(['WORLD', 'AFRICA', 'NORTHERN AFRICA', 'WESTERN AFRICA',
#        'EASTERN AFRICA', 'MIDDLE AFRICA', 'SOUTHERN AFRICA',
#        'NORTHERN AMERICA', 'LATIN AMERICA AND THE CARIBBEAN',
#        'CENTRAL AMERICA', 'CARIBBEAN', 'SOUTH AMERICA', 'ASIA',
#        'WESTERN ASIA', 'CENTRAL ASIA', 'SOUTH ASIA', 'SOUTHEAST ASIA',
#        'EAST ASIA', 'EUROPE', 'NORTHERN EUROPE', 'WESTERN EUROPE',
#        'EASTERN EUROPE', 'SOUTHERN EUROPE', 'OCEANIA'], dtype=object)

# %% [markdown]
# ### Matching and merging the politicians & population datasets
# We will now merge the politicans and population datasets, and log any any countries from the politicans dataset that don't have a corresponding population entry.

# %%
# Merge the politicians dataset with the country population dataset
# Performing a left join to retain all politicians even if there is no population match
merged_df = pd.merge(pol_df, countries_df, how='left', on='country')

# Identify countries from the politicians dataset that don't have a match in the population data
no_match_countries = merged_df[merged_df['population_millions'].isna()]['country'].unique()

# Save the no-match countries to a text file
no_match_file_path = r'C:\Users\clark.roll\python coding\code_personal\Data512\Homework\Assignment 2\wp_countries-no_match.txt'
with open(no_match_file_path, 'w') as file:
    for country in no_match_countries:
        file.write(f"{country}\n")

# Save the cleaned and merged dataset as a CSV
merged_df.to_csv('wp_politicians_by_country.csv', index=False)

# %% [markdown]
# Lets look at the merged dataframe

# %%
merged_df
# Out:
#                       name                                                url  \
# 0           Majah Ha Adrif       https://en.wikipedia.org/wiki/Majah_Ha_Adrif
# 1        Haroon al-Afghani    https://en.wikipedia.org/wiki/Haroon_al-Afghani
# 2              Tayyab Agha          https://en.wikipedia.org/wiki/Tayyab_Agha
# 3     Khadija Zahra Ahmadi  https://en.wikipedia.org/wiki/Khadija_Zahra_Ah...
# 4           Aziza Ahmadyar       https://en.wikipedia.org/wiki/Aziza_Ahmadyar
# ...                    ...                                                ...
# 7150      Josiah Tongogara     https://en.wikipedia.org/wiki/Josiah_Tongogara
# 7151     Langton Towungana    https://en.wikipedia.org/wiki/Langton_Towungana
# 7152     Sengezo Tshabangu    https://en.wikipedia.org/wiki/Sengezo_Tshabangu
# 7153   Herbert Ushewokunze  https://en.wikipedia.org/wiki/Herbert_Ushewokunze
# 7154          Denis Walker         https://en.wikipedia.org/wiki/Denis_Walker
#
#           country  population_millions
# 0     Afghanistan                 42.4
# 1     Afghanistan                 42.4
# 2     Afghanistan                 42.4
# 3     Afghanistan                 42.4
# 4     Afghanistan                 42.4
# ...           ...                  ...
# 7150     Zimbabwe                 16.7
# 7151     Zimbabwe                 16.7
# 7152     Zimbabwe                 16.7
# 7153     Zimbabwe                 16.7
# 7154     Zimbabwe                 16.7
#
# [7155 rows x 4 columns]

# %% [markdown]
# It looks like the 'korean' entry that I was hesitant about in the politicians dataframe was logged as no matches, so that takes care of that.
#
# If that were a particularly important entry, then we could lookup the correct information and manually adjust it, but I think this will be fine for this project

# %% [markdown]
# ## Getting Article Quality Predictions via ORES API

# %% [markdown]
# Lets start by prepping to make requests.
#
# We know that we need our article titles to be URL encoded so lets take care of that now by adding a column to the dataframe called `article_title` that is the URL encoded name

# %%
merged_df['article_title'] = merged_df['name'].apply(prep_article_title)

# %%
merged_df
# Out:
#                       name                                                url  \
# 0           Majah Ha Adrif       https://en.wikipedia.org/wiki/Majah_Ha_Adrif
# 1        Haroon al-Afghani    https://en.wikipedia.org/wiki/Haroon_al-Afghani
# 2              Tayyab Agha          https://en.wikipedia.org/wiki/Tayyab_Agha
# 3     Khadija Zahra Ahmadi  https://en.wikipedia.org/wiki/Khadija_Zahra_Ah...
# 4           Aziza Ahmadyar       https://en.wikipedia.org/wiki/Aziza_Ahmadyar
# ...                    ...                                                ...
# 7150      Josiah Tongogara     https://en.wikipedia.org/wiki/Josiah_Tongogara
# 7151     Langton Towungana    https://en.wikipedia.org/wiki/Langton_Towungana
# 7152     Sengezo Tshabangu    https://en.wikipedia.org/wiki/Sengezo_Tshabangu
# 7153   Herbert Ushewokunze  https://en.wikipedia.org/wiki/Herbert_Ushewokunze
# 7154          Denis Walker         https://en.wikipedia.org/wiki/Denis_Walker
#
#           country  population_millions         article_title
# 0     Afghanistan                 42.4        Majah_Ha_Adrif
# 1     Afghanistan                 42.4     Haroon_al-Afghani
# 2     Afghanistan                 42.4           Tayyab_Agha
# 3     Afghanistan                 42.4  Khadija_Zahra_Ahmadi
# 4     Afghanistan                 42.4        Aziza_Ahmadyar
# ...           ...                  ...                   ...
# 7150     Zimbabwe                 16.7      Josiah_Tongogara
# 7151     Zimbabwe                 16.7     Langton_Towungana
# 7152     Zimbabwe                 16.7     Sengezo_Tshabangu
# 7153     Zimbabwe                 16.7   Herbert_Ushewokunze
# 7154     Zimbabwe                 16.7          Denis_Walker
#
# [7155 rows x 5 columns]

# %% [markdown]
# #### Making requests 1 article at a time

# %% [markdown]
# You can run the code below to get the quality predictions **BUT** it will take **~1-2 hours to run**.
#
# Instead I would suggest running as a batch, which is explained after this

# %%
# Apply the ORES prediction process
merged_df['revision_id'] = merged_df['name'].apply(get_revision_id)
merged_df['article_quality'] = merged_df['revision_id'].apply(get_ores_quality_prediction)

# Log any articles for which the ORES score could not be retrieved
ores_errors = merged_df[merged_df['article_quality'].isna()]
ores_error_rate = len(ores_errors) / len(merged_df)

print(f"ORES request error rate: {ores_error_rate * 100:.2f}%")

# %% [markdown]
# #### Batch requests
#
# **OR** you can use batch processing to reduce the runtime by an order of magnitude

# %%
# Apply the batch request function to get revision IDs for all articles
all_article_titles = merged_df['article_title'].tolist()
all_revision_ids = fetch_revision_ids_for_all_articles(all_article_titles)
# Out:
# Revision ID missing for title: Ezatullah_%28Nangarhar%29
# Revision ID missing for title: Mohammad_Gul_%28Helmand_Council%29
# Revision ID missing for title: Mohammad_Khan_%28athlete%29
# Revision ID missing for title: Ali_Mohammad_%28politician%29
# Revision ID missing for title: Abdul_Zahir_%28Konar_Education_Minister%29
# Revision ID missing for title: Ziauddin_%28Afghan_militia_leader%29
# Revision ID missing for title: Refo_%C3%87apari
# Revision ID missing for title: Themistokli_G%C3%ABrmenji
# Revision ID missing for title: A%C4%87if_Had%C5%BEiahmetovi%C4%87
# Revision ID missing for title: Kurt_Ag%C3%AB_Kadiu
# Revision ID missing for title: Alfred_Karamu%C3%A7o
# Revision ID missing for title: Ali_K%C3%ABlcyra
# Revision ID missing for title: Elez_Ko%C3%A7i
# Revision ID missing for title: Xhelal_Kopr%C3%ABncka
# Revision ID missing for title: Xhelal_Sve%C3%A7la
# Revision ID missing for title: Cha%C3%A2bane_A%C3%AFt_Abderrahim
# Revision ID missing for title: A%C3%AFssa_Bekkai
# Revision ID missing for title: Benaouda_Hadj_Hac%C3%A8ne_Bachterzi
# Revision ID missing for title: Fay%C3%A7al_Bentaleb
# Revision ID missing for title: Sa%C3%AFd_Boualam
# Revision ID missing for title: Abderrahmane_Meziane_Ch%C3%A9rif
# Revision ID missing for title: Sa%C3%AFd_Chibane
# Revision ID missing for title: Ad%C3%A3o_Francisco_Correia_de_Almeida
# Revision ID missing for title: Alexandre_Sebasti%C3%A3o_Andr%C3%A9
# Revision ID missing for title: Bernarda_Gon%C3%A7alves_Martins
# Revision ID missing for title: Jo%C3%A3o_Baptista_Borges
# Revision ID missing for title: Adalberto_Costa_J%C3%BAnior
# Revision ID missing for title: %C3%81lvaro_Arnaldo_Craveiro
# Revision ID missing for title: Faustina_Fernandes_Ingl%C3%AAs_de_Almeida_Alves
# Revision ID missing for title: Abra%C3%A3o_Gourgel
# Revision ID missing for title: Jofre_Van-D%C3%BAnem_J%C3%BAnior
# Revision ID missing for title: Jos%C3%A9_Carvalho_da_Rocha
# Revision ID missing for title: Jos%C3%A9_Luis_de_Matos
# Revision ID missing for title: Maria_C%C3%A2ndida_Pereira_Teixeira
# Revision ID missing for title: Maria_do_Ros%C3%A1rio_Teixeira_de_Alva_Sequeira_Bragan%C3%A7a_Sambo
# Revision ID missing for title: Sa%C3%ADde_Mingas
# Revision ID missing for title: Jos%C3%A9_Ndele
# Revision ID missing for title: Pedro_Pedal%C3%A9
# Revision ID missing for title: Santana_Andr%C3%A9_Pitra
# Revision ID missing for title: Francisco_Manuel_Monteiro_de_Queir%C3%B3z
# Revision ID missing for title: Jos%C3%A9_An%C3%ADbal_Lopes_Rocha
# Revision ID missing for title: Jos%C3%A9_da_Rocha
# Revision ID missing for title: Rosa_Lu%C3%ADs_de_Sousa_Micolo
# Revision ID missing for title: Lu%C3%ADs_Gomes_Sambo
# Revision ID missing for title: Jo%C3%A3o_Ernesto_dos_Santos
# Revision ID missing for title: Jos%C3%A9_Filomeno_dos_Santos
# Revision ID missing for title: Pinda_Sim%C3%A3o
# Revision ID missing for title: Augusto_da_Silva_Tom%C3%A1s
# Revision ID missing for title: Jos%C3%A9_Jacinto_Van-D%C3%BAnem
# Revision ID missing for title: Jos%C3%A9_Vieira_Dias_Van-D%C3%BAnem
# Revision ID missing for title: Luzia_Ingl%C3%AAs_Van-D%C3%BAnem
# Revision ID missing for title: Alex_Browne_%28politician%29
# Revision ID missing for title: Colin_O%27Neil_Browne
# Revision ID missing for title: Rick_James_%28actor%29
# Revision ID missing for title: Johnathan_Joseph_%28politician%29
# Revision ID missing for title: Germ%C3%A1n_Alfaro
# Revision ID missing for title: Joaqu%C3%ADn_Samuel_de_Anchorena
# Revision ID missing for title: Juan_Agust%C3%ADn_Augier
# Revision ID missing for title: Joaqu%C3%ADn_Belgrano
# Revision ID missing for title: H%C3%A9ctor_Bidonde
# Revision ID missing for title: D%C3%A1maso_Centeno
# Revision ID missing for title: L%C3%A1zaro_Chiappe
# Revision ID missing for title: Luis_L._Dom%C3%ADnguez
# Revision ID missing for title: M%C3%A1ximo_Etchecopar
# Revision ID missing for title: H%C3%A9ctor_Toty_Flores
# Revision ID missing for title: Manuel_Jos%C3%A9_Garc%C3%ADa
# Revision ID missing for title: Juan_Jos%C3%A9_G%C3%B3mez_Centuri%C3%B3n
# Revision ID missing for title: Luis_Carlos_G%C3%B3mez_Centuri%C3%B3n
# Revision ID missing for title: Mart%C3%ADn_Guzm%C3%A1n
# Revision ID missing for title: Fernando_Iglesias_%28Argentine_politician%29
# Revision ID missing for title: Andr%C3%A9s_Larroque
# Revision ID missing for title: Juli%C3%A1n_de_Leyva
# Revision ID missing for title: M%C3%B3nica_L%C3%B3pez_%28politician%29
# Revision ID missing for title: Nicol%C3%A1s_Massot
# Revision ID missing for title: Mart%C3%ADn_Menem
# Revision ID missing for title: R%C3%B3mulo_Sebasti%C3%A1n_Na%C3%B3n
# Revision ID missing for title: Santiago_G._O%27Farrell
# Revision ID missing for title: Miguel_%C3%81ngel_Pesce
# Revision ID missing for title: Am%C3%A1n_Rawson
# Revision ID missing for title: Mart%C3%ADn_Sabbatella
# Revision ID missing for title: H%C3%A9ctor_Tiz%C3%B3n
# Revision ID missing for title: Ar%C3%ADstides_Villanueva
# Revision ID missing for title: Gevorg_Ghazaryan_%28politician%29
# Revision ID missing for title: Aram_Grigoryan_%28politician%29
# Article missing for title: Barbara Eibinger-Miedl
# Revision ID missing for title: Karen_Sargsyan_%28sociologist%29
# Revision ID missing for title: Vartkes_Sereng%C3%BClian
# Revision ID missing for title: Maximilian_Anton_Karl%2C_Count_Baillet_de_Latour
# Revision ID missing for title: Count_V%C3%A1clav_Anton%C3%ADn_Chotek_of_Chotkov_and_Vojn%C3%ADn
# Revision ID missing for title: Citizens%27_Ministry
# Revision ID missing for title: Ernst_Hampel_%28politician%29
# Revision ID missing for title: J%C3%BCrgen_Himmelbauer
# Revision ID missing for title: Andreas_H%C3%B6rtnagl
# Revision ID missing for title: Konstantin_Jire%C4%8Dek
# Revision ID missing for title: J%C3%B3zef_Ko%C5%BCdo%C5%84
# Revision ID missing for title: Gottfried_von_K%C3%BChnelt-Leddihn
# Revision ID missing for title: Franz_Leitner_%28politician%29
# Revision ID missing for title: Julius_Lippert_%28historian%29
# Revision ID missing for title: Karl_L%C3%BCtgendorf
# Revision ID missing for title: J%C3%BCrgen_Mandl
# Revision ID missing for title: Gregor_Razumovsky_%28activist%29
# Revision ID missing for title: Georg_Adam%2C_Prince_of_Starhemberg
# Revision ID missing for title: Peter_Strasser_%28politician%29
# Revision ID missing for title: Leopold%2C_Count_von_Thun_und_Hohenstein
# Revision ID missing for title: Curt_Franz_Wenzel_Christoph_Erdmann_Graf_Zedtwitz_von_Morav%C3%A1n_und_Duppau
# Article missing for title: Mehrali Gasimov
# Revision ID missing for title: Garib_Karimo%C4%9Flu
# Revision ID missing for title: Hasan_Seyidov_%28scientist%29
# Revision ID missing for title: Vugar_Mustafayev_%28minister%29
# Revision ID missing for title: Keith_Bell_%28Bahamian_politician%29
# Revision ID missing for title: Charles_Carter_%28Bahamian_journalist%29
# Revision ID missing for title: James_Carmichael_Smith_%28postmaster%29
# Revision ID missing for title: Ahmed_Behzad_%28Bahrain%29
# Revision ID missing for title: Kamal_Ahmed_%28politician%29
# Revision ID missing for title: Abdus_Salam_%28Chattogram_politician%29
# Revision ID missing for title: Muzaffar_Ahmed_%28NAP_politician%29
# Revision ID missing for title: AKM_Fazlul_Haque_%28Jatiya_Party_politician%29
# Revision ID missing for title: Moin_Uddin_%28politician%29
# Revision ID missing for title: Mujibur_Rahman_%28Chattogram_politician%29
# Revision ID missing for title: Abdur_Rahim_%28scholar%29
# Revision ID missing for title: Charles_Duncan_O%27Neal
# Revision ID missing for title: U%C5%82adzimir_Han%C4%8Daryk
# Revision ID missing for title: Tama%C5%A1_Hryb
# Revision ID missing for title: Anato%C4%BA_Kalinin
# Revision ID missing for title: Vo%C4%BAha_Kara%C4%8D
# Revision ID missing for title: U%C5%82adzis%C5%82au_Kaz%C5%82ouski
# Revision ID missing for title: Tadeusz_Ko%C5%9Bciuszko
# Revision ID missing for title: Uladzimir_Mackievi%C4%8D
# Revision ID missing for title: Symon_Rak-Michaj%C5%82o%C5%ADski
# Revision ID missing for title: Jan_Stankievi%C4%8D
# Revision ID missing for title: Edward_Woyni%C5%82%C5%82owicz
# Revision ID missing for title: Jan_B%C3%A9ghin
# Revision ID missing for title: Gustave_Bo%C3%ABl
# Revision ID missing for title: Pol_Clovis_Bo%C3%ABl
# Revision ID missing for title: %C3%89mile_Coulonvaux
# Revision ID missing for title: Nico_Cu%C3%A9
# Revision ID missing for title: Pierre_David_%28mayor%29
# Revision ID missing for title: Ren%C3%A9_De_Feyter
# Revision ID missing for title: Fran%C3%A7ois-Philippe_de_Haussy
# Revision ID missing for title: %C3%89douard_Descamps
# Revision ID missing for title: Jos%C3%A9_Desmarets
# Revision ID missing for title: %C3%89mile_van_Dievoet
# Revision ID missing for title: Jos_Dupr%C3%A9
# Revision ID missing for title: Fran%C3%A7oise_Dupuis
# Revision ID missing for title: Eug%C3%A8ne_Goblet_d%27Alviella
# Revision ID missing for title: Jean-Pierre_Graf%C3%A9
# Revision ID missing for title: Jean-Fran%C3%A7ois_Istasse
# Revision ID missing for title: Andr%C3%A9_Kempinaire
# Revision ID missing for title: Ahmet_Ko%C3%A7_%28politician%29
# Revision ID missing for title: Andr%C3%A9_Molitor
# Revision ID missing for title: Pierre_Emmanuel_F%C3%A9lix_Chazal
# Revision ID missing for title: Andr%C3%A9-Eug%C3%A8ne_Pirson
# Revision ID missing for title: Ga%C3%ABtan_Van_Goidsenhoven
# Revision ID missing for title: Marcel_Van_Langenhove_%28referee%29
# Revision ID missing for title: Arnauld_Antoine_Akodj%C3%A8nou
# Revision ID missing for title: Ugyen_Dorji_%28DNT_politician%29
# Revision ID missing for title: Jigme_Namgyal_%28Bhutan%29
# Revision ID missing for title: Tenzin_%28politician%29
# Revision ID missing for title: Dechen_Wangmo_%28politician%29
# Revision ID missing for title: Botche_Cand%C3%A9
# Revision ID missing for title: Teodora_In%C3%A1cia_Gomes
# Revision ID missing for title: Francisco_Argando%C3%B1a
# Revision ID missing for title: Isaac_%C3%81valos
# Revision ID missing for title: Augusto_C%C3%A9spedes
# Revision ID missing for title: Adolfo_Ch%C3%A1vez
# Revision ID missing for title: Pantale%C3%B3n_Dalence
# Revision ID missing for title: Rafael_Pe%C3%B1a
# Revision ID missing for title: Marcelo_El%C3%ADo
# Revision ID missing for title: Francisco_Burdett_O%27Connor
# Revision ID missing for title: Sim%C3%B3n_Iturri_Pati%C3%B1o
# Revision ID missing for title: Gary_Prado_Salm%C3%B3n
# Revision ID missing for title: Jos%C3%A9_Mariano_Serrano
# Revision ID missing for title: Mois%C3%A9s_Torres_%28politician%29
# Revision ID missing for title: Jaime_de_Zud%C3%A1%C3%B1ez
# Revision ID missing for title: Kemal_Ademovi%C4%87
# Revision ID missing for title: Mehmed_Alajbegovi%C4%87
# Revision ID missing for title: Bo%C5%A1ko_Ba%C5%A1kot
# Revision ID missing for title: Salko_Bukvarevi%C4%87
# Revision ID missing for title: Sabina_%C4%86udi%C4%87
# Revision ID missing for title: D%C5%BEenan_%C4%90onlagi%C4%87
# Revision ID missing for title: D%C5%BEevad_Galija%C5%A1evi%C4%87
# Revision ID missing for title: Josip_Grube%C5%A1a
# Revision ID missing for title: Ankica_Gudeljevi%C4%87
# Revision ID missing for title: Hakija_Had%C5%BEi%C4%87
# Revision ID missing for title: Mirsad_Had%C5%BEikadi%C4%87
# Revision ID missing for title: Sanjin_Halimovi%C4%87
# Revision ID missing for title: Sevlid_Hurti%C4%87
# Revision ID missing for title: Husein_Miljkovi%C4%87
# Revision ID missing for title: Jasmin_Imamovi%C4%87
# Revision ID missing for title: Adamir_Jerkovi%C4%87
# Revision ID missing for title: Esed_Kadri%C4%87
# Revision ID missing for title: Mehmed_Kapetanovi%C4%87
# Revision ID missing for title: Osman_Karabegovi%C4%87
# Revision ID missing for title: Rusmir_Mahmut%C4%87ehaji%C4%87
# Revision ID missing for title: Amor_Ma%C5%A1ovi%C4%87
# Revision ID missing for title: Bo%C5%BEidar_Mati%C4%87
# Revision ID missing for title: Dragan_Mekti%C4%87
# Revision ID missing for title: Ademaga_Me%C5%A1i%C4%87
# Revision ID missing for title: Jelka_Mili%C4%8Devi%C4%87
# Revision ID missing for title: Abdulah_Mutap%C4%8Di%C4%87
# Revision ID missing for title: Abdulah_Naka%C5%A1
# Revision ID missing for title: Damir_Nik%C5%A1i%C4%87
# Revision ID missing for title: %C4%90uro_Pucar
# Revision ID missing for title: Svetozar_Pudari%C4%87
# Revision ID missing for title: Alen_%C5%A0erani%C4%87
# Revision ID missing for title: Uglje%C5%A1a_Uzelac
# Revision ID missing for title: Nezir_%C5%A0kalji%C4%87
# Revision ID missing for title: Ibrahim_Spahi%C4%87
# Revision ID missing for title: Jelena_Trivi%C4%87
# Revision ID missing for title: Dragan_Viki%C4%87
# Revision ID missing for title: Milo%C5%A1_Vuka%C5%A1inovi%C4%87
# Revision ID missing for title: L%C3%A9o_de_Almeida_Neves
# Revision ID missing for title: Ant%C3%B4nio_Pinto_Chichorro_da_Gama
# Revision ID missing for title: Henrique_de_Beaurepaire-Rohan%2C_Viscount_of_Beaurepaire-Rohan
# Revision ID missing for title: Nat%C3%A1lia_Bastos_Bonavides
# Revision ID missing for title: Maur%C3%ADcio_Campos_de_Medeiros
# Revision ID missing for title: Marcelo_Cec%C3%A9
# Revision ID missing for title: Paulo_Corr%C3%AAa
# Revision ID missing for title: Jo%C3%A3o_Cunha_%28politician%29
# Revision ID missing for title: Manuel_Jacinto_Nogueira_da_Gama%2C_Marquis_of_Baependi
# Revision ID missing for title: A%C3%A9cio_de_Borba
# Revision ID missing for title: Jos%C3%A9_Ab%C3%ADlio_Silva_de_Santana
# Revision ID missing for title: Al%C3%A9rcio_Dias
# Revision ID missing for title: D%C3%A9lio_dos_Santos
# Revision ID missing for title: Em%C3%ADlia_Fernandes
# Revision ID missing for title: Jos%C3%A9_Carlos_da_Silva_Mayrink_Ferr%C3%A3o
# Revision ID missing for title: Francisco_Juli%C3%A3o
# Revision ID missing for title: Jos%C3%A9_Carlos_Barbosa
# Revision ID missing for title: Jos%C3%A9_Eriberto_Medeiros
# Revision ID missing for title: Jutahy_J%C3%BAnior
# Revision ID missing for title: Joaquim_Gon%C3%A7alves_Ledo
# Revision ID missing for title: Ant%C3%B4nio_Leite_Andrade
# Revision ID missing for title: Pablo_Mar%C3%A7al
# Revision ID missing for title: Hor%C3%A1cio_de_Matos
# Revision ID missing for title: Gerardo_Melo_Mour%C3%A3o
# Revision ID missing for title: C%C3%A2ndido_Mendes_de_Almeida
# Revision ID missing for title: Jos%C3%A9_M%C3%BAcio
# Revision ID missing for title: Pedro_Soares_Mu%C3%B1oz
# Revision ID missing for title: Manuel_Lu%C3%ADs_Os%C3%B3rio%2C_Marquis_of_Erval
# Revision ID missing for title: Francisco_Jos%C3%A9_Pinheiro
# Revision ID missing for title: Pl%C3%ADnio_de_Arruda_Sampaio_Jr.
# Revision ID missing for title: Eus%C3%A9bio_de_Queir%C3%B3s
# Revision ID missing for title: Robert_Rey_%28plastic_surgeon%29
# Revision ID missing for title: Jos%C3%A9_Richa
# Revision ID missing for title: Ant%C3%B4nio_Ricardo_dos_Santos
# Revision ID missing for title: Augusto_Severo_de_Albuquerque_Maranh%C3%A3o
# Revision ID missing for title: Jos%C3%A9_Manuel_da_Silva%2C_Baron_of_Tiet%C3%AA
# Revision ID missing for title: Irineu_Evangelista_de_Sousa%2C_Viscount_of_Mau%C3%A1
# Revision ID missing for title: Jo%C3%A3o_Cardoso_de_Meneses_e_Sousa%2C_Baron_of_Paranapiacaba
# Revision ID missing for title: Aureliano_C%C3%A2ndido_Tavares_Bastos
# Revision ID missing for title: Juarez_T%C3%A1vora_%28general%29
# Revision ID missing for title: Ant%C3%B4nio_de_Queir%C3%B3s_Teles%2C_Baron_of_Jundia%C3%AD
# Revision ID missing for title: Lu%C3%ADs_Viana_Neto
# Revision ID missing for title: Andr%C3%A9_Zacharow
# Revision ID missing for title: Atanas_Atanasov_%28politician_born_1990%29
# Revision ID missing for title: Atanas_Atanasov_%28politician%29
# Revision ID missing for title: Jonas_Basanavi%C4%8Dius
# Revision ID missing for title: Chairman_%28President%29_of_Bulgaria
# Revision ID missing for title: Stefan_Dimitrov_%28politician%29
# Revision ID missing for title: Ivan_Dimov_%28scientist%29
# Revision ID missing for title: Kostadin_Kostadinov_%28professor%29
# Revision ID missing for title: Stanislav_Stoyanov_%28politician%29
# Revision ID missing for title: Fran%C3%A7ois_Compaor%C3%A9
# Revision ID missing for title: Toub%C3%A9_Cl%C3%A9ment_Dakio
# Revision ID missing for title: Fr%C3%A9d%C3%A9ric_Guirma
# Revision ID missing for title: Zinda_Kabor%C3%A9
# Revision ID missing for title: Jos%C3%A9phine_Drabo_Kanyoulou
# Revision ID missing for title: Jos%C3%A9phine_Ki-Zerbo
# Revision ID missing for title: Begnon-Damien_Kon%C3%A9
# Revision ID missing for title: Kouam%C3%A9_Lougu%C3%A9
# Revision ID missing for title: Jean-Baptiste_Ou%C3%A9draogo
# Revision ID missing for title: Mamadou_Ou%C3%A9draogo
# Revision ID missing for title: Pargui_Emile_Par%C3%A9
# Revision ID missing for title: Maurice_Yam%C3%A9ogo
# Revision ID missing for title: Aye_Ko_%28artist%29
# Revision ID missing for title: Htay_Aung_%28businessman%29
# Article missing for title: Kyaw Myint
# Revision ID missing for title: Sultan_Mahmud_%28minister%29
# Revision ID missing for title: Myint_Swe_%28politician%2C_born_1965%29
# Revision ID missing for title: Sasa_%28politician%29
# Revision ID missing for title: Sein_Win_%28politician%2C_born_1944%29
# Revision ID missing for title: Sultan_Ahmed_%28Burmese_politician%29
# Revision ID missing for title: Thaung_Tun_%28politician%29
# Revision ID missing for title: Thein_Nyunt_%28politician%29
# Revision ID missing for title: G%C3%A9rard_Mfuranzima
# Revision ID missing for title: R%C3%A9v%C3%A9rien_Ndikuriyo
# Revision ID missing for title: Olivier_Bil%C3%A9
# Revision ID missing for title: S%C3%A9raphin_Magloire_Fouda
# Revision ID missing for title: Ren%C3%A9_Jam_Afane
# Revision ID missing for title: Cl%C3%A9mentine_Ananga_Messina
# Revision ID missing for title: Jer%C3%B4me_Mvondo
# Revision ID missing for title: Hermine_Patricia_Toma%C3%AFno_Ndam_Njoya
# Revision ID missing for title: Arouna_N%27Joya
# Revision ID missing for title: Andr%C3%A9_Ngongang_Ouandji
# Revision ID missing for title: F%C3%A9lix_Sabal_Lecco_%28politician%29
# Revision ID missing for title: Fran%C3%A7ois_Sengat-Kuo
# Revision ID missing for title: F%C3%A9lix_Tonye_Mbog
# Revision ID missing for title: Jos%C3%A9_Manuel_Gomes_Andrade
# Revision ID missing for title: Hon%C3%B3rio_Barreto
# Revision ID missing for title: Paulo_Rocha_%28Cape_Verde_politician%29
# Revision ID missing for title: Lu%C3%ADs_Filipe_Tavares
# Revision ID missing for title: Abra%C3%A3o_Vicente
# Revision ID missing for title: Jean-B%C3%A9del_Bokassa
# Revision ID missing for title: Catherine_Denguiad%C3%A9
# Revision ID missing for title: Gaston_N%27Gu%C3%A9r%C3%A9kata
# Revision ID missing for title: Jean-Beno%C3%AEt_Gonda
# Revision ID missing for title: D%C3%A9sir%C3%A9_Kolingba
# Revision ID missing for title: Tchakpa_M%27brede
# Revision ID missing for title: Achta_Ahmat_Brem%C3%A9
# Revision ID missing for title: Baba_Ladd%C3%A9
# Revision ID missing for title: Laoukein_Kourayo_M%C3%A9dard
# Revision ID missing for title: Fran%C3%A7ois_Tombalbaye
# Revision ID missing for title: Beltr%C3%A1n_Mathieu
# Revision ID missing for title: Rolando_Calder%C3%B3n
# Revision ID missing for title: Mar%C3%ADa_Silvia_Correa_Mar%C3%ADn
# Revision ID missing for title: %C3%81lvaro_Covarrubias
# Revision ID missing for title: Juan_Ega%C3%B1a
# Revision ID missing for title: Sergio_Fern%C3%A1ndez_Fern%C3%A1ndez
# Revision ID missing for title: %C3%81ngel_Flisfisch
# Revision ID missing for title: Carlos_Gonz%C3%A1lez_M%C3%A1rquez
# Revision ID missing for title: David_Henr%C3%ADquez_%28footballer%2C_born_1977%29
# Revision ID missing for title: Ricardo_Hormaz%C3%A1bal
# Revision ID missing for title: Auc%C3%A1n_Huilcam%C3%A1n
# Revision ID missing for title: Andr%C3%A9s_Jouannet
# Revision ID missing for title: Antonio_Leal_Labr%C3%ADn
# Revision ID missing for title: Sergio_Ortega_%28composer%29
# Revision ID missing for title: Sergio_P%C3%A1ez_Verdugo
# Revision ID missing for title: H%C3%A9ctor_Parra_%28footballer%29
# Revision ID missing for title: Ignacio_P%C3%A9rez_Walker
# Revision ID missing for title: Germ%C3%A1n_Pic%C3%B3_Ca%C3%B1as
# Revision ID missing for title: Mario_R%C3%ADos_Santander
# Revision ID missing for title: Ram%C3%B3n_Vega_Hidalgo
# Revision ID missing for title: Juan_de_Dios_Vial_del_R%C3%ADo
# Revision ID missing for title: Claudio_Vicu%C3%B1a_Subercaseaux
# Revision ID missing for title: Hern%C3%A1n_Vodanovic
# Revision ID missing for title: Lu_Feng_%28politician%29
# Revision ID missing for title: Shi_Ping_%28politician%29
# Revision ID missing for title: Wang_Wei_%28politician%2C_born_1974%29
# Revision ID missing for title: Zhang_Lin_%28general%29
# Revision ID missing for title: Jos%C3%A9_Manuel_Restrepo_Abondano
# Revision ID missing for title: Yahir_Acu%C3%B1a
# Revision ID missing for title: Iv%C3%A1n_Dar%C3%ADo_Agudelo
# Revision ID missing for title: Carlos_Mario_%C3%81lvarez
# Revision ID missing for title: Germ%C3%A1n_Blanco_%C3%81lvarez
# Revision ID missing for title: Manuel_Jos%C3%A9_Bonnet
# Revision ID missing for title: Gloria_Mar%C3%ADa_Borrero
# Revision ID missing for title: Carlos_Fernando_Gal%C3%A1n
# Revision ID missing for title: Jos%C3%A9_Eusebio_Caro
# Revision ID missing for title: Ana_Mar%C3%ADa_Casta%C3%B1eda
# Revision ID missing for title: Iv%C3%A1n_Cepeda
# Revision ID missing for title: Juan_Jos%C3%A9_Chaux_Mosquera
# Revision ID missing for title: Alfonso_D%C3%A1vila_Ortiz
# Revision ID missing for title: Luis_Eduardo_D%C3%ADaz_Granados
# Revision ID missing for title: Eduardo_Wiesner_Dur%C3%A1n
# Revision ID missing for title: Eduardo_Enr%C3%ADquez_Maya
# Revision ID missing for title: Miguel_Am%C3%ADn_Escaf
# Revision ID missing for title: Claudio_Gal%C3%A1n_Pach%C3%B3n
# Revision ID missing for title: Juan_Garc%C3%ADa_del_R%C3%ADo
# Revision ID missing for title: Daniel_Garc%C3%ADa-Pe%C3%B1a
# Revision ID missing for title: Lucy_In%C3%A9s_Garc%C3%ADa
# Revision ID missing for title: Guillermo_Gonz%C3%A1lez_%28politician%29
# Revision ID missing for title: Augusto_Ib%C3%A1%C3%B1ez_Guzm%C3%A1n
# Revision ID missing for title: Gilma_Jim%C3%A9nez
# Revision ID missing for title: Rodrigo_Hern%C3%A1n_Lloreda_Caicedo
# Revision ID missing for title: Francisco_Jos%C3%A9_Lloreda_Mera
# Revision ID missing for title: Fernando_Londo%C3%B1o
# Revision ID missing for title: Jorge_Eduardo_Londo%C3%B1o
# Revision ID missing for title: Jorge_Miguel_Lozano%2C_Marquis_of_San_Jorge
# Revision ID missing for title: David_Luna_S%C3%A1nchez
# Revision ID missing for title: Iv%C3%A1n_Marulanda
# Revision ID missing for title: Carlos_Eduardo_Medell%C3%ADn_Becerra
# Revision ID missing for title: Germ%C3%A1n_Montoya_V%C3%A9lez
# Revision ID missing for title: Antonio_Ord%C3%B3%C3%B1ez_Plaja
# Revision ID missing for title: Fernando_Ospina_Hern%C3%A1ndez
# Revision ID missing for title: Enrique_Parejo_Gonz%C3%A1lez
# Revision ID missing for title: Carlos_Pizarro_Leong%C3%B3mez
# Revision ID missing for title: Manuel_Mar%C3%ADa_Ram%C3%ADrez_Fortoul
# Revision ID missing for title: Juan_Jos%C3%A9_Reyes-Patria_Escobar
# Revision ID missing for title: %C3%81ngela_Robledo
# Revision ID missing for title: Antonio_Rold%C3%A1n_Betancur
# Revision ID missing for title: Sixta_Pont%C3%B3n_de_Santander
# Revision ID missing for title: Oscar_Ter%C3%A1n_%28lawyer%29
# Revision ID missing for title: Ernesto_Mac%C3%ADas_Tovar
# Revision ID missing for title: Ram%C3%B3n_Maximiliano_Vald%C3%A9s
# Revision ID missing for title: Crist%C3%B3bal_de_Vergara_Azc%C3%A1rate
# Revision ID missing for title: Jos%C3%A9_Mar%C3%ADa_Vergara_y_Vergara
# Revision ID missing for title: Estanislao_Vergara_y_Sanz_de_Santamar%C3%ADa
# Revision ID missing for title: Sa%C3%AFd_Ibrahim_Ben_Ali
# Revision ID missing for title: Sa%C3%AFd_Mohamed_Cheikh
# Revision ID missing for title: Abdou_Soul%C3%A9_Elbak
# Revision ID missing for title: L%C3%A9on_Angor
# Revision ID missing for title: Fr%C3%A9d%C3%A9ric_Bintsamou
# Revision ID missing for title: Fid%C3%A8le_Dimou
# Revision ID missing for title: Gabriel_Val%C3%A8re_Eteka_Yemet
# Revision ID missing for title: Andr%C3%A9_Kerherv%C3%A9
# Revision ID missing for title: Andr%C3%A9_Matsoua
# Revision ID missing for title: %C3%89mile_Mokoko_Wongolo
# Revision ID missing for title: Ren%C3%A9-Dambert_Ndouane
# Revision ID missing for title: Jean_F%C3%A9lix_Demba_Telo
# Revision ID missing for title: C%C3%A9lestin_Cibalonza_Byaterana
# Revision ID missing for title: Martin_Parfait_Aim%C3%A9_Coussoud-Mavoungou
# Revision ID missing for title: Fran%C3%A7ois_Nic%C3%A9phore_Kakese
# Revision ID missing for title: Pierre_Honor%C3%A9_Kazadi_Lukonda_Ngube-Ngube
# Revision ID missing for title: L%C3%A9on_Kengo_wa_Dondo
# Revision ID missing for title: Ang%C3%A8le_Makombo
# Revision ID missing for title: Josu%C3%A9_Alex_Mukendi
# Revision ID missing for title: No%C3%ABl_K._Tshiani_Muadiamvita
# Revision ID missing for title: Alejandro_Alvarado_Garc%C3%ADa
# Revision ID missing for title: Antonio_Salda%C3%B1a
# Revision ID missing for title: Armando_Ar%C3%A1uz_Aguilar
# Revision ID missing for title: Juan_Jos%C3%A9_de_Bonilla_y_Herdocia
# Revision ID missing for title: Miguel_de_Bonilla_y_Laya-Bol%C3%ADvar
# Revision ID missing for title: Ram%C3%B3n_Castro_y_Ram%C3%ADrez
# Revision ID missing for title: Jos%C3%A9_Joaqu%C3%ADn_Chaverri_Sievert
# Revision ID missing for title: Jos%C3%A9_Miguel_Corrales_Bola%C3%B1os
# Revision ID missing for title: Aquileo_J._Echeverr%C3%ADa
# Revision ID missing for title: Gerardo_G%C3%B3mez_Ram%C3%ADrez
# Revision ID missing for title: Joaqu%C3%ADn_Guti%C3%A9rrez
# Revision ID missing for title: Fernando_Guzm%C3%A1n_Mata
# Revision ID missing for title: Gerardo_Guzm%C3%A1n_Quir%C3%B3s
# Revision ID missing for title: Joaqu%C3%ADn_de_Iglesias_Vidamartel
# Revision ID missing for title: Bernal_Jim%C3%A9nez_Monge
# Revision ID missing for title: Ram%C3%B3n_Jim%C3%A9nez_y_Robredo
# Revision ID missing for title: Jos%C3%A9_Miguel_Alfaro_Rodr%C3%ADguez
# Revision ID missing for title: Pedro_Mar%C3%ADa_Le%C3%B3n-P%C3%A1ez_y_Brown
# Revision ID missing for title: %C3%93scar_L%C3%B3pez_%28politician%29
# Revision ID missing for title: F%C3%A9lix_Arcadio_Montero_Monge
# Revision ID missing for title: Jos%C3%A9_Joaqu%C3%ADn_Mora_Porras
# Revision ID missing for title: Mar%C3%ADa_Teresa_Obreg%C3%B3n_Zamora
# Revision ID missing for title: Joaqu%C3%ADn_de_Oreamuno
# Revision ID missing for title: Manuel_Mar%C3%ADa_de_Peralta_y_Alfaro
# Revision ID missing for title: Jos%C3%A9_Mar%C3%ADa_de_Peralta
# Revision ID missing for title: Manuel_Mar%C3%ADa_de_Peralta_y_L%C3%B3pez_del_Corral
# Revision ID missing for title: Cipriano_P%C3%A9rez_y_Arias
# Revision ID missing for title: Carmen_Quesada_Santamar%C3%ADa
# Revision ID missing for title: Jos%C3%A9_Pablo_Quir%C3%B3s_Quir%C3%B3s
# Revision ID missing for title: Gregorio_Jos%C3%A9_Ram%C3%ADrez
# Revision ID missing for title: Rafael_Ram%C3%ADrez_Hidalgo
# Revision ID missing for title: Carlos_Ricardo_Benavides_Jim%C3%A9nez
# Revision ID missing for title: Tom%C3%A1s_Enrique_Soley_Soler
# Revision ID missing for title: Jos%C3%A9_Mar%C3%ADa_Soto_Alfaro
# Revision ID missing for title: Santos_Vel%C3%A1zquez_y_Tinoco
# Revision ID missing for title: William_Forbes_%28Talamancan_king%29
# Revision ID missing for title: Ivan_Anu%C5%A1i%C4%87
# Revision ID missing for title: Mato_Arlovi%C4%87
# Revision ID missing for title: Branko_Ba%C4%8Di%C4%87
# Revision ID missing for title: %C5%BDivko_Berti%C4%87
# Revision ID missing for title: Antun_Bonifa%C4%8Di%C4%87
# Revision ID missing for title: Andrija_Torkvat_Brli%C4%87
# Revision ID missing for title: Gajo_Bulat_%28politician%2C_born_1867%29
# Revision ID missing for title: Nade%C5%BEda_%C4%8Ca%C4%8Dinovi%C4%8D
# Revision ID missing for title: Gjuro_%C4%8Cervar
# Revision ID missing for title: Melko_%C4%8Cingrija
# Revision ID missing for title: Pero_%C4%8Cingrija
# Revision ID missing for title: Juraj_Demetrovi%C4%87
# Revision ID missing for title: Mate_Drinkovi%C4%87
# Revision ID missing for title: Nikica_Gabri%C4%87
# Revision ID missing for title: Leon_Ger%C5%A1kovi%C4%87
# Revision ID missing for title: Pavle_Gregori%C4%87
# Revision ID missing for title: Ernest_Jelu%C5%A1i%C4%87
# Revision ID missing for title: Emerik_Josipovi%C4%87
# Revision ID missing for title: Gejza_Josipovi%C4%87
# Revision ID missing for title: Radovan_Juri%C4%8Di%C4%87
# Revision ID missing for title: Stjepan_Kova%C4%8Devi%C4%87
# Revision ID missing for title: Izidor_Kr%C5%A1njavi
# Revision ID missing for title: %C5%A0ime_Kureli%C4%87
# Revision ID missing for title: Ante_Mandi%C4%87
# Revision ID missing for title: Gavro_Manojlovi%C4%87
# Revision ID missing for title: Vladimir_Ma%C5%BEurani%C4%87
# Revision ID missing for title: Kata_Pejnovi%C4%87
# Revision ID missing for title: Svetozar_Pribi%C4%87evi%C4%87
# Revision ID missing for title: Niko_Puci%C4%87
# Revision ID missing for title: Rafael_Puci%C4%87
# Revision ID missing for title: Mario_Radi%C4%87_%28politician%29
# Revision ID missing for title: Juraj_Rukavina_Vidovgradski_%28politician%29
# Revision ID missing for title: Juraj_Rukavina_Vidovgradski_%28soldier%29
# Revision ID missing for title: Ivan_Vilibor_Sin%C4%8Di%C4%87
# Revision ID missing for title: Tadija_Smi%C4%8Diklas
# Revision ID missing for title: Predrag_%C5%A0tromar
# Revision ID missing for title: Ante_%C5%A0upuk
# Revision ID missing for title: %C4%90uro_%C5%A0urmin
# Revision ID missing for title: Petar_Dragan_Turkovi%C4%87
# Revision ID missing for title: Vjenceslav_Turkovi%C4%87
# Revision ID missing for title: Ljudevit_Vukotinovi%C4%87
# Revision ID missing for title: Ve%C4%87eslav_Wilder
# Revision ID missing for title: Lordan_Zafranovi%C4%87
# Revision ID missing for title: Ivana_%C5%BDivkovi%C4%87
# Revision ID missing for title: Savo_Zlati%C4%87
# Revision ID missing for title: Ante_%C5%BDupanovi%C4%87
# Revision ID missing for title: Eduardo_Agramonte_Pi%C3%B1a
# Revision ID missing for title: Francisco_Ag%C3%BCero_Velasco
# Revision ID missing for title: Alberto_L%C3%B3pez_D%C3%ADaz
# Revision ID missing for title: Vicente_Manuel_de_C%C3%A9spedes
# Revision ID missing for title: Concepci%C3%B3n_Campa_Huergo
# Revision ID missing for title: Jos%C3%A9_Mar%C3%ADa_Coppinger
# Revision ID missing for title: Miguel_D%C3%ADaz-Canel
# Revision ID missing for title: Carlos_Fern%C3%A1ndez_Gond%C3%ADn
# Revision ID missing for title: Francisco_de_Arango_y_Parre%C3%B1o
# Revision ID missing for title: Edith_Garc%C3%ADa_Buchaca
# Revision ID missing for title: Eumel%C3%ADn_Gonz%C3%A1lez_S%C3%A1nchez
# Revision ID missing for title: Jos%C3%A9_Irisarri
# Revision ID missing for title: Jos%C3%A9_Francisco_Lemus
# Revision ID missing for title: Rub%C3%A9n_Mart%C3%ADnez_Puente
# Revision ID missing for title: Augusto_Mart%C3%ADnez_S%C3%A1nchez
# Revision ID missing for title: Bartolom%C3%A9_Mas%C3%B3
# Revision ID missing for title: Ram%C3%B3n_Meza_y_Su%C3%A1rez_Incl%C3%A1n
# Revision ID missing for title: Bartolom%C3%A9_Morales
# Revision ID missing for title: Jos%C3%A9_N%C3%BA%C3%B1ez_de_C%C3%A1ceres
# Revision ID missing for title: Juan_Vitalio_Acu%C3%B1a_N%C3%BA%C3%B1ez
# Revision ID missing for title: Frank_Pa%C3%ADs
# Revision ID missing for title: Pedro_Esteban_Gonz%C3%A1lez-Larrinaga
# Revision ID missing for title: Luis_Alberto_Rodr%C3%ADguez_L%C3%B3pez-Calleja
# Revision ID missing for title: Francisco_S%C3%A1nchez_Betancourt
# Revision ID missing for title: Salvador_Jos%C3%A9_de_Muro%2C_2nd_Marquis_of_Someruelos
# Revision ID missing for title: Salvador_Vald%C3%A9s_Mesa
# Revision ID missing for title: Mine_Atl%C4%B1
# Revision ID missing for title: Christos_Christou_%28politician%29
# Revision ID missing for title: Josef_Bar%C3%A1k
# Revision ID missing for title: Dagmar_Bure%C5%A1ov%C3%A1
# Revision ID missing for title: Franti%C5%A1ek_Ringo_%C4%8Cech
# Revision ID missing for title: Jaroslav_Chalupsk%C3%BD
# Revision ID missing for title: Count_V%C3%A1clav_Anton%C3%ADn_Chotek_of_Chotkov_and_Vojn%C3%ADn
# Revision ID missing for title: Josef_%C5%A0ebesti%C3%A1n_Daubek
# Revision ID missing for title: Vladim%C3%ADr_Franz
# Revision ID missing for title: Josef_V%C3%A1clav_Fri%C4%8D
# Revision ID missing for title: Tom%C3%A1%C5%A1_Grulich
# Revision ID missing for title: Karel_Havl%C3%ADk
# Revision ID missing for title: Vladim%C3%ADr_Hu%C4%8D%C3%ADn
# Revision ID missing for title: Anton%C3%ADn_Janou%C5%A1ek
# Revision ID missing for title: Josef_Je%C5%BEek
# Revision ID missing for title: Ladislav_Jirk%C5%AF
# Revision ID missing for title: Svatopluk_Kar%C3%A1sek
# Revision ID missing for title: Wenzel_Anton%2C_Prince_of_Kaunitz-Rietberg
# Revision ID missing for title: Ji%C5%99%C3%AD_Kopal
# Revision ID missing for title: Jan_Krej%C4%8D%C3%AD
# Revision ID missing for title: Tom%C3%A1%C5%A1_Kvapil
# Revision ID missing for title: Lubom%C3%ADr_Ledl
# Revision ID missing for title: Miroslav_Lidinsk%C3%BD
# Revision ID missing for title: Ji%C5%99%C3%AD_Lobkowicz
# Revision ID missing for title: Ji%C5%99%C3%AD_L%C3%B6w
# Revision ID missing for title: Ivan_Ma%C5%A1ek
# Revision ID missing for title: Mikul%C3%A1%C5%A1_of_Hus
# Revision ID missing for title: Zden%C4%9Bk_Mra%C4%8Dek
# Revision ID missing for title: Jana_Ne%C4%8Dasov%C3%A1
# Revision ID missing for title: Ji%C5%99%C3%AD_Oberfalzer
# Revision ID missing for title: Vladim%C3%ADr_Oplt
# Revision ID missing for title: Mojm%C3%ADr_Povoln%C3%BD
# Revision ID missing for title: Vladim%C3%ADr_Pr%C3%ADkazsk%C3%BD
# Revision ID missing for title: Ond%C5%99ej_P%C5%99ikryl
# Revision ID missing for title: Franti%C5%A1ek_Reichel
# Revision ID missing for title: Bed%C5%99ich_Reicin
# Revision ID missing for title: Tom%C3%A1%C5%A1_Eduard_%C5%A0ilinger
# Revision ID missing for title: Karel_Sladkovsk%C3%BD
# Revision ID missing for title: Karel_%C5%A0togl
# Revision ID missing for title: Mat%C4%9Bj_Stropnick%C3%BD
# Revision ID missing for title: Ji%C5%99%C3%AD_Svoboda_%28director%29
# Revision ID missing for title: Leopold%2C_Count_von_Thun_und_Hohenstein
# Revision ID missing for title: Tom%C3%A1%C5%A1_Vandas
# Revision ID missing for title: Ji%C5%99%C3%AD_Ventruba
# Revision ID missing for title: Jan_Vrba_%28politician%29
# Revision ID missing for title: Stanislav_%C5%BDalud
# Revision ID missing for title: Jos%C3%A9_Rafael_Abinader
# Revision ID missing for title: Roberto_%C3%81lvarez_Gil
# Revision ID missing for title: Ram%C3%B3n_Marrero_Aristy
# Revision ID missing for title: Jos%C3%A9_Mar%C3%ADa_Cabral_y_B%C3%A1ez
# Revision ID missing for title: Jos%C3%A9_Mar%C3%ADa_Caminero
# Revision ID missing for title: Ram%C3%B3n_Tapia_Espinal
# Revision ID missing for title: Jos%C3%A9_Gabriel_Garc%C3%ADa
# Revision ID missing for title: Rosa_G%C3%B3mez_de_Mej%C3%ADa
# Revision ID missing for title: Maximiliano_G%C3%B3mez
# Revision ID missing for title: Juan_Isidro_Jimenes_Grull%C3%B3n
# Revision ID missing for title: Valentin_Medrano_P%C3%A9rez
# Revision ID missing for title: Miguel_Mej%C3%ADa_%28politician%29
# Revision ID missing for title: Mat%C3%ADas_Ram%C3%B3n_Mella
# Revision ID missing for title: Guillermo_Moreno_Garc%C3%ADa
# Revision ID missing for title: Jos%C3%A9_Ignacio_Paliza
# Revision ID missing for title: Porfirio_Andr%C3%A9s_Bautista_Garc%C3%ADa
# Revision ID missing for title: Emilio_Prud%27Homme
# Revision ID missing for title: Ram%C3%B3n_Antonio_Ram%C3%ADrez
# Revision ID missing for title: Juan_S%C3%A1nchez_Ram%C3%ADrez
# Revision ID missing for title: Francisco_del_Rosario_S%C3%A1nchez
# Revision ID missing for title: Juli%C3%A1n_Serulle
# Revision ID missing for title: Tom%C3%A1s_Pimentel
# Revision ID missing for title: El%C3%ADas_Wessin_y_Wessin
# Revision ID missing for title: Jorge_Radham%C3%A9s_Zorrilla_Ozuna
# Revision ID missing for title: Alian%C3%A7a_de_Ara%C3%BAjo
# Revision ID missing for title: Manuel_Carrascal%C3%A3o
# Revision ID missing for title: Brigida_Ant%C3%B3nia_Correia
# Revision ID missing for title: Albina_Mar%C3%A7al_Freitas
# Revision ID missing for title: %C3%81ngela_Freitas
# Revision ID missing for title: Jos%C3%A9_Ab%C3%ADlio_Os%C3%B3rio_Soares
# Revision ID missing for title: Jo%C3%A3o_da_Costa_Tavares
# Revision ID missing for title: M%C3%A1rio_Viegas_Carrascal%C3%A3o
# Revision ID missing for title: Mar%C3%ADa_Sol_Corral
# Revision ID missing for title: Jaime_Dur%C3%A1n_Barba
# Revision ID missing for title: Ibeth_Estupi%C3%B1%C3%A1n
# Revision ID missing for title: Guillermo_Franco_%28Ecuadorian_general%29
# Revision ID missing for title: Andrea_Gonz%C3%A1lez_N%C3%A1der
# Revision ID missing for title: Agust%C3%ADn_Intriago
# Revision ID missing for title: Luis_A._Mart%C3%ADnez
# Revision ID missing for title: Mayra_Monta%C3%B1o
# Revision ID missing for title: Diego_Morej%C3%B3n
# Revision ID missing for title: M%C3%B3nica_Palencia
# Revision ID missing for title: Ismael_P%C3%A9rez_Pazmi%C3%B1o
# Revision ID missing for title: Ahmed_Issa_%28Egyptian_politician%29
# Revision ID missing for title: Elmar_J%C3%A4rvesoo
# Revision ID missing for title: J%C3%BCri_Liim
# Revision ID missing for title: Theodor_R%C3%B5uk
# Revision ID missing for title: Toomas_Sildm%C3%A4e
# Revision ID missing for title: Georg_Tra%C5%A1anov
# Revision ID missing for title: Su%27ad_Ahmed_Farah
# Revision ID missing for title: Erik_Berg_%28politician%29
# Revision ID missing for title: Erik_Fleming_%28councilor%29
# Revision ID missing for title: Fritz_Arthur_Jus%C3%A9lius
# Revision ID missing for title: Carl_Fabian_Langenski%C3%B6ld
# Revision ID missing for title: Olavi_M%C3%A4enp%C3%A4%C3%A4
# Revision ID missing for title: Konni_Zilliacus_%28senior%29
# Revision ID missing for title: Jean-Fran%C3%A7ois_Bazin
# Revision ID missing for title: Bureau_de_La_Rivi%C3%A8re
# Revision ID missing for title: %C3%89tienne-Laurent-Pierre_Burnel
# Revision ID missing for title: Jean_Capelle_%28politician%29
# Revision ID missing for title: Jean_Auguste_de_Chastenet_de_Puys%C3%A9gur
# Revision ID missing for title: Jacques_Antoine_Creuz%C3%A9-Latouche
# Revision ID missing for title: Louis_Gr%C3%A9goire_Deschamps_Destournelles
# Revision ID missing for title: Th%C3%A9odore_Ducos
# Revision ID missing for title: %C3%89douard_Dunglas
# Revision ID missing for title: Jules-Fran%C3%A7ois-Paul_Fauris_de_Saint-Vincens
# Revision ID missing for title: Jacques_Fournier_%28government_official%29
# Revision ID missing for title: Xavier_de_F%C3%BCrst
# Revision ID missing for title: Ag%C3%A9nor_de_Gasparin
# Revision ID missing for title: Joseph_Matthias_G%C3%A9rard_de_Rayneval
# Revision ID missing for title: Charles_Le_B%C3%A8gue_de_Germiny
# Revision ID missing for title: Maurice_d%27Hartoy
# Revision ID missing for title: Guy_Hasco%C3%ABt
# Revision ID missing for title: Jean_Louvet_%28politician%29
# Revision ID missing for title: %C3%89tienne_de_La_Grange
# Revision ID missing for title: Guillaume-Xavier_Labbey_de_Pompi%C3%A8res
# Revision ID missing for title: Chr%C3%A9tien_Fran%C3%A7ois_de_Lamoignon_de_Basville
# Revision ID missing for title: Hyacinthe_Ga%C3%ABtan_de_Lannion
# Revision ID missing for title: Henri_Martin_%28winemaker%29
# Revision ID missing for title: Jean_Matt%C3%A9oli
# Revision ID missing for title: Jeanne_M%C3%A9lin
# Revision ID missing for title: Paul_Mentr%C3%A9
# Revision ID missing for title: Joseph_Fran%C3%A7ois_Augustin_Monneron
# Revision ID missing for title: G%C3%A9rard_Montassier
# Revision ID missing for title: Bernard_Morel_%28economist%29
# Revision ID missing for title: Ilham_Moussa%C3%AFd
# Revision ID missing for title: %C3%89rik_Orsenna
# Revision ID missing for title: H%C3%A9l%C3%A8ne_Pelosse
# Revision ID missing for title: Fran%C3%A7ois-Xavier_de_Peretti
# Revision ID missing for title: Joseph_P%C3%A9rier
# Revision ID missing for title: Henri_Peyroux_de_la_Coudreni%C3%A8re
# Revision ID missing for title: Louis_Ph%C3%A9lypeaux%2C_comte_de_Saint-Florentin
# Revision ID missing for title: Louis_Ph%C3%A9lypeaux%2C_Marquis_of_La_Vrilli%C3%A8re
# Revision ID missing for title: Louis_Ph%C3%A9lypeaux%2C_Seigneur_of_La_Vrilli%C3%A8re
# Revision ID missing for title: Jean-Pierre_Casimir_de_Marcassus%2C_Baron_de_Puymaurin
# Revision ID missing for title: Ren%C3%A9_Ribi%C3%A8re
# Revision ID missing for title: Joseph_Romain-Desfoss%C3%A9s
# Revision ID missing for title: Fran%C3%A7ois-Alexandre_Tardiveau
# Revision ID missing for title: Fran%C3%A7ois_Auguste_de_Thou
# Revision ID missing for title: Anguil%C3%A8_R%C3%A9-Dow%C3%A9
# Revision ID missing for title: Lee_White_%28conservationist%29
# Revision ID missing for title: Werner_E._Abla%C3%9F
# Revision ID missing for title: Heinrich_Flei%C3%9Fner
# Revision ID missing for title: Paul_Fugger_von_Kirchberg_und_Wei%C3%9Fenhorn
# Revision ID missing for title: G%C3%BCnter_Gaus
# Revision ID missing for title: Hermann_Heller_%28legal_scholar%29
# Revision ID missing for title: Franz_Christoph_Anton%2C_Count_of_Hohenzollern-Sigmaringen
# Revision ID missing for title: Martin_Horn_%28politician%29
# Revision ID missing for title: Bernd_H%C3%BCttemann
# Revision ID missing for title: Johann_Ludwig_Kl%C3%BCber
# Revision ID missing for title: Tobias_K%C3%B6ck
# Revision ID missing for title: Ludwig_von_L%C3%BCtzow_%28politician%29
# Revision ID missing for title: Wolfgang_M%C3%BCller_von_K%C3%B6nigswinter
# Revision ID missing for title: Hermann_Sch%C3%A4fer
# Article missing for title: Richard Sumah
# Revision ID missing for title: Joachim%2C_Count_of_Sch%C3%B6nburg-Glauchau
# Revision ID missing for title: Adam%2C_Count_of_Schwarzenberg
# Revision ID missing for title: Adelheid_Tr%C3%B6scher
# Revision ID missing for title: Ioannis_Gryparis_%281848-1922%29
# Revision ID missing for title: Yannis_Moralis_%28politician%29
# Revision ID missing for title: Roberto_Arz%C3%BA
# Revision ID missing for title: Jos%C3%A9_Alejandro_de_Aycinena
# Revision ID missing for title: Juan_Jos%C3%A9_de_Aycinena_y_Pi%C3%B1ol
# Revision ID missing for title: Mariano_de_Aycinena_y_Pi%C3%B1ol
# Revision ID missing for title: Jos%C3%A9_Francisco_Barrundia
# Revision ID missing for title: Jos%C3%A9_Batres_Mont%C3%BAfar
# Revision ID missing for title: Estuardo_Gald%C3%A1mez
# Revision ID missing for title: Jorge_Garc%C3%ADa_Granados
# Revision ID missing for title: Joaqu%C3%ADn_M%C3%A9ndez
# Revision ID missing for title: Jos%C3%A9_Milla_y_Vidaurre
# Revision ID missing for title: Manuel_Francisco_Pav%C3%B3n_Aycinena
# Revision ID missing for title: Carlos_Pineda_%28politician%29
# Revision ID missing for title: M%C3%A1ximo_Santa_Cruz
# Revision ID missing for title: Fod%C3%A9_Bangoura
# Revision ID missing for title: %C3%89douard_Benjamin
# Revision ID missing for title: S%C3%A9ny_Camara
# Revision ID missing for title: Moussa_Diakit%C3%A9_%28politician%29
# Revision ID missing for title: Mamadou_Path%C3%A9_Diallo
# Revision ID missing for title: Lansana_Dian%C3%A9
# Revision ID missing for title: Fod%C3%A9ba_Ke%C3%AFta
# Revision ID missing for title: Ibrahima_Ab%C3%A9_Sylla
# Revision ID missing for title: Facinet_Tour%C3%A9
# Revision ID missing for title: Fode_Mamadou_Tour%C3%A9
# Revision ID missing for title: Isma%C3%ABl_Tour%C3%A9
# Revision ID missing for title: John_Carter_%28ambassador%29
# Revision ID missing for title: Fritz_B%C3%A9lizaire
# Revision ID missing for title: Rony_C%C3%A9lestin
# Revision ID missing for title: G%C3%A9rard_Gourgue
# Revision ID missing for title: Jean-Chrisost%C3%B4me_Imbert
# Revision ID missing for title: Joseph_M%C3%A9c%C3%A8ne_Jean-Louis
# Revision ID missing for title: Joseph_Lambert_%28Haitian_politician%29
# Revision ID missing for title: Robert_Manuel_%28politician%29
# Revision ID missing for title: Fr%C3%A9d%C3%A9ric_Marcelin
# Revision ID missing for title: Solon_M%C3%A9nos
# Revision ID missing for title: Andr%C3%A9_Michel_%28lawyer%29
# Revision ID missing for title: Jovenel_Mo%C3%AFse
# Revision ID missing for title: %C3%89mile_Nau
# Revision ID missing for title: Pomp%C3%A9e_Valentin_Vastey
# Revision ID missing for title: Jos%C3%A9_Francisco_Barrundia
# Revision ID missing for title: An%C3%ADbal_Delgado_Fiallos
# Revision ID missing for title: Miguel_Andonie_Fern%C3%A1ndez
# Revision ID missing for title: Carlos_Z%C3%BA%C3%B1iga_Figueroa
# Revision ID missing for title: %C3%81ngel_G._Hern%C3%A1ndez
# Revision ID missing for title: Jos%C3%A9_Jeronimo_Zelaya
# Revision ID missing for title: Jos%C3%A9_Mar%C3%ADa_Martinez_Salinas
# Revision ID missing for title: Joaqu%C3%ADn_Rivera
# Revision ID missing for title: Marlon_T%C3%A1bora_Mu%C3%B1oz
# Revision ID missing for title: Jos%C3%A9_Cecilio_del_Valle
# Revision ID missing for title: Alad%C3%A1r_Andr%C3%A1ssy
# Revision ID missing for title: Gy%C3%B6rgy_Andr%C3%A1ssy
# Revision ID missing for title: K%C3%A1roly_Andr%C3%A1ssy
# Revision ID missing for title: Tam%C3%A1s_Bak%C3%B3cz
# Revision ID missing for title: Stephen_VII_B%C3%A1thory
# Revision ID missing for title: Balthasar_B%C3%A1thory
# Revision ID missing for title: Stephen_III_B%C3%A1thory
# Revision ID missing for title: Stephen_V_B%C3%A1thory
# Revision ID missing for title: D%C3%A1vid_B%C3%A9lav%C3%A1ry
# Revision ID missing for title: M%C3%A1rton_Berzeviczy
# Revision ID missing for title: J%C3%A1nos_Bethlen
# Revision ID missing for title: Zolt%C3%A1n_B%C3%B6sz%C3%B6rm%C3%A9ny
# Revision ID missing for title: Mih%C3%A1ly_Cs%C3%A1ky
# Revision ID missing for title: Zolt%C3%A1n_Cs%C3%A9falvay
# Revision ID missing for title: D%C3%A9nes_Farkas
# Revision ID missing for title: John_Dr%C3%A1gfi
# Revision ID missing for title: Gy%C3%B6rgy_Ekrem-Kem%C3%A1l
# Revision ID missing for title: L%C3%A1szl%C3%B3_Endre
# Revision ID missing for title: Ferenc_Esterh%C3%A1zy_%281715%E2%80%931785%29
# Revision ID missing for title: J%C3%A1nos_Nepomuk_Farkas
# Revision ID missing for title: J%C3%B3zsef_Farkas_%28politician%29
# Revision ID missing for title: Andr%C3%A1s_F%C3%A1y
# Revision ID missing for title: P%C3%A9ter_F%C3%BCl%C3%B6p
# Revision ID missing for title: J%C3%A1nos_Fuzik
# Revision ID missing for title: J%C3%A1nos_Ghyczy
# Revision ID missing for title: Ott%C3%B3_Herman
# Revision ID missing for title: J%C3%B3zsef_Hertelendy_%281833%E2%80%931891%29
# Revision ID missing for title: S%C3%A1ndor_Holl%C3%A1n_Jr.
# Revision ID missing for title: S%C3%A1ndor_Holl%C3%A1n_Sr.
# Revision ID missing for title: Istv%C3%A1n_Horthy
# Revision ID missing for title: Mikl%C3%B3s_Horthy_Jr.
# Revision ID missing for title: G%C3%A1bor_Hrask%C3%B3
# Revision ID missing for title: L%C3%A1szl%C3%B3_Hunyady_de_K%C3%A9thely
# Revision ID missing for title: J%C3%A1nos_Imreffy
# Revision ID missing for title: Gy%C5%91z%C5%91_Ist%C3%B3czy
# Revision ID missing for title: Mikl%C3%B3s_Istv%C3%A1nffy
# Revision ID missing for title: Oszk%C3%A1r_J%C3%A1szi
# Revision ID missing for title: S%C3%A1ndor_J%C3%B3zan
# Revision ID missing for title: Mih%C3%A1ly_K%C3%A1thay
# Revision ID missing for title: Istv%C3%A1n_Kendi
# Revision ID missing for title: S%C3%A1ndor_Kendi
# Revision ID missing for title: Ferenc_K%C3%B6lcsey
# Revision ID missing for title: Orb%C3%A1n_Kolomp%C3%A1r
# Revision ID missing for title: Juraj_Ko%C5%A1%C3%BAt
# Revision ID missing for title: Gergely_Kov%C3%A1cs_%28politician%29
# Revision ID missing for title: Farkas_Kovacs%C3%B3czy
# Revision ID missing for title: Istv%C3%A1n_Kovacs%C3%B3czy
# Revision ID missing for title: George_Lichtenstein_%28musician%29
# Revision ID missing for title: Gy%C3%B6rgy_Magyar
# Revision ID missing for title: G%C3%A9za_Malasits
# Revision ID missing for title: Ern%C5%91_Mesterh%C3%A1zy
# Revision ID missing for title: Mih%C3%A1ly_Mikes_%28politician%29
# Revision ID missing for title: Mih%C3%A1ly_Mikes_%28soldier%29
# Revision ID missing for title: D%C3%A9nes_P%C3%A1zm%C3%A1ndy_%281848%E2%80%931936%29
# Revision ID missing for title: J%C3%A1nos_Petki
# Revision ID missing for title: J%C3%A1nos_Petr%C3%A1n
# Revision ID missing for title: J%C3%A1nos_Radv%C3%A1nyi
# Revision ID missing for title: Iv%C3%A1n_Skerlecz
# Revision ID missing for title: L%C3%A1szl%C3%B3_Sombori
# Revision ID missing for title: L%C3%A1szl%C3%B3_Szalay
# Revision ID missing for title: Gy%C3%B6rgy_Szap%C3%A1ry
# Revision ID missing for title: R%C3%A9ka_Szemerk%C3%A9nyi
# Revision ID missing for title: P%C3%A1l_Szinyei_Merse
# Revision ID missing for title: G%C3%A9za_Sz%C5%91cs
# Revision ID missing for title: B%C3%A9la_Szombati
# Revision ID missing for title: Mih%C3%A1ly_Teleki
# Revision ID missing for title: K%C3%A1lm%C3%A1n_Thaly
# Revision ID missing for title: Gy%C3%B6rgy_Thurz%C3%B3
# Revision ID missing for title: Vilmos_V%C3%A1lyi-Nagy
# Revision ID missing for title: Guszt%C3%A1v_Vizsolyi
# Revision ID missing for title: B%C3%A9la_V%C3%B6r%C3%B6smarty
# Revision ID missing for title: Paul_Wittich_%28politician%29
# Revision ID missing for title: Ajay_Kumar_Singh_%28Bihar_politician%2C_Indian_National_Congress%29
# Revision ID missing for title: Hemant_Joshi_%28politician%29
# Revision ID missing for title: S._Murugesan_%28DMK_politician%29
# Revision ID missing for title: Talk%3AChamala_Kiran_Kumar_Reddy
# Revision ID missing for title: Sanjeev_Kumar_Singh_%28politician%29
# Revision ID missing for title: Alok_Sharma_%28Indian_politician%29
# Revision ID missing for title: Manju_Sharma_%28politician%29
# Revision ID missing for title: Mukesh_Sharma_%28BJP_politician%29
# Revision ID missing for title: Angad_Singh_%28BJP_politician%29
# Revision ID missing for title: Devendra_Pratap_Singh_%28UP_politician%29
# Revision ID missing for title: Dharmendra_Singh_%28politician%29
# ...
# Revision ID missing for title: Moon_Sung-hyun_%28politician%29
# Revision ID missing for title: Park_Joo-hyun_%28politician%29
# Revision ID missing for title: Park_Ju-won_%28politician%29
# Revision ID missing for title: Park_Jun-young_%28government_official%29
# Revision ID missing for title: Yun_Young-sun_%28minister%29
# Revision ID missing for title: Claro_Ab%C3%A1nades_L%C3%B3pez
# Revision ID missing for title: Joaqu%C3%ADn_Abarca
# Revision ID missing for title: Luis_Alarc%C3%B3n_de_la_Lastra
# Revision ID missing for title: Gil_%C3%81lvarez_Carrillo_de_Albornoz
# Revision ID missing for title: Tom%C3%A1s_Allende
# Revision ID missing for title: Luis_Almarcha_Hern%C3%A1ndez
# Revision ID missing for title: Fadrique_de_Toledo%2C_1st_Marquess_of_Valdueza
# Revision ID missing for title: Fadrique_Alvarez_de_Toledo_y_Ponce_de_Le%C3%B3n
# Revision ID missing for title: Fernando_%C3%81lvarez_de_Toledo%2C_3rd_Duke_of_Alba
# Revision ID missing for title: Garc%C3%ADa_%C3%81lvarez_de_Toledo_y_Osorio
# Revision ID missing for title: Garc%C3%ADa_de_Toledo_Osorio%2C_6th_Marquess_of_Villafranca
# Revision ID missing for title: Manuel_Joaqu%C3%ADn_%C3%81lvarez_de_Toledo
# Revision ID missing for title: Pedro_de_Toledo_Osorio%2C_5th_Marquess_of_Villafranca
# Revision ID missing for title: Diego_de_Alvear_y_Ponce_de_Le%C3%B3n
# Revision ID missing for title: Mart%C3%ADn_de_%C3%81lzaga
# Revision ID missing for title: Antonio_Guti%C3%A9rrez_y_Ulloa
# Revision ID missing for title: Ram%C3%B3n_de_Aras_J%C3%A1uregui
# Revision ID missing for title: Manuel_de_Ar%C3%B3stegui_S%C3%A1enz_de_Olamendi
# Revision ID missing for title: Anna_Arqu%C3%A9_i_Solsona
# Revision ID missing for title: Antonio_Arr%C3%BAe_Zarauz
# Revision ID missing for title: Ignacio_Baleztena_Asc%C3%A1rate
# Revision ID missing for title: Jos%C3%A9_Baqu%C3%ADjano_y_Carrillo%2C_Count_of_Vistaflorida
# Revision ID missing for title: Alfonso_Soriano_Ben%C3%ADtez_de_Lugo
# Revision ID missing for title: Joseph_Bl%C3%A1s_de_Gainza
# Revision ID missing for title: Francisco_Tadeo_Calomarde%2C_1st_Duke_of_Santa_Isabel
# Revision ID missing for title: Jos%C3%A9_Manuel_Campa
# Revision ID missing for title: Carlos_Ca%C3%B1al_y_Migolla
# Revision ID missing for title: Antonio_Carro_Mart%C3%ADnez
# Revision ID missing for title: Nicol%C3%A1s_de_Carvajal%2C_Marquis_of_Sarria
# Revision ID missing for title: Francesc_de_Castellv%C3%AD_i_de_Vic
# Revision ID missing for title: Juan_Francisco_de_la_Cerda%2C_8th_Duke_of_Medinaceli
# Revision ID missing for title: Luis_Francisco_de_la_Cerda%2C_9th_Duke_of_Medinaceli
# Revision ID missing for title: Ram%C3%B3n_Ch%C3%ADes
# Revision ID missing for title: Diego_Clemenc%C3%ADn
# Revision ID missing for title: Diego_D%C3%A1vila_Mes%C3%ADa_y_Guzm%C3%A1n%2C_3rd_Marquess_of_Legan%C3%A9s
# Revision ID missing for title: Rafael_de_Mendiz%C3%A1bal_Allende
# Revision ID missing for title: Juan_Donoso_Cort%C3%A9s
# Revision ID missing for title: Juli%C3%A1n_Elorza_Aizpuru
# Revision ID missing for title: V%C3%ADctor_Eusa_Razquin
# Revision ID missing for title: Diego_Felipez_de_Guzm%C3%A1n%2C_1st_Marquess_of_Legan%C3%A9s
# Revision ID missing for title: Evaristo_Fern%C3%A1ndez_de_San_Miguel
# Revision ID missing for title: Miguel_%C3%81ngel_Fern%C3%A1ndez-Palacios
# Revision ID missing for title: %C3%81lvaro_Gil-Robles
# Revision ID missing for title: Gaspar_M%C3%A9ndez_de_Haro%2C_7th_Marquess_of_Carpio
# Revision ID missing for title: Pedro_Henriquez_de_Acevedo%2C_Count_of_Fuentes
# Revision ID missing for title: Eleazar_Huerta_Valc%C3%A1rcel
# Revision ID missing for title: Alonso_de_Idi%C3%A1quez_y_Yurramendi
# Revision ID missing for title: Manuel_Jim%C3%A9nez_de_Parga
# Revision ID missing for title: Jos%C3%A9_Pascual_de_Li%C3%B1%C3%A1n_y_Eguiz%C3%A1bal
# Revision ID missing for title: Pero_L%C3%B3pez_de_Ayala
# Revision ID missing for title: Luis_Rosado_Bret%C3%B3n
# Revision ID missing for title: %C3%81lvaro_de_Luna
# Revision ID missing for title: Juan_Manuel_Fern%C3%A1ndez_Pacheco%2C_8th_Duke_of_Escalona
# Revision ID missing for title: Dolors_Mart%C3%AD_Dom%C3%A8nech
# Revision ID missing for title: Jos%C3%A9_Luna_Mel%C3%A9ndez
# Revision ID missing for title: Luis_M%C3%A9ndez_de_Haro
# Revision ID missing for title: Marcelino_Men%C3%A9ndez_y_Pelayo
# Revision ID missing for title: Salvador_Minguij%C3%B3n_Adri%C3%A1n
# Revision ID missing for title: Pep_M%C3%B2dol
# Revision ID missing for title: %C3%81lvaro_d%27Ors_P%C3%A9rez-Peix
# Revision ID missing for title: Rom%C3%A1n_Oyarzun_Oyarzun
# Revision ID missing for title: Javier_Mar%C3%ADa_Pascual_Iba%C3%B1ez
# Revision ID missing for title: Pedro_Antonio_de_Arag%C3%B3n
# Revision ID missing for title: Juan_Manuel_de_la_Pe%C3%B1a_Bonifaz
# Revision ID missing for title: Antonio_P%C3%A9rez_Crespo
# Revision ID missing for title: Antonio_P%C3%A9rez_%28statesman%29
# Revision ID missing for title: Pablo_de_Porturas_y_Land%C3%A1zuri
# Revision ID missing for title: Jes%C3%BAs_Quijano
# Revision ID missing for title: Miguel_Romero_%28activist%29
# Revision ID missing for title: Rafael_S%C3%A1nchez_Guerra
# Revision ID missing for title: Bel%C3%A9n_de_S%C3%A1rraga
# Revision ID missing for title: Jos%C3%A9_Sisto
# Revision ID missing for title: Pedro_Soto_%28politician%29
# Revision ID missing for title: Juan_de_Tassis%2C_1st_Count_of_Villamediana
# Revision ID missing for title: Francisco_El%C3%ADas_de_Tejada_y_Sp%C3%ADnola
# Revision ID missing for title: Jos%C3%A9_Perell%C3%B3_Torrens
# Revision ID missing for title: Fernando_de_Vald%C3%A9s_y_Salas
# Revision ID missing for title: Rodrigo_V%C3%A1zquez_de_Arce
# Revision ID missing for title: Jos%C3%A9_Joaqu%C3%ADn_de_Viana
# Revision ID missing for title: Narc%C3%ADs_Vinyoles
# Revision ID missing for title: Mariano_Zuf%C3%ADa_Urrizalqui
# Revision ID missing for title: National_Union_of_Workers_%28Sri_Lanka%29
# Revision ID missing for title: Up-Country_People%27s_Front
# Revision ID missing for title: Ja%27afar_Abdul_El_Hakh
# Revision ID missing for title: Muhammad_Sa%27id_al-Qaddal
# Revision ID missing for title: Muhammad_Sharif_%28Kalifa%29
# Revision ID missing for title: Nils_Cla%C3%ABson
# Revision ID missing for title: Martin_Ekstr%C3%B6m
# Revision ID missing for title: G%C3%B6sta_Hallberg-Cuula
# Revision ID missing for title: Anders_Henriksson_%28politician%29
# Revision ID missing for title: Vilhelm_Lundstr%C3%B6m_%28philologist%29
# Revision ID missing for title: Magnus_Minniski%C3%B6ld
# Revision ID missing for title: Erik_Carlsson_Sj%C3%B6blad
# Revision ID missing for title: Jimmy_St%C3%A5hl
# Revision ID missing for title: V%C3%A1vra_Suk
# Revision ID missing for title: Lars_T%C3%B6rnman
# Revision ID missing for title: Ulrika_Bj%C3%B6rklund
# Revision ID missing for title: Adolf_B%C3%BChler_Jr.
# Revision ID missing for title: Nina_Fehr_D%C3%BCsel
# Revision ID missing for title: Andr%C3%A9_Hediger
# Revision ID missing for title: Heidi_Z%27graggen
# Revision ID missing for title: David_Hess_%28painter%29
# Revision ID missing for title: Jean-Pierre_Hock%C3%A9
# Revision ID missing for title: Walter_K%C3%A4lin
# Revision ID missing for title: Fr%C3%A9d%C3%A9ric-C%C3%A9sar_de_La_Harpe
# Revision ID missing for title: Paul_L%C3%BC%C3%B6nd
# Revision ID missing for title: Martin_H%C3%BCbscher
# Revision ID missing for title: Kurt_Meyer_%28Lucerne%29
# Revision ID missing for title: Damian_M%C3%BCller
# Revision ID missing for title: Eduard_August_R%C3%BCbel
# Revision ID missing for title: Vinzenz_R%C3%BCttimann
# Revision ID missing for title: Nicolas_Th%C3%A9odore_de_Saussure
# Revision ID missing for title: Andr%C3%A9_Simonazzi
# Revision ID missing for title: Charles-Alexandre_Steinh%C3%A4uslin
# Revision ID missing for title: Hansj%C3%B6rg_Trachsel
# Revision ID missing for title: Hadad-yith%27i
# Revision ID missing for title: Mar%27i_Pasha_al-Mallah
# Revision ID missing for title: Mustafa_al-Siba%27i
# Revision ID missing for title: Myriam_Dossou_D%27Almeida
# Revision ID missing for title: Cl%C3%A9ment_Nyaletsossi_Voule
# Revision ID missing for title: Enele_Ma%CA%BBafu
# Revision ID missing for title: Siaosi_Tuku%CA%BBaho
# Revision ID missing for title: Tevita_Tu%CA%BBivakano
# Revision ID missing for title: Viliami_Tupoulahi_Mailefihi_Tuku%27aho
# Revision ID missing for title: %CA%BBUluvalu
# Revision ID missing for title: Gypsy_%28calypsonian%29
# Revision ID missing for title: David_Pitt%2C_Baron_Pitt_of_Hampstead
# Revision ID missing for title: Nizar_Ben_N%C3%A9ji
# Revision ID missing for title: Khema%C3%AFs_Ksila
# Revision ID missing for title: Selma_H%C3%A9dia_Mabrouk
# Revision ID missing for title: Naceur_Ben_Ja%C3%A2far
# Revision ID missing for title: Sa%C3%AFda_Sassi
# Revision ID missing for title: B%C3%A9chir_Sfar
# Revision ID missing for title: O%C4%9Fuzhan_Asilt%C3%BCrk
# Revision ID missing for title: Aziz_Feyzi_Pirin%C3%A7%C3%A7iz%C3%A2de
# Revision ID missing for title: Abdurrahman_Ba%C5%9Fkan
# Revision ID missing for title: Hasan_Basri_G%C3%BCzelo%C4%9Flu
# Revision ID missing for title: Fahri_Bat%C4%B1ca
# Revision ID missing for title: Tuna_Beklevi%C3%A7
# Revision ID missing for title: Ahmet_%C3%87ak%C4%B1r
# Revision ID missing for title: Remzi_%C3%87ay%C4%B1r
# Revision ID missing for title: Davut_G%C3%BCl
# Revision ID missing for title: Tuncay_Din%C3%A7
# Revision ID missing for title: Edip_R%C3%BC%C5%9Ft%C3%BC_Aky%C3%BCrek
# Revision ID missing for title: Ey%C3%BCp_Sabri_Hay%C4%B1rl%C4%B1o%C4%9Flu
# Revision ID missing for title: Taha_Gen%C3%A7
# Revision ID missing for title: Hasan_Re%C5%9Fit_Tankut
# Revision ID missing for title: Hayati_Vasfi_Ta%C5%9Fy%C3%BCrek
# Revision ID missing for title: At%C4%B1f_Kam%C3%A7%C4%B1l
# Revision ID missing for title: %C4%B0mran_K%C4%B1l%C4%B1%C3%A7
# Revision ID missing for title: Ertu%C4%9Frul_Mat
# Revision ID missing for title: Mehmet_Fatih_Kac%C4%B1r
# Revision ID missing for title: Mehmet_Kama%C3%A7
# Revision ID missing for title: Haf%C4%B1z_Mehmet
# Revision ID missing for title: Kemal_Memi%C5%9Fo%C4%9Flu
# Revision ID missing for title: Memduh_O%C4%9Fuz
# Revision ID missing for title: Ya%C5%9Far_Okuyan
# Revision ID missing for title: Saruhan_Olu%C3%A7
# Revision ID missing for title: Fuat_Necati_%C3%96ncel
# Revision ID missing for title: Cahit_Orta%C3%A7
# Revision ID missing for title: Osman_Nuri_%C3%96n%C3%BCg%C3%B6ren
# Revision ID missing for title: Vahdettin_%C3%96zkan
# Revision ID missing for title: Osman_Pamuko%C4%9Flu
# Revision ID missing for title: Musa_Piro%C4%9Flu
# Revision ID missing for title: Re%C5%9Fit_Ronabar
# Revision ID missing for title: H%C3%BCseyin_Sungur
# Revision ID missing for title: Ziya_U%C4%9Fur
# Revision ID missing for title: Serdar_H%C3%BCseyin_Y%C4%B1ld%C4%B1r%C4%B1m
# Revision ID missing for title: Ahmet_Reyiz_Y%C4%B1lmaz
# Revision ID missing for title: Baha_Cemal_Za%C4%9Fra
# Revision ID missing for title: Kasymguly_Baba%C3%BDew
# Revision ID missing for title: Suhan_Baba%C3%BDew
# Revision ID missing for title: Dangatar_K%C3%B6pekow
# Revision ID missing for title: Nazar_So%C3%BDunow
# Revision ID missing for title: Borys_Klimchuk_%28politician%29
# Revision ID missing for title: Ruslan_Magomedov_%28economist%29
# Revision ID missing for title: Sebasti%C3%A1n_Bauz%C3%A1
# Revision ID missing for title: M%C3%B3nica_Bottero
# Revision ID missing for title: Lorenzo_Antonio_Fern%C3%A1ndez
# Revision ID missing for title: Liliam_Kechichi%C3%A1n
# Revision ID missing for title: D%C3%A1maso_Antonio_Larra%C3%B1aga
# Revision ID missing for title: Guido_Manini_R%C3%ADos
# Revision ID missing for title: Isidoro_de_Mar%C3%ADa
# Revision ID missing for title: Luis_Meli%C3%A1n_Lafinur
# Revision ID missing for title: Jos%C3%A9_Benito_Monterroso
# Revision ID missing for title: Trist%C3%A1n_Narvaja
# Revision ID missing for title: Mar%C3%ADa_In%C3%A9s_Obald%C3%ADa
# Revision ID missing for title: Yamand%C3%BA_Orsi
# Revision ID missing for title: Jos%C3%A9_Brito_del_Pino
# Revision ID missing for title: Carlos_Pita_%28politician%29
# Revision ID missing for title: Jos%C3%A9_Rondeau
# Revision ID missing for title: Florencio_S%C3%A1nchez
# Revision ID missing for title: Jos%C3%A9_Pedro_Varela
# Revision ID missing for title: Pedro_Vaz_%28diplomat%29
# Revision ID missing for title: Sa%27dulla_Begaliyev
# Revision ID missing for title: Bakhodir_Kurbanov_%28general%29
# Revision ID missing for title: Bo%CA%BBritosh_Mustafoyev
# Revision ID missing for title: Jimmy_Stevens_%28politician%29
# Revision ID missing for title: Alejandra_Ben%C3%ADtez
# Revision ID missing for title: Jos%C3%A9_Brito_%28politician%29
# Revision ID missing for title: Rub%C3%A9n_Gonz%C3%A1lez_C%C3%A1rdenas
# Revision ID missing for title: Jos%C3%A9_Curiel
# Revision ID missing for title: Felix_D%C3%ADaz_Ortega
# Revision ID missing for title: Vicente_Jos%C3%A9_Gregorio_D%C3%ADaz_Silva
# Revision ID missing for title: Al%C3%AD_Dom%C3%ADnguez
# Revision ID missing for title: Arnoldo_Gabald%C3%B3n
# Revision ID missing for title: Vladimir_Gessen_%28Venezuelan_politician%29
# Revision ID missing for title: C%C3%A9sar_Gonz%C3%A1lez_Mart%C3%ADnez
# Revision ID missing for title: Jos%C3%A9_Bernab%C3%A9_Guti%C3%A9rrez
# Revision ID missing for title: Mar%C3%ADa_Cristina_Iglesias
# Revision ID missing for title: Andr%C3%A9s_Izarra
# Revision ID missing for title: Carlos_Augusto_Le%C3%B3n
# Revision ID missing for title: Ram%C3%B3n_Lobo_%28economist%29
# Revision ID missing for title: Jorge_Elieser_M%C3%A1rquez
# Revision ID missing for title: Am%C3%A9rico_Mart%C3%ADn
# Revision ID missing for title: Nelson_Mart%C3%ADnez_%28politician%29
# Revision ID missing for title: Reinaldo_Mu%C3%B1oz_Pedroza
# Revision ID missing for title: Mois%C3%A9s_Na%C3%ADm
# Revision ID missing for title: Freddy_%C3%91%C3%A1%C3%B1ez
# Revision ID missing for title: Alejandro_Pe%C3%B1a_Esclusa
# Revision ID missing for title: Miguel_Pe%C3%B1a_%28politician%29
# Revision ID missing for title: Lewis_P%C3%A9rez
# Revision ID missing for title: Eduardo_Pi%C3%B1ate
# Revision ID missing for title: Benjam%C3%ADn_Rausseo
# Revision ID missing for title: Bolivia_Su%C3%A1rez
# Revision ID missing for title: Jos%C3%A9_Herrera_Uslar
# Revision ID missing for title: Jos%C3%A9_Antonio_Velutini
# Revision ID missing for title: B%C3%B9i_Ti%E1%BA%BFn_D%C5%A9ng_%28politician%29
# Revision ID missing for title: Chu_V%C4%83n_An
# Revision ID missing for title: Nguy%E1%BB%85n_Qu%E1%BB%91c_%C4%90%E1%BB%8Bnh
# Revision ID missing for title: %C4%90inh_Xu%C3%A2n_Qu%E1%BA%A3ng
# Revision ID missing for title: %C4%90%E1%BB%97_Quang_Giai
# Revision ID missing for title: H%E1%BB%93_%C4%90%E1%BA%AFc_%C4%90i%E1%BB%81m
# Revision ID missing for title: H%E1%BB%93_V%C4%83n_Nh%E1%BB%B1t
# Revision ID missing for title: Ho%C3%A0ng_Cao_Kh%E1%BA%A3i
# Revision ID missing for title: Hu%E1%BB%B3nh_V%C4%83n_Cao
# Revision ID missing for title: Ki%E1%BB%81u_M%E1%BB%99ng_Thu
# Revision ID missing for title: L%C3%AA_Minh_H%C6%B0%C6%A1ng
# Revision ID missing for title: L%C3%AA_Qu%E1%BB%91c_Minh
# Revision ID missing for title: L%C3%AA_V%C4%83n_Th%C3%A0nh
# Revision ID missing for title: L%C6%B0%C6%A1ng_Th%E1%BA%BF_Huy
# Revision ID missing for title: Nguy%E1%BB%85n_H%E1%BB%93ng_Di%C3%AAn
# Revision ID missing for title: Nguy%E1%BB%85n_%C4%90%E1%BB%A9c_Chung
# Revision ID missing for title: Nguy%E1%BB%85n_D%C6%B0%C6%A1ng_%C4%90%C3%B4n
# Revision ID missing for title: Nguy%E1%BB%85n_Duy_Qu%C3%BD
# Revision ID missing for title: Nguy%E1%BB%85n_H%E1%BB%A3p_%C4%90o%C3%A0n
# Revision ID missing for title: Nguy%E1%BB%85n_Phan_Long
# Revision ID missing for title: Nguy%E1%BB%85n_Qu%E1%BB%91c_C%C6%B0%E1%BB%9Dng
# Revision ID missing for title: Nguy%E1%BB%85n_Th%E1%BB%8B_H%E1%BB%93ng_%28economist%29
# Revision ID missing for title: Nguy%E1%BB%85n_Th%E1%BB%8B_Th%E1%BA%ADp
# Revision ID missing for title: Nguy%E1%BB%85n_V%C4%83n_Huy%E1%BB%81n
# Revision ID missing for title: Nguy%E1%BB%85n_V%C4%83n_L%E1%BB%B1c
# Revision ID missing for title: Nguy%E1%BB%85n_V%C4%83n_Tr%C3%A2n
# Revision ID missing for title: Nguy%E1%BB%85n_V%C4%83n_Xu%C3%A2n
# Revision ID missing for title: T%E1%BA%A1_Quang_B%E1%BB%ADu
# Revision ID missing for title: Tr%E1%BA%A7n_Qu%E1%BB%91c_V%C6%B0%E1%BB%A3ng_%28politician%29
# Revision ID missing for title: Tr%E1%BA%A7n_V%C4%83n_H%E1%BB%AFu
# Revision ID missing for title: Tr%C6%B0%C6%A1ng_%C4%90%C3%ACnh_Dzu
# Revision ID missing for title: V%C3%B5_V%C4%83n_Th%C6%B0%E1%BB%9Fng

# %%
all_revision_ids
# Out:
# {'Ezatullah_%28Nangarhar%29': None,
#  'Mohammad_Gul_%28Helmand_Council%29': None,
#  'Mohammad_Khan_%28athlete%29': None,
#  'Abdul Baqi Turkistani': 1231655023,
#  'Abdul Ghani Ghani': 1227026187,
#  'Abdul Rahim Ayoubi': 1226326055,
#  'Ahmad Wali Massoud': 1221720658,
#  'Aimal Faizi': 1185105938,
#  'Amir Muhammad Akhundzada': 1247931713,
#  'Aziza Ahmadyar': 1195651393,
#  'Azizullah Lodin': 1247762293,
#  'Baran Khan Kudezai': 1176481824,
#  'Bashir Ahmad Bezan': 1248505877,
#  'Cheragh Ali Cheragh': 1193992206,
#  'Fazel Ahmed Manawi': 1234514379,
#  'Gajinder Singh Safri': 1212323536,
#  'Ghulam Ghaus': 1158659195,
#  'Ghulam Muhammad Ghobar': 1240993642,
#  'Hafizullah Shabaz Khail': 1238402857,
#  'Haroon al-Afghani': 1230459615,
#  'Hashmat Ghani Ahmadzai': 1207743719,
#  'Ismael Balkhi': 1244521219,
#  'Jan Baz': 1227635806,
#  'Khadija Zahra Ahmadi': 1234741562,
#  'Mahboba Hoqomal': 1243745950,
#  'Majah Ha Adrif': 1233202991,
#  'Masoud Khalili': 1246566971,
#  'Mirza Muhammad Ismail': 1235165845,
#  'Moeen Marastial': 1246567093,
#  'Mohammad Daud Miraki': 1227103354,
#  'Mohammad Ghous Bashiri': 1237694188,
#  'Mohammad Sarwar Ahmedzai': 1176429234,
#  'Mohammad Siddiq Chakari': 1134129082,
#  'Muhammad Hashim Esmatullahi': 949986748,
#  'Muqadasa Ahmadzai': 1235521766,
#  'Musa Hotak': 1246566804,
#  'Nasir Ahmad Durrani': 988838315,
#  'Nasrullah Baryalai Arsalai': 1225385278,
#  'Qutbuddin Hilal': 1246566795,
#  'Rafiullah Bidar': 1197443408,
#  'Rangina Hamidi': 1234743111,
#  'Razaq Mamoon': 1227180106,
#  'Said Tayeb Jawad': 1248976824,
#  'Samoud Khan': 1195409073,
#  'Sayed Jalal': 1137130537,
#  'Sayed Jalal Karim': 1136614743,
#  'Sayed Yousuf Halim': 1234514565,
#  'Sayed Zafar Hashemi': 1179137138,
#  'Sharif Ghalib': 1245967190,
#  'Tayyab Agha': 1225661708,
#  'Ali_Mohammad_%28politician%29': None,
#  'Abdul_Zahir_%28Konar_Education_Minister%29': None,
#  'Ziauddin_%28Afghan_militia_leader%29': None,
#  'Refo_%C3%87apari': None,
#  'Abdul Ghafor Zori': 1136614520,
#  'Abdul Karim Misaq': 1235405154,
#  'Abdul Majid Samim': 1225425205,
#  'Abdul Salam Zaeef': 1243758857,
#  'Abdul Sattar Mirzakwal': 1145249317,
#  'Ahmadullah Wasiq': 1171042170,
#  'Ali Pasha of Gusinje': 1244421894,
#  'Azis Tahir Ajdonati': 1192928746,
#  'Baktash Siawash': 1250972393,
#  'Bardhok Biba': 1250227174,
#  'Bislim Bajgora': 1217284690,
#  'Daoud Naji': 1247131367,
#  'Davood Moradian': 1239319380,
#  'Fazal Hadi Shinwari': 1242412237,
#  'Gholam Rabani Nasher': 1136534788,
#  'Ghulam Faroq Nijrabi': 1136614778,
#  'Ghulam Hassan Safi': 1176507815,
#  'Ghulam Mohammad Rigi': 1129192917,
#  'Gul Ahmmad Yama': 1136614561,
#  'Hanifa Safi': 1123824802,
#  'Hasan Ali Sultani': 1136614726,
#  'Hysni Curri': 1198914812,
#  'Ibrahim Dalliu': 1248264998,
#  'Kastriot Berissa': 1244463139,
#  'Kostandin Boshnjaku': 1250227994,
#  'Mohammad Hashem Taufiqui': 1233490009,
#  'Mohammed Qalamuddin': 1178097642,
#  'Mohammed Tahir Omar': 1185088733,
#  'Mohammed Zaman': 1229734414,
#  'Mohammed Zia Salehi': 1225457074,
#  'Nasruddin Mohseni': 1136630129,
#  'Neritan Ceka': 1184807608,
#  'Niazi Demi': 1209346411,
#  'Pacha Gul Wafadar': 1227179979,
#  'Qari Ziauddin': 1245217124,
#  'Saber Sangar': 1227951669,
#  'Safet Butka': 1189442848,
#  'Sardar Mohammad Nadir Naeem': 1204109653,
#  'Sayed Nasim Mihanparast': 1172646418,
#  'Spartak Braho': 1224650124,
#  'Suhail Shaheen': 1198363158,
#  'Uran Butka': 1196422551,
#  'Wahidullah Waissi': 1232389768,
#  'Ylli Asllani': 1221605713,
#  'Zabih-U-llah Ghazi Noristani': 1136614682,
#  'Zalmai Mujadidi': 1223903677,
#  'Themistokli_G%C3%ABrmenji': None,
#  'A%C4%87if_Had%C5%BEiahmetovi%C4%87': None,
#  'Kurt_Ag%C3%AB_Kadiu': None,
#  'Alfred_Karamu%C3%A7o': None,
#  'Ali_K%C3%ABlcyra': None,
#  'Elez_Ko%C3%A7i': None,
#  'Xhelal_Kopr%C3%ABncka': None,
#  'Xhelal_Sve%C3%A7la': None,
#  'Abas Ermenji': 1240801210,
#  'Abdurrahman Dibra': 1244008227,
#  'Adrian Neritani': 1196135017,
#  'Afrim Tole': 1241836925,
#  'Ahmed Dino': 1209165678,
#  'Aqif Pasha Elbasani': 1243882903,
#  'Artur Kuko': 1112281132,
#  'Athanas Shundi': 1220369492,
#  'Avni Rustemi': 1229276965,
#  'Bajram Kelmendi': 1237006808,
#  'Bedri Pejani': 1220757655,
#  'Behxhet Nepravishta': 1180949734,
#  'Bujar Dida': 1222151681,
#  'Chatin Sarachi': 1141930406,
#  'Eduard Shalsi': 1173107489,
#  'Ferhat Bey Draga': 1236738861,
#  'Gjon Markagjoni': 1227760361,
#  'High Council of Regency': 1245450388,
#  'Hysni Milloshi': 1218412314,
#  'Ibrahim Karbunara': 1235824719,
#  'Ibrahim Temo': 1228151428,
#  'Kadri Prishtina': 1198167947,
#  'Kristo Kirka': 1237950375,
#  'Kryeziu family': 1236739222,
#  'Mehmed Kalakula': 1145510350,
#  'Mehmet Tahsini': 1239924043,
#  'Mihal Grameno': 1226635783,
#  'Musa Qazimi': 1235824584,
#  'Mustafa Ndroqi': 1198219291,
#  'Nebi Sefa': 1244486537,
#  'Nexhip Draga': 1236738502,
#  'Qamil Musa Haxhi Feza': 1198224146,
#  'Rasih Dino': 1180949327,
#  'Sabit Lulo': 1180950488,
#  'Sabri Godo': 1230739582,
#  'Sali Nivica': 1240539074,
#  'Syreja Vlora': 1186986269,
#  'Tefik Mborja': 1234673487,
#  'Thoma Orologa': 1180949774,
#  'Xhavid Leskoviku': 1180950536,
#  'Ylli Vesel Shehu': 1250811470,
#  'Ymer Prizreni': 1215667416,
#  'Cha%C3%A2bane_A%C3%AFt_Abderrahim': None,
#  'A%C3%AFssa_Bekkai': None,
#  'Benaouda_Hadj_Hac%C3%A8ne_Bachterzi': None,
#  'Fay%C3%A7al_Bentaleb': None,
#  'Sa%C3%AFd_Boualam': None,
#  'Abderrahmane_Meziane_Ch%C3%A9rif': None,
#  'Sa%C3%AFd_Chibane': None,
#  'Abdelhakim Belabed': 1218173615,
#  'Abdelkader Zoukh': 1250270534,
#  'Abdelkrim Benmbarek': 1245801726,
#  'Abdeslam Bouchouareb': 1203569345,
#  'Abdyl Ypi': 1220281072,
#  'Aboubakr Belkaid': 1176411375,
#  'Ahmed Bidani': 1212186965,
#  'Ahmed Hamiani': 1226452639,
#  'Ali Aoun': 1214835889,
#  'Basma Azouar': 1192088820,
#  'Bouras Djamel': 1226437538,
#  'Brahim Chibout': 1053460621,
#  'Brahim Djamel Kassali': 1172500304,
#  'Fatiha Serour': 1218302579,
#  'Fazia Dahleb': 1244337610,
#  'Foued Chehat': 1242037866,
#  'Hamza Al Sid Cheikh': 1248318178,
#  'Hocine Cherhabil': 1242619010,
#  'Ibrahim Boughali': 1230623499,
#  'Kamel Beldjoud': 1214832676,
#  'Kamel Bidari': 1249963763,
#  'Lamine Bechichi': 1111537825,
#  'Menduh Zavalani': 1235824554,
#  'Mohamed Belouizdad': 1169278443,
#  'Mohamed Bensalam': 1235672021,
#  'Mohamed Bouslimani': 1224118485,
#  'Mohamed Cherif Belmihoub': 1226553342,
#  'Mohamed Seghir Babes': 1226280389,
#  'Mohamed Tarek Belaribi': 1241671793,
#  'Mokhtar Didouche': 1227200392,
#  'Nadir Kassab': 1226271746,
#  'Nassim Diafat': 1213342432,
#  'Noureddine Bahbouh': 1099284595,
#  'Rabah Bouaziz': 1232492563,
#  'Rachid Bladehane': 1186319378,
#  'Souad Bendjaballah': 1134649751,
#  'Taha Derbal': 1213344636,
#  'Visar Ymeri': 1248230838,
#  'Visarion Xhuvani': 1135323365,
#  'Xhezair Zaganjori': 1143896123,
#  'Yahia Boukhari': 1186319308,
#  'Youcef Belmehdi': 1239235131,
#  'Youcef Chorfa': 1214834266,
#  'Ad%C3%A3o_Francisco_Correia_de_Almeida': None,
#  'Alexandre_Sebasti%C3%A3o_Andr%C3%A9': None,
#  'Bernarda_Gon%C3%A7alves_Martins': None,
#  'Jo%C3%A3o_Baptista_Borges': None,
#  'Adalberto_Costa_J%C3%BAnior': None,
#  '%C3%81lvaro_Arnaldo_Craveiro': None,
#  'Faustina_Fernandes_Ingl%C3%AAs_de_Almeida_Alves': None,
#  'Abra%C3%A3o_Gourgel': None,
#  'Jofre_Van-D%C3%BAnem_J%C3%BAnior': None,
#  'Jos%C3%A9_Carvalho_da_Rocha': None,
#  'Jos%C3%A9_Luis_de_Matos': None,
#  'Abdelhak Saihi': 1218004839,
#  'Abderezak Sebgag': 1212579707,
#  'Abderrachid Tabbi': 1218530483,
#  'Abel Chivukuvuku': 1165626565,
#  'Adjany Costa': 1242000475,
#  'Ahmed Zeghdar': 1213778323,
#  'Amar Makhloufi': 1235394946,
#  'Amar Mohammedi': 1226279231,
#  'Ana Paula Chantre Luna de Carvalho': 1209514022,
#  'Arlete Chimbinda': 1177486404,
#  'Azzedine Mihoubi': 1233387309,
#  'Bachir Messaitfa': 1186318318,
#  'Brahim Merad': 1244511083,
#  'Carolina Cerqueira': 1241977204,
#  'Cherif Rahmani': 1053461144,
#  'Diamantino Pedro Azevedo': 1209522689,
#  'Fiel Domingos Constantino': 1217387083,
#  'Hichem Sofiane Salaouatchi': 1212186286,
#  'Jeremias Chitunda': 1220287872,
#  'Jesus Faria Maiato': 1209631313,
#  'Kafundanga Chingunji': 1191431794,
#  'Kambamba Kulaxingo': 1093124425,
#  'Kamel Rezig': 1215901775,
#  'Kaoutar Krikou': 1213795388,
#  'Karim Bibi Triki': 1213794210,
#  'Laid Rebiga': 1248662394,
#  'Lakhdar Rakhroukh': 1186317568,
#  'Layachi Yaker': 1226060720,
#  'Mohamed Ali Boughazi': 1213870570,
#  'Mohamed Maghlaoui': 1053469610,
#  'Naima Salhi': 1213404244,
#  'Paulino Baptista': 1242307496,
#  'Raul Danda': 1158035855,
#  'Salim Saadi': 1229426851,
#  'Samia Moualfi': 1212181372,
#  'Sassi Lamouri': 1181986973,
#  'Soraya Mouloudji': 1226335614,
#  'Yacine Oualid': 1214837789,
#  'Yassine Merabi': 1214841607,
#  'Maria_C%C3%A2ndida_Pereira_Teixeira': None,
#  'Maria_do_Ros%C3%A1rio_Teixeira_de_Alva_Sequeira_Bragan%C3%A7a_Sambo': None,
#  'Sa%C3%ADde_Mingas': None,
#  'Jos%C3%A9_Ndele': None,
#  'Pedro_Pedal%C3%A9': None,
#  'Santana_Andr%C3%A9_Pitra': None,
#  'Francisco_Manuel_Monteiro_de_Queir%C3%B3z': None,
#  'Jos%C3%A9_An%C3%ADbal_Lopes_Rocha': None,
#  'Jos%C3%A9_da_Rocha': None,
#  'Rosa_Lu%C3%ADs_de_Sousa_Micolo': None,
#  'Lu%C3%ADs_Gomes_Sambo': None,
#  'Jo%C3%A3o_Ernesto_dos_Santos': None,
#  'Jos%C3%A9_Filomeno_dos_Santos': None,
#  'Pinda_Sim%C3%A3o': None,
#  'Augusto_da_Silva_Tom%C3%A1s': None,
#  'Jos%C3%A9_Jacinto_Van-D%C3%BAnem': None,
#  'Jos%C3%A9_Vieira_Dias_Van-D%C3%BAnem': None,
#  'Luzia_Ingl%C3%AAs_Van-D%C3%BAnem': None,
#  'Alex_Browne_%28politician%29': None,
#  'Colin_O%27Neil_Browne': None,
#  'Rick_James_%28actor%29': None,
#  'Ana Paula Sacramento Neto': 1227909121,
#  'Branca Manuel Espirito Santo': 1142474441,
#  'Caleb Gardiner': 1241563135,
#  'Cheryl Mary Clare Hurst': 1242813942,
#  'Clement Antonio': 1241563106,
#  'Daniel Ntongi-Nzinga': 1187961349,
#  'David Mendes': 1024544204,
#  'Elias Salupeto Pena': 1220287990,
#  'Fernando Faustino Muteka': 1241977176,
#  'Gail Christian': 1241563122,
#  'James Carlisle': 1242152285,
#  'Johnny Eduardo Pinnock': 1242307359,
#  'Jonas Savimbi': 1246026420,
#  'Mackenzie Frank': 1247632329,
#  'Manuel Bernardo de Sousa': 1233607984,
#  'Manuel Neto da Costa': 1209411144,
#  'Manuel Tavares de Almeida': 1209411217,
#  'Manuel Vicente': 1250493481,
#  'Marcos Alexandre Nhunga': 1209413818,
#  'Mfulupinga Nlando Victor': 1243272129,
#  'Osbert Richard Frederick': 1241563130,
#  'Paula Cristina Francisco Coelho': 1209410923,
#  'Pedro Mutinde': 1209539718,
#  'Randolph Beazer': 1247631912,
#  'Shenella Mary Shadida Govia': 1241563138,
#  'Studiation Brown': 825090349,
#  'Tim Hector': 1227026341,
#  'Wilfred Jacobs': 1246340247,
#  'William Haynes-Smith': 1250666577,
#  'Johnathan_Joseph_%28politician%29': None,
#  'Germ%C3%A1n_Alfaro': None,
#  'Joaqu%C3%ADn_Samuel_de_Anchorena': None,
#  'Juan_Agust%C3%ADn_Augier': None,
#  'Joaqu%C3%ADn_Belgrano': None,
#  'H%C3%A9ctor_Bidonde': None,
#  'D%C3%A1maso_Centeno': None,
#  'L%C3%A1zaro_Chiappe': None,
#  'Luis_L._Dom%C3%ADnguez': None,
#  'M%C3%A1ximo_Etchecopar': None,
#  'H%C3%A9ctor_Toty_Flores': None,
#  'Manuel_Jos%C3%A9_Garc%C3%ADa': None,
#  'Juan_Jos%C3%A9_G%C3%B3mez_Centuri%C3%B3n': None,
#  'Luis_Carlos_G%C3%B3mez_Centuri%C3%B3n': None,
#  'Mart%C3%ADn_Guzm%C3%A1n': None,
#  'Alberto Manuel Campos': 1166331326,
#  'Alejo Castex': 1231276700,
#  'Alincia Williams-Grant': 1241592542,
#  'Antonio Bermejo': 1225811362,
#  'Antonio Beruti': 1243926512,
#  'Bernard Percival': 1241564686,
#  'Carlos Corach': 1227620960,
#  'Carlos de la Rosa': 1209668330,
#  'David Massiah': 1247632248,
#  'Dwayne George': 1247631631,
#  'Edmond Mansoor': 1248648606,
#  'Exequiel Bustillo': 1188044851,
#  'Fabian Jones': 1247632282,
#  'Federico Helguera': 1162056054,
#  'Guillermo Francos': 1245178482,
#  'Harold Lovell': 1241564680,
#  'Jamale Pringle': 1241592215,
#  'Joanne Massiah': 1241592526,
#  'Jorge Coscia': 1227459720,
#  'Juan Alemann': 1227499891,
#  'Juan Carlos Del Bello': 1225784914,
#  'Juan Fugl': 1148828249,
#  'Kelvin Simon': 1241592202,
#  'Kiz Johnson': 1247632301,
#  'Knacyntar Nedd': 1247514093,
#  'Marco Aurelio Avellaneda': 1233010330,
#  'Mario Cafiero': 1135193654,
#  'Melford Nicholas': 1241592535,
#  'Philip Shoul': 1247632342,
#  'Rawdon Turner': 1247632346,
#  'Rossana Chahla': 1227517224,
#  'Santiago Gallo': 1039135531,
#  'Shawn Nicholas': 1247632364,
#  'Silvano Bores': 1225775647,
#  'Uladislao Augier': 1217815124,
#  'Fernando_Iglesias_%28Argentine_politician%29': None,
#  'Andr%C3%A9s_Larroque': None,
#  'Juli%C3%A1n_de_Leyva': None,
#  'M%C3%B3nica_L%C3%B3pez_%28politician%29': None,
#  'Nicol%C3%A1s_Massot': None,
#  'Mart%C3%ADn_Menem': None,
#  'R%C3%B3mulo_Sebasti%C3%A1n_Na%C3%B3n': None,
#  'Santiago_G._O%27Farrell': None,
#  'Miguel_%C3%81ngel_Pesce': None,
#  'Am%C3%A1n_Rawson': None,
#  'Mart%C3%ADn_Sabbatella': None,
#  'H%C3%A9ctor_Tiz%C3%B3n': None,
#  'Ar%C3%ADstides_Villanueva': None,
#  'Gevorg_Ghazaryan_%28politician%29': None,
#  'Aram_Grigoryan_%28politician%29': None,
#  'Abel Posse': 1245068036,
#  'Aldo Pignanelli': 1106856167,
#  'Alejo Peyret': 1138003698,
#  'Alfredo Olmedo': 1226445117,
#  'Andrias Ghukasyan': 1214660728,
#  'Aram Manukyan': 1214661551,
#  'Ashot Arsenyan': 1218601969,
#  'Carlos Kunkel': 1225799546,
#  'Carlos Petroni': 1199679676,
#  'Claudio Uberti': 1245464700,
#  'Enrique S. Quintana': 1016343362,
#  'Fernando Nadra': 1238199017,
#  'Gevorg Melik-Karagyozyan': 1180063778,
#  'Guillermo Montenegro': 1096175549,
#  'Gurgen Egiazaryan': 1103745376,
#  'Hayk Chobanyan': 1231768992,
#  'Hrant Maloyan': 1250311867,
#  'Jorge Yoma': 1191859791,
#  'Juan Mignaburu': 1166892817,
#  'Juan Pablo Schiavi': 1195011460,
#  'Khachatur Malumian': 1210493386,
#  'Lucio Victorio Mansilla': 1210433646,
#  'Marcelo Muniagurria': 1242262794,
#  'Mariano Moreno': 1248788227,
#  'Mikayel Kotanyan': 1226313476,
#  'Norberto La Porta': 1225799869,
#  'Parunak Ferukhan': 1214660598,
#  'Ricardo Kennedy': 1240898573,
#  'Ruben Miroyan': 1228290809,
#  'Ruben Mirzakhanyan': 1214661775,
#  'Tigran Karapetyan': 1231946069,
#  'Tigran Khzmalyan': 1237979345,
#  'Vahagn Hovakimyan': 1224369324,
#  'Vahan Minakhoryan': 1214661649,
#  'Vigen Chitechyan': 1124301399,
#  'Barbara Eibinger-Miedl': None,
#  'Karen_Sargsyan_%28sociologist%29': None,
#  'Vartkes_Sereng%C3%BClian': None,
#  'Maximilian_Anton_Karl%2C_Count_Baillet_de_Latour': None,
#  'Count_V%C3%A1clav_Anton%C3%ADn_Chotek_of_Chotkov_and_Vojn%C3%ADn': None,
#  'Citizens%27_Ministry': None,
#  'Ernst_Hampel_%28politician%29': None,
#  'J%C3%BCrgen_Himmelbauer': None,
#  'Andreas_H%C3%B6rtnagl': None,
#  'Konstantin_Jire%C4%8Dek': None,
#  'Alfons Adam': 1244617588,
#  'Anton Hofer': 1215044432,
#  'Badal Muradyan': 1214662146,
#  'Eduard Hedvicek': 1215043825,
#  'Eduard von Grebmer zu Wolfsthurn': 1216075327,
#  'Franz Dinghofer': 1244619292,
#  'Franz Jetzinger': 1214236945,
#  'Friedhelm Frischenschlager': 1223497595,
#  'Friedrich Wilhelm von Haugwitz': 1215043658,
#  'Gabriel Noradoungian': 1240224564,
#  'Garo Paylan': 1249622641,
#  'Genrikh Poghosyan': 1214662694,
#  'George Abraham von Dyhrn': 1231555745,
#  'Hans Ferlitsch': 1240489075,
#  'Hans Peter Haselsteiner': 1226351964,
#  'Heinrich Alfred Barb': 1214670404,
#  'Hermann Stern': 1215044008,
#  'Hrayr Tovmasyan': 1243511026,
#  'Hugo Jury': 1225140706,
#  'Ingo Appelt': 1244447844,
#  'Ishkhan Saghatelyan': 1243510830,
#  'Israel Ori': 1214986895,
#  'Joseph Buttinger': 1214670744,
#  'Joseph Kenner': 1169137921,
#  'Kegham Vanigian': 1214670011,
#  'Leopold Berchtold': 1228353209,
#  'Martiros Sarukhanyan': 1214669503,
#  'Michael Killisch-Horn': 1106829544,
#  'Narine Tukhikyan': 1233470777,
#  'Ohannes Tchekidjian': 1215201883,
#  'Paul Paul': 1215924661,
#  'Prince Carl of Solms-Braunfels': 1237091760,
#  'Richard von Coudenhove-Kalergi': 1243336388,
#  'Serop Zakaryan': 1222543352,
#  'Sophia Kircher': 1242552103,
#  'Suren Shadunts': 1242146414,
#  'Theodor Kery': 1215046740,
#  'Ulrich Habsburg-Lothringen': 1216088776,
#  'Usub Bek Temuryan': 1243494457,
#  'Walter Guggenberger': 1154443829,
#  'J%C3%B3zef_Ko%C5%BCdo%C5%84': None,
#  'Gottfried_von_K%C3%BChnelt-Leddihn': None,
#  'Franz_Leitner_%28politician%29': None,
#  'Julius_Lippert_%28historian%29': None,
#  'Karl_L%C3%BCtgendorf': None,
#  'J%C3%BCrgen_Mandl': None,
#  'Gregor_Razumovsky_%28activist%29': None,
#  'Georg_Adam%2C_Prince_of_Starhemberg': None,
#  'Peter_Strasser_%28politician%29': None,
#  'Leopold%2C_Count_von_Thun_und_Hohenstein': None,
#  'Curt_Franz_Wenzel_Christoph_Erdmann_Graf_Zedtwitz_von_Morav%C3%A1n_und_Duppau': None,
#  'Alexander Zach': 1215187552,
#  'Aliabbas Salahzade': 1211047878,
#  'Anton von Winzor': 1231556425,
#  'Brigitta Pallauf': 1215184008,
#  'Christoph Matznetter': 1250934182,
#  'Dilara Aliyeva': 1236388140,
#  'Elchin Afandiyev': 1243626881,
#  'Elmar Lichtenegger': 1215483185,
#  'Emil Sax': 1215185845,
#  'Enver Alikhanov': 1161577254,
#  'Fazail Agamali': 1250642641,
#  'Ferdinand Mannlicher': 1250188481,
#  'Franz Moroder': 1228417930,
#  'Gerhard Pfanzelter': 1238011369,
#  'Gisela Wurm': 1215187415,
#  'Gundaker Thomas Starhemberg': 1246777408,
#  'Heidemaria Onodi': 1246630894,
#  'Heinz Nittel': 1226214871,
#  'Horst Rosenkranz': 1215185628,
#  'Hubert Klausner': 1242810704,
#  'Johann Anton von Pergen': 1248404055,
#  'Johann Gregor Memhardt': 1226209962,
#  'Josef Staribacher': 1215186443,
#  'Julius Tandler': 1153989705,
#  'Karl Freiherr von Vogelsang': 1231556362,
#  'Karl Schmitzer': 1215186109,
#  'Karl von Zinzendorf': 1240906258,
#  'Leopold Poetsch': 1248552155,
#  'Leyla Abdullayeva': 1230366514,
#  'Martin Kocher': 1241392879,
#  'Muzamil Abdullayev': 1223484511,
#  'Peter Schieder': 1239601735,
#  'Reinhold Lopatka': 1250933660,
#  'Renate Mann': 1099978355,
#  'Sonja Zwazl': 1235856770,
#  'Tarlan Aliyarbayov': 1240965677,
#  'Thomas Prinzhorn': 1215185462,
#  'Walter Pfrimer': 1249288737,
#  'Wladimir von Pawlowski': 1242446030,
#  'Mehrali Gasimov': None,
#  'Garib_Karimo%C4%9Flu': None,
#  'Abdurrahman Fatalibeyli': 1241052691,
#  'Afshan Gadimbeyova': 1243747432,
#  'Ahmad Kordary': 1187254621,
#  'Ajdar Ismailov': 1157124148,
#  'Akram Aylisli': 1247420701,
#  'Ali Asadov': 1237483914,
#  'Ali Huseynli': 1245270394,
#  'Ali Ibrahimov': 1244157806,
#  'Ali M. Hasanov': 1245282668,
#  'Alisahib Huseynov': 1246588423,
#  'Alovsat Bakhshiyev': 1207738330,
#  'Anar Karimov': 1245270299,
#  'Arastun Javadov': 1147579900,
#  'Araz Alizadeh': 1246060446,
#  'Asaf Hajiyev': 1235219197,
#  'Ashraf Bey Taghiyev': 1213943020,
#  'Bakhish bey Rustambeyov': 1246060690,
#  'Boris Kevorkov': 1217681945,
#  'Chimnaz Aslanova': 1245503366,
#  'Farhad Hajiyev': 1246286594,
#  'Fazail Ibrahimli': 1243509483,
#  'Gudrat Gasanguliev': 1234004989,
#  'Gurban Khalilov': 1243520102,
#  'Haji Molla Ahmad Nuruzade': 1239189558,
#  'Hasan Hasanli': 1244589428,
#  'Hasan Majidov': 1236490430,
#  'Huseyngulu Baghirov': 1199215674,
#  'Ilham Madatov': 1011331249,
#  'Irshad Aliyev': 1225308278,
#  'Jamil Hasanli': 1248447237,
#  'Jeyhun Jalilov': 1228687346,
#  'Lutfali bey Behbudov': 1226230854,
#  'Majnun Mammadov': 1248225337,
#  'Makhmud Mamed-Guliev': 1243510539,
#  'Mamed Iskenderov': 1244201378,
#  'Mammad Gurbanov': 1237445893,
#  'Mirgasim Cheshmazer': 1226415908,
#  'Musa Hacigasimov': 1236490449,
#  'Musa Mammadov': 1243510550,
#  'Ramin Mammadov': 1248662299,
#  'Rovshan Javadov': 1250266366,
#  'Saftar Jafarov': 1222623261,
#  'Sahil Babayev': 1207600921,
#  'Solomon Grobshtein': 1067081975,
#  'Teymur Guliyev': 1232296078,
#  'Vidadi Isgandarov': 1249203876,
#  'Vilayat Eyvazov': 1208072134,
#  'Zakir Hasanov': 1224596001,
#  'Hasan_Seyidov_%28scientist%29': None,
#  'Vugar_Mustafayev_%28minister%29': None,
#  'Keith_Bell_%28Bahamian_politician%29': None,
#  'Charles_Carter_%28Bahamian_journalist%29': None,
#  'James_Carmichael_Smith_%28postmaster%29': None,
#  'Ahmed_Behzad_%28Bahrain%29': None,
#  'Kamal_Ahmed_%28politician%29': None,
#  'Abdulla Adel Fakhro': 1223700072,
#  'Abdullah bin Isa Al Khalifa': 1182830303,
#  'Abid Sharifov': 1243510547,
#  'Ammar Al Bannai': 1231654401,
#  'Aymen Tawfeeq Almoayed': 1227286508,
#  'Bakhtiyar Vahabzadeh': 1249675761,
#  'Eldar Namazov': 1206211739,
#  'Elshad Mirbashir oghlu': 1194162044,
#  'Eugene Dupuch': 1181612386,
#  'Faisal al-Hamar': 1218302538,
#  'Fuad Naghiyev': 1248662296,
#  'Harold Christie': 1142294843,
#  'Hasan Seyidov': 1148385245,
#  'Huseyn Rahmanov': 1106104383,
#  'Ikhtiyar Shirinov': 1243510572,
#  'Isa bin Abdulrahman Al Hammadi': 1098344827,
#  'Isa bin Ibrahim Al Khalifa': 1146485875,
#  'Jameel Humadan': 1148959062,
#  'Jawad Fairooz': 1177286981,
#  'Joseph Robert Love': 1177467150,
#  'Khalid Almoayed': 1215466172,
#  'Mahmood Al Bahrani': 1161492589,
#  'Mammad agha Shahtakhtinski': 1185599926,
#  'McKell Bonaby': 1238577650,
#  'Mohamed Ali Hasan Ali': 1006173162,
#  'Mohammed Isa Al Abbasi': 1171757402,
#  'Movsum Samadov': 1241255046,
#  'Nabeel bin Yaqub Al-Hamar': 1159628135,
#  'Namig Nasrullayev': 1158375491,
#  'Nazar Al Baharna': 1241906132,
#  'Nurali Yusifbayli': 1243510541,
#  'Pakesia Parker-Edgecombe': 1226025677,
#  'Parviz Shahbazov': 1213858589,
#  'Qasim Fakhro': 1099067663,
#  'Rovshen Rzayev': 1208078338,
#  'Sadig Rahimov': 1245157534,
#  'Shirali Akhundov': 1213002608,
#  'Siyavush Novruzov': 1243520070,
#  'Suleyman Rahimov': 1193027962,
#  'Tahir Mirkishili': 1210593900,
#  'Timothy Donaldson': 1245586658,
#  'Yusif Ziya Talibzadeh': 1243510546,
#  'Zahid Oruj': 1213965350,
#  'Abdus_Salam_%28Chattogram_politician%29': None,
#  'Muzaffar_Ahmed_%28NAP_politician%29': None,
#  'AKM Fazlul Kabir Chowdhury': 1245380545,
#  'AKM Hafizuddin': 1246694478,
#  'Abdul Motaleb': 1245374567,
#  'Abdulhussain bin Ali Mirza': 1195787872,
#  'Abdulla Hassan Saif': 1219928150,
#  'Abdullah bin Hamad bin Isa Al Khalifa': 1241499929,
#  'Abdullatif Al-Mahmood': 1227285970,
#  'Abdulrahman al-Nuaimi': 1235804624,
#  'Abul Hashim': 1232200030,
#  'Ahmed Al-Salloum': 1244755894,
#  'Ahmed bin Mohamed Al Khalifa': 1221144846,
#  'Ali bin Khalifa Al Khalifa': 1250923005,
#  'Ali bin Saleh Al Saleh': 1239617504,
#  'Aminul Islam Chowdhury': 1175807916,
#  'Aminul Islam Rabel': 1245379837,
#  'Ammar Qambar': 1140605737,
#  'Anwarul Karim Chowdhury': 1245395466,
#  'Ashab Uddin Ahmad': 1245380479,
#  'Birendra Kishore Roaza': 1246126702,
#  'Bishnu Chattopadhyay': 1242147738,
#  'Chowdhury Shamsuddin Ahmed': 1237261756,
#  'Essam Khalaf': 1006167519,
#  'Fahmi al-Jowder': 1172576081,
#  'Farid Ahmed': 1245375794,
#  'Hala bint Mohammed Al Khalifa': 1232948277,
#  'Hamad Al Kooheji': 1233118749,
#  'Ibrahim ibn Khalifa Al Khalifa': 1156409493,
#  'Isa Qassim': 1249444464,
#  'Khalid Al Maskati': 1209519423,
#  'M Hossain Ali': 1242815841,
#  'Mai bint Mohammed Al Khalifa': 1217876419,
#  'Mohammad A. Arafat': 1250896485,
#  'Mohammad Manjur Alam': 1245377984,
#  'Mohammed Al-Buainain': 1063213013,
#  'Mohammed bin Khalifa bin Ahmed': 1244455253,
#  'Mohammed bin Khalifa bin Ali Al Khalifa': 1202322111,
#  'Moinuddin Ahmed Chowdhury': 1166369458,
#  'Nurul Huq Bhuiyan': 1236303322,
#  'Oli Ahad': 1247061966,
#  'Rasheed Mohammed Al Maraj': 1247375502,
#  'Salman bin Hamad Al Khalifa': 1250494329,
#  'Salman bin Khalifa Al Khalifa': 1247375519,
#  'Sarwar Jan Chowdhury': 1245377291,
#  'Saud Kanoo': 1098699647,
#  'Selina Banu': 1183475136,
#  'Shafiqur Rahman Badsha': 1245374148,
#  'Shahinur Pasha Chowdhury': 1245379554,
#  'Yusuf Ali Chowdhury': 1228415190,
#  'AKM_Fazlul_Haque_%28Jatiya_Party_politician%29': None,
#  'Moin_Uddin_%28politician%29': None,
#  'Mujibur_Rahman_%28Chattogram_politician%29': None,
#  'Abdur_Rahim_%28scholar%29': None,
#  'Abdul Halim Ghaznavi': 1237265302,
#  'Abul Kalam Shamsuddin': 1246347372,
#  'Abul Kashem': 1232782976,
#  'Abul Kashem Khan': 1245380771,
#  'Asheq Ullah Rafiq': 1245374666,
#  'Badruddin Umar': 1220769997,
#  'Badruddoza Ahmed Shuja': 1245376617,
#  'Debendra Nath Ghosh': 1240939624,
#  'Devasish Roy': 1247376048,
#  'Elliott Belgrave': 1242611945,
#  'Fazlul Haque Montu': 1243563371,
#  'Ferdous Ahmed Qureshi': 1250961688,
#  'Golam Maula Rony': 1250725167,
#  'Habibar Rahman': 1245395381,
#  'Haji Mohammad Danesh': 1230176939,
#  'Hatem Ali Khan': 1237261567,
#  'Husam Uddin Chowdhury Fultali': 1247693188,
#  'James Leo Ferguson': 1212687396,
#  'Jyotirindra Bodhipriya Larma': 1247242676,
#  'Kazi Abdus Shahid Lal': 1237261507,
#  'M. Anwar Hossain': 1226325755,
#  'M. M. Rahmatullah': 1242580877,
#  'Mahmudul Haque Sayem': 1250491967,
#  'Manik Lal Ray': 1117752666,
#  'Manjurul Imam': 1245961260,
#  'Maulana Shakhawat': 1067136662,
#  'Mohammad Sultan': 1237264157,
#  'Mohammad Toaha': 1046006361,
#  'Mohammad Zillur Rahman': 1245374883,
#  'Muhammad Bayazeed Khan Panni': 1225060231,
#  'Muhammad Hamidullah Khan': 1249497016,
#  'Mujahidul Islam Selim': 1241208220,
#  'Mushrefa Mishu': 1066093324,
#  'Nozir Hossain': 1245378724,
#  'Pulin De': 1242126632,
#  'Ranesh Das Gupta': 1242257552,
#  'SM Nuruzzaman': 1246459927,
#  'Shafiul Alam Chowdhury Nadel': 1245978368,
#  'Shamima Harun Lubna': 1245374454,
#  'Shamsul Huda Panchbagi': 1232199873,
#  'Sourendra Nath Chakraborty': 1245374793,
#  'Syed Muhammad Ibrahim': 1247089625,
#  'Syed Najmuddin Hashim': 1245394398,
#  'Syed Sayedul Haque Suman': 1247669907,
#  'Yar Mohammad Khan': 1244156514,
#  'Zahidunnabi Dewan Shamim': 1237263822,
#  'Charles_Duncan_O%27Neal': None,
#  'U%C5%82adzimir_Han%C4%8Daryk': None,
#  'Tama%C5%A1_Hryb': None,
#  'Anato%C4%BA_Kalinin': None,
#  'Vo%C4%BAha_Kara%C4%8D': None,
#  'U%C5%82adzis%C5%82au_Kaz%C5%82ouski': None,
#  'Tadeusz_Ko%C5%9Bciuszko': None,
#  'Uladzimir_Mackievi%C4%8D': None,
#  'Symon_Rak-Michaj%C5%82o%C5%ADski': None,
#  'Adrian Forde': 1079840895,
#  'Alaksandar Dubko': 1173907794,
#  'Aleksandr Potupa': 1235204307,
#  'Alexander Radkov': 1216932338,
#  'Aliaksandr Azarau': 1249779544,
#  'Chad Blackman': 1239861059,
#  'Colin Everett Jordan': 1090593974,
#  'Crystal Haynes': 1219669780,
#  'Cynthia Y. Forde': 1200176178,
#  'Damien K. A. Griffith': 1123730836,
#  'Davidson Ishmael': 1123554066,
#  'Dwight Sutherland': 1226875792,
#  'Gennady Grushevoy': 1225610619,
#  'Glyne Murray': 1218309623,
#  'Ian Gooding-Edghill': 1245455194,
#  'Ivan Kubrakov': 1243510259,
#  'Jan Pazniak': 1246821242,
#  'John Andrew King': 1191591712,
#  'Kerrie Symmonds': 1226922424,
#  'Kirk Matthew Humphrey': 1079886049,
#  'Lyavon Barshchewski': 1237691839,
#  'Michael A. Carrington': 1090468579,
#  'Moshe Gutman': 1226775102,
#  'Philip St. Hill': 1132713774,
#  'Pyotr Prakapovich': 1228551886,
#  'Reginald Farley': 1223215475,
#  'Ryan Straughn': 1232133512,
#  'Samuel Jackman Prescod': 1227284229,
#  'Santia Bradshaw': 1225635388,
#  'Shanika Roberts-Odle': 1126117422,
#  'Shantal Munro-Knight': 1248634872,
#  'Siamion Domash': 1245495829,
#  'Siarhei Cherachen': 1177364352,
#  'Sonia Browne': 1080633319,
#  'Tsimafei Dranchuk': 1115164729,
#  'V. L. Mukha': 1144551736,
#  'Valery Levaneuski': 1248009248,
#  'Vladimir Kumets': 1147914902,
#  'William Fondleroy Duguid': 1149070233,
#  'Yury Ambrazevich': 1172992483,
#  'Zmitser Dashkevich': 1244903816,
#  'Jan_Stankievi%C4%8D': None,
#  'Edward_Woyni%C5%82%C5%82owicz': None,
#  'Jan_B%C3%A9ghin': None,
#  'Gustave_Bo%C3%ABl': None,
#  'Pol_Clovis_Bo%C3%ABl': None,
#  '%C3%89mile_Coulonvaux': None,
#  'Nico_Cu%C3%A9': None,
#  'Pierre_David_%28mayor%29': None,
#  'Ren%C3%A9_De_Feyter': None,
#  'Fran%C3%A7ois-Philippe_de_Haussy': None,
#  '%C3%89douard_Descamps': None,
#  'Jos%C3%A9_Desmarets': None,
#  '%C3%89mile_van_Dievoet': None,
#  'Jos_Dupr%C3%A9': None,
#  'Fran%C3%A7oise_Dupuis': None,
#  'Eug%C3%A8ne_Goblet_d%27Alviella': None,
#  'Jean-Pierre_Graf%C3%A9': None,
#  'Aleksandr Turchin': 1245495069,
#  'Aliaksandr Shakutsin': 1246263655,
#  'Antoine Brun': 1179322005,
#  'August De Boodt': 1140361651,
#  'Auguste Couvreur': 1058540061,
#  'Dirk De fauw': 1248580125,
#  'Dominik Semashko': 1214790691,
#  'Fernand Cocq': 1243330963,
#  'Frank Beke': 1161024456,
#  'Guy Hance': 1217126753,
#  'Herman Baltia': 1231554975,
#  'Ihar Rynkevich': 1064451133,
#  'Ivan Yermachenka': 1243935880,
#  'Jacques Grippa': 1226329636,
#  'Joris Helleputte': 1051591828,
#  'Jules Hiernaux': 1194388133,
#  'Julien Goekint': 1149315537,
#  'Julius Hoste Jr.': 1215066294,
#  'Lucienne Herman-Michielsens': 1235711895,
#  'Manuel Abramowicz': 1243531072,
#  'Marc Drumaux': 1250856746,
#  'Marcel de Baer': 1221734112,
#  'Mikola Statkevich': 1243221482,
#  'Nikolai Shelyagovich': 1206663730,
#  'Norbert De Cuyper': 1165947877,
#  'Norbert Hougardy': 1139979372,
#  'Rudy Aernoudt': 1241935456,
#  'Sergei Tikhanovsky': 1247883595,
#  'Valery Sakhashchyk': 1250695986,
#  'Veerle Geerinckx': 1246136139,
#  'Victor de Laveleye': 1173454330,
#  'Vladimir Rusakevich': 1236837678,
#  'Yury Voskresensky': 1173778739,
#  'Jean-Fran%C3%A7ois_Istasse': None,
#  'Andr%C3%A9_Kempinaire': None,
#  'Ahmet_Ko%C3%A7_%28politician%29': None,
#  'Andr%C3%A9_Molitor': None,
#  'Pierre_Emmanuel_F%C3%A9lix_Chazal': None,
#  'Andr%C3%A9-Eug%C3%A8ne_Pirson': None,
#  'Ga%C3%ABtan_Van_Goidsenhoven': None,
#  'Marcel_Van_Langenhove_%28referee%29': None,
#  'Arnauld_Antoine_Akodj%C3%A8nou': None,
#  'Adolphe Van Glabbeke': 1224501115,
#  'Alexander Albert Hunter': 1247370963,
#  'Alfons Siffer': 1044386557,
#  'Basilio Ah': 1242446129,
#  'Bert Tucker': 1215561378,
#  'Beverly Castillo': 1171859695,
#  'Charles Bartlett Hyde': 1247370983,
#  'Cyrille Tahay': 1244463135,
#  'Dorah Ilunga': 1183327367,
#  'Elfreda Reyes': 1225001639,
#  'Father Samuel': 1249920109,
#  'Fientje Moerman': 1229904524,
#  'Georges Kaeckenbeeck': 1212308026,
#  'Glenn Godfrey': 1239031792,
#  'Gustave Rolin-Jaequemyns': 1236873042,
#  'Hippolyte Rolin': 1029822060,
#  'Jacques Timmermans': 1243748132,
#  'Jacques Van Gompel': 1136564688,
#  'Jacques van Ypersele de Strihou': 1162861355,
#  'Jean-Marie Piret': 1140972331,
#  'Jean Pede': 1179788619,
#  'Jean Richardot the Younger': 1143555621,
#  'Johan Verbeke': 1247551813,
#  'Joseph Houssa': 1109576011,
#  'Lodewijk Verreycken': 1235733819,
#  'Louis-Joseph Seutin': 1233472654,
#  'Louis Waltniel': 1058900581,
#  'Luc Michel': 1178923770,
#  'Marjet Van Puymbroeck': 1233204055,
#  'Milou Jeunehomme': 1136573750,
#  'Nemencio Acosta': 1216990637,
#  'Pierre Imperiali': 1189630357,
#  'Pierre Van Humbeeck': 1136575793,
#  'Rachid Madrane': 1188233504,
#  'Robert Urbain': 1073906467,
#  'Roger Windels': 1185742670,
#  'Vincent Houssiau': 1145182533,
#  'Willy Kuijpers': 1105018002,
#  'Woldrich Harrison Courtenay': 1237091310,
#  'Yvan Verougstraete': 1250929396,
#  'Yves de Wasseige': 1175107156,
#  'Ugyen_Dorji_%28DNT_politician%29': None,
#  'Jigme_Namgyal_%28Bhutan%29': None,
#  'Tenzin_%28politician%29': None,
#  'Dechen_Wangmo_%28politician%29': None,
#  'Arouna Mama': 1162194883,
#  'Chogyal Dago Rigdzin': 1240180535,
#  'Choida Jamtsho': 1154610749,
#  'Choki Gyeltshen': 967051066,
#  'D. N. Dhungyel': 1226923015,
#  'Dechen Zangmo': 1212616003,
#  'Dorjee Wangmo': 1060085965,
#  'Dorji Namgyal': 1157335890,
#  'Dorji Tshering': 1205736909,
#  'Dupthob': 986218104,
#  'Francis Covi': 1197447438,
#  'Jai Bir Rai': 1247671463,
#  'Jigme Wangchuk': 1076705305,
#  'Jules-Armand Aniambossou': 1248386169,
#  'Karma Donnen Wangdi': 1150559998,
#  'Karma Rangdol': 1140545677,
#  'Khandu Wangchuk': 1225408958,
#  'Kinga Penjor': 1029727171,
#  'Kinga Tshering': 1220863731,
#  'Kuenga Loday': 1135378735,
#  'Kunzang C. Namgyel': 1157055139,
#  'Lhatu Wangchuk': 1242666773,
#  'Loknath Sharma': 1151281659,
#  'Louis Hunkanrin': 1212917164,
#  'Louis Ignacio-Pinto': 1192236303,
#  'Namgay Tshering': 1226645464,
#  'Neten Zangmo': 1244820972,
#  'Nidup Zangpo': 1179648130,
#  'Norbu Wangchuk': 1105642733,
#  'Pema Chewang': 1241911285,
#  'Pema Gyamtsho': 1250135261,
#  'Rinzin Jamtsho': 986219619,
#  'Sefou Fagbohoun': 1244960174,
#  'Sherub Gyeltshen': 1151261156,
#  'Shingkhar Lam': 1205968589,
#  'Sonam Tobgye': 1211978424,
#  'Thakur S. Powdyel': 1184305239,
#  'Tshencho Wangdi': 935053725,
#  'Tshering Wangchuk': 1227847643,
#  'Tshewang Lhamo': 1134603390,
#  'Ugyen Tshering': 1216960207,
#  'Ugyen Wangdi': 1010522641,
#  'Wangdi Norbu': 1226646329,
#  'Yeshey Penjor': 1154435788,
#  'Yeshey Zimba': 1245331050,
#  'Zangley Dukpa': 1068932528,
#  'Botche_Cand%C3%A9': None,
#  'Teodora_In%C3%A1cia_Gomes': None,
#  'Francisco_Argando%C3%B1a': None,
#  'Isaac_%C3%81valos': None,
#  'Augusto_C%C3%A9spedes': None,
#  'Adolfo_Ch%C3%A1vez': None,
#  'Pantale%C3%B3n_Dalence': None,
#  'Rafael_Pe%C3%B1a': None,
#  'Marcelo_El%C3%ADo': None,
#  'Francisco_Burdett_O%27Connor': None,
#  'Sim%C3%B3n_Iturri_Pati%C3%B1o': None,
#  'Gary_Prado_Salm%C3%B3n': None,
#  'Jos%C3%A9_Mariano_Serrano': None,
#  'Mois%C3%A9s_Torres_%28politician%29': None,
#  'Jaime_de_Zud%C3%A1%C3%B1ez': None,
#  'Kemal_Ademovi%C4%87': None,
#  'Mehmed_Alajbegovi%C4%87': None,
#  'Bo%C5%A1ko_Ba%C5%A1kot': None,
#  'Salko_Bukvarevi%C4%87': None,
#  'Sabina_%C4%86udi%C4%87': None,
#  'D%C5%BEenan_%C4%90onlagi%C4%87': None,
#  'D%C5%BEevad_Galija%C5%A1evi%C4%87': None,
#  'Josip_Grube%C5%A1a': None,
#  'Ankica_Gudeljevi%C4%87': None,
#  'Hakija_Had%C5%BEi%C4%87': None,
#  'Mirsad_Had%C5%BEikadi%C4%87': None,
#  'Sanjin_Halimovi%C4%87': None,
#  'Sevlid_Hurti%C4%87': None,
#  'Husein_Miljkovi%C4%87': None,
#  'Adolfo Mendoza': 1214469646,
#  'Agnelo Regalla': 1189186057,
#  'Antonio Machaca': 1219966135,
#  'Aristide Menezes': 1142925183,
#  'Atanasio de Urioste Velasco': 1227518654,
#  'Bonifacio Pinedo': 1249373475,
#  'Carmelita Pires': 1185452679,
#  'Chi Hyun Chung': 1241844844,
#  'Desejado Lima da Costa': 1200012565,
#  'Edin Forto': 1220369102,
#  'Fernando Eloy Guachalla': 1239045289,
#  'Fernando Vargas Mosua': 1218741477,
#  'Florentino Mendes Pereira': 1177678990,
#  'Juliano Fernandes': 1015285975,
#  'Julio Pinedo': 1250888240,
#  'Manuel Luis de Oliden': 1227718125,
#  'Manuel de Molina Zamudio': 1234177241,
#  'Marcial Fabricano': 1064844718,
#  'Nataniel Aguirre': 1226514494,
#  'Pedro Domingo Murillo': 1234930001,
#  'Toribia Lero Quispe': 1242300969,
#  'Jasmin_Imamovi%C4%87': None,
#  'Adamir_Jerkovi%C4%87': None,
#  'Esed_Kadri%C4%87': None,
#  'Mehmed_Kapetanovi%C4%87': None,
#  'Osman_Karabegovi%C4%87': None,
#  'Rusmir_Mahmut%C4%87ehaji%C4%87': None,
#  'Amor_Ma%C5%A1ovi%C4%87': None,
#  'Bo%C5%BEidar_Mati%C4%87': None,
#  'Dragan_Mekti%C4%87': None,
#  'Ademaga_Me%C5%A1i%C4%87': None,
#  'Jelka_Mili%C4%8Devi%C4%87': None,
#  'Abdulah_Mutap%C4%8Di%C4%87': None,
#  'Abdulah_Naka%C5%A1': None,
#  'Damir_Nik%C5%A1i%C4%87': None,
#  '%C4%90uro_Pucar': None,
#  'Svetozar_Pudari%C4%87': None,
#  'Alen_%C5%A0erani%C4%87': None,
#  'Uglje%C5%A1a_Uzelac': None,
#  'Nezir_%C5%A0kalji%C4%87': None,
#  'Ibrahim_Spahi%C4%87': None,
#  'Jelena_Trivi%C4%87': None,
#  'Dragan_Viki%C4%87': None,
#  'Milo%C5%A1_Vuka%C5%A1inovi%C4%87': None,
#  'L%C3%A9o_de_Almeida_Neves': None,
#  'Ant%C3%B4nio_Pinto_Chichorro_da_Gama': None,
#  'Henrique_de_Beaurepaire-Rohan%2C_Viscount_of_Beaurepaire-Rohan': None,
#  'Nat%C3%A1lia_Bastos_Bonavides': None,
#  'Maur%C3%ADcio_Campos_de_Medeiros': None,
#  'Marcelo_Cec%C3%A9': None,
#  'Paulo_Corr%C3%AAa': None,
#  'Jo%C3%A3o_Cunha_%28politician%29': None,
#  'Amador Bueno': 1218000288,
#  'Cipriano Barata': 1248173582,
#  'Djalma Bastos de Morais': 1180933919,
#  'Hakija Pozderac': 1184510646,
#  'Hamdija Pozderac': 1195934285,
#  'Irani Barbosa': 1199631944,
#  'Ismet Popovac': 1231812222,
#  'Izolda Cela': 1246064910,
#  'Jader Barbalho Filho': 1153333232,
#  'Leetile Disang Raditladi': 1178476996,
#  'Marcos Braz': 1194912644,
#  'Margarete Coelho': 1234976623,
#  'Medeiros e Albuquerque': 1176588076,
#  'Miguel Couto': 1237350838,
#  'Milan Uzelac': 1243511577,
#  'Nurija Pozderac': 1197296458,
#  'Patrick van Rensburg': 1247394394,
#  'Philip Matante': 1246418220,
#  'Tobias de Aguiar': 1226478932,
#  ...}

# %%
# Add the revision IDs to the DataFrame
merged_df['revision_id'] = merged_df['name'].map(all_revision_ids)

# %%
merged_df[merged_df["revision_id"].notnull()]
