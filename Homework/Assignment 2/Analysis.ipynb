# %% [markdown]
# # Notebook 1

# %% [markdown]
# This is the first notebook for doing initial data cleaning and retrieving information from wikipedia

# %% [markdown]
# ### Imports

# %%
import os
import time
import json
import requests
import urllib.parse
import pandas as pd
from typing import Any, Dict, List, Optional

# %%
import wiki_requests as wr

# %% [markdown]
# ## Data Loading and Cleaning

# %% [markdown]
# ### Load the provided politicans and population datasets

# %%
politicians_df = pd.read_csv('politicians_by_country_AUG2024.csv')
population_df = pd.read_csv('population_by_country_AUG2024.csv')

# %% [markdown]
# Display the first few rows of each dataframe to inspect structure

# %%
politicians_df.head()
# Out:
#                    name                                                url  \
# 0        Majah Ha Adrif       https://en.wikipedia.org/wiki/Majah_Ha_Adrif
# 1     Haroon al-Afghani    https://en.wikipedia.org/wiki/Haroon_al-Afghani
# 2           Tayyab Agha          https://en.wikipedia.org/wiki/Tayyab_Agha
# 3  Khadija Zahra Ahmadi  https://en.wikipedia.org/wiki/Khadija_Zahra_Ah...
# 4        Aziza Ahmadyar       https://en.wikipedia.org/wiki/Aziza_Ahmadyar
#
#        country
# 0  Afghanistan
# 1  Afghanistan
# 2  Afghanistan
# 3  Afghanistan
# 4  Afghanistan

# %%
population_df.head()
# Out:
#          Geography  Population
# 0            WORLD      8009.0
# 1           AFRICA      1453.0
# 2  NORTHERN AFRICA       256.0
# 3          Algeria        46.8
# 4            Egypt       105.2

# %% [markdown]
# ### Clean & Standardize the data
# We need to clean and standardize the country names in both datasets to ensure the entries are consistent.
#
# We will also exclude cumulative regional rows (like "AFRICA", "NORTHERN AFRICA") from the country-specific analysis but retain them in a separate dataframe for regional-level analysis.

# %%
# Clean the population dataset
# Separate out regions (all caps) and countries
regions_df = population_df[population_df['Geography'].str.isupper()]
countries_df = population_df[~population_df['Geography'].str.isupper()]

# Rename columns to have a consistent naming format
countries_df = countries_df.rename(columns={'Geography': 'country', 'Population': 'population_millions'})
regions_df = regions_df.rename(columns={'Geography': 'region', 'Population': 'population_millions'})

# Standardize the column names for the politicians dataset as well
politicians_df = politicians_df.rename(columns={'country': 'country'})

# %%
# lets save the interum dataframes
countries_df.to_csv('population_by_country.csv', index=False)
regions_df.to_csv('population_by_region.csv', index=False)

# %% [markdown]
# Let’s view the intermediate cleaned dataframes

# %%
politicians_df['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan', 'Guinea-Bissau',
#        'Bolivia', 'Bosnia Herzegovina', 'Botswana', 'Brazil', 'Bulgaria',
#        'Burkina Faso', 'Myanmar', 'Burundi', 'Cambodia', 'Cameroon',
#        'Cape Verde', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo', 'Congo DR', 'Costa Rica',
#        'Croatia', 'Cuba', 'Cyprus', 'Czechia', 'Djibouti',
#        'Dominican Republic', 'Timor Leste', 'Ecuador', 'Egypt',
#        'United Arab Emirates', 'Equatorial Guinea', 'Eritrea', 'Estonia',
#        'Ethiopia', 'Finland', 'France', 'Gabon', 'Gambia', 'Germany',
#        'Ghana', 'Greece', 'Grenada', 'Guatemala', 'Guinea', 'Guyana',
#        'Haiti', 'Honduras', 'Hungary', 'India', 'Indonesia', 'Iran',
#        'Iraq', 'Israel', 'Italy', "Cote d'Ivoire", 'Japan', 'Jordan',
#        'Kazakhstan', 'Kenya', 'Korean', 'Kosovo', 'Kuwait', 'Kyrgyzstan',
#        'Laos', 'Latvia', 'Lebanon', 'Lesotho', 'Liberia', 'Libya',
#        'Lithuania', 'Luxembourg', 'North Macedonia', 'Madagascar',
#        'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Marshall Islands', 'Mauritania', 'Federated States of Micronesia',
#        'Moldova', 'Monaco', 'Mongolia', 'Montenegro', 'Morocco',
#        'Mozambique', 'Namibia', 'Nepal', 'Nicaragua', 'Nigeria', 'Niger',
#        'Norway', 'Oman', 'Pakistan', 'Palestinian Territory', 'Panama',
#        'Papua New Guinea', 'Paraguay', 'Peru', 'Poland', 'Portugal',
#        'Qatar', 'Russia', 'Rwanda', 'St. Kitts and Nevis', 'St. Lucia',
#        'St. Vincent and the Grenadines', 'El Salvador', 'Samoa',
#        'Saudi Arabia', 'Senegal', 'Serbia', 'Seychelles', 'Sierra Leone',
#        'Singapore', 'Slovakia', 'Slovenia', 'Solomon Islands', 'Somalia',
#        'South Africa', 'Korea, South', 'South Sudan', 'Spain',
#        'Sri Lanka', 'Sudan', 'Sweden', 'Switzerland', 'Syria', 'Taiwan',
#        'Tajikistan', 'Tanzania', 'Thailand', 'Togo', 'Tonga',
#        'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan',
#        'Tuvalu', 'Uganda', 'Ukraine', 'Uruguay', 'Uzbekistan', 'Vanuatu',
#        'Venezuela', 'Vietnam', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %%
countries_df.head()
# Out:
#    country  population_millions
# 3  Algeria                 46.8
# 4    Egypt                105.2
# 5    Libya                  6.9
# 6  Morocco                 37.0
# 7    Sudan                 48.1

# %%
countries_df["country"].unique()
# Out:
# array(['Algeria', 'Egypt', 'Libya', 'Morocco', 'Sudan', 'Tunisia',
#        'Western Sahara', 'Benin', 'Burkina Faso', 'Cape Verde',
#        "Cote d'Ivoire", 'Gambia', 'Ghana', 'Guinea', 'GuineaBissau',
#        'Liberia', 'Mali', 'Mauritania', 'Niger', 'Nigeria', 'Senegal',
#        'Sierra Leone', 'Togo', 'Burundi', 'Comoros', 'Djibouti',
#        'Eritrea', 'Ethiopia', 'Kenya', 'Madagascar', 'Malawi',
#        'Mauritius', 'Mayotte', 'Mozambique', 'Reunion', 'Rwanda',
#        'Seychelles', 'Somalia', 'South Sudan', 'Tanzania', 'Uganda',
#        'Zambia', 'Zimbabwe', 'Angola', 'Cameroon',
#        'Central African Republic', 'Chad', 'Congo', 'Congo DR',
#        'Equatorial Guinea', 'Gabon', 'Sao Tome and Principe', 'Botswana',
#        'eSwatini', 'Lesotho', 'Namibia', 'South Africa', 'Canada',
#        'United States', 'Belize', 'Costa Rica', 'El Salvador',
#        'Guatemala', 'Honduras', 'Mexico', 'Nicaragua', 'Panama',
#        'Antigua and Barbuda', 'Bahamas', 'Barbados', 'Cuba', 'Curacao',
#        'Dominica', 'Dominican Republic', 'Grenada', 'Guadeloupe', 'Haiti',
#        'Jamaica', 'Martinique', 'Puerto Rico', 'St. Kitts and Nevis',
#        'St. Lucia', 'St. Vincent and the Grenadines',
#        'Trinidad and Tobago', 'Argentina', 'Bolivia', 'Brazil', 'Chile',
#        'Colombia', 'Ecuador', 'French Guiana', 'Guyana', 'Paraguay',
#        'Peru', 'Suriname', 'Uruguay', 'Venezuela', 'Armenia',
#        'Azerbaijan', 'Bahrain', 'Cyprus', 'Georgia', 'Iraq', 'Israel',
#        'Jordan', 'Kuwait', 'Lebanon', 'Oman', 'Palestinian Territory',
#        'Qatar', 'Saudi Arabia', 'Syria', 'Turkey', 'United Arab Emirates',
#        'Yemen', 'Kazakhstan', 'Kyrgyzstan', 'Tajikistan', 'Turkmenistan',
#        'Uzbekistan', 'Afghanistan', 'Bangladesh', 'Bhutan', 'India',
#        'Iran', 'Maldives', 'Nepal', 'Pakistan', 'Sri Lanka', 'Brunei',
#        'Cambodia', 'Indonesia', 'Laos', 'Malaysia', 'Myanmar',
#        'Philippines', 'Singapore', 'Thailand', 'Timor Leste', 'Vietnam',
#        'China', 'China (Hong Kong SAR)', 'China (Macao SAR)', 'Japan',
#        'Korea (North)', 'Korea (South)', 'Mongolia', 'Taiwan', 'Denmark',
#        'Estonia', 'Finland', 'Iceland', 'Ireland', 'Latvia', 'Lithuania',
#        'Norway', 'Sweden', 'United Kingdom', 'Austria', 'Belgium',
#        'France', 'Germany', 'Liechtenstein', 'Luxembourg', 'Monaco',
#        'Netherlands', 'Switzerland', 'Belarus', 'Bulgaria', 'Czechia',
#        'Hungary', 'Moldova', 'Poland', 'Romania', 'Russia', 'Slovakia',
#        'Ukraine', 'Albania', 'Andorra', 'Bosnia Herzegovina', 'Croatia',
#        'Greece', 'Italy', 'Kosovo', 'Malta', 'Montenegro',
#        'North Macedonia', 'Portugal', 'San Marino', 'Serbia', 'Slovenia',
#        'Spain', 'Australia', 'Federated States of Micronesia', 'Fiji',
#        'French Polynesia', 'Guam', 'Kiribati', 'Marshall Islands',
#        'Nauru', 'New Caledonia', 'New Zealand', 'Palau',
#        'Papua New Guinea', 'Samoa', 'Solomon Islands', 'Tonga', 'Tuvalu',
#        'Vanuatu'], dtype=object)

# %% [markdown]
# The one thing I'm noticing is that in the politicians df there is a country 'Korean'- which I'm not sure if that means Korea (North) because there is an n at the end of it. That might be something to keep an eye on.

# %%
regions_df.head()
# Out:
#              region  population_millions
# 0             WORLD               8009.0
# 1            AFRICA               1453.0
# 2   NORTHERN AFRICA                256.0
# 10   WESTERN AFRICA                442.0
# 27   EASTERN AFRICA                483.0

# %%
regions_df["region"].unique()
# Out:
# array(['WORLD', 'AFRICA', 'NORTHERN AFRICA', 'WESTERN AFRICA',
#        'EASTERN AFRICA', 'MIDDLE AFRICA', 'SOUTHERN AFRICA',
#        'NORTHERN AMERICA', 'LATIN AMERICA AND THE CARIBBEAN',
#        'CENTRAL AMERICA', 'CARIBBEAN', 'SOUTH AMERICA', 'ASIA',
#        'WESTERN ASIA', 'CENTRAL ASIA', 'SOUTH ASIA', 'SOUTHEAST ASIA',
#        'EAST ASIA', 'EUROPE', 'NORTHERN EUROPE', 'WESTERN EUROPE',
#        'EASTERN EUROPE', 'SOUTHERN EUROPE', 'OCEANIA'], dtype=object)

# %% [markdown]
# ### Matching and merging the politicians & population datasets
# We will now merge the politicans and population datasets, and log any any countries from the politicans dataset that don't have a corresponding population entry.

# %%
# Merge the politicians dataset with the country population dataset
# Performing a left join to retain all politicians even if there is no population match
pol_pop_df = pd.merge(politicians_df,
                      countries_df,
                      how='left', on='country')

# Identify countries from the politicians dataset that don't have a match in the population data
no_match_countries = pol_pop_df[pol_pop_df['population_millions'].isna()]['country'].unique()

# Save the no-match countries to a text file
no_match_file_path = r'C:\Users\clark.roll\python coding\code_personal\Data512\Homework\Assignment 2\wp_countries-no_match.txt'
with open(no_match_file_path, 'w') as file:
    for country in no_match_countries:
        file.write(f"{country}\n")

# Save the cleaned and merged dataset as a CSV
pol_pop_df.to_csv('wp_politicians_by_country.csv', index=False)

# %% [markdown]
# Lets look at the merged dataframe

# %%
pol_pop_df
# Out:
#                       name                                                url  \
# 0           Majah Ha Adrif       https://en.wikipedia.org/wiki/Majah_Ha_Adrif
# 1        Haroon al-Afghani    https://en.wikipedia.org/wiki/Haroon_al-Afghani
# 2              Tayyab Agha          https://en.wikipedia.org/wiki/Tayyab_Agha
# 3     Khadija Zahra Ahmadi  https://en.wikipedia.org/wiki/Khadija_Zahra_Ah...
# 4           Aziza Ahmadyar       https://en.wikipedia.org/wiki/Aziza_Ahmadyar
# ...                    ...                                                ...
# 7150      Josiah Tongogara     https://en.wikipedia.org/wiki/Josiah_Tongogara
# 7151     Langton Towungana    https://en.wikipedia.org/wiki/Langton_Towungana
# 7152     Sengezo Tshabangu    https://en.wikipedia.org/wiki/Sengezo_Tshabangu
# 7153   Herbert Ushewokunze  https://en.wikipedia.org/wiki/Herbert_Ushewokunze
# 7154          Denis Walker         https://en.wikipedia.org/wiki/Denis_Walker
#
#           country  population_millions
# 0     Afghanistan                 42.4
# 1     Afghanistan                 42.4
# 2     Afghanistan                 42.4
# 3     Afghanistan                 42.4
# 4     Afghanistan                 42.4
# ...           ...                  ...
# 7150     Zimbabwe                 16.7
# 7151     Zimbabwe                 16.7
# 7152     Zimbabwe                 16.7
# 7153     Zimbabwe                 16.7
# 7154     Zimbabwe                 16.7
#
# [7155 rows x 4 columns]

# %% [markdown]
# It looks like the 'korean' entry that I was hesitant about in the politicians dataframe was logged as no matches, so that takes care of that.
#
# If that were a particularly important entry, then we could lookup the correct information and manually adjust it, but I think this will be fine for this project

# %% [markdown]
# ## Retrieve Information from WIKI

# %% [markdown]
# ### Prep

# %% [markdown]
# Lets start by prepping to make requests.
#
# We know that we need our article titles to be URL encoded so lets take care of that now by adding a column to the dataframe called `article_title` that is the URL encoded name

# %%
pol_pop_df['article_title'] = pol_pop_df['name'].apply(wr.prep_article_title)

# %%
pol_pop_df
# Out:
#                       name                                                url  \
# 0           Majah Ha Adrif       https://en.wikipedia.org/wiki/Majah_Ha_Adrif
# 1        Haroon al-Afghani    https://en.wikipedia.org/wiki/Haroon_al-Afghani
# 2              Tayyab Agha          https://en.wikipedia.org/wiki/Tayyab_Agha
# 3     Khadija Zahra Ahmadi  https://en.wikipedia.org/wiki/Khadija_Zahra_Ah...
# 4           Aziza Ahmadyar       https://en.wikipedia.org/wiki/Aziza_Ahmadyar
# ...                    ...                                                ...
# 7150      Josiah Tongogara     https://en.wikipedia.org/wiki/Josiah_Tongogara
# 7151     Langton Towungana    https://en.wikipedia.org/wiki/Langton_Towungana
# 7152     Sengezo Tshabangu    https://en.wikipedia.org/wiki/Sengezo_Tshabangu
# 7153   Herbert Ushewokunze  https://en.wikipedia.org/wiki/Herbert_Ushewokunze
# 7154          Denis Walker         https://en.wikipedia.org/wiki/Denis_Walker
#
#           country  population_millions         article_title
# 0     Afghanistan                 42.4        Majah_Ha_Adrif
# 1     Afghanistan                 42.4     Haroon_al-Afghani
# 2     Afghanistan                 42.4           Tayyab_Agha
# 3     Afghanistan                 42.4  Khadija_Zahra_Ahmadi
# 4     Afghanistan                 42.4        Aziza_Ahmadyar
# ...           ...                  ...                   ...
# 7150     Zimbabwe                 16.7      Josiah_Tongogara
# 7151     Zimbabwe                 16.7     Langton_Towungana
# 7152     Zimbabwe                 16.7     Sengezo_Tshabangu
# 7153     Zimbabwe                 16.7   Herbert_Ushewokunze
# 7154     Zimbabwe                 16.7          Denis_Walker
#
# [7155 rows x 5 columns]

# %% [markdown]
# ### Get Page Info (and revision id)

# %% [markdown]
# #### Single Article

# %% [markdown]
# Lets look at a single article to see how the page info is structured

# %%
# lets get information for 1 article. 
example_article = pol_pop_df['article_title'][0]
example_article
# Out:
# 'Majah_Ha_Adrif'

# %%
wr.request_pageinfo_per_article(example_article)
# Out:
# {'batchcomplete': '',
#  'query': {'normalized': [{'from': 'Majah_Ha_Adrif', 'to': 'Majah Ha Adrif'}],
#   'pages': {'10483286': {'pageid': 10483286,
#     'ns': 0,
#     'title': 'Majah Ha Adrif',
#     'contentmodel': 'wikitext',
#     'pagelanguage': 'en',
#     'pagelanguagehtmlcode': 'en',
#     'pagelanguagedir': 'ltr',
#     'touched': '2024-09-30T14:32:18Z',
#     'lastrevid': 1233202991,
#     'length': 3188,
#     'talkid': 13330265,
#     'fullurl': 'https://en.wikipedia.org/wiki/Majah_Ha_Adrif',
#     'editurl': 'https://en.wikipedia.org/w/index.php?title=Majah_Ha_Adrif&action=edit',
#     'canonicalurl': 'https://en.wikipedia.org/wiki/Majah_Ha_Adrif'}}}}

# %% [markdown]
# You could cycle through the code above in a for-loop to get the page information per article but that would take **BUT** it would take **~1-2 hours to run**.
#
# Instead I would suggest running as a batch, as is shown here.
#
# #### Multiple Articles
#
# You can adjust the batch size to get this to run faster but **do not exceed a batch size of 50**

# %%
all_article_titles = pol_pop_df["article_title"].tolist()

# %%
all_pages_info = wr.get_page_info_for_multiple_articles(all_article_titles, 
                                                        batch_size=10,
                                                        output_file="page_info_output.json")
# Out:
# Fetching page info data for: Majah_Ha_Adrif|Haroon_al-Afghani|Tayyab_Agha|Khadija_Zahra_Ahmadi|Aziza_Ahmadyar|Muqadasa_Ahmadzai|Mohammad_Sarwar_Ahmedzai|Amir_Muhammad_Akhundzada|Nasrullah_Baryalai_Arsalai|Abdul_Rahim_Ayoubi
# Page info saved to page_info_output.json
# Fetching page info data for: Ismael_Balkhi|Abdul_Baqi_Turkistani|Mohammad_Ghous_Bashiri|Jan_Baz|Bashir_Ahmad_Bezan|Rafiullah_Bidar|Mohammad_Siddiq_Chakari|Cheragh_Ali_Cheragh|Nasir_Ahmad_Durrani|Muhammad_Hashim_Esmatullahi
# Page info saved to page_info_output.json
# Fetching page info data for: Ezatullah_%28Nangarhar%29|Aimal_Faizi|Gajinder_Singh_Safri|Sharif_Ghalib|Hashmat_Ghani_Ahmadzai|Abdul_Ghani_Ghani|Ghulam_Ghaus|Ghulam_Muhammad_Ghobar|Mohammad_Gul_%28Helmand_Council%29|Sayed_Yousuf_Halim
# Page info saved to page_info_output.json
# Fetching page info data for: Rangina_Hamidi|Sayed_Zafar_Hashemi|Qutbuddin_Hilal|Mahboba_Hoqomal|Musa_Hotak|Mirza_Muhammad_Ismail|Sayed_Jalal|Said_Tayeb_Jawad|Sayed_Jalal_Karim|Hafizullah_Shabaz_Khail
# Page info saved to page_info_output.json
# Fetching page info data for: Masoud_Khalili|Mohammad_Khan_%28athlete%29|Samoud_Khan|Baran_Khan_Kudezai|Azizullah_Lodin|Razaq_Mamoon|Fazel_Ahmed_Manawi|Moeen_Marastial|Ahmad_Wali_Massoud|Mohammad_Daud_Miraki
# Page info saved to page_info_output.json
# Fetching page info data for: Abdul_Sattar_Mirzakwal|Abdul_Karim_Misaq|Ali_Mohammad_%28politician%29|Nasruddin_Mohseni|Davood_Moradian|Zalmai_Mujadidi|Sardar_Mohammad_Nadir_Naeem|Daoud_Naji|Gholam_Rabani_Nasher|Ghulam_Faroq_Nijrabi
# Page info saved to page_info_output.json
# Fetching page info data for: Zabih-U-llah_Ghazi_Noristani|Mohammed_Tahir_Omar|Mohammed_Qalamuddin|Ghulam_Mohammad_Rigi|Ghulam_Hassan_Safi|Hanifa_Safi|Mohammed_Zia_Salehi|Abdul_Majid_Samim|Saber_Sangar|Sayed_Nasim_Mihanparast
# Page info saved to page_info_output.json
# Fetching page info data for: Suhail_Shaheen|Fazal_Hadi_Shinwari|Baktash_Siawash|Hasan_Ali_Sultani|Mohammad_Hashem_Taufiqui|Pacha_Gul_Wafadar|Wahidullah_Waissi|Ahmadullah_Wasiq|Gul_Ahmmad_Yama|Abdul_Salam_Zaeef
# Page info saved to page_info_output.json
# Fetching page info data for: Abdul_Zahir_%28Konar_Education_Minister%29|Mohammed_Zaman|Ziauddin_%28Afghan_militia_leader%29|Qari_Ziauddin|Abdul_Ghafor_Zori|Ali_Pasha_of_Gusinje|Ylli_Asllani|Azis_Tahir_Ajdonati|Bislim_Bajgora|Kastriot_Berissa
# Page info saved to page_info_output.json
# Fetching page info data for: Bardhok_Biba|Kostandin_Boshnjaku|Spartak_Braho|Safet_Butka|Uran_Butka|Refo_%C3%87apari|Neritan_Ceka|Hysni_Curri|Ibrahim_Dalliu|Niazi_Demi
# Page info saved to page_info_output.json
# Fetching page info data for: Abdurrahman_Dibra|Bujar_Dida|Ahmed_Dino|Rasih_Dino|Ferhat_Bey_Draga|Nexhip_Draga|Aqif_Pasha_Elbasani|Abas_Ermenji|Qamil_Musa_Haxhi_Feza|Themistokli_G%C3%ABrmenji
# Page info saved to page_info_output.json
# Fetching page info data for: Sabri_Godo|Mihal_Grameno|A%C4%87if_Had%C5%BEiahmetovi%C4%87|High_Council_of_Regency|Kurt_Ag%C3%AB_Kadiu|Mehmed_Kalakula|Alfred_Karamu%C3%A7o|Ibrahim_Karbunara|Ali_K%C3%ABlcyra|Bajram_Kelmendi
# Page info saved to page_info_output.json
# Fetching page info data for: Kristo_Kirka|Elez_Ko%C3%A7i|Xhelal_Kopr%C3%ABncka|Kryeziu_family|Artur_Kuko|Xhavid_Leskoviku|Sabit_Lulo|Gjon_Markagjoni|Tefik_Mborja|Hysni_Milloshi
# Page info saved to page_info_output.json
# Fetching page info data for: Musa_Qazimi|Mustafa_Ndroqi|Behxhet_Nepravishta|Adrian_Neritani|Sali_Nivica|Thoma_Orologa|Bedri_Pejani|Kadri_Prishtina|Ymer_Prizreni|Avni_Rustemi
# Page info saved to page_info_output.json
# Fetching page info data for: Chatin_Sarachi|Nebi_Sefa|Eduard_Shalsi|Ylli_Vesel_Shehu|Athanas_Shundi|Xhelal_Sve%C3%A7la|Mehmet_Tahsini|Ibrahim_Temo|Afrim_Tole|Syreja_Vlora
# Page info saved to page_info_output.json
# Fetching page info data for: Visarion_Xhuvani|Visar_Ymeri|Abdyl_Ypi|Xhezair_Zaganjori|Menduh_Zavalani|Abdelkader_Zoukh|Cha%C3%A2bane_A%C3%AFt_Abderrahim|Ali_Aoun|Basma_Azouar|Mohamed_Seghir_Babes
# Page info saved to page_info_output.json
# Fetching page info data for: Noureddine_Bahbouh|Lamine_Bechichi|A%C3%AFssa_Bekkai|Abdelhakim_Belabed|Mohamed_Tarek_Belaribi|Kamel_Beldjoud|Aboubakr_Belkaid|Youcef_Belmehdi|Mohamed_Cherif_Belmihoub|Mohamed_Belouizdad
# Page info saved to page_info_output.json
# Fetching page info data for: Benaouda_Hadj_Hac%C3%A8ne_Bachterzi|Souad_Bendjaballah|Abdelkrim_Benmbarek|Mohamed_Bensalam|Fay%C3%A7al_Bentaleb|Ahmed_Bidani|Kamel_Bidari|Rachid_Bladehane|Sa%C3%AFd_Boualam|Rabah_Bouaziz
# Page info saved to page_info_output.json
# Fetching page info data for: Abdeslam_Bouchouareb|Ibrahim_Boughali|Yahia_Boukhari|Mohamed_Bouslimani|Foued_Chehat|Hamza_Al_Sid_Cheikh|Hocine_Cherhabil|Abderrahmane_Meziane_Ch%C3%A9rif|Sa%C3%AFd_Chibane|Brahim_Chibout
# Page info saved to page_info_output.json
# Fetching page info data for: Youcef_Chorfa|Fazia_Dahleb|Taha_Derbal|Nassim_Diafat|Mokhtar_Didouche|Bouras_Djamel|Fatiha_Serour|Ahmed_Hamiani|Nadir_Kassab|Brahim_Djamel_Kassali
# Page info saved to page_info_output.json
# Fetching page info data for: Kaoutar_Krikou|Sassi_Lamouri|Mohamed_Maghlaoui|Amar_Makhloufi|Yassine_Merabi|Brahim_Merad|Bachir_Messaitfa|Azzedine_Mihoubi|Mohamed_Ali_Boughazi|Amar_Mohammedi
# Page info saved to page_info_output.json
# Fetching page info data for: Samia_Moualfi|Soraya_Mouloudji|Yacine_Oualid|Cherif_Rahmani|Lakhdar_Rakhroukh|Laid_Rebiga|Kamel_Rezig|Salim_Saadi|Abdelhak_Saihi|Hichem_Sofiane_Salaouatchi
# Page info saved to page_info_output.json
# Fetching page info data for: Naima_Salhi|Abderezak_Sebgag|Abderrachid_Tabbi|Karim_Bibi_Triki|Layachi_Yaker|Ahmed_Zeghdar|Ad%C3%A3o_Francisco_Correia_de_Almeida|Ana_Paula_Chantre_Luna_de_Carvalho|Alexandre_Sebasti%C3%A3o_Andr%C3%A9|Paulino_Baptista
# Page info saved to page_info_output.json
# Fetching page info data for: Bernarda_Gon%C3%A7alves_Martins|Jo%C3%A3o_Baptista_Borges|Carolina_Cerqueira|Arlete_Chimbinda|Kafundanga_Chingunji|Jeremias_Chitunda|Abel_Chivukuvuku|Fiel_Domingos_Constantino|Adalberto_Costa_J%C3%BAnior|Adjany_Costa
# Page info saved to page_info_output.json
# Fetching page info data for: Vilayat_Eyvazov|Abdurrahman_Fatalibeyli|Fazail_Ibrahimli|Afshan_Gadimbeyova|Garib_Karimo%C4%9Flu|Gudrat_Gasanguliev|Mehrali_Gasimov|Solomon_Grobshtein|Teymur_Guliyev|Mammad_Gurbanov
# Page info saved to page_info_output.json
# Fetching page info data for: Musa_Hacigasimov|Asaf_Hajiyev|Haji_Molla_Ahmad_Nuruzade|Farhad_Hajiyev|Hasan_Majidov|Hasan_Hasanli|Jamil_Hasanli|Ali_M._Hasanov|Zakir_Hasanov|Ali_Huseynli
# Page info saved to page_info_output.json
# Fetching page info data for: Alisahib_Huseynov|Ali_Ibrahimov|Irshad_Aliyev|Mamed_Iskenderov|Vidadi_Isgandarov|Ajdar_Ismailov|Saftar_Jafarov|Jeyhun_Jalilov|Arastun_Javadov|Rovshan_Javadov
# Page info saved to page_info_output.json
# Fetching page info data for: Anar_Karimov|Boris_Kevorkov|Gurban_Khalilov|Ahmad_Kordary|Lutfali_bey_Behbudov|Ilham_Madatov|Makhmud_Mamed-Guliev|Majnun_Mammadov|Musa_Mammadov|Ramin_Mammadov
# Page info saved to page_info_output.json
# Fetching page info data for: Elshad_Mirbashir_oghlu|Tahir_Mirkishili|Movsum_Samadov|Fuad_Naghiyev|Eldar_Namazov|Namig_Nasrullayev|Siyavush_Novruzov|Zahid_Oruj|Sadig_Rahimov|Suleyman_Rahimov
# Page info saved to page_info_output.json
# Fetching page info data for: Huseyn_Rahmanov|Rovshen_Rzayev|Hasan_Seyidov|Hasan_Seyidov_%28scientist%29|Parviz_Shahbazov|Mammad_agha_Shahtakhtinski|Abid_Sharifov|Shirali_Akhundov|Ikhtiyar_Shirinov|Bakhtiyar_Vahabzadeh
# Page info saved to page_info_output.json
# Fetching page info data for: Vugar_Mustafayev_%28minister%29|Yusif_Ziya_Talibzadeh|Nurali_Yusifbayli|Keith_Bell_%28Bahamian_politician%29|Charles_Carter_%28Bahamian_journalist%29|Harold_Christie|Timothy_Donaldson|Eugene_Dupuch|Joseph_Robert_Love|McKell_Bonaby
# Page info saved to page_info_output.json
# Fetching page info data for: Pakesia_Parker-Edgecombe|James_Carmichael_Smith_%28postmaster%29|Mohammed_Isa_Al_Abbasi|Abdulla_Adel_Fakhro|Abdullah_bin_Isa_Al_Khalifa|Ahmed_Behzad_%28Bahrain%29|Kamal_Ahmed_%28politician%29|Mohamed_Ali_Hasan_Ali|Khalid_Almoayed|Aymen_Tawfeeq_Almoayed
# Page info saved to page_info_output.json
# Fetching page info data for: Nazar_Al_Baharna|Mahmood_Al_Bahrani|Ammar_Al_Bannai|Jawad_Fairooz|Qasim_Fakhro|Faisal_al-Hamar|Nabeel_bin_Yaqub_Al-Hamar|Isa_bin_Abdulrahman_Al_Hammadi|Jameel_Humadan|Isa_bin_Ibrahim_Al_Khalifa
# Page info saved to page_info_output.json
# Fetching page info data for: Fahmi_al-Jowder|Saud_Kanoo|Essam_Khalaf|Abdullah_bin_Hamad_bin_Isa_Al_Khalifa|Ahmed_bin_Mohamed_Al_Khalifa|Ali_bin_Khalifa_Al_Khalifa|Hala_bint_Mohammed_Al_Khalifa|Ibrahim_ibn_Khalifa_Al_Khalifa|Mai_bint_Mohammed_Al_Khalifa|Salman_bin_Khalifa_Al_Khalifa
# Page info saved to page_info_output.json
# Fetching page info data for: Hamad_Al_Kooheji|Abdullatif_Al-Mahmood|Rasheed_Mohammed_Al_Maraj|Khalid_Al_Maskati|Abdulhussain_bin_Ali_Mirza|Mohammed_Al-Buainain|Mohammed_bin_Khalifa_bin_Ahmed|Mohammed_bin_Khalifa_bin_Ali_Al_Khalifa|Abdulrahman_al-Nuaimi|Ammar_Qambar
# Page info saved to page_info_output.json
# Fetching page info data for: Isa_Qassim|Abdulla_Hassan_Saif|Ali_bin_Saleh_Al_Saleh|Ahmed_Al-Salloum|Salman_bin_Hamad_Al_Khalifa|Abdul_Motaleb|Abdus_Salam_%28Chattogram_politician%29|Abul_Hashim|Oli_Ahad|Chowdhury_Shamsuddin_Ahmed
# Page info saved to page_info_output.json
# Fetching page info data for: Farid_Ahmed|Muzaffar_Ahmed_%28NAP_politician%29|AKM_Hafizuddin|Mohammad_Manjur_Alam|M_Hossain_Ali|Aminul_Islam_Rabel|Mohammad_A._Arafat|Ashab_Uddin_Ahmad|Shafiqur_Rahman_Badsha|Selina_Banu
# Page info saved to page_info_output.json
# Fetching page info data for: Nurul_Huq_Bhuiyan|Birendra_Kishore_Roaza|Bishnu_Chattopadhyay|AKM_Fazlul_Kabir_Chowdhury|Aminul_Islam_Chowdhury|Anwarul_Karim_Chowdhury|Moinuddin_Ahmed_Chowdhury|Sarwar_Jan_Chowdhury|Shahinur_Pasha_Chowdhury|Yusuf_Ali_Chowdhury
# Page info saved to page_info_output.json
# Fetching page info data for: Haji_Mohammad_Danesh|Pulin_De|James_Leo_Ferguson|Abdul_Halim_Ghaznavi|Debendra_Nath_Ghosh|Ranesh_Das_Gupta|AKM_Fazlul_Haque_%28Jatiya_Party_politician%29|Syed_Najmuddin_Hashim|M._Anwar_Hossain|Nozir_Hossain
# Page info saved to page_info_output.json
# Fetching page info data for: Husam_Uddin_Chowdhury_Fultali|Syed_Muhammad_Ibrahim|Abul_Kashem|Abul_Kashem_Khan|Hatem_Ali_Khan|Muhammad_Hamidullah_Khan|Yar_Mohammad_Khan|Kazi_Abdus_Shahid_Lal|Jyotirindra_Bodhipriya_Larma|Shamima_Harun_Lubna
# Page info saved to page_info_output.json
# Fetching page info data for: Manik_Lal_Ray|Manjurul_Imam|Mushrefa_Mishu|Moin_Uddin_%28politician%29|Fazlul_Haque_Montu|Mujahidul_Islam_Selim|Mujibur_Rahman_%28Chattogram_politician%29|Shafiul_Alam_Chowdhury_Nadel|SM_Nuruzzaman|Shamsul_Huda_Panchbagi
# Page info saved to page_info_output.json
# Fetching page info data for: Muhammad_Bayazeed_Khan_Panni|Ferdous_Ahmed_Qureshi|Asheq_Ullah_Rafiq|Abdur_Rahim_%28scholar%29|Habibar_Rahman|M._M._Rahmatullah|Golam_Maula_Rony|Devasish_Roy|Mahmudul_Haque_Sayem|Maulana_Shakhawat
# Page info saved to page_info_output.json
# Fetching page info data for: Eug%C3%A8ne_Goblet_d%27Alviella|Julien_Goekint|Jean-Pierre_Graf%C3%A9|Jacques_Grippa|Guy_Hance|Joris_Helleputte|Lucienne_Herman-Michielsens|Jules_Hiernaux|Julius_Hoste_Jr.|Norbert_Hougardy
# Page info saved to page_info_output.json
# Fetching page info data for: Joseph_Houssa|Vincent_Houssiau|Pierre_Van_Humbeeck|Dorah_Ilunga|Pierre_Imperiali|Jean-Fran%C3%A7ois_Istasse|Milou_Jeunehomme|Georges_Kaeckenbeeck|Andr%C3%A9_Kempinaire|Ahmet_Ko%C3%A7_%28politician%29
# Page info saved to page_info_output.json
# Fetching page info data for: Willy_Kuijpers|Rachid_Madrane|Luc_Michel|Fientje_Moerman|Andr%C3%A9_Molitor|Jean_Pede|Pierre_Emmanuel_F%C3%A9lix_Chazal|Jean-Marie_Piret|Andr%C3%A9-Eug%C3%A8ne_Pirson|Marjet_Van_Puymbroeck
# Page info saved to page_info_output.json
# Fetching page info data for: Jean_Richardot_the_Younger|Gustave_Rolin-Jaequemyns|Hippolyte_Rolin|Father_Samuel|Louis-Joseph_Seutin|Alfons_Siffer|Cyrille_Tahay|Jacques_Timmermans|Robert_Urbain|Adolphe_Van_Glabbeke
# Page info saved to page_info_output.json
# Fetching page info data for: Ga%C3%ABtan_Van_Goidsenhoven|Jacques_Van_Gompel|Marcel_Van_Langenhove_%28referee%29|Johan_Verbeke|Yvan_Verougstraete|Lodewijk_Verreycken|Louis_Waltniel|Yves_de_Wasseige|Roger_Windels|Jacques_van_Ypersele_de_Strihou
# Page info saved to page_info_output.json
# Fetching page info data for: Nemencio_Acosta|Basilio_Ah|Beverly_Castillo|Charles_Bartlett_Hyde|Glenn_Godfrey|Alexander_Albert_Hunter|Elfreda_Reyes|Bert_Tucker|Woldrich_Harrison_Courtenay|Arnauld_Antoine_Akodj%C3%A8nou
# Page info saved to page_info_output.json
# Fetching page info data for: Jules-Armand_Aniambossou|Francis_Covi|Sefou_Fagbohoun|Louis_Hunkanrin|Louis_Ignacio-Pinto|Arouna_Mama|D._N._Dhungyel|Dorjee_Wangmo|Ugyen_Dorji_%28DNT_politician%29|Zangley_Dukpa
# Page info saved to page_info_output.json
# Fetching page info data for: Dupthob|Choki_Gyeltshen|Sherub_Gyeltshen|Choida_Jamtsho|Rinzin_Jamtsho|Shingkhar_Lam|Tshewang_Lhamo|Kuenga_Loday|Dorji_Namgyal|Jigme_Namgyal_%28Bhutan%29
# Page info saved to page_info_output.json
# Fetching page info data for: Kunzang_C._Namgyel|Wangdi_Norbu|Pema_Chewang|Pema_Gyamtsho|Kinga_Penjor|Yeshey_Penjor|Thakur_S._Powdyel|Jai_Bir_Rai|Karma_Rangdol|Chogyal_Dago_Rigdzin
# Page info saved to page_info_output.json
# Page info saved to page_info_output.json
# Fetching page info data for: Marcio_Pochmann|Presidency_of_Castelo_Branco|Presidency_of_Eurico_Gaspar_Dutra|Presidency_of_Fernando_Henrique_Cardoso|Presidency_of_Itamar_Franco|Presidency_of_Juscelino_Kubitschek|Irondi_Pugliesi|Eus%C3%A9bio_de_Queir%C3%B3s|Marco_Antonio_Raupp|Renan_Contar
# Page info saved to page_info_output.json
# Fetching page info data for: Robert_Rey_%28plastic_surgeon%29|Jos%C3%A9_Richa|Ary_Rigo|Eduardo_Rocha|Betinho_Rosado|Rosana_Martinelli|Ant%C3%B4nio_Ricardo_dos_Santos|Augusto_Severo_de_Albuquerque_Maranh%C3%A3o|Jos%C3%A9_Manuel_da_Silva%2C_Baron_of_Tiet%C3%AA|Fabiano_Silveira
# Page info saved to page_info_output.json
# Fetching page info data for: Vittorio_Sorotiuk|Jose_de_Sousa_Campos|Irineu_Evangelista_de_Sousa%2C_Viscount_of_Mau%C3%A1|Jo%C3%A3o_Cardoso_de_Meneses_e_Sousa%2C_Baron_of_Paranapiacaba|Aureliano_C%C3%A2ndido_Tavares_Bastos|Juarez_T%C3%A1vora_%28general%29|Ant%C3%B4nio_de_Queir%C3%B3s_Teles%2C_Baron_of_Jundia%C3%AD|Nelson_Trad_Filho|Evaristo_da_Veiga|Lu%C3%ADs_Viana_Neto
# Page info saved to page_info_output.json
# Fetching page info data for: Augusto_Ximeno_de_Villeroy|Andr%C3%A9_Zacharow|Murilo_Zauith|Zeca_do_PT|Aleksandar_Alekov|Anyu_Angelov|Atanas_Zapryanov|Atanas_Atanasov_%28politician_born_1990%29|Atanas_Atanasov_%28politician%29|Hristo_Atanassov
# Page info saved to page_info_output.json
# Fetching page info data for: Jonas_Basanavi%C4%8Dius|Tsvetko_Boboshevski|Alexander_Bogoridi|Chairman_%28President%29_of_Bulgaria|Dzhevdet_Chakarov|Vasil_Chichibaba|Lea_Cohen|Vladimir_Damgov|Stanislav_Daskalov|Stefan_Dimitrov_%28politician%29
# Page info saved to page_info_output.json
# Fetching page info data for: Ivan_Dimov_%28scientist%29|Valentin_Fortunov|Tsoncho_Ganev|Georgi_Gvozdeykov|Goritsa_Grancharova|Ivancho_Hadzhipenchovich|Ivan_Demerdzhiev|Aleksi_Ivanov|Grozdan_Karadzhov|Vladimir_Karolev
# Page info saved to page_info_output.json
# Fetching page info data for: Georgi_Kirkov|Spiro_Kitinchev|Ivan_Kondov|Kostadin_Kostadinov_%28professor%29|Gavril_Krastevich|Petar_Kulenski|Lazar_Lazarov|Nikola_Lazarov|Ivan_Marazov|Venko_Markovski
# Page info saved to page_info_output.json
# Fetching page info data for: Yakov_Matakiev|Ilian_Mihov|Raya_Nazaryan|Nikolay_Milkov|Plamen_Panayotov|Vladislav_Panev|Asparuh_Panov|Atanas_Pekanov|Sasho_Penov|Lyudmila_Petkova
# Page info saved to page_info_output.json
# Fetching page info data for: Hristo_Petrov|Rosen_Plevneliev|Aleksandur_Pulev|Denitsa_Simeonova|Ivan_Stanchov|Kalin_Stoyanov|Stanislav_Stoyanov_%28politician%29|Dragomir_Stoynev|Teodora_Genchovska|Daniel_Valchev
# Page info saved to page_info_output.json
# Fetching page info data for: Krasimir_Valchev|Velko_Valkanov|Ventsislav_Varbanov|Damyan_Velchev|Svetoslav_Vitkov|Mincho_Yovchev|Atanas_Zafirov|Martin_Zaimov|Dragomir_Zakov|Nayden_Zelenogorski
# Page info saved to page_info_output.json
# Fetching page info data for: Boureima_Badini|Blaise_Bassoleth|Nazi_Boni|Eric_Bougouma|Fran%C3%A7ois_Compaor%C3%A9|Daniel_Ouezzin_Coulibaly|Toub%C3%A9_Cl%C3%A9ment_Dakio|Fr%C3%A9d%C3%A9ric_Guirma|Emile_Ilboudo|Zinda_Kabor%C3%A9
# Page info saved to page_info_output.json
# Fetching page info data for: Christophe_Kalenzaga|Jos%C3%A9phine_Drabo_Kanyoulou|Jos%C3%A9phine_Ki-Zerbo|Begnon-Damien_Kon%C3%A9|Yabre_Juliette_Kongo|Kouam%C3%A9_Lougu%C3%A9|Jean-Baptiste_Natama|Jean-Baptiste_Ou%C3%A9draogo|Mamadou_Ou%C3%A9draogo|Ousmane_Bougouma
# Page info saved to page_info_output.json
# Fetching page info data for: Pargui_Emile_Par%C3%A9|Filippe_Savadogo|Nouhoun_Sigue|Diongolo_Traore|Maurice_Yam%C3%A9ogo|Saye_Zerbo|Aung_Than_Oo|Aye_Ko_%28artist%29|Ba_Shin|Bao_Youxiang
# Page info saved to page_info_output.json
# Fetching page info data for: Bawk_Ja|Cheery_Zahau|Oscar_de_Glanville|M._A._Gaffar|Han_Tha_Myint|Hla_Maung_Shwe|Hso_Khan_Pha|Nai_Htaw_Sorn|Htay_Aung_%28businessman%29|Htin_Linn_Aung
# Page info saved to page_info_output.json
# Fetching page info data for: Ja_Htoi_Pan|Khin_Kyaw_Han|Khin_Ma_Ma_Myo|Khin_Maung_Swe|Khun_San_Lwin|Ko_Ni|Thakin_Kodaw_Hmaing|Kwe_Te_No|Sao_Kya_Seng|Kyaw_Moe_Tun
# Page info saved to page_info_output.json
# Fetching page info data for: Kyaw_Myint|Kyaw_Tun|Kyaw_Zaw_Oo|Duwa_Lashi_La|Lian_Hmung_Sakhong|Sultan_Mahmud_%28minister%29|Maran_Brang_Seng|Gani_Markan|Maw_Htun_Aung|Myint_Swe_%28politician%2C_born_1965%29
# Page info saved to page_info_output.json
# Fetching page info data for: Myo_Yan_Naung_Thein|Naw_Ohn_Hla|Nay_Myo_Wai|Nay_Zin_Lat|Kyaw_Ni|Nyi_Sein|Nyo_Nyo_Thin|Pu_Pa_Thang|San_Tun|Sao_Sanda
# Page info saved to page_info_output.json
# Fetching page info data for: Sasa_%28politician%29|Saw_Sa|Saya_Gyi_U_Nu|Sein_Win_%28politician%2C_born_1944%29|Mya_Lay_Sein|Sao_Seng_Suk|Shwe_Ohn|Soe_Moe_Hlaing|Sultan_Ahmed_%28Burmese_politician%29|Naw_Susanna_Hla_Hla_Soe
# Page info saved to page_info_output.json
# Fetching page info data for: Tan_Yu_Sai|Taw_Phaya_Galay|Tayzar_San|Than_Nyein|Than_Sein|Than_Win|Thaung_Tun_%28politician%29|Baganset_U_Thaw|Thein_Maung|Thein_Nyunt_%28politician%29
# Page info saved to page_info_output.json
# Fetching page info data for: Thet_Win_Aung|Thirty_Comrades|Tin_Aye|Tu_Hkawng|Wai_Moe_Naing|Win_Ko_Ko_Latt|Maung_Wuntha|Yawd_Serk|Za_Hlei_Thang|Zaw_Htay
# Page info saved to page_info_output.json
# Fetching page info data for: Zura_Begum|Pierre_Baranyanka|Joseph_Biroli|Evelyne_Butoyi|Joseph_Cimpaye|Edouard_Nduwimana|Gervais_Nyangoma|G%C3%A9rard_Mfuranzima|Cyrille_Ndayirukiye|R%C3%A9v%C3%A9rien_Ndikuriyo
# Page info saved to page_info_output.json
# Fetching page info data for: Tharcisse_Niyongabo|Gabriel_Nizigama|Jean-Baptiste_Ntidendereza|Ririkumutima|Agathon_Rwasa|Imelde_Sabushimike|Alexis_Sinduhije|Ang_Vong_Vathana|Samheng_Boros|Bun_Chanmol
# Page info saved to page_info_output.json
# Fetching page info data for: Chem_Snguon|Chhan_Sokhom|Chuon_Saodi|Duong_Sam_Ol|Ieu_Koeus|Ith_Samheng|Khem_Veasna|Kou_Roun|Daran_Kravanh|Lon_Nil
# Page info saved to page_info_output.json
# Fetching page info data for: Mao_Ayuth|Neav_Sithong|Ngoun_Chhay_Kry|Norodom_Norindeth|Norodom_Phurissara|Oung_Ouen|Phlek_Chhat|Ponn_Vongs_Vaddey|Samheng_Bora|Say_Phouthang
# Page info saved to page_info_output.json
# Fetching page info data for: Sisowath_Youtevong|So_Nem|Tep_Hun|Tep_Phan|Tep_Vattho|Thiounn|Touch_Kim|Truong_Cang|Tuot_Saron|Uch_Ven
# Page info saved to page_info_output.json
# Fetching page info data for: Uk_Vithun|Ung_Hong_Sath|Veng_Sakhon|Yat_Hwaidi|Marie_Catherine_Abena|Haman_Adama|Vincent_de_Paul_Ahanda|Ahmadou_Ahidjo|Joseph_Beti_Assomo|Charles_Ateba_Eyene
# Page info saved to page_info_output.json
# Fetching page info data for: Olivier_Bil%C3%A9|Dsamou_Micheline|Lawrence_Fonka_Shang|Victor_Fotso|S%C3%A9raphin_Magloire_Fouda|Lucy_Gwanmesia|Njomgang_Isaac|Ren%C3%A9_Jam_Afane|Augustine_Ngom_Jua|Paul_Monyonge_Kale
# Page info saved to page_info_output.json
# Fetching page info data for: Enanga_Kebbi|Pierre_Kotouo|Laurentine_Mbede|Albert_Mbida|Ibrahim_Mbombo_Njoya|Cl%C3%A9mentine_Ananga_Messina|Ousmane_Mey|Victor_Mukete|Bernard_Muna|Jer%C3%B4me_Mvondo
# Page info saved to page_info_output.json
# Fetching page info data for: Anne_Marthe_Mvoto|Hermine_Patricia_Toma%C3%AFno_Ndam_Njoya|Pierre_Ngayewang|John_Ebong_Ngole|Xavier_Ngoubeyou|Victor_Anomah_Ngu|Julienne_Niat|Dorothy_L._Njeuma|Bernard_Njonga|Arouna_N%27Joya
# Page info saved to page_info_output.json
# Fetching page info data for: Gjuro_%C4%8Cervar|Melko_%C4%8Cingrija|Pero_%C4%8Cingrija|Juraj_Demetrovi%C4%87|Mate_Drinkovi%C4%87|Nikica_Gabri%C4%87|Leon_Ger%C5%A1kovi%C4%87|Pavle_Gregori%C4%87|Ernest_Jelu%C5%A1i%C4%87|Emerik_Josipovi%C4%87
# Page info saved to page_info_output.json
# Fetching page info data for: Gejza_Josipovi%C4%87|Radovan_Juri%C4%8Di%C4%87|Luka_Kirac|Stjepan_Kova%C4%8Devi%C4%87|Josip_Kregar|Izidor_Kr%C5%A1njavi|Ivo_Krstelj|%C5%A0ime_Kureli%C4%87|Ante_Mandi%C4%87|Gavro_Manojlovi%C4%87
# Page info saved to page_info_output.json
# Fetching page info data for: Vladimir_Ma%C5%BEurani%C4%87|Francesco_Neffat|Fran_Novljan|Adam_Oster|Kata_Pejnovi%C4%87|Ivo_Pilar|Pero_Pirker|Vladimir_Prebeg|Svetozar_Pribi%C4%87evi%C4%87|Niko_Puci%C4%87
# Page info saved to page_info_output.json
# ...
# Page info saved to page_info_output.json
# Fetching page info data for: Hangthong_Thammawattana|Kasidej_Chutimant|Khrong_Chandawong|Kriangkrai_Srirak|Maris_Sangiampongsa|Mongkol_Surasajja|Natthaphong_Ruengpanyawut|Nukun_Prachuapmo|Padipat_Suntiphada|Pallop_Pinmanee
# Page info saved to page_info_output.json
# Fetching page info data for: Phayom_Chulanont|Pichit_Chuenban|Pita_Limjaroenrat|Rangsiman_Rome|Rukchanok_Srinork|Samak_Jalikula|Sang_Phathanothai|Sereepisuth_Temeeyaves|Singsuk_Singpai|So_Sethaputra
# Page info saved to page_info_output.json
# Fetching page info data for: Sodsai_Rungphothong|Sophon_Suphapong|Suchatvee_Suwansawat|Surangkana_Wayuparb|Suriya_Chindawongse|Sutin_Klungsang|Teerakiat_Jaroensettasin|Thamanat_Prompow|Tiang_Sirikhanth|Vichien_Khaokham
# Page info saved to page_info_output.json
# Fetching page info data for: Luang_Wichitwathakan|Yat_Hwaidi|Jacques_Amouzou|Myriam_Dossou_D%27Almeida|Issifou_Tabiou_Taffa|Kodjo_Amegnisso_Tossou|Cl%C3%A9ment_Nyaletsossi_Voule|Sani_Yaya|Solomone_Ula_Ata|Shirley_Waldemar_Baker
# Page info saved to page_info_output.json
# Fetching page info data for: Enele_Ma%CA%BBafu|Siaosi_Tuku%CA%BBaho|Semisi_Sika|Sione_Tupou_Mateialona|Siosateki_Tonga|Tevita_Tu%CA%BBivakano|Viliami_Tupoulahi_Mailefihi_Tuku%27aho|%CA%BBUluvalu|Henry_Alcazar|James_Biggart
# Page info saved to page_info_output.json
# Fetching page info data for: Cyrus_Prudhomme_David|William_Demas|Gypsy_%28calypsonian%29|Isaac_Hope|Rudranath_Indarsingh|Martin_Joseph|Kenneth_Lalla|Emmanuel_Mzumbo_Lazare|Randall_Mitchell|Arnold_Piggott
# Page info saved to page_info_output.json
# Page info saved to page_info_output.json
# Fetching page info data for: Mehmet_Fatih_Kac%C4%B1r|Mehmet_Kama%C3%A7|Haf%C4%B1z_Mehmet|Abdurrahman_Melek|Kemal_Memi%C5%9Fo%C4%9Flu|Mustafa_Arif_Deymer|Memduh_O%C4%9Fuz|Ya%C5%9Far_Okuyan|Saruhan_Olu%C3%A7|Fuat_Necati_%C3%96ncel
# Page info saved to page_info_output.json
# Fetching page info data for: Cahit_Orta%C3%A7|Osman_Nuri_%C3%96n%C3%BCg%C3%B6ren|Faik_Ali_Ozansoy|Vahdettin_%C3%96zkan|Osman_Pamuko%C4%9Flu|Musa_Piro%C4%9Flu|Re%C5%9Fit_Ronabar|Kader_Sevinc|H%C3%BCseyin_Sungur|Kemal_Tekden
# Page info saved to page_info_output.json
# Fetching page info data for: Mustafa_Timisi|Turgut_Okyay|Ziya_U%C4%9Fur|Suut_Kemal_Yetkin|Serdar_H%C3%BCseyin_Y%C4%B1ld%C4%B1r%C4%B1m|Ahmet_Reyiz_Y%C4%B1lmaz|Baha_Cemal_Za%C4%9Fra|Khalnazar_Agakhanov|Kasymguly_Baba%C3%BDew|Suhan_Baba%C3%BDew
# Page info saved to page_info_output.json
# Fetching page info data for: Saparmyrat_Batyrow|Ashyrguly_Begliyev|Annaguly_Deryayev|Mammetmyrat_Geldinyyazov|Dangatar_K%C3%B6pekow|Kurban_Permanov|Akmyrat_Rejepow|Ata_Serdarow|Nazar_So%C3%BDunow|Solofa_Uota
# Page info saved to page_info_output.json
# Fetching page info data for: Ssendi_Mosh_Afrikan|Christine_Akello|Joan_Acom_Alobo|Christine_Apolot|Kenny_Auma|Charles_Ayume|Balyeku_Moses_Grace|Christine_Bukenya_Ssendawula|Ekwau_Ibi_Florence|Karubanga_Jacob
# Page info saved to page_info_output.json
# Fetching page info data for: Jane_Awich|Jane_Kabajungu_Bainomugisha|John_Kabaireho|Joseph_Kabuleta|Apollo_Kaggwa|Michael_Kawalya_Kagwa|Robert_Mugabe_Kakyebezi|Joselyn_Kamateneti|Amos_Mubunga_Kambere|Paulo_Kavuma
# Page info saved to page_info_output.json
# Fetching page info data for: Patrick_Kayemba|Kabuye_Frank_Kibirige|Julia_Kibubura|Daniel_Kidega|Yabezi_Kiiza|Beatrice_Kiraso|Kiwanuka_Sulaiman|Ruth_Molly_Lematia|Annie_Logiel|Ajok_Lucy
# Page info saved to page_info_output.json
# Fetching page info data for: Jack_Odur_Lutanywa|James_Mamawi|Margaret_Rwebyambu|Margret_Okunga_Makoha|Jack_Maumbe_Mukhwana|Willy_Mayambala|Kibirige_Mayanja|Tamale_Mirundi|Milly_Mugeni|Isaac_Mulindwa
# Page info saved to page_info_output.json
# Fetching page info data for: Besueri_Kiwanuka_Lusse_Mulondo|Victoria_Mwaka|Fred_Mwesigye|Mary_Annet_Nakato|Faridah_Nambi|Ndyomugyenyi_Roland_Bish|Linos_Ngompek|Asinansi_Nyakato|Geoffrey_Onegi_Obel|Onegi_Obel
# Page info saved to page_info_output.json
# Fetching page info data for: James_Obita|Apollo_Ofwono|Amos_Okot|Moses_Okot_Jr|Okullo_Aabuka_Jallon_Anthony|Bosmic_Otim|Patrick_Nsamba_Oshabe|Ricky_Richard_Anywar|Flavia_Rwabuhoro_Kabahenda|Eric_Sakwa
# Page info saved to page_info_output.json
# Fetching page info data for: Sitenda_Sebalu|Mayanja_Kyompitira_Sebalu|Simeo_Muwanga_Nsubuga|Wilson_Tumwine|Sarah_Nambozo_Wekomba|Sergey_Abisov|Yakiv_Apter|Volodymyr_Artyukh|Alexander_Barybin|Olha_Bench
# Page info saved to page_info_output.json
# Fetching page info data for: Serhiy_Berezenko|Andriy_Beshta|Ivan_Bisyuk|Volodymyr_Boyko|Ihor_Dolhov|Anatoliy_Fedorchuk|Ivan_Gel|Moshe_Gutman|Olena_Halushka|Izet_Hdanov
# Page info saved to page_info_output.json
# Fetching page info data for: Artur_Herasymov|Valeriy_Holovko|Volodymyr_Hryshchenko|Stepan_Ivakhiv|Borys_Kachura|Dmytro_Kashchuk|Serhii_Khlan|Borys_Klimchuk_%28politician%29|Klitschko_brothers|Mykola_Kolisnyk
# Page info saved to page_info_output.json
# Fetching page info data for: Mykhailo_Korolenko|Ivan_Korshynskyi|Roman_Kostenko|Heorhiy_Kryuchkov|Mykola_Kulinich|Vitalii_Kurylo|Anatolii_Kutsevol|Ihor_Kyzym|Hennadiy_Lahuta|Yurii_Lavreniuk
# Page info saved to page_info_output.json
# Fetching page info data for: Andriy_Levus|Ivan_Lypa|Roman_Mashovets|Denys_Maslov|Volodymyr_Matvienko|Pavlo_Matvienko|Oleh_Meidych|Mykola_Popov|Denys_Myrgorodskyi|Sergey_Nazarov
# Page info saved to page_info_output.json
# Fetching page info data for: Andriy_Odarchenko|Hryhoriy_Omelchenko|Volodymyr_Petrov|Mykola_Petruk|Vasyl_Poraiko|Yelena_Protsenko|Mykhailo_Reznik|Oleksandr_Ryzhenkov|Petro_Gadz|Ruslan_Magomedov_%28economist%29
# Page info saved to page_info_output.json
# Fetching page info data for: Oleksandr_Ruzhytskyi|Mykola_Riabovil|Vladimir_Saldo|Olena_Semeniaka|Volodymyr_Serhiychuk|Oleh_Shamshur|Vyacheslav_Shapovalov|Serhii_Shapran|Iryna_Stavchuk|Volodymyr_Stelmakh
# Page info saved to page_info_output.json
# Fetching page info data for: Viacheslav_Suprunenko|Taras_Tarasenko|Volodymyr_Tsvil|Volodymyr_Tyahlo|Serhiy_Tymchenko|Kyrylo_Tymoshenko|Evgeniy_Udod|Dmytro_Vorona|Mykola_Yankovsky|Kostiantyn_Yastrub
# Page info saved to page_info_output.json
# Fetching page info data for: Yuriy_Vozniuk|Andriy_Yusov|Anatoliy_Zasukha|Vitaly_Zholobov|Luis_Almagro|Sebasti%C3%A1n_Bauz%C3%A1|M%C3%B3nica_Bottero|Jorge_Bruni|Guillermo_Chifflet|Laura_Cortinas
# Page info saved to page_info_output.json
# Page info saved to page_info_output.json
# Fetching page info data for: V%C3%B5_V%C4%83n_Th%C6%B0%E1%BB%9Fng|Abdullah_Noman|Hashid_Abdullah_al-Ahmar|Himyar_Abdullah_al-Ahmar|Sam_Yahya_Al-Ahmar|Ameen_Ali_al-Akimi|Talal_Aklan|Abdullatif_Al-Sayed|Muhammad_Musa_al-Amri|Mohamed_al-Atifi
# Page info saved to page_info_output.json
# Fetching page info data for: Yasser_Al-Awadi|Sagheer_Hamoud_Aziz|Sultan_al-Barakani|Faraj_Salmin_Al-Bahsani|Ali_Al_Bukhaiti|Bruce_Conde|Abdul_Wahab_Al-Dailami|Ali_Ahmad_Nasser_al-Dhahab|Badreddin_al-Houthi|Ibrahim_Bin_Ali_Al_Wazeer
# Page info saved to page_info_output.json
# Fetching page info data for: Mohammed_Lutf_al-Iryani|Abd_Al-Rahman_Ali_Al-Jifri|Hussein_Khairan|Mohammed_Ali_Al-Maqdashi|Hooria_Mashhour|Muhammad_bin_Yahya_bin_Muhammad|Abdul_Qader_Qahtan|Abdulwahab_al-Rawhani|Mohammed_al-Sabry|Yahya_Mohamed_Abdullah_Saleh
# Page info saved to page_info_output.json
# Fetching page info data for: Ali_Taysir|Yahya_Muhammad_Hamid_ed-Din|Aidarus_al-Zoubaidi|Francis_Kapyanga|Lily_Monze|Olipa_Phiri|Gift_Banda|Flora_Buka|Bulelani_Lobengula|Joseph_Makamba_Busha
# Page info saved to page_info_output.json
# Fetching page info data for: Darlington_Dzikamai_Chigumbu|James_Chikerema|Paul_Chimedza|Chenhamo_Chimutengwende|Ruth_Chinamano|George_Chiweshe|Phillip_Chiyangwa|Guy_Clutton-Brock|Margaret_Dongo|Jabulani_Dube
# Page info saved to page_info_output.json
# Fetching page info data for: Fletcher_Dulini_Ncube|Ken_Flower|Aguy_Georgias|Sithembile_Gumbo|Josiah_Zion_Gumede|Ellen_Gwaradzimba|Andre_Sothern_Holland|Byron_Hove|Tonderai_Kasu|Wilson_Khumbula
# Page info saved to page_info_output.json
# Fetching page info data for: Lovemore_Madhuku|Sarah_Mahoka|Alfred_Makwarimba|Washington_Malianga|Elliot_Manyika|Linda_Masarira|Jevan_Maseko|Anxious_Masuka|Lovemore_Matombo|Bright_Matonga
# Page info saved to page_info_output.json
# Fetching page info data for: Isaac_Matongo|Obedingwa_Mguni|Promise_Mkwananzi|Max_Mnkandla|Bekithemba_Mpofu|Earnest_Mudzengi|Mugabe_family|Kisinoti_Mukwazhe|Edwin_Mushoriwa|Munacho_Mutezo
# Page info saved to page_info_output.json
# Fetching page info data for: Abel_Muzorewa|Prag_Lalloo_Naran|Owen_Ncube|Nhlanhlayamangwe_Felix_Ndiweni|Gundwane_Ndiweni|Khayisa_Ndiweni|Jane_Ngwenya|Maurice_Nyagumbo|George_Nyandoro|Sekai_Nzenza
# Page info saved to page_info_output.json
# Fetching page info data for: Engelbert_Rugeje|Tinos_Rusere|Scot_Sakupwanya|Daniel_Shumba|Maxwell_Zeb_Shumba|Nkululeko_Mkastos_Sibanda|Leopold_Takawira|Gift_Tandare|Rekayi_Tangwena|Temba_Mliswa
# Page info saved to page_info_output.json
# Fetching page info data for: Josiah_Tongogara|Langton_Towungana|Sengezo_Tshabangu|Herbert_Ushewokunze|Denis_Walker
# Page info saved to page_info_output.json

# %%
## Lets take a look at the output!
all_pages_info
# Out:
# {'44482763': {'pageid': 44482763,
#   'ns': 0,
#   'title': 'Abdul Rahim Ayoubi',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T14:00:56Z',
#   'lastrevid': 1226326055,
#   'length': 7313,
#   'talkid': 44489967,
#   'fullurl': 'https://en.wikipedia.org/wiki/Abdul_Rahim_Ayoubi',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Abdul_Rahim_Ayoubi&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Abdul_Rahim_Ayoubi'},
#  '12084570': {'pageid': 12084570,
#   'ns': 0,
#   'title': 'Amir Muhammad Akhundzada',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-05T14:27:31Z',
#   'lastrevid': 1247931713,
#   'length': 8865,
#   'talkid': 23510494,
#   'fullurl': 'https://en.wikipedia.org/wiki/Amir_Muhammad_Akhundzada',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Amir_Muhammad_Akhundzada&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Amir_Muhammad_Akhundzada'},
#  '47805901': {'pageid': 47805901,
#   'ns': 0,
#   'title': 'Aziza Ahmadyar',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-13T14:46:20Z',
#   'lastrevid': 1195651393,
#   'length': 3790,
#   'talkid': 47806200,
#   'fullurl': 'https://en.wikipedia.org/wiki/Aziza_Ahmadyar',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Aziza_Ahmadyar&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Aziza_Ahmadyar'},
#  '11966231': {'pageid': 11966231,
#   'ns': 0,
#   'title': 'Haroon al-Afghani',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-05T14:27:29Z',
#   'lastrevid': 1230459615,
#   'length': 17027,
#   'talkid': 15250816,
#   'fullurl': 'https://en.wikipedia.org/wiki/Haroon_al-Afghani',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Haroon_al-Afghani&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Haroon_al-Afghani'},
#  '71600382': {'pageid': 71600382,
#   'ns': 0,
#   'title': 'Khadija Zahra Ahmadi',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T14:05:22Z',
#   'lastrevid': 1234741562,
#   'length': 2569,
#   'talkid': 71610138,
#   'fullurl': 'https://en.wikipedia.org/wiki/Khadija_Zahra_Ahmadi',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Khadija_Zahra_Ahmadi&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Khadija_Zahra_Ahmadi'},
#  '10483286': {'pageid': 10483286,
#   'ns': 0,
#   'title': 'Majah Ha Adrif',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-09-30T14:32:18Z',
#   'lastrevid': 1233202991,
#   'length': 3188,
#   'talkid': 13330265,
#   'fullurl': 'https://en.wikipedia.org/wiki/Majah_Ha_Adrif',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Majah_Ha_Adrif&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Majah_Ha_Adrif'},
#  '27664854': {'pageid': 27664854,
#   'ns': 0,
#   'title': 'Mohammad Sarwar Ahmedzai',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-13T20:04:55Z',
#   'lastrevid': 1176429234,
#   'length': 4420,
#   'talkid': 60642795,
#   'fullurl': 'https://en.wikipedia.org/wiki/Mohammad_Sarwar_Ahmedzai',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Mohammad_Sarwar_Ahmedzai&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Mohammad_Sarwar_Ahmedzai'},
#  '70019038': {'pageid': 70019038,
#   'ns': 0,
#   'title': 'Muqadasa Ahmadzai',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-12T10:32:44Z',
#   'lastrevid': 1235521766,
#   'length': 3796,
#   'talkid': 70021080,
#   'fullurl': 'https://en.wikipedia.org/wiki/Muqadasa_Ahmadzai',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Muqadasa_Ahmadzai&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Muqadasa_Ahmadzai'},
#  '22588409': {'pageid': 22588409,
#   'ns': 0,
#   'title': 'Nasrullah Baryalai Arsalai',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-13T20:04:32Z',
#   'lastrevid': 1225385278,
#   'length': 7127,
#   'talkid': 22639116,
#   'fullurl': 'https://en.wikipedia.org/wiki/Nasrullah_Baryalai_Arsalai',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Nasrullah_Baryalai_Arsalai&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Nasrullah_Baryalai_Arsalai'},
#  '46841383': {'pageid': 46841383,
#   'ns': 0,
#   'title': 'Tayyab Agha',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T14:01:14Z',
#   'lastrevid': 1225661708,
#   'length': 6346,
#   'talkid': 46843786,
#   'fullurl': 'https://en.wikipedia.org/wiki/Tayyab_Agha',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Tayyab_Agha&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Tayyab_Agha'},
#  '27428272': {'pageid': 27428272,
#   'ns': 0,
#   'title': 'Abdul Baqi Turkistani',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-13T20:04:54Z',
#   'lastrevid': 1231655023,
#   'length': 1357,
#   'talkid': 27595416,
#   'fullurl': 'https://en.wikipedia.org/wiki/Abdul_Baqi_Turkistani',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Abdul_Baqi_Turkistani&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Abdul_Baqi_Turkistani'},
#  '27663861': {'pageid': 27663861,
#   'ns': 0,
#   'title': 'Bashir Ahmad Bezan',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-13T20:04:55Z',
#   'lastrevid': 1248505877,
#   'length': 2298,
#   'talkid': 28093401,
#   'fullurl': 'https://en.wikipedia.org/wiki/Bashir_Ahmad_Bezan',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Bashir_Ahmad_Bezan&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Bashir_Ahmad_Bezan'},
#  '24963809': {'pageid': 24963809,
#   'ns': 0,
#   'title': 'Cheragh Ali Cheragh',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-08-17T23:53:15Z',
#   'lastrevid': 1193992206,
#   'length': 5351,
#   'talkid': 25410745,
#   'fullurl': 'https://en.wikipedia.org/wiki/Cheragh_Ali_Cheragh',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Cheragh_Ali_Cheragh&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Cheragh_Ali_Cheragh'},
#  '25153929': {'pageid': 25153929,
#   'ns': 0,
#   'title': 'Ismael Balkhi',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T13:56:55Z',
#   'lastrevid': 1244521219,
#   'length': 6810,
#   'talkid': 28093455,
#   'fullurl': 'https://en.wikipedia.org/wiki/Ismael_Balkhi',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Ismael_Balkhi&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Ismael_Balkhi'},
#  '10305348': {'pageid': 10305348,
#   'ns': 0,
#   'title': 'Jan Baz',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-09-27T00:09:10Z',
#   'lastrevid': 1227635806,
#   'length': 1776,
#   'talkid': 15014548,
#   'fullurl': 'https://en.wikipedia.org/wiki/Jan_Baz',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Jan_Baz&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Jan_Baz'},
#  '40960242': {'pageid': 40960242,
#   'ns': 0,
#   'title': 'Mohammad Ghous Bashiri',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-13T20:06:09Z',
#   'lastrevid': 1237694188,
#   'length': 2720,
#   'talkid': 40960350,
#   'fullurl': 'https://en.wikipedia.org/wiki/Mohammad_Ghous_Bashiri',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Mohammad_Ghous_Bashiri&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Mohammad_Ghous_Bashiri'},
#  '14454477': {'pageid': 14454477,
#   'ns': 0,
#   'title': 'Mohammad Siddiq Chakari',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-09-27T00:25:02Z',
#   'lastrevid': 1134129082,
#   'length': 1808,
#   'talkid': 14454495,
#   'fullurl': 'https://en.wikipedia.org/wiki/Mohammad_Siddiq_Chakari',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Mohammad_Siddiq_Chakari&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Mohammad_Siddiq_Chakari'},
#  '26835722': {'pageid': 26835722,
#   'ns': 0,
#   'title': 'Muhammad Hashim Esmatullahi',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-08T01:15:48Z',
#   'lastrevid': 949986748,
#   'length': 2254,
#   'talkid': 26840249,
#   'fullurl': 'https://en.wikipedia.org/wiki/Muhammad_Hashim_Esmatullahi',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Muhammad_Hashim_Esmatullahi&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Muhammad_Hashim_Esmatullahi'},
#  '59378987': {'pageid': 59378987,
#   'ns': 0,
#   'title': 'Nasir Ahmad Durrani',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-09-27T02:16:56Z',
#   'lastrevid': 988838315,
#   'length': 2435,
#   'talkid': 59397424,
#   'fullurl': 'https://en.wikipedia.org/wiki/Nasir_Ahmad_Durrani',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Nasir_Ahmad_Durrani&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Nasir_Ahmad_Durrani'},
#  '16351100': {'pageid': 16351100,
#   'ns': 0,
#   'title': 'Rafiullah Bidar',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-09-27T00:31:39Z',
#   'lastrevid': 1197443408,
#   'length': 3439,
#   'talkid': 28093476,
#   'fullurl': 'https://en.wikipedia.org/wiki/Rafiullah_Bidar',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Rafiullah_Bidar&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Rafiullah_Bidar'},
#  '-1': {'title': 'V%C3%B5_V%C4%83n_Th%C6%B0%E1%BB%9Fng',
#   'invalidreason': 'The requested page title contains invalid characters: "%C3".',
#   'invalid': ''},
#  '-2': {'title': 'Nguy%E1%BB%85n_V%C4%83n_L%E1%BB%B1c',
#   'invalidreason': 'The requested page title contains invalid characters: "%E1".',
#   'invalid': ''},
#  '29443640': {'pageid': 29443640,
#   'ns': 0,
#   'title': 'Abdul Ghani Ghani',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T13:57:42Z',
#   'lastrevid': 1227026187,
#   'length': 1292,
#   'talkid': 29453228,
#   'fullurl': 'https://en.wikipedia.org/wiki/Abdul_Ghani_Ghani',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Abdul_Ghani_Ghani&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Abdul_Ghani_Ghani'},
#  '52438668': {'pageid': 52438668,
#   'ns': 0,
#   'title': 'Aimal Faizi',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T14:02:04Z',
#   'lastrevid': 1185105938,
#   'length': 2791,
#   'talkid': 52491442,
#   'fullurl': 'https://en.wikipedia.org/wiki/Aimal_Faizi',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Aimal_Faizi&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Aimal_Faizi'},
#  '72903967': {'pageid': 72903967,
#   'ns': 0,
#   'title': 'Gajinder Singh Safri',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-09-27T02:38:35Z',
#   'lastrevid': 1212323536,
#   'length': 1901,
#   'talkid': 73162614,
#   'fullurl': 'https://en.wikipedia.org/wiki/Gajinder_Singh_Safri',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Gajinder_Singh_Safri&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Gajinder_Singh_Safri'},
#  '68918472': {'pageid': 68918472,
#   'ns': 0,
#   'title': 'Ghulam Ghaus',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-12T10:32:36Z',
#   'lastrevid': 1158659195,
#   'length': 1450,
#   'talkid': 69064071,
#   'fullurl': 'https://en.wikipedia.org/wiki/Ghulam_Ghaus',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Ghulam_Ghaus&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Ghulam_Ghaus'},
#  '25630787': {'pageid': 25630787,
#   'ns': 0,
#   'title': 'Ghulam Muhammad Ghobar',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T13:57:00Z',
#   'lastrevid': 1240993642,
#   'length': 3731,
#   'talkid': 27237347,
#   'fullurl': 'https://en.wikipedia.org/wiki/Ghulam_Muhammad_Ghobar',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Ghulam_Muhammad_Ghobar&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Ghulam_Muhammad_Ghobar'},
#  '13368923': {'pageid': 13368923,
#   'ns': 0,
#   'title': 'Hashmat Ghani Ahmadzai',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T13:54:08Z',
#   'lastrevid': 1207743719,
#   'length': 8585,
#   'watchers': 108,
#   'talkid': 28093454,
#   'fullurl': 'https://en.wikipedia.org/wiki/Hashmat_Ghani_Ahmadzai',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Hashmat_Ghani_Ahmadzai&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Hashmat_Ghani_Ahmadzai'},
#  '72051141': {'pageid': 72051141,
#   'ns': 0,
#   'title': 'Sayed Yousuf Halim',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-12T10:32:58Z',
#   'lastrevid': 1234514565,
#   'length': 4686,
#   'talkid': 72051146,
#   'fullurl': 'https://en.wikipedia.org/wiki/Sayed_Yousuf_Halim',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Sayed_Yousuf_Halim&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Sayed_Yousuf_Halim'},
#  '8054084': {'pageid': 8054084,
#   'ns': 0,
#   'title': 'Sharif Ghalib',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-09-28T23:10:01Z',
#   'lastrevid': 1245967190,
#   'length': 10292,
#   'watchers': 100,
#   'talkid': 8284074,
#   'fullurl': 'https://en.wikipedia.org/wiki/Sharif_Ghalib',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Sharif_Ghalib&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Sharif_Ghalib'},
#  '5294659': {'pageid': 5294659,
#   'ns': 0,
#   'title': 'Hafizullah Shabaz Khail',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-08T00:32:46Z',
#   'lastrevid': 1238402857,
#   'length': 7544,
#   'talkid': 6598565,
#   'fullurl': 'https://en.wikipedia.org/wiki/Hafizullah_Shabaz_Khail',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Hafizullah_Shabaz_Khail&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Hafizullah_Shabaz_Khail'},
#  '35512380': {'pageid': 35512380,
#   'ns': 0,
#   'title': 'Mahboba Hoqomal',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-13T20:05:38Z',
#   'lastrevid': 1243745950,
#   'length': 3137,
#   'talkid': 37057619,
#   'fullurl': 'https://en.wikipedia.org/wiki/Mahboba_Hoqomal',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Mahboba_Hoqomal&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Mahboba_Hoqomal'},
#  '39258771': {'pageid': 39258771,
#   'ns': 0,
#   'title': 'Mirza Muhammad Ismail',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-12T10:26:35Z',
#   'lastrevid': 1235165845,
#   'length': 10878,
#   'talkid': 39258729,
#   'fullurl': 'https://en.wikipedia.org/wiki/Mirza_Muhammad_Ismail',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Mirza_Muhammad_Ismail&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Mirza_Muhammad_Ismail'},
#  '8575012': {'pageid': 8575012,
#   'ns': 0,
#   'title': 'Musa Hotak',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-09-27T00:01:49Z',
#   'lastrevid': 1246566804,
#   'length': 3007,
#   'talkid': 9295688,
#   'fullurl': 'https://en.wikipedia.org/wiki/Musa_Hotak',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Musa_Hotak&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Musa_Hotak'},
#  '41835910': {'pageid': 41835910,
#   'ns': 0,
#   'title': 'Qutbuddin Hilal',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-11T16:51:31Z',
#   'lastrevid': 1246566795,
#   'length': 3403,
#   'talkid': 41837941,
#   'fullurl': 'https://en.wikipedia.org/wiki/Qutbuddin_Hilal',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Qutbuddin_Hilal&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Qutbuddin_Hilal'},
#  '68487239': {'pageid': 68487239,
#   'ns': 0,
#   'title': 'Rangina Hamidi',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-12T10:32:32Z',
#   'lastrevid': 1234743111,
#   'length': 12718,
#   'talkid': 68503822,
#   'fullurl': 'https://en.wikipedia.org/wiki/Rangina_Hamidi',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Rangina_Hamidi&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Rangina_Hamidi'},
#  '6392185': {'pageid': 6392185,
#   'ns': 0,
#   'title': 'Said Tayeb Jawad',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T13:52:29Z',
#   'lastrevid': 1248976824,
#   'length': 29048,
#   'watchers': 68,
#   'talkid': 7156482,
#   'fullurl': 'https://en.wikipedia.org/wiki/Said_Tayeb_Jawad',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Said_Tayeb_Jawad&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Said_Tayeb_Jawad'},
#  '21500352': {'pageid': 21500352,
#   'ns': 0,
#   'title': 'Sayed Jalal',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-09-30T20:32:04Z',
#   'lastrevid': 1137130537,
#   'length': 2913,
#   'talkid': 21502485,
#   'fullurl': 'https://en.wikipedia.org/wiki/Sayed_Jalal',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Sayed_Jalal&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Sayed_Jalal'},
#  '27668571': {'pageid': 27668571,
#   'ns': 0,
#   'title': 'Sayed Jalal Karim',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-13T20:04:55Z',
#   'lastrevid': 1136614743,
#   'length': 4009,
#   'talkid': 28093484,
#   'fullurl': 'https://en.wikipedia.org/wiki/Sayed_Jalal_Karim',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Sayed_Jalal_Karim&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Sayed_Jalal_Karim'},
#  '52438868': {'pageid': 52438868,
#   'ns': 0,
#   'title': 'Sayed Zafar Hashemi',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T14:02:04Z',
#   'lastrevid': 1179137138,
#   'length': 3053,
#   'talkid': 52492081,
#   'fullurl': 'https://en.wikipedia.org/wiki/Sayed_Zafar_Hashemi',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Sayed_Zafar_Hashemi&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Sayed_Zafar_Hashemi'},
#  '34682634': {'pageid': 34682634,
#   'ns': 0,
#   'title': 'Ahmad Wali Massoud',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T13:58:43Z',
#   'lastrevid': 1221720658,
#   'length': 3529,
#   'talkid': 34682647,
#   'fullurl': 'https://en.wikipedia.org/wiki/Ahmad_Wali_Massoud',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Ahmad_Wali_Massoud&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Ahmad_Wali_Massoud'},
#  '24850187': {'pageid': 24850187,
#   'ns': 0,
#   'title': 'Azizullah Lodin',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-13T20:04:43Z',
#   'lastrevid': 1247762293,
#   'length': 3067,
#   'talkid': 24850621,
#   'fullurl': 'https://en.wikipedia.org/wiki/Azizullah_Lodin',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Azizullah_Lodin&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Azizullah_Lodin'},
#  '23672202': {'pageid': 23672202,
#   'ns': 0,
#   'title': 'Baran Khan Kudezai',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-13T20:04:38Z',
#   'lastrevid': 1176481824,
#   'length': 3759,
#   'talkid': 23992347,
#   'fullurl': 'https://en.wikipedia.org/wiki/Baran_Khan_Kudezai',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Baran_Khan_Kudezai&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Baran_Khan_Kudezai'},
#  '273143': {'pageid': 273143,
#   'ns': 0,
#   'title': 'Fazel Ahmed Manawi',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-12T10:12:23Z',
#   'lastrevid': 1234514379,
#   'length': 2608,
#   'talkid': 9295258,
#   'fullurl': 'https://en.wikipedia.org/wiki/Fazel_Ahmed_Manawi',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Fazel_Ahmed_Manawi&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Fazel_Ahmed_Manawi'},
#  '3056711': {'pageid': 3056711,
#   'ns': 0,
#   'title': 'Masoud Khalili',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T13:51:12Z',
#   'lastrevid': 1246566971,
#   'length': 23129,
#   'watchers': 94,
#   'talkid': 7104082,
#   'fullurl': 'https://en.wikipedia.org/wiki/Masoud_Khalili',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Masoud_Khalili&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Masoud_Khalili'},
#  '64024293': {'pageid': 64024293,
#   'ns': 0,
#   'title': 'Moeen Marastial',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-09-27T02:24:23Z',
#   'lastrevid': 1246567093,
#   'length': 7932,
#   'talkid': 64026333,
#   'fullurl': 'https://en.wikipedia.org/wiki/Moeen_Marastial',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Moeen_Marastial&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Moeen_Marastial'},
#  '24781312': {'pageid': 24781312,
#   'ns': 0,
#   'title': 'Mohammad Daud Miraki',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T13:56:51Z',
#   'lastrevid': 1227103354,
#   'length': 6691,
#   'talkid': 24793110,
#   'fullurl': 'https://en.wikipedia.org/wiki/Mohammad_Daud_Miraki',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Mohammad_Daud_Miraki&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Mohammad_Daud_Miraki'},
#  '17013397': {'pageid': 17013397,
#   'ns': 0,
#   'title': 'Razaq Mamoon',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T13:55:07Z',
#   'lastrevid': 1227180106,
#   'length': 4078,
#   'watchers': 43,
#   'talkid': 28093653,
#   'fullurl': 'https://en.wikipedia.org/wiki/Razaq_Mamoon',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Razaq_Mamoon&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Razaq_Mamoon'},
#  '7493859': {'pageid': 7493859,
#   'ns': 0,
#   'title': 'Samoud Khan',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-09-29T00:40:43Z',
#   'lastrevid': 1195409073,
#   'length': 4068,
#   'talkid': 9287527,
#   'fullurl': 'https://en.wikipedia.org/wiki/Samoud_Khan',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Samoud_Khan&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Samoud_Khan'},
#  '69128654': {'pageid': 69128654,
#   'ns': 0,
#   'title': 'Abdul Karim Misaq',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T14:04:53Z',
#   'lastrevid': 1235405154,
#   'length': 2938,
#   'talkid': 69128772,
#   'fullurl': 'https://en.wikipedia.org/wiki/Abdul_Karim_Misaq',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Abdul_Karim_Misaq&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Abdul_Karim_Misaq'},
#  '68481190': {'pageid': 68481190,
#   'ns': 0,
#   'title': 'Abdul Sattar Mirzakwal',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-09-27T02:32:19Z',
#   'lastrevid': 1145249317,
#   'length': 2014,
#   'talkid': 68481193,
#   'fullurl': 'https://en.wikipedia.org/wiki/Abdul_Sattar_Mirzakwal',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Abdul_Sattar_Mirzakwal&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Abdul_Sattar_Mirzakwal'},
#  '66087536': {'pageid': 66087536,
#   'ns': 0,
#   'title': 'Daoud Naji',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T14:04:21Z',
#   'lastrevid': 1247131367,
#   'length': 5429,
#   'talkid': 66111399,
#   'fullurl': 'https://en.wikipedia.org/wiki/Daoud_Naji',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Daoud_Naji&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Daoud_Naji'},
#  '41428570': {'pageid': 41428570,
#   'ns': 0,
#   'title': 'Davood Moradian',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-09-28T23:11:36Z',
#   'lastrevid': 1239319380,
#   'length': 2260,
#   'talkid': 41631237,
#   'fullurl': 'https://en.wikipedia.org/wiki/Davood_Moradian',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Davood_Moradian&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Davood_Moradian'},
#  '2333651': {'pageid': 2333651,
#   'ns': 0,
#   'title': 'Gholam Rabani Nasher',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-13T20:02:57Z',
#   'lastrevid': 1136534788,
#   'length': 2427,
#   'talkid': 7102786,
#   'fullurl': 'https://en.wikipedia.org/wiki/Gholam_Rabani_Nasher',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Gholam_Rabani_Nasher&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Gholam_Rabani_Nasher'},
#  '27669652': {'pageid': 27669652,
#   'ns': 0,
#   'title': 'Ghulam Faroq Nijrabi',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-13T20:04:55Z',
#   'lastrevid': 1136614778,
#   'length': 1741,
#   'talkid': 28093423,
#   'fullurl': 'https://en.wikipedia.org/wiki/Ghulam_Faroq_Nijrabi',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Ghulam_Faroq_Nijrabi&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Ghulam_Faroq_Nijrabi'},
#  '35507800': {'pageid': 35507800,
#   'ns': 0,
#   'title': 'Nasruddin Mohseni',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-13T20:05:38Z',
#   'lastrevid': 1136630129,
#   'length': 3654,
#   'talkid': 35512128,
#   'fullurl': 'https://en.wikipedia.org/wiki/Nasruddin_Mohseni',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Nasruddin_Mohseni&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Nasruddin_Mohseni'},
#  '41840150': {'pageid': 41840150,
#   'ns': 0,
#   'title': 'Sardar Mohammad Nadir Naeem',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-05T14:35:13Z',
#   'lastrevid': 1204109653,
#   'length': 2068,
#   'talkid': 41872390,
#   'fullurl': 'https://en.wikipedia.org/wiki/Sardar_Mohammad_Nadir_Naeem',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Sardar_Mohammad_Nadir_Naeem&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Sardar_Mohammad_Nadir_Naeem'},
#  '34497282': {'pageid': 34497282,
#   'ns': 0,
#   'title': 'Zalmai Mujadidi',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T13:58:41Z',
#   'lastrevid': 1223903677,
#   'length': 5257,
#   'talkid': 34498009,
#   'fullurl': 'https://en.wikipedia.org/wiki/Zalmai_Mujadidi',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Zalmai_Mujadidi&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Zalmai_Mujadidi'},
#  '27678731': {'pageid': 27678731,
#   'ns': 0,
#   'title': 'Abdul Majid Samim',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-13T20:04:55Z',
#   'lastrevid': 1225425205,
#   'length': 3823,
#   'talkid': 28093433,
#   'fullurl': 'https://en.wikipedia.org/wiki/Abdul_Majid_Samim',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Abdul_Majid_Samim&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Abdul_Majid_Samim'},
#  '25634863': {'pageid': 25634863,
#   'ns': 0,
#   'title': 'Ghulam Hassan Safi',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-09-28T23:10:53Z',
#   'lastrevid': 1176507815,
#   'length': 1688,
#   'talkid': 27237342,
#   'fullurl': 'https://en.wikipedia.org/wiki/Ghulam_Hassan_Safi',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Ghulam_Hassan_Safi&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Ghulam_Hassan_Safi'},
#  '27657851': {'pageid': 27657851,
#   'ns': 0,
#   'title': 'Ghulam Mohammad Rigi',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-13T20:04:55Z',
#   'lastrevid': 1129192917,
#   'length': 1535,
#   'talkid': 28093449,
#   'fullurl': 'https://en.wikipedia.org/wiki/Ghulam_Mohammad_Rigi',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Ghulam_Mohammad_Rigi&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Ghulam_Mohammad_Rigi'},
#  '36473152': {'pageid': 36473152,
#   'ns': 0,
#   'title': 'Hanifa Safi',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-09-27T01:31:13Z',
#   'lastrevid': 1123824802,
#   'length': 1885,
#   'talkid': 37045459,
#   'fullurl': 'https://en.wikipedia.org/wiki/Hanifa_Safi',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Hanifa_Safi&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Hanifa_Safi'},
#  '212331': {'pageid': 212331,
#   'ns': 0,
#   'title': 'Mohammed Qalamuddin',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T13:48:59Z',
#   'lastrevid': 1178097642,
#   'length': 968,
#   'talkid': 745078,
#   'fullurl': 'https://en.wikipedia.org/wiki/Mohammed_Qalamuddin',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Mohammed_Qalamuddin&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Mohammed_Qalamuddin'},
#  '29170618': {'pageid': 29170618,
#   'ns': 0,
#   'title': 'Mohammed Tahir Omar',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-13T20:05:02Z',
#   'lastrevid': 1185088733,
#   'length': 2574,
#   'talkid': 34963842,
#   'fullurl': 'https://en.wikipedia.org/wiki/Mohammed_Tahir_Omar',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Mohammed_Tahir_Omar&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Mohammed_Tahir_Omar'},
#  '28566318': {'pageid': 28566318,
#   'ns': 0,
#   'title': 'Mohammed Zia Salehi',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-11T14:11:33Z',
#   'lastrevid': 1225457074,
#   'length': 1962,
#   'talkid': 36784816,
#   'fullurl': 'https://en.wikipedia.org/wiki/Mohammed_Zia_Salehi',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Mohammed_Zia_Salehi&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Mohammed_Zia_Salehi'},
#  '51559994': {'pageid': 51559994,
#   'ns': 0,
#   'title': 'Saber Sangar',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-13T20:07:13Z',
#   'lastrevid': 1227951669,
#   'length': 1676,
#   'talkid': 51595428,
#   'fullurl': 'https://en.wikipedia.org/wiki/Saber_Sangar',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Saber_Sangar&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Saber_Sangar'},
#  '34845573': {'pageid': 34845573,
#   'ns': 0,
#   'title': 'Sayed Nasim Mihanparast',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T13:58:45Z',
#   'lastrevid': 1172646418,
#   'length': 1711,
#   'talkid': 34845583,
#   'fullurl': 'https://en.wikipedia.org/wiki/Sayed_Nasim_Mihanparast',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Sayed_Nasim_Mihanparast&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Sayed_Nasim_Mihanparast'},
#  '27664625': {'pageid': 27664625,
#   'ns': 0,
#   'title': 'Zabih-U-llah Ghazi Noristani',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-13T20:04:55Z',
#   'lastrevid': 1136614682,
#   'length': 2975,
#   'talkid': 28093494,
#   'fullurl': 'https://en.wikipedia.org/wiki/Zabih-U-llah_Ghazi_Noristani',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Zabih-U-llah_Ghazi_Noristani&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Zabih-U-llah_Ghazi_Noristani'},
#  '627316': {'pageid': 627316,
#   'ns': 0,
#   'title': 'Abdul Salam Zaeef',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-12T10:13:06Z',
#   'lastrevid': 1243758857,
#   'length': 25071,
#   'watchers': 32,
#   'talkid': 6597825,
#   'fullurl': 'https://en.wikipedia.org/wiki/Abdul_Salam_Zaeef',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Abdul_Salam_Zaeef&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Abdul_Salam_Zaeef'},
#  '68624823': {'pageid': 68624823,
#   'ns': 0,
#   'title': 'Ahmadullah Wasiq',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T14:04:48Z',
#   'lastrevid': 1171042170,
#   'length': 5247,
#   'talkid': 68639469,
#   'fullurl': 'https://en.wikipedia.org/wiki/Ahmadullah_Wasiq',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Ahmadullah_Wasiq&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Ahmadullah_Wasiq'},
#  '38515087': {'pageid': 38515087,
#   'ns': 0,
#   'title': 'Baktash Siawash',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-13T17:03:07Z',
#   'lastrevid': 1250972393,
#   'length': 1302,
#   'talkid': 38515146,
#   'fullurl': 'https://en.wikipedia.org/wiki/Baktash_Siawash',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Baktash_Siawash&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Baktash_Siawash'},
#  '2202177': {'pageid': 2202177,
#   'ns': 0,
#   'title': 'Fazal Hadi Shinwari',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-12T10:14:56Z',
#   'lastrevid': 1242412237,
#   'length': 15076,
#   'talkid': 8160597,
#   'fullurl': 'https://en.wikipedia.org/wiki/Fazal_Hadi_Shinwari',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Fazal_Hadi_Shinwari&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Fazal_Hadi_Shinwari'},
#  '27656776': {'pageid': 27656776,
#   'ns': 0,
#   'title': 'Gul Ahmmad Yama',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-13T20:04:55Z',
#   'lastrevid': 1136614561,
#   'length': 3324,
#   'talkid': 28093452,
#   'fullurl': 'https://en.wikipedia.org/wiki/Gul_Ahmmad_Yama',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Gul_Ahmmad_Yama&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Gul_Ahmmad_Yama'},
#  '27666240': {'pageid': 27666240,
#   'ns': 0,
#   'title': 'Hasan Ali Sultani',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-13T20:04:55Z',
#   'lastrevid': 1136614726,
#   'length': 1975,
#   'talkid': 28093453,
#   'fullurl': 'https://en.wikipedia.org/wiki/Hasan_Ali_Sultani',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Hasan_Ali_Sultani&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Hasan_Ali_Sultani'},
#  '23564221': {'pageid': 23564221,
#   'ns': 0,
#   'title': 'Mohammad Hashem Taufiqui',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-13T20:04:37Z',
#   'lastrevid': 1233490009,
#   'length': 3605,
#   'talkid': 28093461,
#   'fullurl': 'https://en.wikipedia.org/wiki/Mohammad_Hashem_Taufiqui',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Mohammad_Hashem_Taufiqui&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Mohammad_Hashem_Taufiqui'},
#  '47145503': {'pageid': 47145503,
#   'ns': 0,
#   'title': 'Pacha Gul Wafadar',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T14:01:17Z',
#   'lastrevid': 1227179979,
#   'length': 2985,
#   'talkid': 47467474,
#   'fullurl': 'https://en.wikipedia.org/wiki/Pacha_Gul_Wafadar',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Pacha_Gul_Wafadar&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Pacha_Gul_Wafadar'},
#  '68232272': {'pageid': 68232272,
#   'ns': 0,
#   'title': 'Suhail Shaheen',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T14:04:43Z',
#   'lastrevid': 1198363158,
#   'length': 6532,
#   'talkid': 68279751,
#   'fullurl': 'https://en.wikipedia.org/wiki/Suhail_Shaheen',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Suhail_Shaheen&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Suhail_Shaheen'},
#  '52202939': {'pageid': 52202939,
#   'ns': 0,
#   'title': 'Wahidullah Waissi',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T14:02:03Z',
#   'lastrevid': 1232389768,
#   'length': 33842,
#   'talkid': 52225983,
#   'fullurl': 'https://en.wikipedia.org/wiki/Wahidullah_Waissi',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Wahidullah_Waissi&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Wahidullah_Waissi'},
#  '27656055': {'pageid': 27656055,
#   'ns': 0,
#   'title': 'Abdul Ghafor Zori',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-13T20:04:55Z',
#   'lastrevid': 1136614520,
#   'length': 2711,
#   'talkid': 28093426,
#   'fullurl': 'https://en.wikipedia.org/wiki/Abdul_Ghafor_Zori',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Abdul_Ghafor_Zori&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Abdul_Ghafor_Zori'},
#  '7249978': {'pageid': 7249978,
#   'ns': 0,
#   'title': 'Ali Pasha of Gusinje',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T13:52:46Z',
#   'lastrevid': 1244421894,
#   'length': 11196,
#   'watchers': 32,
#   'talkid': 10482642,
#   'fullurl': 'https://en.wikipedia.org/wiki/Ali_Pasha_of_Gusinje',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Ali_Pasha_of_Gusinje&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Ali_Pasha_of_Gusinje'},
#  '19887970': {'pageid': 19887970,
#   'ns': 0,
#   'title': 'Azis Tahir Ajdonati',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T13:55:45Z',
#   'lastrevid': 1192928746,
#   'length': 1864,
#   'talkid': 25727972,
#   'fullurl': 'https://en.wikipedia.org/wiki/Azis_Tahir_Ajdonati',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Azis_Tahir_Ajdonati&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Azis_Tahir_Ajdonati'},
#  '49011996': {'pageid': 49011996,
#   'ns': 0,
#   'title': 'Bislim Bajgora',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-13T20:07:00Z',
#   'lastrevid': 1217284690,
#   'length': 7992,
#   'talkid': 49015444,
#   'fullurl': 'https://en.wikipedia.org/wiki/Bislim_Bajgora',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Bislim_Bajgora&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Bislim_Bajgora'},
#  '52237560': {'pageid': 52237560,
#   'ns': 0,
#   'title': 'Kastriot Berissa',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T14:02:03Z',
#   'lastrevid': 1244463139,
#   'length': 7665,
#   'talkid': 52283699,
#   'fullurl': 'https://en.wikipedia.org/wiki/Kastriot_Berissa',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Kastriot_Berissa&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Kastriot_Berissa'},
#  '4928280': {'pageid': 4928280,
#   'ns': 0,
#   'title': 'Mohammed Zaman',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T15:01:23Z',
#   'lastrevid': 1229734414,
#   'length': 5722,
#   'talkid': 7492387,
#   'fullurl': 'https://en.wikipedia.org/wiki/Mohammed_Zaman',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Mohammed_Zaman&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Mohammed_Zaman'},
#  '13849010': {'pageid': 13849010,
#   'ns': 0,
#   'title': 'Qari Ziauddin',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-09-11T18:16:06Z',
#   'lastrevid': 1245217124,
#   'length': 3975,
#   'talkid': 15015662,
#   'fullurl': 'https://en.wikipedia.org/wiki/Qari_Ziauddin',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Qari_Ziauddin&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Qari_Ziauddin'},
#  '43393251': {'pageid': 43393251,
#   'ns': 0,
#   'title': 'Ylli Asllani',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-12T10:27:32Z',
#   'lastrevid': 1221605713,
#   'length': 2900,
#   'talkid': 43422107,
#   'fullurl': 'https://en.wikipedia.org/wiki/Ylli_Asllani',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Ylli_Asllani&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Ylli_Asllani'},
#  '30319287': {'pageid': 30319287,
#   'ns': 0,
#   'title': 'Bardhok Biba',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T13:57:51Z',
#   'lastrevid': 1250227174,
#   'length': 7501,
#   'talkid': 30319345,
#   'fullurl': 'https://en.wikipedia.org/wiki/Bardhok_Biba',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Bardhok_Biba&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Bardhok_Biba'},
#  '41892010': {'pageid': 41892010,
#   'ns': 0,
#   'title': 'Hysni Curri',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T14:00:24Z',
#   'lastrevid': 1198914812,
#   'length': 12108,
#   'talkid': 42108932,
#   'fullurl': 'https://en.wikipedia.org/wiki/Hysni_Curri',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Hysni_Curri&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Hysni_Curri'},
#  '48684644': {'pageid': 48684644,
#   'ns': 0,
#   'title': 'Ibrahim Dalliu',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-12T10:28:36Z',
#   'lastrevid': 1248264998,
#   'length': 6918,
#   'talkid': 48823779,
#   'fullurl': 'https://en.wikipedia.org/wiki/Ibrahim_Dalliu',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Ibrahim_Dalliu&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Ibrahim_Dalliu'},
#  '40754760': {'pageid': 40754760,
#   'ns': 0,
#   'title': 'Kostandin Boshnjaku',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T14:00:03Z',
#   'lastrevid': 1250227994,
#   'length': 21400,
#   'talkid': 40775176,
#   'fullurl': 'https://en.wikipedia.org/wiki/Kostandin_Boshnjaku',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Kostandin_Boshnjaku&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Kostandin_Boshnjaku'},
#  '15675174': {'pageid': 15675174,
#   'ns': 0,
#   'title': 'Neritan Ceka',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T13:54:41Z',
#   'lastrevid': 1184807608,
#   'length': 4119,
#   'talkid': 18998538,
#   'fullurl': 'https://en.wikipedia.org/wiki/Neritan_Ceka',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Neritan_Ceka&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Neritan_Ceka'},
#  '27166018': {'pageid': 27166018,
#   'ns': 0,
#   'title': 'Niazi Demi',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T13:57:15Z',
#   'lastrevid': 1209346411,
#   'length': 1470,
#   'talkid': 27166023,
#   'fullurl': 'https://en.wikipedia.org/wiki/Niazi_Demi',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Niazi_Demi&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Niazi_Demi'},
#  '28634810': {'pageid': 28634810,
#   'ns': 0,
#   'title': 'Safet Butka',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-13T20:05:01Z',
#   'lastrevid': 1189442848,
#   'length': 9518,
#   'talkid': 28634870,
#   'fullurl': 'https://en.wikipedia.org/wiki/Safet_Butka',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Safet_Butka&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Safet_Butka'},
#  '62554029': {'pageid': 62554029,
#   'ns': 0,
#   'title': 'Spartak Braho',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-09-27T02:21:57Z',
#   'lastrevid': 1224650124,
#   'length': 3245,
#   'talkid': 62657955,
#   'fullurl': 'https://en.wikipedia.org/wiki/Spartak_Braho',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Spartak_Braho&action=edit',
# ...
#   'touched': '2024-10-14T13:51:31Z',
#   'lastrevid': 1242193633,
#   'length': 15032,
#   'watchers': 32,
#   'talkid': 7337244,
#   'fullurl': 'https://en.wikipedia.org/wiki/Thirty_Comrades',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Thirty_Comrades&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Thirty_Comrades'},
#  '35480486': {'pageid': 35480486,
#   'ns': 0,
#   'title': 'Tin Aye',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T13:58:51Z',
#   'lastrevid': 1239526756,
#   'length': 3889,
#   'talkid': 36447750,
#   'fullurl': 'https://en.wikipedia.org/wiki/Tin_Aye',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Tin_Aye&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Tin_Aye'},
#  '68113104': {'pageid': 68113104,
#   'ns': 0,
#   'title': 'Tu Hkawng',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T14:04:42Z',
#   'lastrevid': 1245373670,
#   'length': 5884,
#   'talkid': 68113111,
#   'fullurl': 'https://en.wikipedia.org/wiki/Tu_Hkawng',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Tu_Hkawng&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Tu_Hkawng'},
#  '67920066': {'pageid': 67920066,
#   'ns': 0,
#   'title': 'Wai Moe Naing',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T14:04:40Z',
#   'lastrevid': 1142166678,
#   'length': 5186,
#   'talkid': 67920098,
#   'fullurl': 'https://en.wikipedia.org/wiki/Wai_Moe_Naing',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Wai_Moe_Naing&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Wai_Moe_Naing'},
#  '55681817': {'pageid': 55681817,
#   'ns': 0,
#   'title': 'Win Ko Ko Latt',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T14:02:29Z',
#   'lastrevid': 1243165916,
#   'length': 7834,
#   'talkid': 55682041,
#   'fullurl': 'https://en.wikipedia.org/wiki/Win_Ko_Ko_Latt',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Win_Ko_Ko_Latt&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Win_Ko_Ko_Latt'},
#  '48284709': {'pageid': 48284709,
#   'ns': 0,
#   'title': 'Yawd Serk',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T14:01:28Z',
#   'lastrevid': 1250459738,
#   'length': 1899,
#   'talkid': 48971199,
#   'fullurl': 'https://en.wikipedia.org/wiki/Yawd_Serk',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Yawd_Serk&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Yawd_Serk'},
#  '57617065': {'pageid': 57617065,
#   'ns': 0,
#   'title': 'Za Hlei Thang',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T17:11:54Z',
#   'lastrevid': 1251143874,
#   'length': 12635,
#   'talkid': 59141547,
#   'fullurl': 'https://en.wikipedia.org/wiki/Za_Hlei_Thang',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Za_Hlei_Thang&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Za_Hlei_Thang'},
#  '55316041': {'pageid': 55316041,
#   'ns': 0,
#   'title': 'Zaw Htay',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T14:02:27Z',
#   'lastrevid': 1220263916,
#   'length': 10297,
#   'talkid': 55316484,
#   'fullurl': 'https://en.wikipedia.org/wiki/Zaw_Htay',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Zaw_Htay&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Zaw_Htay'},
#  '46712332': {'pageid': 46712332,
#   'ns': 0,
#   'title': 'Cyrille Ndayirukiye',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-10T22:55:27Z',
#   'lastrevid': 1235862392,
#   'length': 2491,
#   'talkid': 67505495,
#   'fullurl': 'https://en.wikipedia.org/wiki/Cyrille_Ndayirukiye',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Cyrille_Ndayirukiye&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Cyrille_Ndayirukiye'},
#  '68178616': {'pageid': 68178616,
#   'ns': 0,
#   'title': 'Edouard Nduwimana',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-07T10:56:55Z',
#   'lastrevid': 1249889245,
#   'length': 2517,
#   'talkid': 68178760,
#   'fullurl': 'https://en.wikipedia.org/wiki/Edouard_Nduwimana',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Edouard_Nduwimana&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Edouard_Nduwimana'},
#  '76201751': {'pageid': 76201751,
#   'ns': 0,
#   'title': 'Evelyne Butoyi',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-09-27T02:43:28Z',
#   'lastrevid': 1226287594,
#   'length': 1186,
#   'talkid': 76202059,
#   'fullurl': 'https://en.wikipedia.org/wiki/Evelyne_Butoyi',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Evelyne_Butoyi&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Evelyne_Butoyi'},
#  '68690445': {'pageid': 68690445,
#   'ns': 0,
#   'title': 'Gervais Nyangoma',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-10T23:34:01Z',
#   'lastrevid': 1172072408,
#   'length': 4264,
#   'talkid': 68690637,
#   'fullurl': 'https://en.wikipedia.org/wiki/Gervais_Nyangoma',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Gervais_Nyangoma&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Gervais_Nyangoma'},
#  '68663833': {'pageid': 68663833,
#   'ns': 0,
#   'title': 'Joseph Biroli',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-10T19:28:12Z',
#   'lastrevid': 1244607980,
#   'length': 13725,
#   'talkid': 68664178,
#   'fullurl': 'https://en.wikipedia.org/wiki/Joseph_Biroli',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Joseph_Biroli&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Joseph_Biroli'},
#  '18761140': {'pageid': 18761140,
#   'ns': 0,
#   'title': 'Joseph Cimpaye',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-12T10:21:44Z',
#   'lastrevid': 1247008320,
#   'length': 9166,
#   'talkid': 18761147,
#   'fullurl': 'https://en.wikipedia.org/wiki/Joseph_Cimpaye',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Joseph_Cimpaye&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Joseph_Cimpaye'},
#  '69671736': {'pageid': 69671736,
#   'ns': 0,
#   'title': 'Pierre Baranyanka',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-08-29T01:17:18Z',
#   'lastrevid': 1227694880,
#   'length': 12944,
#   'talkid': 69671741,
#   'fullurl': 'https://en.wikipedia.org/wiki/Pierre_Baranyanka',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Pierre_Baranyanka&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Pierre_Baranyanka'},
#  '55137257': {'pageid': 55137257,
#   'ns': 0,
#   'title': 'Zura Begum',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-05T14:38:33Z',
#   'lastrevid': 1207585856,
#   'length': 3202,
#   'talkid': 55137259,
#   'fullurl': 'https://en.wikipedia.org/wiki/Zura_Begum',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Zura_Begum&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Zura_Begum'},
#  '12125280': {'pageid': 12125280,
#   'ns': 0,
#   'title': 'Agathon Rwasa',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-05T14:27:31Z',
#   'lastrevid': 1227287425,
#   'length': 4889,
#   'talkid': 14691259,
#   'fullurl': 'https://en.wikipedia.org/wiki/Agathon_Rwasa',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Agathon_Rwasa&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Agathon_Rwasa'},
#  '17295805': {'pageid': 17295805,
#   'ns': 0,
#   'title': 'Alexis Sinduhije',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-13T20:04:11Z',
#   'lastrevid': 1227751790,
#   'length': 10820,
#   'talkid': 23060386,
#   'fullurl': 'https://en.wikipedia.org/wiki/Alexis_Sinduhije',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Alexis_Sinduhije&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Alexis_Sinduhije'},
#  '50040955': {'pageid': 50040955,
#   'ns': 0,
#   'title': 'Ang Vong Vathana',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T14:01:43Z',
#   'lastrevid': 1242000913,
#   'length': 2668,
#   'talkid': 50040967,
#   'fullurl': 'https://en.wikipedia.org/wiki/Ang_Vong_Vathana',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Ang_Vong_Vathana&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Ang_Vong_Vathana'},
#  '71693220': {'pageid': 71693220,
#   'ns': 0,
#   'title': 'Bun Chanmol',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T14:05:23Z',
#   'lastrevid': 1229174400,
#   'length': 11001,
#   'talkid': 71699499,
#   'fullurl': 'https://en.wikipedia.org/wiki/Bun_Chanmol',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Bun_Chanmol&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Bun_Chanmol'},
#  '64470367': {'pageid': 64470367,
#   'ns': 0,
#   'title': 'Gabriel Nizigama',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-12T04:36:41Z',
#   'lastrevid': 1193500276,
#   'length': 1772,
#   'talkid': 64750546,
#   'fullurl': 'https://en.wikipedia.org/wiki/Gabriel_Nizigama',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Gabriel_Nizigama&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Gabriel_Nizigama'},
#  '68076550': {'pageid': 68076550,
#   'ns': 0,
#   'title': 'Imelde Sabushimike',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-09-27T02:31:39Z',
#   'lastrevid': 1243757340,
#   'length': 3019,
#   'talkid': 68169612,
#   'fullurl': 'https://en.wikipedia.org/wiki/Imelde_Sabushimike',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Imelde_Sabushimike&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Imelde_Sabushimike'},
#  '68695700': {'pageid': 68695700,
#   'ns': 0,
#   'title': 'Jean-Baptiste Ntidendereza',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-09-18T09:23:33Z',
#   'lastrevid': 1176698590,
#   'length': 9178,
#   'talkid': 68714652,
#   'fullurl': 'https://en.wikipedia.org/wiki/Jean-Baptiste_Ntidendereza',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Jean-Baptiste_Ntidendereza&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Jean-Baptiste_Ntidendereza'},
#  '43047944': {'pageid': 43047944,
#   'ns': 0,
#   'title': 'Ririkumutima',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-05T14:35:33Z',
#   'lastrevid': 1233102698,
#   'length': 6489,
#   'talkid': 43052167,
#   'fullurl': 'https://en.wikipedia.org/wiki/Ririkumutima',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Ririkumutima&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Ririkumutima'},
#  '75523295': {'pageid': 75523295,
#   'ns': 0,
#   'title': 'Samheng Boros',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-05T14:43:42Z',
#   'lastrevid': 1217047991,
#   'length': 5410,
#   'talkid': 75523308,
#   'fullurl': 'https://en.wikipedia.org/wiki/Samheng_Boros',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Samheng_Boros&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Samheng_Boros'},
#  '68249082': {'pageid': 68249082,
#   'ns': 0,
#   'title': 'Tharcisse Niyongabo',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-12T05:05:14Z',
#   'lastrevid': 1218269209,
#   'length': 1878,
#   'talkid': 68260591,
#   'fullurl': 'https://en.wikipedia.org/wiki/Tharcisse_Niyongabo',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Tharcisse_Niyongabo&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Tharcisse_Niyongabo'},
#  '60528821': {'pageid': 60528821,
#   'ns': 0,
#   'title': 'Chem Snguon',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-09-28T16:48:25Z',
#   'lastrevid': 1243810904,
#   'length': 940,
#   'talkid': 60528825,
#   'fullurl': 'https://en.wikipedia.org/wiki/Chem_Snguon',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Chem_Snguon&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Chem_Snguon'},
#  '60528895': {'pageid': 60528895,
#   'ns': 0,
#   'title': 'Chhan Sokhom',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-09-28T16:48:25Z',
#   'lastrevid': 1243810911,
#   'length': 711,
#   'talkid': 60528901,
#   'fullurl': 'https://en.wikipedia.org/wiki/Chhan_Sokhom',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Chhan_Sokhom&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Chhan_Sokhom'},
#  '60532005': {'pageid': 60532005,
#   'ns': 0,
#   'title': 'Chuon Saodi',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-09-28T16:48:25Z',
#   'lastrevid': 1243810923,
#   'length': 842,
#   'talkid': 60532009,
#   'fullurl': 'https://en.wikipedia.org/wiki/Chuon_Saodi',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Chuon_Saodi&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Chuon_Saodi'},
#  '21422911': {'pageid': 21422911,
#   'ns': 0,
#   'title': 'Daran Kravanh',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-11T22:53:36Z',
#   'lastrevid': 1096672232,
#   'length': 3344,
#   'talkid': 50812614,
#   'fullurl': 'https://en.wikipedia.org/wiki/Daran_Kravanh',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Daran_Kravanh&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Daran_Kravanh'},
#  '60532120': {'pageid': 60532120,
#   'ns': 0,
#   'title': 'Duong Sam Ol',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T14:03:14Z',
#   'lastrevid': 1250510333,
#   'length': 1216,
#   'talkid': 60532127,
#   'fullurl': 'https://en.wikipedia.org/wiki/Duong_Sam_Ol',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Duong_Sam_Ol&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Duong_Sam_Ol'},
#  '1999882': {'pageid': 1999882,
#   'ns': 0,
#   'title': 'Ieu Koeus',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2024-10-14T17:34:27Z',
#   'lastrevid': 1251147085,
#   'length': 3589,
#   'talkid': 7065272,
#   'fullurl': 'https://en.wikipedia.org/wiki/Ieu_Koeus',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Ieu_Koeus&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Ieu_Koeus'},
#  ...}

# %%
# first we extract the article title and revision id from the page information dictionary
all_revision_ids = wr.extract_revision_ids_from_page_info(all_pages_info)
all_revision_ids
# Out:
#                politician_name  revision_id
# 0           Abdul Rahim Ayoubi   1226326055
# 1     Amir Muhammad Akhundzada   1247931713
# 2               Aziza Ahmadyar   1195651393
# 3            Haroon al-Afghani   1230459615
# 4         Khadija Zahra Ahmadi   1234741562
# ...                        ...          ...
# 5413              Denis Walker   1247902630
# 5414       Herbert Ushewokunze    959111842
# 5415          Josiah Tongogara   1203429435
# 5416         Langton Towungana   1246280093
# 5417         Sengezo Tshabangu   1228478288
#
# [5418 rows x 2 columns]

# %%
# Since this took soo long to generate, lets save it to a csv
all_revision_ids.to_csv('revision_ids_by_politician.csv', index=False)

# %% [markdown]
# #### Get the predicted ORES article quality score

# %% [markdown]
# Now lets get the article quality for a given revision id
#
# Again lets look at 1 to get a sense of the schema

# %%
# Get the ORES info for a single article revision and take a look at the structure:

# get a revid 
example_revID = all_revision_ids["revision_id"][7]

# make the request
wr.request_ores_score_per_article(int(example_revID))
# Out:
# {'enwiki': {'models': {'articlequality': {'version': '0.9.2'}},
#   'scores': {'1235521766': {'articlequality': {'score': {'prediction': 'Start',
#       'probability': {'B': 0.05357764010649692,
#        'C': 0.1420153651045843,
#        'FA': 0.004558064005040723,
#        'GA': 0.017818853559952434,
#        'Start': 0.7365463681382165,
#        'Stub': 0.04548370908570939}}}}}}}

# %% [markdown]
# #### Prep the revision_ids to look up ORES Predicition scores

# %% [markdown]
# python dataframes tend to save ints at int64 or int32 so we need to make a list of just ints to put into our function to get ores predicition scores for a revision id

# %%
rev_ids_list = all_revision_ids["revision_id"].tolist()
rev_ids_list = list(map(int, rev_ids_list))

# %% [markdown]
# Alright we're all set up, lets run this!
#
# **This function takes a very long time to run!**

# %%
ores_scores = wr.request_all_ores_scores(rev_ids_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 ores_scores = request_all_ores_scores(rev_ids_list)
#
# NameError: name 'request_all_ores_scores' is not defined

# %%
ores_scores
# Out:
#       Revision ID ORES Prediction
# 0      1226326055           Start
# 1      1247931713           Start
# 2      1195651393           Start
# 3      1230459615               B
# 4      1234741562            Stub
# ...           ...             ...
# 5413   1247902630               C
# 5414    959111842            Stub
# 5415   1203429435               C
# 5416   1246280093            Stub
# 5417   1228478288           Start
#
# [5418 rows x 2 columns]

# %% [markdown]
# Okay lets clean up some of the dataframes column names so we can merge them

# %%
ores_scores.rename(columns={'Revision ID': 'revision_id',
                           'ORES Prediction': 'quality_prediction'}, inplace=True)

# %%
rev_ids_df.rename(columns={'revid': 'revision_id',
                           'title': 'politician_name'}, inplace=True)

# %%
# Merge rev_ids_df with ores_scores on the Revision ID
rev_ores_df = pd.merge(rev_ids_df, ores_scores, on = 'revision_id')
rev_ores_df
# Out:
#                politician_name  revision_id quality_prediction
# 0           Abdul Rahim Ayoubi   1226326055              Start
# 1     Amir Muhammad Akhundzada   1247931713              Start
# 2               Aziza Ahmadyar   1195651393              Start
# 3            Haroon al-Afghani   1230459615                  B
# 4         Khadija Zahra Ahmadi   1234741562               Stub
# ...                        ...          ...                ...
# 5413              Denis Walker   1247902630                  C
# 5414       Herbert Ushewokunze    959111842               Stub
# 5415          Josiah Tongogara   1203429435                  C
# 5416         Langton Towungana   1246280093               Stub
# 5417         Sengezo Tshabangu   1228478288              Start
#
# [5418 rows x 3 columns]

# %%
# Merge merged_df with the rev_ores_df on the article title and title columns
full_merged_df = pd.merge(merged_df, rev_ores_df, left_on='name', right_on='politician_name')
full_merged_df
# Out:
#                       name                                                url  \
# 0           Majah Ha Adrif       https://en.wikipedia.org/wiki/Majah_Ha_Adrif
# 1        Haroon al-Afghani    https://en.wikipedia.org/wiki/Haroon_al-Afghani
# 2              Tayyab Agha          https://en.wikipedia.org/wiki/Tayyab_Agha
# 3     Khadija Zahra Ahmadi  https://en.wikipedia.org/wiki/Khadija_Zahra_Ah...
# 4           Aziza Ahmadyar       https://en.wikipedia.org/wiki/Aziza_Ahmadyar
# ...                    ...                                                ...
# 5440      Josiah Tongogara     https://en.wikipedia.org/wiki/Josiah_Tongogara
# 5441     Langton Towungana    https://en.wikipedia.org/wiki/Langton_Towungana
# 5442     Sengezo Tshabangu    https://en.wikipedia.org/wiki/Sengezo_Tshabangu
# 5443   Herbert Ushewokunze  https://en.wikipedia.org/wiki/Herbert_Ushewokunze
# 5444          Denis Walker         https://en.wikipedia.org/wiki/Denis_Walker
#
#           country  population_millions         article_title  \
# 0     Afghanistan                 42.4        Majah_Ha_Adrif
# 1     Afghanistan                 42.4     Haroon_al-Afghani
# 2     Afghanistan                 42.4           Tayyab_Agha
# 3     Afghanistan                 42.4  Khadija_Zahra_Ahmadi
# 4     Afghanistan                 42.4        Aziza_Ahmadyar
# ...           ...                  ...                   ...
# 5440     Zimbabwe                 16.7      Josiah_Tongogara
# 5441     Zimbabwe                 16.7     Langton_Towungana
# 5442     Zimbabwe                 16.7     Sengezo_Tshabangu
# 5443     Zimbabwe                 16.7   Herbert_Ushewokunze
# 5444     Zimbabwe                 16.7          Denis_Walker
#
#            politician_name  revision_id quality_prediction
# 0           Majah Ha Adrif   1233202991              Start
# 1        Haroon al-Afghani   1230459615                  B
# 2              Tayyab Agha   1225661708              Start
# 3     Khadija Zahra Ahmadi   1234741562               Stub
# 4           Aziza Ahmadyar   1195651393              Start
# ...                    ...          ...                ...
# 5440      Josiah Tongogara   1203429435                  C
# 5441     Langton Towungana   1246280093               Stub
# 5442     Sengezo Tshabangu   1228478288              Start
# 5443   Herbert Ushewokunze    959111842               Stub
# 5444          Denis Walker   1247902630                  C
#
# [5445 rows x 8 columns]

# %%
fully_merged.drop_duplicates(subset=['brand'])

# %%
merged_df[merged_df.duplicated(subset=['article_title'], keep=False)]
# Out:
#                                                    name  \
# 151                                         Visar Ymeri
# 393                                       Hrant Maloyan
# 424   Count Václav Antonín Chotek of Chotkov and Vojnín
# 438                                     Eduard Hedvicek
# 485              Leopold, Count von Thun und Hohenstein
# ...                                                 ...
# 6504                                Torokul Dzhanuzakov
# 6591                                         Yat Hwaidi
# 6815                                      Sergey Abisov
# 6827                                       Moshe Gutman
# 6937                                Torokul Dzhanuzakov
#
#                                                     url     country  \
# 151           https://en.wikipedia.org/wiki/Visar_Ymeri     Albania
# 393         https://en.wikipedia.org/wiki/Hrant_Maloyan     Armenia
# 424   https://en.wikipedia.org/wiki/Count_Václav_Ant...     Austria
# 438       https://en.wikipedia.org/wiki/Eduard_Hedvicek     Austria
# 485   https://en.wikipedia.org/wiki/Leopold,_Count_v...     Austria
# ...                                                 ...         ...
# 6504  https://en.wikipedia.org/wiki/Torokul_Dzhanuzakov  Tajikistan
# 6591           https://en.wikipedia.org/wiki/Yat_Hwaidi    Thailand
# 6815        https://en.wikipedia.org/wiki/Sergey_Abisov     Ukraine
# 6827         https://en.wikipedia.org/wiki/Moshe_Gutman     Ukraine
# 6937  https://en.wikipedia.org/wiki/Torokul_Dzhanuzakov  Uzbekistan
#
#       population_millions                                      article_title
# 151                   2.7                                        Visar_Ymeri
# 393                   3.0                                      Hrant_Maloyan
# 424                   9.2  Count_V%C3%A1clav_Anton%C3%ADn_Chotek_of_Chotk...
# 438                   9.2                                    Eduard_Hedvicek
# 485                   9.2           Leopold%2C_Count_von_Thun_und_Hohenstein
# ...                   ...                                                ...
# 6504                 10.2                                Torokul_Dzhanuzakov
# 6591                 66.0                                         Yat_Hwaidi
# 6815                 36.7                                      Sergey_Abisov
# 6827                 36.7                                       Moshe_Gutman
# 6937                 36.4                                Torokul_Dzhanuzakov
#
# [85 rows x 5 columns]

# %%
df.rename(columns={'politician_name': 'article_title'}, inplace=True)

# %%
# Add the revision IDs to the DataFrame
merged_df['revision_id'] = merged_df['name'].map(all_revision_ids)

# %%
merged_df[merged_df["revision_id"].notnull()]
